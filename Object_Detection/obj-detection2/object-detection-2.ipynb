# %% [markdown]
# ## Assignment: Object detection
# - Alumno 1: Vittorio Alberto Gianfrate
# - Alumno 2: Alex Ferroni
# - Alumno 3:
#
# The goals of the assignment are:
# * Put into practice acquired knowledge to detect and recognize objects of interest within a satellite image.
#
# To address this problem, you must choose one of the following options:
# *	Implement a sliding window strategy to process the whole image, and then train a classifier that determines whether each window includes or not an object of interest. In this way, you can use previous image classification model to infer the object category.
# *	Build a single-stage object detection model (e.g., YOLO, SSD, RetinaNet, etc.).
# *	Build a two-stage object detection model (e.g., Faster R-CNN, R-FCN, etc.).
#
# Follow the link below to download the detection data set “xview_detection”: [https://drive.upm.es/s/P7nEf3Bygns7tbM](https://drive.upm.es/s/P7nEf3Bygns7tbM)

# %%
# !pip install rasterio
# Out:
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (1.5.0)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio) (25.4.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from rasterio) (2026.1.4)
# Requirement already satisfied: click!=8.2.*,>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio) (8.3.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.0.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio) (3.3.1)

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import uuid
import numpy as np

class GenericObject:
    """
    Generic object data.
    """
    def __init__(self):
        self.id = uuid.uuid4()
        self.bb = (-1, -1, -1, -1)
        self.category= -1
        self.score = -1

class GenericImage:
    """
    Generic image data.
    """
    def __init__(self, filename):
        self.filename = filename
        self.tile = np.array([-1, -1, -1, -1])  # (pt_x, pt_y, pt_x+width, pt_y+height)
        self.objects = list([])

    def add_object(self, obj: GenericObject):
        self.objects.append(obj)

# %%
categories = {0: 'Small car', 1: 'Bus', 2: 'Truck', 3: 'Building'}

# %%
import warnings
import rasterio
import numpy as np

def load_geoimage(filename):
    warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
    base_path = '/kaggle/input/datasets/alexferroni/detection/'
    
    src_raster = rasterio.open(base_path + filename, 'r')
    # RasterIO to OpenCV (see inconsistencies between libjpeg and libjpeg-turbo)
    input_type = src_raster.profile['dtype']
    input_channels = src_raster.count
    img = np.zeros((src_raster.height, src_raster.width, src_raster.count), dtype=input_type)
    for band in range(input_channels):
        img[:, :, band] = src_raster.read(band+1)
    return img

# %% [markdown]
# #### Training
# Design and train a detector to deal with the “xview_detection” perception task.

# %%
import json

# Load database
json_file = '/kaggle/input/datasets/alexferroni/detection/xview_det_train.json'
with open(json_file) as ifs:
    json_data = json.load(ifs)
ifs.close()
print("Annotazioni caricate con successo!")
# Out:
# Annotazioni caricate con successo!

# %%
import numpy as np

counts = dict.fromkeys(categories.values(), 0)
anns = []
for json_img in json_data['images'].values():
    image = GenericImage(json_img['filename'])
    image.tile = np.array([0, 0, json_img['width'], json_img['height']])
    for json_ann in [elem for elem in json_data['annotations'].values() if elem['image_id'] == json_img['image_id']]:
        obj = GenericObject()
        obj.id = json_ann['image_id']
        obj.bb = (int(json_ann['bbox'][0]), int(json_ann['bbox'][1]), int(json_ann['bbox'][2]), int(json_ann['bbox'][3]))
        obj.category = json_ann['category_id']
        counts[obj.category] += 1
        image.add_object(obj)
    anns.append(image)
print(counts)
# Out:
# {'Small car': 188300, 'Bus': 6269, 'Truck': 10600, 'Building': 275943}

# %%
from sklearn.model_selection import train_test_split

anns_train, anns_valid = train_test_split(anns, test_size=0.1, random_state=1, shuffle=True)
print('Number of training images: ' + str(len(anns_train)))
print('Number of validation images: ' + str(len(anns_valid)))
# Out:
# Number of training images: 6845
# Number of validation images: 761

# %%
import keras_cv

print('Loading model...')
prediction_decoder = keras_cv.layers.NonMaxSuppression(
    bounding_box_format='xyxy',
    from_logits=False,
    confidence_threshold=0.2,
    iou_threshold=0.7
)
# Prof usava yolo_v8_xs → noi usiamo yolo_v8_m per più capacità
model = keras_cv.models.YOLOV8Detector.from_preset(
    preset='yolo_v8_m_backbone_coco',
    num_classes=len(categories),
    load_weights=True,
    bounding_box_format='xyxy',
    prediction_decoder=prediction_decoder
)
model.summary()
# Out:
# Loading model...
# Model: "yolov8_detector_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, None,      │          0 │ -                 │
# │ (InputLayer)        │ None, 3)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ functional_1        │ [(None, None,     │ 11,872,464 │ input_layer_3[0]… │
# │ (Functional)        │ None, 192),       │            │                   │
# │                     │ (None, None,      │            │                   │
# │                     │ None, 384),       │            │                   │
# │                     │ (None, None,      │            │                   │
# │                     │ None, 576)]       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ repeat_4 (Repeat)   │ (None, None,      │          0 │ functional_1[0][… │
# │                     │ None, 576)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ repeat_5 (Repeat)   │ (None, None,      │          0 │ repeat_4[0][0]    │
# │                     │ None, 576)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_22      │ (None, None,      │          0 │ repeat_5[0][0],   │
# │ (Concatenate)       │ None, 960)        │            │ functional_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_co… │ (None, None,      │    368,640 │ concatenate_22[0… │
# │ (Conv2D)            │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_bn  │ (None, None,      │      1,536 │ pa_fpn_p4p5_pre_… │
# │ (BatchNormalizatio… │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre     │ (None, None,      │          0 │ pa_fpn_p4p5_pre_… │
# │ (Activation)        │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ split_12 (Split)    │ [(None, None,     │          0 │ pa_fpn_p4p5_pre[… │
# │                     │ None, 192),       │            │                   │
# │                     │ (None, None,      │            │                   │
# │                     │ None, 192)]       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_0_… │ (None, None,      │          0 │ split_12[0][1]    │
# │ (ZeroPadding2D)     │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_0_… │ (None, None,      │    331,776 │ pa_fpn_p4p5_pre_… │
# │ (Conv2D)            │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_0_… │ (None, None,      │        768 │ pa_fpn_p4p5_pre_… │
# │ (BatchNormalizatio… │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_0_1 │ (None, None,      │          0 │ pa_fpn_p4p5_pre_… │
# │ (Activation)        │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_0_… │ (None, None,      │          0 │ pa_fpn_p4p5_pre_… │
# │ (ZeroPadding2D)     │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_0_… │ (None, None,      │    331,776 │ pa_fpn_p4p5_pre_… │
# │ (Conv2D)            │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_0_… │ (None, None,      │        768 │ pa_fpn_p4p5_pre_… │
# │ (BatchNormalizatio… │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_0_2 │ (None, None,      │          0 │ pa_fpn_p4p5_pre_… │
# │ (Activation)        │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_1_… │ (None, None,      │          0 │ pa_fpn_p4p5_pre_… │
# │ (ZeroPadding2D)     │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_1_… │ (None, None,      │    331,776 │ pa_fpn_p4p5_pre_… │
# │ (Conv2D)            │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_1_… │ (None, None,      │        768 │ pa_fpn_p4p5_pre_… │
# │ (BatchNormalizatio… │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_1_1 │ (None, None,      │          0 │ pa_fpn_p4p5_pre_… │
# │ (Activation)        │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_1_… │ (None, None,      │          0 │ pa_fpn_p4p5_pre_… │
# │ (ZeroPadding2D)     │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_1_… │ (None, None,      │    331,776 │ pa_fpn_p4p5_pre_… │
# │ (Conv2D)            │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_1_… │ (None, None,      │        768 │ pa_fpn_p4p5_pre_… │
# │ (BatchNormalizatio… │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_1_2 │ (None, None,      │          0 │ pa_fpn_p4p5_pre_… │
# │ (Activation)        │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_23      │ (None, None,      │          0 │ split_12[0][0],   │
# │ (Concatenate)       │ None, 768)        │            │ split_12[0][1],   │
# │                     │                   │            │ pa_fpn_p4p5_pre_… │
# │                     │                   │            │ pa_fpn_p4p5_pre_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_output… │ (None, None,      │    294,912 │ concatenate_23[0… │
# │ (Conv2D)            │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_output… │ (None, None,      │      1,536 │ pa_fpn_p4p5_outp… │
# │ (BatchNormalizatio… │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_output  │ (None, None,      │          0 │ pa_fpn_p4p5_outp… │
# │ (Activation)        │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ repeat_6 (Repeat)   │ (None, None,      │          0 │ pa_fpn_p4p5_outp… │
# │                     │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ repeat_7 (Repeat)   │ (None, None,      │          0 │ repeat_6[0][0]    │
# │                     │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_24      │ (None, None,      │          0 │ repeat_7[0][0],   │
# │ (Concatenate)       │ None, 576)        │            │ functional_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │    110,592 │ concatenate_24[0… │
# │ (Conv2D)            │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │        768 │ pa_fpn_p3p4p5_pr… │
# │ (BatchNormalizatio… │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre   │ (None, None,      │          0 │ pa_fpn_p3p4p5_pr… │
# │ (Activation)        │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ split_13 (Split)    │ [(None, None,     │          0 │ pa_fpn_p3p4p5_pr… │
# │                     │ None, 96), (None, │            │                   │
# │                     │ None, None, 96)]  │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │          0 │ split_13[0][1]    │
# │ (ZeroPadding2D)     │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │     82,944 │ pa_fpn_p3p4p5_pr… │
# │ (Conv2D)            │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │        384 │ pa_fpn_p3p4p5_pr… │
# │ (BatchNormalizatio… │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │          0 │ pa_fpn_p3p4p5_pr… │
# │ (Activation)        │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │          0 │ pa_fpn_p3p4p5_pr… │
# │ (ZeroPadding2D)     │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │     82,944 │ pa_fpn_p3p4p5_pr… │
# │ (Conv2D)            │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │        384 │ pa_fpn_p3p4p5_pr… │
# │ (BatchNormalizatio… │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │          0 │ pa_fpn_p3p4p5_pr… │
# │ (Activation)        │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │          0 │ pa_fpn_p3p4p5_pr… │
# │ (ZeroPadding2D)     │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │     82,944 │ pa_fpn_p3p4p5_pr… │
# │ (Conv2D)            │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │        384 │ pa_fpn_p3p4p5_pr… │
# │ (BatchNormalizatio… │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │          0 │ pa_fpn_p3p4p5_pr… │
# │ (Activation)        │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │          0 │ pa_fpn_p3p4p5_pr… │
# │ (ZeroPadding2D)     │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │     82,944 │ pa_fpn_p3p4p5_pr… │
# │ (Conv2D)            │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │        384 │ pa_fpn_p3p4p5_pr… │
# │ (BatchNormalizatio… │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │          0 │ pa_fpn_p3p4p5_pr… │
# │ (Activation)        │ None, 96)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_25      │ (None, None,      │          0 │ split_13[0][0],   │
# │ (Concatenate)       │ None, 384)        │            │ split_13[0][1],   │
# │                     │                   │            │ pa_fpn_p3p4p5_pr… │
# │                     │                   │            │ pa_fpn_p3p4p5_pr… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_outp… │ (None, None,      │     73,728 │ concatenate_25[0… │
# │ (Conv2D)            │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_outp… │ (None, None,      │        768 │ pa_fpn_p3p4p5_ou… │
# │ (BatchNormalizatio… │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_outp… │ (None, None,      │          0 │ pa_fpn_p3p4p5_ou… │
# │ (Activation)        │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_ou… │
# │ (ZeroPadding2D)     │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │    331,776 │ pa_fpn_p3p4p5_do… │
# │ (Conv2D)            │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │        768 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_26      │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Concatenate)       │ None, 576)        │            │ pa_fpn_p4p5_outp… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │    221,184 │ concatenate_26[0… │
# │ (Conv2D)            │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │      1,536 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ split_14 (Split)    │ [(None, None,     │          0 │ pa_fpn_p3p4p5_do… │
# │                     │ None, 192),       │            │                   │
# │                     │ (None, None,      │            │                   │
# │                     │ None, 192)]       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ split_14[0][1]    │
# │ (ZeroPadding2D)     │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │    331,776 │ pa_fpn_p3p4p5_do… │
# │ (Conv2D)            │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │        768 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (ZeroPadding2D)     │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │    331,776 │ pa_fpn_p3p4p5_do… │
# │ (Conv2D)            │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │        768 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (ZeroPadding2D)     │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │    331,776 │ pa_fpn_p3p4p5_do… │
# │ (Conv2D)            │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │        768 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (ZeroPadding2D)     │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │    331,776 │ pa_fpn_p3p4p5_do… │
# │ (Conv2D)            │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │        768 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_27      │ (None, None,      │          0 │ split_14[0][0],   │
# │ (Concatenate)       │ None, 768)        │            │ split_14[0][1],   │
# │                     │                   │            │ pa_fpn_p3p4p5_do… │
# │                     │                   │            │ pa_fpn_p3p4p5_do… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │    294,912 │ concatenate_27[0… │
# │ (Conv2D)            │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │      1,536 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (ZeroPadding2D)     │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │  1,327,104 │ pa_fpn_p3p4p5_do… │
# │ (Conv2D)            │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │      1,536 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_28      │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Concatenate)       │ None, 960)        │            │ functional_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │    552,960 │ concatenate_28[0… │
# │ (Conv2D)            │ None, 576)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │      2,304 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 576)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 576)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ split_15 (Split)    │ [(None, None,     │          0 │ pa_fpn_p3p4p5_do… │
# │                     │ None, 288),       │            │                   │
# │                     │ (None, None,      │            │                   │
# │                     │ None, 288)]       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ split_15[0][1]    │
# │ (ZeroPadding2D)     │ None, 288)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │    746,496 │ pa_fpn_p3p4p5_do… │
# │ (Conv2D)            │ None, 288)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │      1,152 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 288)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 288)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (ZeroPadding2D)     │ None, 288)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │    746,496 │ pa_fpn_p3p4p5_do… │
# │ (Conv2D)            │ None, 288)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │      1,152 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 288)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 288)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (ZeroPadding2D)     │ None, 288)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │    746,496 │ pa_fpn_p3p4p5_do… │
# │ (Conv2D)            │ None, 288)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │      1,152 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 288)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 288)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (ZeroPadding2D)     │ None, 288)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │    746,496 │ pa_fpn_p3p4p5_do… │
# │ (Conv2D)            │ None, 288)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │      1,152 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 288)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 288)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_29      │ (None, None,      │          0 │ split_15[0][0],   │
# │ (Concatenate)       │ None, 1152)       │            │ split_15[0][1],   │
# │                     │                   │            │ pa_fpn_p3p4p5_do… │
# │                     │                   │            │ pa_fpn_p3p4p5_do… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │    663,552 │ concatenate_29[0… │
# │ (Conv2D)            │ None, 576)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │      2,304 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 576)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 576)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_cla… │ (None, None,      │          0 │ pa_fpn_p3p4p5_ou… │
# │ (ZeroPadding2D)     │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_cla… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (ZeroPadding2D)     │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_cla… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (ZeroPadding2D)     │ None, 576)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_box… │ (None, None,      │          0 │ pa_fpn_p3p4p5_ou… │
# │ (ZeroPadding2D)     │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_cla… │ (None, None,      │    331,776 │ yolo_v8_head_1_c… │
# │ (Conv2D)            │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_box… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (ZeroPadding2D)     │ None, 384)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_cla… │ (None, None,      │    663,552 │ yolo_v8_head_2_c… │
# │ (Conv2D)            │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_box… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (ZeroPadding2D)     │ None, 576)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_cla… │ (None, None,      │    995,328 │ yolo_v8_head_3_c… │
# │ (Conv2D)            │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_box… │ (None, None,      │    110,592 │ yolo_v8_head_1_b… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_cla… │ (None, None,      │        768 │ yolo_v8_head_1_c… │
# │ (BatchNormalizatio… │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_box… │ (None, None,      │    221,184 │ yolo_v8_head_2_b… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_cla… │ (None, None,      │        768 │ yolo_v8_head_2_c… │
# │ (BatchNormalizatio… │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_box… │ (None, None,      │    331,776 │ yolo_v8_head_3_b… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_cla… │ (None, None,      │        768 │ yolo_v8_head_3_c… │
# │ (BatchNormalizatio… │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_box… │ (None, None,      │        256 │ yolo_v8_head_1_b… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_cla… │ (None, None,      │          0 │ yolo_v8_head_1_c… │
# │ (Activation)        │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_box… │ (None, None,      │        256 │ yolo_v8_head_2_b… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_cla… │ (None, None,      │          0 │ yolo_v8_head_2_c… │
# │ (Activation)        │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_box… │ (None, None,      │        256 │ yolo_v8_head_3_b… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_cla… │ (None, None,      │          0 │ yolo_v8_head_3_c… │
# │ (Activation)        │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_box… │ (None, None,      │          0 │ yolo_v8_head_1_b… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_cla… │ (None, None,      │          0 │ yolo_v8_head_1_c… │
# │ (ZeroPadding2D)     │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_box… │ (None, None,      │          0 │ yolo_v8_head_2_b… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_cla… │ (None, None,      │          0 │ yolo_v8_head_2_c… │
# │ (ZeroPadding2D)     │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_box… │ (None, None,      │          0 │ yolo_v8_head_3_b… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_cla… │ (None, None,      │          0 │ yolo_v8_head_3_c… │
# │ (ZeroPadding2D)     │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_box… │ (None, None,      │          0 │ yolo_v8_head_1_b… │
# │ (ZeroPadding2D)     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_cla… │ (None, None,      │    331,776 │ yolo_v8_head_1_c… │
# │ (Conv2D)            │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_box… │ (None, None,      │          0 │ yolo_v8_head_2_b… │
# │ (ZeroPadding2D)     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_cla… │ (None, None,      │    331,776 │ yolo_v8_head_2_c… │
# │ (Conv2D)            │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_box… │ (None, None,      │          0 │ yolo_v8_head_3_b… │
# │ (ZeroPadding2D)     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_cla… │ (None, None,      │    331,776 │ yolo_v8_head_3_c… │
# │ (Conv2D)            │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_box… │ (None, None,      │     36,864 │ yolo_v8_head_1_b… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_cla… │ (None, None,      │        768 │ yolo_v8_head_1_c… │
# │ (BatchNormalizatio… │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_box… │ (None, None,      │     36,864 │ yolo_v8_head_2_b… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_cla… │ (None, None,      │        768 │ yolo_v8_head_2_c… │
# │ (BatchNormalizatio… │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_box… │ (None, None,      │     36,864 │ yolo_v8_head_3_b… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_cla… │ (None, None,      │        768 │ yolo_v8_head_3_c… │
# │ (BatchNormalizatio… │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_box… │ (None, None,      │        256 │ yolo_v8_head_1_b… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_cla… │ (None, None,      │          0 │ yolo_v8_head_1_c… │
# │ (Activation)        │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_box… │ (None, None,      │        256 │ yolo_v8_head_2_b… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_cla… │ (None, None,      │          0 │ yolo_v8_head_2_c… │
# │ (Activation)        │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_box… │ (None, None,      │        256 │ yolo_v8_head_3_b… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_cla… │ (None, None,      │          0 │ yolo_v8_head_3_c… │
# │ (Activation)        │ None, 192)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_box… │ (None, None,      │          0 │ yolo_v8_head_1_b… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_cla… │ (None, None,      │        772 │ yolo_v8_head_1_c… │
# │ (Conv2D)            │ None, 4)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_box… │ (None, None,      │          0 │ yolo_v8_head_2_b… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_cla… │ (None, None,      │        772 │ yolo_v8_head_2_c… │
# │ (Conv2D)            │ None, 4)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_box… │ (None, None,      │          0 │ yolo_v8_head_3_b… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_cla… │ (None, None,      │        772 │ yolo_v8_head_3_c… │
# │ (Conv2D)            │ None, 4)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_box… │ (None, None,      │      4,160 │ yolo_v8_head_1_b… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_cla… │ (None, None,      │          0 │ yolo_v8_head_1_c… │
# │ (Activation)        │ None, 4)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_box… │ (None, None,      │      4,160 │ yolo_v8_head_2_b… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_cla… │ (None, None,      │          0 │ yolo_v8_head_2_c… │
# │ (Activation)        │ None, 4)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_box… │ (None, None,      │      4,160 │ yolo_v8_head_3_b… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_cla… │ (None, None,      │          0 │ yolo_v8_head_3_c… │
# │ (Activation)        │ None, 4)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_30      │ (None, None,      │          0 │ yolo_v8_head_1_b… │
# │ (Concatenate)       │ None, 68)         │            │ yolo_v8_head_1_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_31      │ (None, None,      │          0 │ yolo_v8_head_2_b… │
# │ (Concatenate)       │ None, 68)         │            │ yolo_v8_head_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_32      │ (None, None,      │          0 │ yolo_v8_head_3_b… │
# │ (Concatenate)       │ None, 68)         │            │ yolo_v8_head_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_out… │ (None, None, 68)  │          0 │ concatenate_30[0… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_out… │ (None, None, 68)  │          0 │ concatenate_31[0… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_out… │ (None, None, 68)  │          0 │ concatenate_32[0… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_33      │ (None, None, 68)  │          0 │ yolo_v8_head_1_o… │
# │ (Concatenate)       │                   │            │ yolo_v8_head_2_o… │
# │                     │                   │            │ yolo_v8_head_3_o… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ box_outputs         │ (None, None, 68)  │          0 │ concatenate_33[0… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_2          │ (None, None, 64)  │          0 │ box_outputs[0][0] │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_3          │ (None, None, 4)   │          0 │ box_outputs[0][0] │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ box (Concatenate)   │ (None, None, 64)  │          0 │ get_item_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ class (Concatenate) │ (None, None, 4)   │          0 │ get_item_3[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 25,891,740 (98.77 MB)
#  Trainable params: 25,858,620 (98.64 MB)
#  Non-trainable params: 33,120 (129.38 KB)

# %%
from tensorflow.keras.optimizers import SGD

opt = SGD(learning_rate=1e-3, momentum=0.9, global_clipnorm=10.0)

# Compilazione per RetinaNet
model.compile(
    optimizer=opt,
    classification_loss='binary_crossentropy',  # ✅ corretto per YOLO
    box_loss='ciou',                              # ✅ corretto per YOLO
    jit_compile=False
)

# %%
from tensorflow.keras.callbacks import TerminateOnNaN, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

model_checkpoint = ModelCheckpoint('retinanet.keras', monitor='val_loss', verbose=1, save_best_only=True)
reduce_lr = ReduceLROnPlateau('val_loss', factor=0.1, patience=7, verbose=1)
early_stop = EarlyStopping('val_loss', patience=15, verbose=1)
terminate = TerminateOnNaN()
callbacks = [model_checkpoint, reduce_lr, early_stop, terminate]

# %%
def image_generator(filename, tile, bboxes, categories):
    def load_sample(filepath):
        image = load_geoimage(filepath.numpy().decode('utf-8'))
        return tf.cast(image, tf.uint8)
    # Load image
    img = tf.squeeze(tf.py_function(func=load_sample, inp=[filename], Tout=[tf.uint8]), axis=0)  # tf.print(tf.shape(img)) -> [H, W, 3]
    img_roi = tf.image.pad_to_bounding_box(img, 0, 0, 640, 640)
    return {'images': tf.cast(img_roi, tf.float32), 'bounding_boxes': {'boxes': bboxes, 'classes': categories}}

def ragged_to_dense(inputs):
    from keras_cv import bounding_box
    return {'images': inputs['images'].to_tensor(), 'bounding_boxes': bounding_box.to_dense(inputs['bounding_boxes'], max_boxes=2000)}

def dict_to_tuple(inputs):
    return inputs['images'], inputs['bounding_boxes']

# %%
# Generate the list of objects from annotations
filenames_train, tiles_train, bboxes_train, categories_train = zip(*list(map(lambda img_ann: (img_ann.filename, list(img_ann.tile), list([list(obj_ann.bb) for obj_ann in img_ann.objects]), list([list(categories.keys())[list(categories.values()).index(obj_ann.category)] for obj_ann in img_ann.objects])), anns_train)))
filenames_valid, tiles_valid, bboxes_valid, categories_valid = zip(*list(map(lambda img_ann: (img_ann.filename, list(img_ann.tile), list([list(obj_ann.bb) for obj_ann in img_ann.objects]), list([list(categories.keys())[list(categories.values()).index(obj_ann.category)] for obj_ann in img_ann.objects])), anns_valid)))
ds_train = tf.data.Dataset.from_tensor_slices((tf.cast(filenames_train, tf.string), tf.cast(tiles_train, tf.int32), tf.cast(tf.ragged.constant(bboxes_train), tf.float32).to_tensor(), tf.cast(tf.ragged.constant(categories_train), tf.float32).to_tensor()))
ds_valid = tf.data.Dataset.from_tensor_slices((tf.cast(filenames_valid, tf.string), tf.cast(tiles_valid, tf.int32), tf.cast(tf.ragged.constant(bboxes_valid), tf.float32).to_tensor(), tf.cast(tf.ragged.constant(categories_valid), tf.float32).to_tensor()))
ds_train = ds_train.map(image_generator, num_parallel_calls=tf.data.AUTOTUNE)
ds_valid = ds_valid.map(image_generator, num_parallel_calls=tf.data.AUTOTUNE)
# Generators
batch_size = 4
ds_train = ds_train.shuffle(batch_size*5)
ds_train = ds_train.ragged_batch(batch_size=batch_size, drop_remainder=True)
ds_valid = ds_valid.ragged_batch(batch_size=batch_size, drop_remainder=True)
data_augmentation = tf.keras.Sequential([
    keras_cv.layers.RandomFlip(mode='horizontal_and_vertical', bounding_box_format='xyxy'),
    keras_cv.layers.RandomShear(x_factor=0.2, y_factor=0.2, bounding_box_format='xyxy'),
    keras_cv.layers.RandomColorDegeneration(factor=0.5),
    keras_cv.layers.RandomBrightness(factor=0.2),  
])
ds_train = ds_train.map(data_augmentation, num_parallel_calls=tf.data.AUTOTUNE)
# Bounding box tensors need to be Dense instead of Ragged
ds_train = ds_train.map(ragged_to_dense, num_parallel_calls=tf.data.AUTOTUNE)
ds_valid = ds_valid.map(ragged_to_dense, num_parallel_calls=tf.data.AUTOTUNE)
ds_train = ds_train.map(dict_to_tuple, num_parallel_calls=tf.data.AUTOTUNE).prefetch(tf.data.AUTOTUNE)
ds_valid = ds_valid.map(dict_to_tuple, num_parallel_calls=tf.data.AUTOTUNE).prefetch(tf.data.AUTOTUNE)

# %%
import numpy as np

print('Training model')
epochs = 40
train_steps, valid_steps = len(ds_train), len(ds_valid)
h = model.fit(ds_train, steps_per_epoch=train_steps, validation_data=ds_valid, validation_steps=valid_steps, epochs=epochs, callbacks=callbacks, verbose=1)
# Best validation model
best_idx = int(np.argmin(h.history['val_loss']))
best_value = np.min(h.history['val_loss'])
print('Best validation model: epoch ' + str(best_idx+1)-, ' - val_loss ' + str(best_value))
# Out:
# Training model
# Epoch 1/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - box_loss: 3.2116 - class_loss: 9.1499 - loss: 12.3616
# Epoch 1: val_loss improved from inf to 2.74061, saving model to retinanet.keras
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 940s 532ms/step - box_loss: 3.2113 - class_loss: 9.1462 - loss: 12.3575 - val_box_loss: 2.2840 - val_class_loss: 0.4566 - val_loss: 2.7406 - learning_rate: 0.0010
# Epoch 2/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - box_loss: 2.2458 - class_loss: 0.4755 - loss: 2.7213
# Epoch 2: val_loss improved from 2.74061 to 2.67119, saving model to retinanet.keras
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 908s 530ms/step - box_loss: 2.2458 - class_loss: 0.4755 - loss: 2.7213 - val_box_loss: 2.2524 - val_class_loss: 0.4188 - val_loss: 2.6712 - learning_rate: 0.0010
# Epoch 3/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - box_loss: 2.1638 - class_loss: 0.4260 - loss: 2.5897
# Epoch 3: val_loss improved from 2.67119 to 2.63183, saving model to retinanet.keras
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 907s 530ms/step - box_loss: 2.1638 - class_loss: 0.4260 - loss: 2.5897 - val_box_loss: 2.2425 - val_class_loss: 0.3893 - val_loss: 2.6318 - learning_rate: 0.0010
# Epoch 4/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - box_loss: 2.0995 - class_loss: 0.3988 - loss: 2.4983
# Epoch 4: val_loss improved from 2.63183 to 2.61222, saving model to retinanet.keras
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 907s 529ms/step - box_loss: 2.0995 - class_loss: 0.3988 - loss: 2.4983 - val_box_loss: 2.2239 - val_class_loss: 0.3884 - val_loss: 2.6122 - learning_rate: 0.0010
# Epoch 5/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - box_loss: 2.0742 - class_loss: 0.3882 - loss: 2.4624
# Epoch 5: val_loss improved from 2.61222 to 2.56960, saving model to retinanet.keras
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 907s 529ms/step - box_loss: 2.0742 - class_loss: 0.3881 - loss: 2.4624 - val_box_loss: 2.1991 - val_class_loss: 0.3705 - val_loss: 2.5696 - learning_rate: 0.0010
# Epoch 6/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - box_loss: 2.0421 - class_loss: 0.3746 - loss: 2.4167
# Epoch 6: val_loss did not improve from 2.56960
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 907s 530ms/step - box_loss: 2.0421 - class_loss: 0.3746 - loss: 2.4167 - val_box_loss: 2.1934 - val_class_loss: 0.3777 - val_loss: 2.5712 - learning_rate: 0.0010
# Epoch 7/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - box_loss: 2.0179 - class_loss: 0.3672 - loss: 2.3852
# Epoch 7: val_loss improved from 2.56960 to 2.55960, saving model to retinanet.keras
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 908s 530ms/step - box_loss: 2.0179 - class_loss: 0.3672 - loss: 2.3852 - val_box_loss: 2.1870 - val_class_loss: 0.3726 - val_loss: 2.5596 - learning_rate: 0.0010
# Epoch 8/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - box_loss: 2.0021 - class_loss: 0.3617 - loss: 2.3638
# Epoch 8: val_loss improved from 2.55960 to 2.53734, saving model to retinanet.keras
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 907s 529ms/step - box_loss: 2.0021 - class_loss: 0.3617 - loss: 2.3638 - val_box_loss: 2.1767 - val_class_loss: 0.3606 - val_loss: 2.5373 - learning_rate: 0.0010
# Epoch 9/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - box_loss: 1.9778 - class_loss: 0.3541 - loss: 2.3318
# Epoch 9: val_loss improved from 2.53734 to 2.50395, saving model to retinanet.keras
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 906s 529ms/step - box_loss: 1.9778 - class_loss: 0.3541 - loss: 2.3318 - val_box_loss: 2.1386 - val_class_loss: 0.3654 - val_loss: 2.5039 - learning_rate: 0.0010
# Epoch 10/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - box_loss: 1.9728 - class_loss: 0.3516 - loss: 2.3244
# Epoch 10: val_loss did not improve from 2.50395
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 905s 528ms/step - box_loss: 1.9728 - class_loss: 0.3516 - loss: 2.3244 - val_box_loss: 2.1665 - val_class_loss: 0.3599 - val_loss: 2.5263 - learning_rate: 0.0010
# Epoch 11/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - box_loss: 1.9568 - class_loss: 0.3490 - loss: 2.3058
# Epoch 11: val_loss did not improve from 2.50395
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 904s 528ms/step - box_loss: 1.9568 - class_loss: 0.3490 - loss: 2.3058 - val_box_loss: 2.1499 - val_class_loss: 0.3577 - val_loss: 2.5075 - learning_rate: 0.0010
# Epoch 12/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - box_loss: 1.9460 - class_loss: 0.3446 - loss: 2.2906
# Epoch 12: val_loss did not improve from 2.50395
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 905s 528ms/step - box_loss: 1.9460 - class_loss: 0.3446 - loss: 2.2906 - val_box_loss: 2.1688 - val_class_loss: 0.3562 - val_loss: 2.5250 - learning_rate: 0.0010
# Epoch 13/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - box_loss: 1.9347 - class_loss: 0.3417 - loss: 2.2764
# Epoch 13: val_loss did not improve from 2.50395
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 905s 528ms/step - box_loss: 1.9347 - class_loss: 0.3417 - loss: 2.2764 - val_box_loss: 2.1783 - val_class_loss: 0.3605 - val_loss: 2.5389 - learning_rate: 0.0010
# Epoch 14/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - box_loss: 1.9334 - class_loss: 0.3390 - loss: 2.2724
# Epoch 14: val_loss did not improve from 2.50395
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 905s 529ms/step - box_loss: 1.9334 - class_loss: 0.3390 - loss: 2.2724 - val_box_loss: 2.1529 - val_class_loss: 0.3540 - val_loss: 2.5070 - learning_rate: 0.0010
# Epoch 15/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - box_loss: 1.9170 - class_loss: 0.3386 - loss: 2.2556
# Epoch 15: val_loss improved from 2.50395 to 2.44227, saving model to retinanet.keras
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 906s 529ms/step - box_loss: 1.9170 - class_loss: 0.3386 - loss: 2.2556 - val_box_loss: 2.0979 - val_class_loss: 0.3443 - val_loss: 2.4423 - learning_rate: 0.0010
# Epoch 16/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - box_loss: 1.9132 - class_loss: 0.3357 - loss: 2.2488
# Epoch 16: val_loss did not improve from 2.44227
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 905s 528ms/step - box_loss: 1.9132 - class_loss: 0.3357 - loss: 2.2488 - val_box_loss: 2.1379 - val_class_loss: 0.3470 - val_loss: 2.4849 - learning_rate: 0.0010
# Epoch 17/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - box_loss: 1.9005 - class_loss: 0.3330 - loss: 2.2335
# Epoch 17: val_loss did not improve from 2.44227
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 922s 528ms/step - box_loss: 1.9005 - class_loss: 0.3330 - loss: 2.2335 - val_box_loss: 2.2033 - val_class_loss: 0.3492 - val_loss: 2.5525 - learning_rate: 0.0010
# Epoch 18/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - box_loss: 1.8998 - class_loss: 0.3321 - loss: 2.2319
# Epoch 18: val_loss did not improve from 2.44227
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 905s 529ms/step - box_loss: 1.8998 - class_loss: 0.3321 - loss: 2.2319 - val_box_loss: 2.0992 - val_class_loss: 0.3473 - val_loss: 2.4465 - learning_rate: 0.0010
# Epoch 19/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - box_loss: 1.8948 - class_loss: 0.3291 - loss: 2.2239
# Epoch 19: val_loss did not improve from 2.44227
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 905s 528ms/step - box_loss: 1.8948 - class_loss: 0.3291 - loss: 2.2239 - val_box_loss: 2.1098 - val_class_loss: 0.3414 - val_loss: 2.4512 - learning_rate: 0.0010
# Epoch 20/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - box_loss: 1.8769 - class_loss: 0.3268 - loss: 2.2038
# Epoch 20: val_loss did not improve from 2.44227
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 904s 528ms/step - box_loss: 1.8770 - class_loss: 0.3268 - loss: 2.2038 - val_box_loss: 2.0968 - val_class_loss: 0.3465 - val_loss: 2.4433 - learning_rate: 0.0010
# Epoch 21/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - box_loss: 1.8792 - class_loss: 0.3252 - loss: 2.2044
# Epoch 21: val_loss improved from 2.44227 to 2.41045, saving model to retinanet.keras
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 907s 529ms/step - box_loss: 1.8792 - class_loss: 0.3252 - loss: 2.2044 - val_box_loss: 2.0722 - val_class_loss: 0.3383 - val_loss: 2.4104 - learning_rate: 0.0010
# Epoch 22/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - box_loss: 1.8779 - class_loss: 0.3255 - loss: 2.2034
# Epoch 22: val_loss did not improve from 2.41045
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 905s 528ms/step - box_loss: 1.8779 - class_loss: 0.3255 - loss: 2.2034 - val_box_loss: 2.0800 - val_class_loss: 0.3524 - val_loss: 2.4324 - learning_rate: 0.0010
# Epoch 23/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - box_loss: 1.8714 - class_loss: 0.3221 - loss: 2.1934
# Epoch 23: val_loss did not improve from 2.41045
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 905s 528ms/step - box_loss: 1.8714 - class_loss: 0.3221 - loss: 2.1934 - val_box_loss: 2.1203 - val_class_loss: 0.3429 - val_loss: 2.4633 - learning_rate: 0.0010
# Epoch 24/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - box_loss: 1.8668 - class_loss: 0.3210 - loss: 2.1878
# Epoch 24: val_loss did not improve from 2.41045
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 906s 529ms/step - box_loss: 1.8668 - class_loss: 0.3210 - loss: 2.1878 - val_box_loss: 2.0751 - val_class_loss: 0.3475 - val_loss: 2.4226 - learning_rate: 0.0010
# Epoch 25/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - box_loss: 1.8629 - class_loss: 0.3194 - loss: 2.1823
# Epoch 25: val_loss did not improve from 2.41045
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 905s 528ms/step - box_loss: 1.8629 - class_loss: 0.3194 - loss: 2.1823 - val_box_loss: 2.0819 - val_class_loss: 0.3392 - val_loss: 2.4211 - learning_rate: 0.0010
# Epoch 26/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - box_loss: 1.8506 - class_loss: 0.3192 - loss: 2.1698
# Epoch 26: val_loss improved from 2.41045 to 2.40370, saving model to retinanet.keras
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 906s 529ms/step - box_loss: 1.8506 - class_loss: 0.3192 - loss: 2.1698 - val_box_loss: 2.0648 - val_class_loss: 0.3389 - val_loss: 2.4037 - learning_rate: 0.0010
# Epoch 27/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - box_loss: 1.8501 - class_loss: 0.3169 - loss: 2.1670
# Epoch 27: val_loss improved from 2.40370 to 2.38502, saving model to retinanet.keras
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 906s 529ms/step - box_loss: 1.8501 - class_loss: 0.3169 - loss: 2.1670 - val_box_loss: 2.0438 - val_class_loss: 0.3412 - val_loss: 2.3850 - learning_rate: 0.0010
# Epoch 28/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - box_loss: 1.8536 - class_loss: 0.3175 - loss: 2.1710
# Epoch 28: val_loss did not improve from 2.38502
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 904s 528ms/step - box_loss: 1.8536 - class_loss: 0.3175 - loss: 2.1710 - val_box_loss: 2.1205 - val_class_loss: 0.3458 - val_loss: 2.4663 - learning_rate: 0.0010
# Epoch 29/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - box_loss: 1.8372 - class_loss: 0.3155 - loss: 2.1527
# Epoch 29: val_loss did not improve from 2.38502
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 905s 528ms/step - box_loss: 1.8372 - class_loss: 0.3155 - loss: 2.1527 - val_box_loss: 2.0808 - val_class_loss: 0.3317 - val_loss: 2.4126 - learning_rate: 0.0010
# Epoch 30/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - box_loss: 1.8350 - class_loss: 0.3129 - loss: 2.1479
# Epoch 30: val_loss did not improve from 2.38502
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 905s 528ms/step - box_loss: 1.8350 - class_loss: 0.3129 - loss: 2.1479 - val_box_loss: 2.1310 - val_class_loss: 0.3439 - val_loss: 2.4749 - learning_rate: 0.0010
# Epoch 31/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - box_loss: 1.8366 - class_loss: 0.3141 - loss: 2.1508
# Epoch 31: val_loss did not improve from 2.38502
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 905s 528ms/step - box_loss: 1.8366 - class_loss: 0.3141 - loss: 2.1508 - val_box_loss: 2.1201 - val_class_loss: 0.3354 - val_loss: 2.4555 - learning_rate: 0.0010
# Epoch 32/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - box_loss: 1.8276 - class_loss: 0.3114 - loss: 2.1390
# Epoch 32: val_loss did not improve from 2.38502
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 905s 528ms/step - box_loss: 1.8276 - class_loss: 0.3114 - loss: 2.1390 - val_box_loss: 2.0840 - val_class_loss: 0.3326 - val_loss: 2.4166 - learning_rate: 0.0010
# Epoch 33/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - box_loss: 1.8299 - class_loss: 0.3104 - loss: 2.1402
# Epoch 33: val_loss improved from 2.38502 to 2.38300, saving model to retinanet.keras
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 907s 530ms/step - box_loss: 1.8299 - class_loss: 0.3104 - loss: 2.1402 - val_box_loss: 2.0499 - val_class_loss: 0.3331 - val_loss: 2.3830 - learning_rate: 0.0010
# Epoch 34/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - box_loss: 1.8225 - class_loss: 0.3097 - loss: 2.1322
# Epoch 34: val_loss did not improve from 2.38300
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 909s 530ms/step - box_loss: 1.8225 - class_loss: 0.3097 - loss: 2.1322 - val_box_loss: 2.1446 - val_class_loss: 0.3351 - val_loss: 2.4797 - learning_rate: 0.0010
# Epoch 35/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - box_loss: 1.8168 - class_loss: 0.3093 - loss: 2.1261
# Epoch 35: val_loss did not improve from 2.38300
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 909s 531ms/step - box_loss: 1.8168 - class_loss: 0.3093 - loss: 2.1261 - val_box_loss: 2.0679 - val_class_loss: 0.3354 - val_loss: 2.4033 - learning_rate: 0.0010
# Epoch 36/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - box_loss: 1.8211 - class_loss: 0.3086 - loss: 2.1298
# Epoch 36: val_loss did not improve from 2.38300
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 908s 530ms/step - box_loss: 1.8211 - class_loss: 0.3087 - loss: 2.1298 - val_box_loss: 2.0548 - val_class_loss: 0.3301 - val_loss: 2.3849 - learning_rate: 0.0010
# Epoch 37/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - box_loss: 1.8171 - class_loss: 0.3073 - loss: 2.1244
# Epoch 37: val_loss did not improve from 2.38300
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 910s 531ms/step - box_loss: 1.8171 - class_loss: 0.3073 - loss: 2.1244 - val_box_loss: 2.1150 - val_class_loss: 0.3393 - val_loss: 2.4543 - learning_rate: 0.0010
# Epoch 38/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - box_loss: 1.8118 - class_loss: 0.3068 - loss: 2.1186
# Epoch 38: val_loss did not improve from 2.38300
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 910s 531ms/step - box_loss: 1.8117 - class_loss: 0.3068 - loss: 2.1186 - val_box_loss: 2.0912 - val_class_loss: 0.3320 - val_loss: 2.4232 - learning_rate: 0.0010
# Epoch 39/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - box_loss: 1.8051 - class_loss: 0.3054 - loss: 2.1105
# Epoch 39: val_loss did not improve from 2.38300
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 908s 530ms/step - box_loss: 1.8051 - class_loss: 0.3054 - loss: 2.1105 - val_box_loss: 2.0666 - val_class_loss: 0.3321 - val_loss: 2.3987 - learning_rate: 0.0010
# Epoch 40/40
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - box_loss: 1.8110 - class_loss: 0.3037 - loss: 2.1147
# Epoch 40: val_loss did not improve from 2.38300
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 909s 531ms/step - box_loss: 1.8110 - class_loss: 0.3037 - loss: 2.1147 - val_box_loss: 2.1055 - val_class_loss: 0.3372 - val_loss: 2.4427 - learning_rate: 0.0010
# Best validation model: epoch 33  - val_loss 2.3830008506774902

# %%
print(h.history.keys())
# Out:
# dict_keys(['box_loss', 'class_loss', 'loss', 'val_box_loss', 'val_class_loss', 'val_loss', 'learning_rate'])

# %% [markdown]
# #### Validation
# Compute validation metrics.

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as col
import numpy as np
# %matplotlib inline

def area_intersection(boxes, box):
    xmin = np.maximum(np.min(boxes[:, 0::2], axis=1), np.min(box[0::2]))
    ymin = np.maximum(np.min(boxes[:, 1::2], axis=1), np.min(box[1::2]))
    xmax = np.minimum(np.max(boxes[:, 0::2], axis=1), np.max(box[0::2]))
    ymax = np.minimum(np.max(boxes[:, 1::2], axis=1), np.max(box[1::2]))
    w = np.maximum(xmax - xmin + 1.0, 0.0)
    h = np.maximum(ymax - ymin + 1.0, 0.0)
    return w * h

def area_union(boxes, box):
    area_anns = (np.max(box[0::2])-np.min(box[0::2])+1.0) * (np.max(box[1::2])-np.min(box[1::2])+1.0)
    area_pred = (np.max(boxes[:, 0::2], axis=1)-np.min(boxes[:, 0::2], axis=1)+1.0) * (np.max(boxes[:, 1::2], axis=1)-np.min(boxes[:, 1::2], axis=1)+1.0)
    return area_anns + area_pred - area_intersection(boxes, box)

def calc_iou(boxes, box):
    iou = area_intersection(boxes, box) / area_union(boxes, box)
    max_value = np.max(iou)
    max_index = np.argmax(iou)
    return max_value, max_index

def calc_ap(rec, prec):
    # First append sentinel values at the end
    mrec = np.concatenate(([0.0], rec, [1.0]))
    mpre = np.concatenate(([0.0], prec, [0.0]))
    # Compute the precision envelope
    for i in range(mpre.size-1, 0, -1):
        mpre[i-1] = np.maximum(mpre[i-1], mpre[i])
    # To calculate area under PR curve, look for points where X axis (recall) changes value
    i = np.where(mrec[1:] != mrec[:-1])[0]
    # and sum (\Delta recall) * prec
    ap = np.sum((mrec[i+1] - mrec[i]) * mpre[i+1])
    return ap

def draw_confusion_matrix(cm, categories):
    # Draw confusion matrix
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    cm = cm.astype('float') / np.maximum(cm.sum(axis=1)[:, np.newaxis], np.finfo(np.float64).eps)
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.get_cmap('Blues'))
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=categories, yticklabels=categories, ylabel='Annotation', xlabel='Prediction')
    # Rotate the tick labels and set their alignment
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Loop over data dimensions and create text annotations
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], '.2f'), ha="center", va="center", color="white" if cm[i, j] > thresh else "black", fontsize=int(20-pow(len(categories), 0.5)))
    fig.tight_layout()
    plt.show()

def draw_precision_recall(precisions, recalls, categories):
    # Draw precision-recall curves for each category
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    plt.axis([0, 1, 0, 1])
    c_dark = list(filter(lambda x: x.startswith('dark'), col.cnames.keys()))
    aps = []
    # Compare categories for a specific algorithm
    for idx in range(len(categories)):
        plt.plot(recalls[idx], precisions[idx], color=c_dark[idx], label=categories[idx], linewidth=4.0)
        aps.append(calc_ap(recalls[idx], precisions[idx]))
    handles, labels = ax.get_legend_handles_labels()
    labels = [str(val + ' [' + "{:.3f}".format(aps[idx]) + ']') for idx, val in enumerate(labels)]
    handles = [h for (ap, h) in sorted(zip(aps, handles), key=lambda x: x[0], reverse=True)]
    labels = [l for (ap, l) in sorted(zip(aps, labels), key=lambda x: x[0], reverse=True)]
    leg = plt.legend(handles, labels, loc='upper right')
    leg.set_zorder(100)
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.grid("on", linestyle="--", linewidth=2.0)
    fig.tight_layout()
    plt.show()

# %%
import numpy as np
from tqdm import tqdm

model.load_weights('retinanet.keras')
# Generate the list of objects from annotations
ds_valid = tf.data.Dataset.from_tensor_slices((tf.cast(filenames_valid, tf.string), tf.cast(tiles_valid, tf.int32), tf.cast(tf.ragged.constant(bboxes_valid), tf.float32).to_tensor(), tf.cast(tf.ragged.constant(categories_valid), tf.float32).to_tensor()))
ds_valid = ds_valid.map(image_generator, num_parallel_calls=tf.data.AUTOTUNE).cache()
ds_valid = ds_valid.batch(batch_size=1)
ds_valid = ds_valid.map(dict_to_tuple, num_parallel_calls=tf.data.AUTOTUNE).prefetch(tf.data.AUTOTUNE)
# Process each tile sequentially
iterator = iter(ds_valid)
annotations, predictions = {}, {}
for ann in tqdm(anns_valid):
    # Save annotations
    annotations.setdefault(ann.filename, {})
    predictions.setdefault(ann.filename, {})
    for obj in ann.objects:
        annotations[ann.filename].setdefault(obj.category, {'bbox': []})
        annotations[ann.filename][obj.category]['bbox'].append(obj.bb)
    # Save prediction
    image, _ = next(iterator)
    y_pred = model.predict(image, verbose=0)
    for i in range(np.squeeze(y_pred['num_detections'])):
        obj = GenericObject()
        bbox = np.squeeze(y_pred['boxes'])[i]
        obj.bb = (bbox[0], bbox[1], bbox[2], bbox[3])
        obj.category = categories[np.squeeze(y_pred['classes'])[i]]
        obj.score = np.squeeze(y_pred['confidence'])[i]
        predictions[ann.filename].setdefault(obj.category, {'bbox': [], 'confidence': []})
        predictions[ann.filename][obj.category]['bbox'].append(obj.bb)
        predictions[ann.filename][obj.category]['confidence'].append(obj.score)  # sort detections by confidence
# Out:
# 100%|██████████| 761/761 [01:56<00:00,  6.54it/s]

# %%
threshold = 0.5
default_cls = 'BACKGROUND'
y_true, y_pred = [], []  # confusion matrix
tps, confidences = dict(), dict()  # draw precision-recall curves for each category
for cls in categories.values():
    # Compute TP, FP and FN for each image
    tps[cls], confidences[cls] = [], []
    for f in predictions:
        # Sort 'cls' predictions by confidence for each file
        pred_boxes, pred_confidences = [], []
        if cls in predictions[f].keys():
            for idx in range(len(predictions[f][cls]['bbox'])):
                pred_boxes.append(predictions[f][cls]['bbox'][idx])
                pred_confidences.append(predictions[f][cls]['confidence'][idx])
            sorted_ind = np.argsort(-np.array(pred_confidences))
            pred_boxes = np.array(pred_boxes)[sorted_ind, :]
        pred_boxes = np.array(pred_boxes).astype(float)
        # Define 'cls' annotations for each file
        anno_boxes = []
        if cls in annotations[f].keys():
            anno_boxes = annotations[f][cls]['bbox']
        anno_boxes = np.array(anno_boxes).astype(float)
        # Define horizontal or oriented bounding boxes
        anno_indices = list(range(len(anno_boxes)))
        # Compare a single prediction 'pred_box' with all annotations 'anno_boxes'
        for pred_idx, pred_box in enumerate(pred_boxes):
            # A prediction is correct if its IoU with the ground truth is above the threshold
            iou_value, ann_index = calc_iou(anno_boxes, pred_box) if len(anno_boxes) > 0 else (-1, -1)
            if iou_value > threshold and ann_index in anno_indices:
                # TP
                anno_indices.remove(int(ann_index))
                tps[cls] += [1.0]
                y_true += [cls]
            else:
                # FP
                tps[cls] += [0.0]
                y_true += [default_cls]
            y_pred += [cls]
            confidences[cls] += [pred_confidences[pred_idx]]
        # FN
        y_true += [cls] * len(anno_indices)
        y_pred += [default_cls] * len(anno_indices)
y_true, y_pred = np.array(y_true), np.array(y_pred)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score

# Compute AP metric
precision_list, recall_list, ap_list = [], [], []
for cls in categories.values():
    sorted_ind = np.argsort(-np.array(confidences[cls]))
    tp = np.cumsum(np.array(tps[cls])[sorted_ind], dtype=float)
    recall = np.array([0.0]) if len(tp) == 0 else tp / np.maximum(np.sum(y_true == cls), np.finfo(np.float64).eps)
    precision = np.array([0.0]) if len(tp) == 0 else tp / np.maximum(list(range(1, np.sum(y_pred == cls)+1)), np.finfo(np.float64).eps)
    ap = calc_ap(recall, precision)
    print('> %s: Recall: %.3f%% Precision: %.3f%% AP: %.3f%%' % (cls, recall[-1]*100, precision[-1]*100, ap*100))
    precision_list.append(precision)
    recall_list.append(recall)
    ap_list.append(ap)
mean_ap = np.mean(ap_list)
print('mAccuracy: %.3f%%' % (accuracy_score(y_true, y_pred)*100))
print('mRecall: %.3f%%' % (recall_score(y_true, y_pred, average='macro', zero_division=1)*100))
print('mPrecision: %.3f%%' % (precision_score(y_true, y_pred, average='macro', zero_division=1)*100))
print('mAP: %.3f%%' % (mean_ap*100))
# Out:
# > Small car: Recall: 34.307% Precision: 48.287% AP: 23.789%
# > Bus: Recall: 19.062% Precision: 39.482% AP: 11.683%
# > Truck: Recall: 2.586% Precision: 43.548% AP: 1.158%
# > Building: Recall: 53.240% Precision: 60.417% AP: 44.856%
# mAccuracy: 33.207%
# mRecall: 21.839%
# mPrecision: 38.347%
# mAP: 20.372%

# %%
names = list(categories.values()).copy()
names.insert(0, default_cls)
cm = confusion_matrix(y_true, y_pred, labels=names)
print('Confusion matrix:')
print(cm)
draw_confusion_matrix(cm, names)
draw_precision_recall(precision_list, recall_list, categories)
# Out:
# Confusion matrix:
# [[    0  6430   187    35 10017]
#  [11497  6004     0     0     0]
#  [  518     0   122     0     0]
#  [ 1017     0     0    27     0]
#  [13428     0     0     0 15289]]
# /tmp/ipykernel_55/2574756117.py:44: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.get_cmap('Blues'))

# %% [markdown]
# #### Testing
# Try to improve the results provided in the competition.

# %%
import os
import numpy as np

anns = []
test_dir = '/kaggle/input/datasets/alexferroni/detection/xview_test'

for (dirpath, dirnames, filenames) in os.walk(test_dir):
    for filename in filenames:
        # Inseriamo esplicitamente solo la cartella e il nome del file
        image = GenericImage('xview_test/' + filename)
        image.tile = np.array([0, 0, 640, 640])
        anns.append(image)
        
print('Number of testing images: ' + str(len(anns)))
# Out:
# Number of testing images: 852

# %%
import numpy as np
from tqdm import tqdm

model.load_weights('retinanet.keras')
# Generate the list of objects from annotations
filenames_test, tiles_test, bboxes_test, categories_test = zip(*list(map(lambda img_ann: (img_ann.filename, list(img_ann.tile), list([list(obj_ann.bb) for obj_ann in img_ann.objects]), list([list(categories.keys())[list(categories.values()).index(obj_ann.category)] for obj_ann in img_ann.objects])), anns)))
ds_test = tf.data.Dataset.from_tensor_slices((tf.cast(filenames_test, tf.string), tf.cast(tiles_test, tf.int32), tf.cast(tf.ragged.constant(bboxes_test), tf.float32).to_tensor(), tf.cast(tf.ragged.constant(categories_test), tf.float32).to_tensor()))
ds_test = ds_test.map(image_generator, num_parallel_calls=tf.data.AUTOTUNE).cache()
ds_test = ds_test.batch(batch_size=1)
ds_test = ds_test.map(dict_to_tuple, num_parallel_calls=tf.data.AUTOTUNE).prefetch(tf.data.AUTOTUNE)
# Process each tile sequentially
iterator = iter(ds_test)
predictions = {}
for ann in tqdm(anns):
    # Generate prediction
    image, _ = next(iterator)
    y_pred = model.predict(image, verbose=0)
    predictions.setdefault(ann.filename, {})
    for i in range(np.squeeze(y_pred['num_detections'])):
        obj = GenericObject()
        bbox = np.squeeze(y_pred['boxes'])[i]
        obj.bb = (bbox[0], bbox[1], bbox[2], bbox[3])
        obj.category = categories[np.squeeze(y_pred['classes'])[i]]
        obj.score = np.squeeze(y_pred['confidence'])[i]
        predictions[ann.filename].setdefault(obj.category, {'bbox': [], 'confidence': []})
        predictions[ann.filename][obj.category]['bbox'].append(obj.bb)
        predictions[ann.filename][obj.category]['confidence'].append(obj.score)  # sort detections by confidence
# Save prediction
predictions_data = {"images": {}, "annotations": {}, "categories": {}}
predictions_data["categories"] = categories
imgs_idx, annos_idx = 0, 0
for pred in predictions:
    num_objects = 0
    for cat in predictions[pred]:
        for bb in predictions[pred][cat]['bbox']:
            num_objects += len(predictions[pred][cat]['bbox'])
    image_data = {"image_id": pred.split('/')[-1], "filename": pred, "num_objects": num_objects, "width": 640, "height": 640}
    predictions_data["images"][imgs_idx] = image_data
    imgs_idx += 1
    bboxes, confs = [], []
    for cat in predictions[pred]:
        for i in range(len(predictions[pred][cat]['bbox'])):  
            bbox = predictions[pred][cat]['bbox'][i]
            conf = predictions[pred][cat]['confidence'][i]
            annotation_data = {"image_id": pred.split('/')[-1], "category_id": cat, "bbox": (int(bbox[0]), int(bbox[1]), int(bbox[2]), int(bbox[3])), "confidence": str(conf)}
            predictions_data["annotations"][annos_idx] = annotation_data
            annos_idx += 1
# Out:
# 100%|██████████| 852/852 [02:06<00:00,  6.72it/s]

# %%
with open("prediction_retinanet.json", "w") as outfile:
    json.dump(predictions_data, outfile)

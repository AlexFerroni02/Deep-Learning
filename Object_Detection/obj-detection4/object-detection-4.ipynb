# %% [markdown]
# ## Assignment: Object detection
# - Alumno 1: Vittorio Alberto Gianfrate
# - Alumno 2: Alex Ferroni
# - Alumno 3:
#
# The goals of the assignment are:
# * Put into practice acquired knowledge to detect and recognize objects of interest within a satellite image.
#
# To address this problem, you must choose one of the following options:
# *	Implement a sliding window strategy to process the whole image, and then train a classifier that determines whether each window includes or not an object of interest. In this way, you can use previous image classification model to infer the object category.
# *	Build a single-stage object detection model (e.g., YOLO, SSD, RetinaNet, etc.).
# *	Build a two-stage object detection model (e.g., Faster R-CNN, R-FCN, etc.).
#
# Follow the link below to download the detection data set “xview_detection”: [https://drive.upm.es/s/P7nEf3Bygns7tbM](https://drive.upm.es/s/P7nEf3Bygns7tbM)

# %%
# !pip install rasterio
# Out:
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (1.5.0)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio) (25.4.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from rasterio) (2026.1.4)
# Requirement already satisfied: click!=8.2.*,>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio) (8.3.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.0.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio) (3.3.1)

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# 2026-04-07 09:12:07.601917: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775553127.775283      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775553127.822230      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775553128.245449      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775553128.245496      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775553128.245500      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775553128.245502      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import uuid
import numpy as np

class GenericObject:
    """
    Generic object data.
    """
    def __init__(self):
        self.id = uuid.uuid4()
        self.bb = (-1, -1, -1, -1)
        self.category= -1
        self.score = -1

class GenericImage:
    """
    Generic image data.
    """
    def __init__(self, filename):
        self.filename = filename
        self.tile = np.array([-1, -1, -1, -1])  # (pt_x, pt_y, pt_x+width, pt_y+height)
        self.objects = list([])

    def add_object(self, obj: GenericObject):
        self.objects.append(obj)

# %%
categories = {0: 'Small car', 1: 'Bus', 2: 'Truck', 3: 'Building'}

# %%
import warnings
import rasterio
import numpy as np

def load_geoimage(filename):
    warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
    base_path = '/kaggle/input/datasets/alexferroni/detection/'
    
    src_raster = rasterio.open(base_path + filename, 'r')
    # RasterIO to OpenCV (see inconsistencies between libjpeg and libjpeg-turbo)
    input_type = src_raster.profile['dtype']
    input_channels = src_raster.count
    img = np.zeros((src_raster.height, src_raster.width, src_raster.count), dtype=input_type)
    for band in range(input_channels):
        img[:, :, band] = src_raster.read(band+1)
    return img

# %% [markdown]
# #### Training
# Design and train a detector to deal with the “xview_detection” perception task.

# %%
import json

# Load database
json_file = '/kaggle/input/datasets/alexferroni/detection/xview_det_train.json'
with open(json_file) as ifs:
    json_data = json.load(ifs)
ifs.close()
print("Annotazioni caricate con successo!")
# Out:
# Annotazioni caricate con successo!

# %%
import numpy as np

counts = dict.fromkeys(categories.values(), 0)
anns = []
for json_img in json_data['images'].values():
    image = GenericImage(json_img['filename'])
    image.tile = np.array([0, 0, json_img['width'], json_img['height']])
    for json_ann in [elem for elem in json_data['annotations'].values() if elem['image_id'] == json_img['image_id']]:
        obj = GenericObject()
        obj.id = json_ann['image_id']
        obj.bb = (int(json_ann['bbox'][0]), int(json_ann['bbox'][1]), int(json_ann['bbox'][2]), int(json_ann['bbox'][3]))
        obj.category = json_ann['category_id']
        counts[obj.category] += 1
        image.add_object(obj)
    anns.append(image)
print(counts)
# Out:
# {'Small car': 188300, 'Bus': 6269, 'Truck': 10600, 'Building': 275943}

# %%
from sklearn.model_selection import train_test_split

anns_train, anns_valid = train_test_split(anns, test_size=0.1, random_state=1, shuffle=True)
print('Number of training images: ' + str(len(anns_train)))
print('Number of validation images: ' + str(len(anns_valid)))
# Out:
# Number of training images: 6845
# Number of validation images: 761

# %%
import keras_cv

print('Loading model...')
prediction_decoder = keras_cv.layers.NonMaxSuppression(
    bounding_box_format='xyxy',
    from_logits=False,
    confidence_threshold=0.2,
    iou_threshold=0.7
)

# Usiamo la versione Large (L) o Extra Large (XL) per massime prestazioni
model = keras_cv.models.YOLOV8Detector.from_preset(
    preset='yolo_v8_xl_backbone_coco',  
    num_classes=len(categories),
    bounding_box_format='xyxy',
    prediction_decoder=prediction_decoder,
    load_weights=True
)


# Se vuoi sbloccare i pesi per l'addestramento (Fine-tuning)
model.trainable = True

model.summary()
# Out:
# Loading model...
# I0000 00:00:1775553508.769611      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "yolov8_detector"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, None,      │          0 │ -                 │
# │ (InputLayer)        │ None, 3)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ functional          │ [(None, None,     │ 30,972,080 │ input_layer_1[0]… │
# │ (Functional)        │ None, 320),       │            │                   │
# │                     │ (None, None,      │            │                   │
# │                     │ None, 640),       │            │                   │
# │                     │ (None, None,      │            │                   │
# │                     │ None, 640)]       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ repeat (Repeat)     │ (None, None,      │          0 │ functional[0][2]  │
# │                     │ None, 640)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ repeat_1 (Repeat)   │ (None, None,      │          0 │ repeat[0][0]      │
# │                     │ None, 640)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, None,      │          0 │ repeat_1[0][0],   │
# │ (Concatenate)       │ None, 1280)       │            │ functional[0][1]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_co… │ (None, None,      │    819,200 │ concatenate_5[0]… │
# │ (Conv2D)            │ None, 640)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_bn  │ (None, None,      │      2,560 │ pa_fpn_p4p5_pre_… │
# │ (BatchNormalizatio… │ None, 640)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre     │ (None, None,      │          0 │ pa_fpn_p4p5_pre_… │
# │ (Activation)        │ None, 640)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ split_4 (Split)     │ [(None, None,     │          0 │ pa_fpn_p4p5_pre[… │
# │                     │ None, 320),       │            │                   │
# │                     │ (None, None,      │            │                   │
# │                     │ None, 320)]       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_0_… │ (None, None,      │          0 │ split_4[0][1]     │
# │ (ZeroPadding2D)     │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_0_… │ (None, None,      │    921,600 │ pa_fpn_p4p5_pre_… │
# │ (Conv2D)            │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_0_… │ (None, None,      │      1,280 │ pa_fpn_p4p5_pre_… │
# │ (BatchNormalizatio… │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_0_1 │ (None, None,      │          0 │ pa_fpn_p4p5_pre_… │
# │ (Activation)        │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_0_… │ (None, None,      │          0 │ pa_fpn_p4p5_pre_… │
# │ (ZeroPadding2D)     │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_0_… │ (None, None,      │    921,600 │ pa_fpn_p4p5_pre_… │
# │ (Conv2D)            │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_0_… │ (None, None,      │      1,280 │ pa_fpn_p4p5_pre_… │
# │ (BatchNormalizatio… │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_0_2 │ (None, None,      │          0 │ pa_fpn_p4p5_pre_… │
# │ (Activation)        │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_1_… │ (None, None,      │          0 │ pa_fpn_p4p5_pre_… │
# │ (ZeroPadding2D)     │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_1_… │ (None, None,      │    921,600 │ pa_fpn_p4p5_pre_… │
# │ (Conv2D)            │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_1_… │ (None, None,      │      1,280 │ pa_fpn_p4p5_pre_… │
# │ (BatchNormalizatio… │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_1_1 │ (None, None,      │          0 │ pa_fpn_p4p5_pre_… │
# │ (Activation)        │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_1_… │ (None, None,      │          0 │ pa_fpn_p4p5_pre_… │
# │ (ZeroPadding2D)     │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_1_… │ (None, None,      │    921,600 │ pa_fpn_p4p5_pre_… │
# │ (Conv2D)            │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_1_… │ (None, None,      │      1,280 │ pa_fpn_p4p5_pre_… │
# │ (BatchNormalizatio… │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_1_2 │ (None, None,      │          0 │ pa_fpn_p4p5_pre_… │
# │ (Activation)        │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, None,      │          0 │ split_4[0][0],    │
# │ (Concatenate)       │ None, 1280)       │            │ split_4[0][1],    │
# │                     │                   │            │ pa_fpn_p4p5_pre_… │
# │                     │                   │            │ pa_fpn_p4p5_pre_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_output… │ (None, None,      │    819,200 │ concatenate_6[0]… │
# │ (Conv2D)            │ None, 640)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_output… │ (None, None,      │      2,560 │ pa_fpn_p4p5_outp… │
# │ (BatchNormalizatio… │ None, 640)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_output  │ (None, None,      │          0 │ pa_fpn_p4p5_outp… │
# │ (Activation)        │ None, 640)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ repeat_2 (Repeat)   │ (None, None,      │          0 │ pa_fpn_p4p5_outp… │
# │                     │ None, 640)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ repeat_3 (Repeat)   │ (None, None,      │          0 │ repeat_2[0][0]    │
# │                     │ None, 640)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, None,      │          0 │ repeat_3[0][0],   │
# │ (Concatenate)       │ None, 960)        │            │ functional[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │    307,200 │ concatenate_7[0]… │
# │ (Conv2D)            │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │      1,280 │ pa_fpn_p3p4p5_pr… │
# │ (BatchNormalizatio… │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre   │ (None, None,      │          0 │ pa_fpn_p3p4p5_pr… │
# │ (Activation)        │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ split_5 (Split)     │ [(None, None,     │          0 │ pa_fpn_p3p4p5_pr… │
# │                     │ None, 160),       │            │                   │
# │                     │ (None, None,      │            │                   │
# │                     │ None, 160)]       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │          0 │ split_5[0][1]     │
# │ (ZeroPadding2D)     │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │    230,400 │ pa_fpn_p3p4p5_pr… │
# │ (Conv2D)            │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │        640 │ pa_fpn_p3p4p5_pr… │
# │ (BatchNormalizatio… │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │          0 │ pa_fpn_p3p4p5_pr… │
# │ (Activation)        │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │          0 │ pa_fpn_p3p4p5_pr… │
# │ (ZeroPadding2D)     │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │    230,400 │ pa_fpn_p3p4p5_pr… │
# │ (Conv2D)            │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │        640 │ pa_fpn_p3p4p5_pr… │
# │ (BatchNormalizatio… │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │          0 │ pa_fpn_p3p4p5_pr… │
# │ (Activation)        │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │          0 │ pa_fpn_p3p4p5_pr… │
# │ (ZeroPadding2D)     │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │    230,400 │ pa_fpn_p3p4p5_pr… │
# │ (Conv2D)            │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │        640 │ pa_fpn_p3p4p5_pr… │
# │ (BatchNormalizatio… │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │          0 │ pa_fpn_p3p4p5_pr… │
# │ (Activation)        │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │          0 │ pa_fpn_p3p4p5_pr… │
# │ (ZeroPadding2D)     │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │    230,400 │ pa_fpn_p3p4p5_pr… │
# │ (Conv2D)            │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │        640 │ pa_fpn_p3p4p5_pr… │
# │ (BatchNormalizatio… │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │          0 │ pa_fpn_p3p4p5_pr… │
# │ (Activation)        │ None, 160)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_8       │ (None, None,      │          0 │ split_5[0][0],    │
# │ (Concatenate)       │ None, 640)        │            │ split_5[0][1],    │
# │                     │                   │            │ pa_fpn_p3p4p5_pr… │
# │                     │                   │            │ pa_fpn_p3p4p5_pr… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_outp… │ (None, None,      │    204,800 │ concatenate_8[0]… │
# │ (Conv2D)            │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_outp… │ (None, None,      │      1,280 │ pa_fpn_p3p4p5_ou… │
# │ (BatchNormalizatio… │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_outp… │ (None, None,      │          0 │ pa_fpn_p3p4p5_ou… │
# │ (Activation)        │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_ou… │
# │ (ZeroPadding2D)     │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │    921,600 │ pa_fpn_p3p4p5_do… │
# │ (Conv2D)            │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │      1,280 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_9       │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Concatenate)       │ None, 960)        │            │ pa_fpn_p4p5_outp… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │    614,400 │ concatenate_9[0]… │
# │ (Conv2D)            │ None, 640)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │      2,560 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 640)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 640)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ split_6 (Split)     │ [(None, None,     │          0 │ pa_fpn_p3p4p5_do… │
# │                     │ None, 320),       │            │                   │
# │                     │ (None, None,      │            │                   │
# │                     │ None, 320)]       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ split_6[0][1]     │
# │ (ZeroPadding2D)     │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │    921,600 │ pa_fpn_p3p4p5_do… │
# │ (Conv2D)            │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │      1,280 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (ZeroPadding2D)     │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │    921,600 │ pa_fpn_p3p4p5_do… │
# │ (Conv2D)            │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │      1,280 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (ZeroPadding2D)     │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │    921,600 │ pa_fpn_p3p4p5_do… │
# │ (Conv2D)            │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │      1,280 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (ZeroPadding2D)     │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │    921,600 │ pa_fpn_p3p4p5_do… │
# │ (Conv2D)            │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │      1,280 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_10      │ (None, None,      │          0 │ split_6[0][0],    │
# │ (Concatenate)       │ None, 1280)       │            │ split_6[0][1],    │
# │                     │                   │            │ pa_fpn_p3p4p5_do… │
# │                     │                   │            │ pa_fpn_p3p4p5_do… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │    819,200 │ concatenate_10[0… │
# │ (Conv2D)            │ None, 640)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │      2,560 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 640)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 640)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (ZeroPadding2D)     │ None, 640)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │  3,686,400 │ pa_fpn_p3p4p5_do… │
# │ (Conv2D)            │ None, 640)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │      2,560 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 640)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 640)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_11      │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Concatenate)       │ None, 1280)       │            │ functional[0][2]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │    819,200 │ concatenate_11[0… │
# │ (Conv2D)            │ None, 640)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │      2,560 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 640)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 640)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ split_7 (Split)     │ [(None, None,     │          0 │ pa_fpn_p3p4p5_do… │
# │                     │ None, 320),       │            │                   │
# │                     │ (None, None,      │            │                   │
# │                     │ None, 320)]       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ split_7[0][1]     │
# │ (ZeroPadding2D)     │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │    921,600 │ pa_fpn_p3p4p5_do… │
# │ (Conv2D)            │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │      1,280 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (ZeroPadding2D)     │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │    921,600 │ pa_fpn_p3p4p5_do… │
# │ (Conv2D)            │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │      1,280 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (ZeroPadding2D)     │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │    921,600 │ pa_fpn_p3p4p5_do… │
# │ (Conv2D)            │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │      1,280 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (ZeroPadding2D)     │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │    921,600 │ pa_fpn_p3p4p5_do… │
# │ (Conv2D)            │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │      1,280 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_12      │ (None, None,      │          0 │ split_7[0][0],    │
# │ (Concatenate)       │ None, 1280)       │            │ split_7[0][1],    │
# │                     │                   │            │ pa_fpn_p3p4p5_do… │
# │                     │                   │            │ pa_fpn_p3p4p5_do… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │    819,200 │ concatenate_12[0… │
# │ (Conv2D)            │ None, 640)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │      2,560 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 640)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 640)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_cla… │ (None, None,      │          0 │ pa_fpn_p3p4p5_ou… │
# │ (ZeroPadding2D)     │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_cla… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (ZeroPadding2D)     │ None, 640)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_cla… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (ZeroPadding2D)     │ None, 640)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_box… │ (None, None,      │          0 │ pa_fpn_p3p4p5_ou… │
# │ (ZeroPadding2D)     │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_cla… │ (None, None,      │    921,600 │ yolo_v8_head_1_c… │
# │ (Conv2D)            │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_box… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (ZeroPadding2D)     │ None, 640)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_cla… │ (None, None,      │  1,843,200 │ yolo_v8_head_2_c… │
# │ (Conv2D)            │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_box… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (ZeroPadding2D)     │ None, 640)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_cla… │ (None, None,      │  1,843,200 │ yolo_v8_head_3_c… │
# │ (Conv2D)            │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_box… │ (None, None,      │    230,400 │ yolo_v8_head_1_b… │
# │ (Conv2D)            │ None, 80)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_cla… │ (None, None,      │      1,280 │ yolo_v8_head_1_c… │
# │ (BatchNormalizatio… │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_box… │ (None, None,      │    460,800 │ yolo_v8_head_2_b… │
# │ (Conv2D)            │ None, 80)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_cla… │ (None, None,      │      1,280 │ yolo_v8_head_2_c… │
# │ (BatchNormalizatio… │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_box… │ (None, None,      │    460,800 │ yolo_v8_head_3_b… │
# │ (Conv2D)            │ None, 80)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_cla… │ (None, None,      │      1,280 │ yolo_v8_head_3_c… │
# │ (BatchNormalizatio… │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_box… │ (None, None,      │        320 │ yolo_v8_head_1_b… │
# │ (BatchNormalizatio… │ None, 80)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_cla… │ (None, None,      │          0 │ yolo_v8_head_1_c… │
# │ (Activation)        │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_box… │ (None, None,      │        320 │ yolo_v8_head_2_b… │
# │ (BatchNormalizatio… │ None, 80)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_cla… │ (None, None,      │          0 │ yolo_v8_head_2_c… │
# │ (Activation)        │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_box… │ (None, None,      │        320 │ yolo_v8_head_3_b… │
# │ (BatchNormalizatio… │ None, 80)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_cla… │ (None, None,      │          0 │ yolo_v8_head_3_c… │
# │ (Activation)        │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_box… │ (None, None,      │          0 │ yolo_v8_head_1_b… │
# │ (Activation)        │ None, 80)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_cla… │ (None, None,      │          0 │ yolo_v8_head_1_c… │
# │ (ZeroPadding2D)     │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_box… │ (None, None,      │          0 │ yolo_v8_head_2_b… │
# │ (Activation)        │ None, 80)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_cla… │ (None, None,      │          0 │ yolo_v8_head_2_c… │
# │ (ZeroPadding2D)     │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_box… │ (None, None,      │          0 │ yolo_v8_head_3_b… │
# │ (Activation)        │ None, 80)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_cla… │ (None, None,      │          0 │ yolo_v8_head_3_c… │
# │ (ZeroPadding2D)     │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_box… │ (None, None,      │          0 │ yolo_v8_head_1_b… │
# │ (ZeroPadding2D)     │ None, 80)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_cla… │ (None, None,      │    921,600 │ yolo_v8_head_1_c… │
# │ (Conv2D)            │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_box… │ (None, None,      │          0 │ yolo_v8_head_2_b… │
# │ (ZeroPadding2D)     │ None, 80)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_cla… │ (None, None,      │    921,600 │ yolo_v8_head_2_c… │
# │ (Conv2D)            │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_box… │ (None, None,      │          0 │ yolo_v8_head_3_b… │
# │ (ZeroPadding2D)     │ None, 80)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_cla… │ (None, None,      │    921,600 │ yolo_v8_head_3_c… │
# │ (Conv2D)            │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_box… │ (None, None,      │     57,600 │ yolo_v8_head_1_b… │
# │ (Conv2D)            │ None, 80)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_cla… │ (None, None,      │      1,280 │ yolo_v8_head_1_c… │
# │ (BatchNormalizatio… │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_box… │ (None, None,      │     57,600 │ yolo_v8_head_2_b… │
# │ (Conv2D)            │ None, 80)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_cla… │ (None, None,      │      1,280 │ yolo_v8_head_2_c… │
# │ (BatchNormalizatio… │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_box… │ (None, None,      │     57,600 │ yolo_v8_head_3_b… │
# │ (Conv2D)            │ None, 80)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_cla… │ (None, None,      │      1,280 │ yolo_v8_head_3_c… │
# │ (BatchNormalizatio… │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_box… │ (None, None,      │        320 │ yolo_v8_head_1_b… │
# │ (BatchNormalizatio… │ None, 80)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_cla… │ (None, None,      │          0 │ yolo_v8_head_1_c… │
# │ (Activation)        │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_box… │ (None, None,      │        320 │ yolo_v8_head_2_b… │
# │ (BatchNormalizatio… │ None, 80)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_cla… │ (None, None,      │          0 │ yolo_v8_head_2_c… │
# │ (Activation)        │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_box… │ (None, None,      │        320 │ yolo_v8_head_3_b… │
# │ (BatchNormalizatio… │ None, 80)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_cla… │ (None, None,      │          0 │ yolo_v8_head_3_c… │
# │ (Activation)        │ None, 320)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_box… │ (None, None,      │          0 │ yolo_v8_head_1_b… │
# │ (Activation)        │ None, 80)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_cla… │ (None, None,      │      1,284 │ yolo_v8_head_1_c… │
# │ (Conv2D)            │ None, 4)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_box… │ (None, None,      │          0 │ yolo_v8_head_2_b… │
# │ (Activation)        │ None, 80)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_cla… │ (None, None,      │      1,284 │ yolo_v8_head_2_c… │
# │ (Conv2D)            │ None, 4)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_box… │ (None, None,      │          0 │ yolo_v8_head_3_b… │
# │ (Activation)        │ None, 80)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_cla… │ (None, None,      │      1,284 │ yolo_v8_head_3_c… │
# │ (Conv2D)            │ None, 4)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_box… │ (None, None,      │      5,184 │ yolo_v8_head_1_b… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_cla… │ (None, None,      │          0 │ yolo_v8_head_1_c… │
# │ (Activation)        │ None, 4)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_box… │ (None, None,      │      5,184 │ yolo_v8_head_2_b… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_cla… │ (None, None,      │          0 │ yolo_v8_head_2_c… │
# │ (Activation)        │ None, 4)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_box… │ (None, None,      │      5,184 │ yolo_v8_head_3_b… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_cla… │ (None, None,      │          0 │ yolo_v8_head_3_c… │
# │ (Activation)        │ None, 4)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_13      │ (None, None,      │          0 │ yolo_v8_head_1_b… │
# │ (Concatenate)       │ None, 68)         │            │ yolo_v8_head_1_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_14      │ (None, None,      │          0 │ yolo_v8_head_2_b… │
# │ (Concatenate)       │ None, 68)         │            │ yolo_v8_head_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_15      │ (None, None,      │          0 │ yolo_v8_head_3_b… │
# │ (Concatenate)       │ None, 68)         │            │ yolo_v8_head_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_out… │ (None, None, 68)  │          0 │ concatenate_13[0… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_out… │ (None, None, 68)  │          0 │ concatenate_14[0… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_out… │ (None, None, 68)  │          0 │ concatenate_15[0… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_16      │ (None, None, 68)  │          0 │ yolo_v8_head_1_o… │
# │ (Concatenate)       │                   │            │ yolo_v8_head_2_o… │
# │                     │                   │            │ yolo_v8_head_3_o… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ box_outputs         │ (None, None, 68)  │          0 │ concatenate_16[0… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item (GetItem)  │ (None, None, 64)  │          0 │ box_outputs[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_1          │ (None, None, 4)   │          0 │ box_outputs[0][0] │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ box (Concatenate)   │ (None, None, 64)  │          0 │ get_item[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ class (Concatenate) │ (None, None, 4)   │          0 │ get_item_1[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 61,549,564 (234.79 MB)
#  Trainable params: 61,495,964 (234.59 MB)
#  Non-trainable params: 53,600 (209.38 KB)

# %%
from tensorflow.keras.optimizers import SGD

opt = SGD(learning_rate=1e-3, momentum=0.9, global_clipnorm=10.0)

# Compilazione per RetinaNet
model.compile(
    optimizer=opt,
    classification_loss='binary_crossentropy',  # ✅ corretto per YOLO
    box_loss='ciou',                              # ✅ corretto per YOLO
    jit_compile=False
)

# %%
from tensorflow.keras.callbacks import TerminateOnNaN, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

model_checkpoint = ModelCheckpoint('retinanet.keras', monitor='val_loss', verbose=1, save_best_only=True)
reduce_lr = ReduceLROnPlateau('val_loss', factor=0.1, patience=7, verbose=1)
early_stop = EarlyStopping('val_loss', patience=15, verbose=1)
terminate = TerminateOnNaN()
callbacks = [model_checkpoint, reduce_lr, early_stop, terminate]

# %%
def image_generator(filename, tile, bboxes, categories):
    def load_sample(filepath):
        image = load_geoimage(filepath.numpy().decode('utf-8'))
        return tf.cast(image, tf.uint8)
    # Load image
    img = tf.squeeze(tf.py_function(func=load_sample, inp=[filename], Tout=[tf.uint8]), axis=0)  # tf.print(tf.shape(img)) -> [H, W, 3]
    img_roi = tf.image.pad_to_bounding_box(img, 0, 0, 640, 640)
    return {'images': tf.cast(img_roi, tf.float32), 'bounding_boxes': {'boxes': bboxes, 'classes': categories}}

def ragged_to_dense(inputs):
    from keras_cv import bounding_box
    return {'images': inputs['images'].to_tensor(), 'bounding_boxes': bounding_box.to_dense(inputs['bounding_boxes'], max_boxes=1000)}

def dict_to_tuple(inputs):
    return inputs['images'], inputs['bounding_boxes']

# %%
# Generate the list of objects from annotations
filenames_train, tiles_train, bboxes_train, categories_train = zip(*list(map(lambda img_ann: (img_ann.filename, list(img_ann.tile), list([list(obj_ann.bb) for obj_ann in img_ann.objects]), list([list(categories.keys())[list(categories.values()).index(obj_ann.category)] for obj_ann in img_ann.objects])), anns_train)))
filenames_valid, tiles_valid, bboxes_valid, categories_valid = zip(*list(map(lambda img_ann: (img_ann.filename, list(img_ann.tile), list([list(obj_ann.bb) for obj_ann in img_ann.objects]), list([list(categories.keys())[list(categories.values()).index(obj_ann.category)] for obj_ann in img_ann.objects])), anns_valid)))
ds_train = tf.data.Dataset.from_tensor_slices((tf.cast(filenames_train, tf.string), tf.cast(tiles_train, tf.int32), tf.cast(tf.ragged.constant(bboxes_train), tf.float32).to_tensor(), tf.cast(tf.ragged.constant(categories_train), tf.float32).to_tensor()))
ds_valid = tf.data.Dataset.from_tensor_slices((tf.cast(filenames_valid, tf.string), tf.cast(tiles_valid, tf.int32), tf.cast(tf.ragged.constant(bboxes_valid), tf.float32).to_tensor(), tf.cast(tf.ragged.constant(categories_valid), tf.float32).to_tensor()))
ds_train = ds_train.map(image_generator, num_parallel_calls=tf.data.AUTOTUNE)
ds_valid = ds_valid.map(image_generator, num_parallel_calls=tf.data.AUTOTUNE)
# Generators
batch_size = 8
ds_train = ds_train.shuffle(batch_size*5)
ds_train = ds_train.ragged_batch(batch_size=batch_size, drop_remainder=True)
ds_valid = ds_valid.ragged_batch(batch_size=batch_size, drop_remainder=True)
data_augmentation = tf.keras.Sequential([
    keras_cv.layers.RandomFlip(mode='horizontal_and_vertical', bounding_box_format='xyxy'),
    keras_cv.layers.RandomShear(x_factor=0.2, y_factor=0.2, bounding_box_format='xyxy'),
    keras_cv.layers.RandomColorDegeneration(factor=0.5),
    keras_cv.layers.RandomBrightness(factor=0.2),  
])
ds_train = ds_train.map(data_augmentation, num_parallel_calls=tf.data.AUTOTUNE)
# Bounding box tensors need to be Dense instead of Ragged
ds_train = ds_train.map(ragged_to_dense, num_parallel_calls=tf.data.AUTOTUNE)
ds_valid = ds_valid.map(ragged_to_dense, num_parallel_calls=tf.data.AUTOTUNE)
ds_train = ds_train.map(dict_to_tuple, num_parallel_calls=tf.data.AUTOTUNE).prefetch(tf.data.AUTOTUNE)
ds_valid = ds_valid.map(dict_to_tuple, num_parallel_calls=tf.data.AUTOTUNE).prefetch(tf.data.AUTOTUNE)

# %%
import numpy as np

print('Training model')
epochs = 35
train_steps, valid_steps = len(ds_train), len(ds_valid)
h = model.fit(ds_train, steps_per_epoch=train_steps, validation_data=ds_valid, validation_steps=valid_steps, epochs=epochs, callbacks=callbacks, verbose=1)
# Best validation model
best_idx = int(np.argmin(h.history['val_loss']))
best_value = np.min(h.history['val_loss'])
print('Best validation model: epoch ' + str(best_idx+1) + ' - val_loss ' + str(best_value))
# Out:
# Training model
# Epoch 1/35
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775553557.171381     127 service.cc:152] XLA service 0x7ecf3d7265c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1775553557.171464     127 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1775553557.236342     127 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1775553559.603730     127 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 3.4212 - class_loss: 14.3851 - loss: 17.8064
# Epoch 1: val_loss improved from inf to 2.82249, saving model to retinanet.keras
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1252s 1s/step - box_loss: 3.4205 - class_loss: 14.3738 - loss: 17.7942 - val_box_loss: 2.3514 - val_class_loss: 0.4711 - val_loss: 2.8225 - learning_rate: 0.0010
# Epoch 2/35
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 2.1869 - class_loss: 0.4696 - loss: 2.6565
# Epoch 2: val_loss improved from 2.82249 to 2.54201, saving model to retinanet.keras
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1136s 1s/step - box_loss: 2.1869 - class_loss: 0.4695 - loss: 2.6564 - val_box_loss: 2.1447 - val_class_loss: 0.3973 - val_loss: 2.5420 - learning_rate: 0.0010
# Epoch 3/35
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 2.0373 - class_loss: 0.4021 - loss: 2.4395
# Epoch 3: val_loss did not improve from 2.54201
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1134s 1s/step - box_loss: 2.0373 - class_loss: 0.4021 - loss: 2.4394 - val_box_loss: 2.1721 - val_class_loss: 0.3763 - val_loss: 2.5483 - learning_rate: 0.0010
# Epoch 4/35
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 1.9711 - class_loss: 0.3749 - loss: 2.3460
# Epoch 4: val_loss improved from 2.54201 to 2.41460, saving model to retinanet.keras
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1138s 1s/step - box_loss: 1.9711 - class_loss: 0.3749 - loss: 2.3460 - val_box_loss: 2.0522 - val_class_loss: 0.3624 - val_loss: 2.4146 - learning_rate: 0.0010
# Epoch 5/35
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 1.9250 - class_loss: 0.3574 - loss: 2.2824
# Epoch 5: val_loss did not improve from 2.41460
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1135s 1s/step - box_loss: 1.9250 - class_loss: 0.3574 - loss: 2.2824 - val_box_loss: 2.0667 - val_class_loss: 0.3602 - val_loss: 2.4269 - learning_rate: 0.0010
# Epoch 6/35
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 1.8950 - class_loss: 0.3454 - loss: 2.2404
# Epoch 6: val_loss improved from 2.41460 to 2.39426, saving model to retinanet.keras
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1138s 1s/step - box_loss: 1.8950 - class_loss: 0.3454 - loss: 2.2404 - val_box_loss: 2.0464 - val_class_loss: 0.3479 - val_loss: 2.3943 - learning_rate: 0.0010
# Epoch 7/35
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 1.8743 - class_loss: 0.3390 - loss: 2.2134
# Epoch 7: val_loss improved from 2.39426 to 2.35309, saving model to retinanet.keras
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1139s 1s/step - box_loss: 1.8743 - class_loss: 0.3390 - loss: 2.2134 - val_box_loss: 2.0008 - val_class_loss: 0.3523 - val_loss: 2.3531 - learning_rate: 0.0010
# Epoch 8/35
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 1.8416 - class_loss: 0.3296 - loss: 2.1712
# Epoch 8: val_loss improved from 2.35309 to 2.32796, saving model to retinanet.keras
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1140s 1s/step - box_loss: 1.8416 - class_loss: 0.3296 - loss: 2.1712 - val_box_loss: 1.9795 - val_class_loss: 0.3484 - val_loss: 2.3280 - learning_rate: 0.0010
# Epoch 9/35
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 1.8365 - class_loss: 0.3275 - loss: 2.1639
# Epoch 9: val_loss did not improve from 2.32796
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1141s 1s/step - box_loss: 1.8364 - class_loss: 0.3275 - loss: 2.1639 - val_box_loss: 1.9934 - val_class_loss: 0.3423 - val_loss: 2.3357 - learning_rate: 0.0010
# Epoch 10/35
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 1.8177 - class_loss: 0.3228 - loss: 2.1405
# Epoch 10: val_loss improved from 2.32796 to 2.31928, saving model to retinanet.keras
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1147s 1s/step - box_loss: 1.8177 - class_loss: 0.3228 - loss: 2.1405 - val_box_loss: 1.9892 - val_class_loss: 0.3300 - val_loss: 2.3193 - learning_rate: 0.0010
# Epoch 11/35
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 1.8050 - class_loss: 0.3163 - loss: 2.1214
# Epoch 11: val_loss improved from 2.31928 to 2.26248, saving model to retinanet.keras
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1145s 1s/step - box_loss: 1.8050 - class_loss: 0.3163 - loss: 2.1213 - val_box_loss: 1.9356 - val_class_loss: 0.3269 - val_loss: 2.2625 - learning_rate: 0.0010
# Epoch 12/35
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 1.7942 - class_loss: 0.3138 - loss: 2.1080
# Epoch 12: val_loss did not improve from 2.26248
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1142s 1s/step - box_loss: 1.7941 - class_loss: 0.3138 - loss: 2.1080 - val_box_loss: 1.9453 - val_class_loss: 0.3305 - val_loss: 2.2758 - learning_rate: 0.0010
# Epoch 13/35
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 1.7768 - class_loss: 0.3099 - loss: 2.0867
# Epoch 13: val_loss did not improve from 2.26248
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1143s 1s/step - box_loss: 1.7768 - class_loss: 0.3099 - loss: 2.0867 - val_box_loss: 1.9449 - val_class_loss: 0.3187 - val_loss: 2.2636 - learning_rate: 0.0010
# Epoch 14/35
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 1.7669 - class_loss: 0.3063 - loss: 2.0733
# Epoch 14: val_loss did not improve from 2.26248
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1140s 1s/step - box_loss: 1.7669 - class_loss: 0.3064 - loss: 2.0733 - val_box_loss: 2.0122 - val_class_loss: 0.3255 - val_loss: 2.3377 - learning_rate: 0.0010
# Epoch 15/35
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 1.7676 - class_loss: 0.3073 - loss: 2.0748
# Epoch 15: val_loss did not improve from 2.26248
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1140s 1s/step - box_loss: 1.7676 - class_loss: 0.3073 - loss: 2.0748 - val_box_loss: 2.0783 - val_class_loss: 0.3277 - val_loss: 2.4060 - learning_rate: 0.0010
# Epoch 16/35
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 1.7549 - class_loss: 0.3051 - loss: 2.0599
# Epoch 16: val_loss did not improve from 2.26248
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1139s 1s/step - box_loss: 1.7549 - class_loss: 0.3051 - loss: 2.0599 - val_box_loss: 2.0458 - val_class_loss: 0.3295 - val_loss: 2.3753 - learning_rate: 0.0010
# Epoch 17/35
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 1.7418 - class_loss: 0.2996 - loss: 2.0414
# Epoch 17: val_loss did not improve from 2.26248
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1140s 1s/step - box_loss: 1.7418 - class_loss: 0.2996 - loss: 2.0414 - val_box_loss: 1.9685 - val_class_loss: 0.3176 - val_loss: 2.2861 - learning_rate: 0.0010
# Epoch 18/35
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 1.7378 - class_loss: 0.2992 - loss: 2.0370
# Epoch 18: val_loss improved from 2.26248 to 2.25824, saving model to retinanet.keras
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1181s 1s/step - box_loss: 1.7378 - class_loss: 0.2992 - loss: 2.0370 - val_box_loss: 1.9429 - val_class_loss: 0.3154 - val_loss: 2.2582 - learning_rate: 0.0010
# Epoch 19/35
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 1.7336 - class_loss: 0.2977 - loss: 2.0314
# Epoch 19: val_loss improved from 2.25824 to 2.21904, saving model to retinanet.keras
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1142s 1s/step - box_loss: 1.7336 - class_loss: 0.2977 - loss: 2.0314 - val_box_loss: 1.9071 - val_class_loss: 0.3119 - val_loss: 2.2190 - learning_rate: 0.0010
# Epoch 20/35
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 1.7284 - class_loss: 0.2965 - loss: 2.0249
# Epoch 20: val_loss did not improve from 2.21904
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1139s 1s/step - box_loss: 1.7284 - class_loss: 0.2965 - loss: 2.0249 - val_box_loss: 1.9217 - val_class_loss: 0.3122 - val_loss: 2.2339 - learning_rate: 0.0010
# Epoch 21/35
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 1.7228 - class_loss: 0.2945 - loss: 2.0173
# Epoch 21: val_loss improved from 2.21904 to 2.15869, saving model to retinanet.keras
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1143s 1s/step - box_loss: 1.7228 - class_loss: 0.2945 - loss: 2.0173 - val_box_loss: 1.8393 - val_class_loss: 0.3194 - val_loss: 2.1587 - learning_rate: 0.0010
# Epoch 22/35
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 1.7195 - class_loss: 0.2945 - loss: 2.0140
# Epoch 22: val_loss did not improve from 2.15869
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1142s 1s/step - box_loss: 1.7195 - class_loss: 0.2945 - loss: 2.0140 - val_box_loss: 1.8739 - val_class_loss: 0.3115 - val_loss: 2.1854 - learning_rate: 0.0010
# Epoch 23/35
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 1.7060 - class_loss: 0.2906 - loss: 1.9965
# Epoch 23: val_loss did not improve from 2.15869
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1140s 1s/step - box_loss: 1.7060 - class_loss: 0.2906 - loss: 1.9965 - val_box_loss: 1.9491 - val_class_loss: 0.3151 - val_loss: 2.2643 - learning_rate: 0.0010
# Epoch 24/35
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 1.7108 - class_loss: 0.2913 - loss: 2.0020
# Epoch 24: val_loss did not improve from 2.15869
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1140s 1s/step - box_loss: 1.7108 - class_loss: 0.2913 - loss: 2.0020 - val_box_loss: 1.8980 - val_class_loss: 0.3106 - val_loss: 2.2086 - learning_rate: 0.0010
# Epoch 25/35
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 1.7002 - class_loss: 0.2884 - loss: 1.9887
# Epoch 25: val_loss did not improve from 2.15869
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1142s 1s/step - box_loss: 1.7002 - class_loss: 0.2884 - loss: 1.9887 - val_box_loss: 1.9427 - val_class_loss: 0.3212 - val_loss: 2.2639 - learning_rate: 0.0010
# Epoch 26/35
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 1.6888 - class_loss: 0.2856 - loss: 1.9745
# Epoch 26: val_loss did not improve from 2.15869
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1141s 1s/step - box_loss: 1.6888 - class_loss: 0.2856 - loss: 1.9745 - val_box_loss: 1.8986 - val_class_loss: 0.3087 - val_loss: 2.2073 - learning_rate: 0.0010
# Epoch 27/35
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 1.6869 - class_loss: 0.2853 - loss: 1.9722
# Epoch 27: val_loss did not improve from 2.15869
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1139s 1s/step - box_loss: 1.6869 - class_loss: 0.2853 - loss: 1.9722 - val_box_loss: 1.8723 - val_class_loss: 0.3062 - val_loss: 2.1785 - learning_rate: 0.0010
# Epoch 28/35
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 1.6851 - class_loss: 0.2848 - loss: 1.9699
# Epoch 28: val_loss did not improve from 2.15869
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1163s 1s/step - box_loss: 1.6851 - class_loss: 0.2848 - loss: 1.9699 - val_box_loss: 1.8878 - val_class_loss: 0.3047 - val_loss: 2.1925 - learning_rate: 0.0010
# Epoch 29/35
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 1.6600 - class_loss: 0.2806 - loss: 1.9407
# Epoch 29: val_loss did not improve from 2.15869
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1138s 1s/step - box_loss: 1.6600 - class_loss: 0.2806 - loss: 1.9406 - val_box_loss: 1.8614 - val_class_loss: 0.2998 - val_loss: 2.1612 - learning_rate: 1.0000e-04
# Epoch 30/35
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 1.6402 - class_loss: 0.2759 - loss: 1.9161
# Epoch 30: val_loss improved from 2.15869 to 2.14520, saving model to retinanet.keras
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1143s 1s/step - box_loss: 1.6401 - class_loss: 0.2759 - loss: 1.9161 - val_box_loss: 1.8464 - val_class_loss: 0.2987 - val_loss: 2.1452 - learning_rate: 1.0000e-04
# Epoch 31/35
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 1.6420 - class_loss: 0.2756 - loss: 1.9176
# Epoch 31: val_loss did not improve from 2.14520
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1135s 1s/step - box_loss: 1.6420 - class_loss: 0.2756 - loss: 1.9176 - val_box_loss: 1.8497 - val_class_loss: 0.2988 - val_loss: 2.1485 - learning_rate: 1.0000e-04
# Epoch 32/35
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 1.6350 - class_loss: 0.2742 - loss: 1.9092
# Epoch 32: val_loss did not improve from 2.14520
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1130s 1s/step - box_loss: 1.6350 - class_loss: 0.2742 - loss: 1.9092 - val_box_loss: 1.8653 - val_class_loss: 0.3007 - val_loss: 2.1660 - learning_rate: 1.0000e-04
# Epoch 33/35
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 1.6370 - class_loss: 0.2740 - loss: 1.9110
# Epoch 33: val_loss did not improve from 2.14520
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1129s 1s/step - box_loss: 1.6370 - class_loss: 0.2740 - loss: 1.9110 - val_box_loss: 1.8547 - val_class_loss: 0.3002 - val_loss: 2.1549 - learning_rate: 1.0000e-04
# Epoch 34/35
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 1.6303 - class_loss: 0.2735 - loss: 1.9038
# Epoch 34: val_loss did not improve from 2.14520
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1129s 1s/step - box_loss: 1.6303 - class_loss: 0.2735 - loss: 1.9038 - val_box_loss: 1.8556 - val_class_loss: 0.2996 - val_loss: 2.1552 - learning_rate: 1.0000e-04
# Epoch 35/35
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 1.6296 - class_loss: 0.2720 - loss: 1.9017
# Epoch 35: val_loss did not improve from 2.14520
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 1130s 1s/step - box_loss: 1.6296 - class_loss: 0.2720 - loss: 1.9017 - val_box_loss: 1.8546 - val_class_loss: 0.2981 - val_loss: 2.1527 - learning_rate: 1.0000e-04
# Best validation model: epoch 30 - val_loss 2.145195960998535

# %%
print(h.history.keys())
import matplotlib.pyplot as plt

def plot_yolo_results(history):
    # Estraiamo le chiavi disponibili (per evitare errori se alcune mancano)
    keys = history.history.keys()
    epochs = range(1, len(history.history['loss']) + 1)

    # Creiamo una figura con 3 grafici (Totale, Box, Classe)
    plt.figure(figsize=(20, 6))

    # --- 1. TOTAL LOSS ---
    plt.subplot(1, 3, 1)
    plt.plot(epochs, history.history['loss'], label='Train Total Loss', color='blue')
    if 'val_loss' in keys:
        plt.plot(epochs, history.history['val_loss'], label='Val Total Loss', color='red')
    plt.title('Total Loss')
    plt.xlabel('Epoche')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    # --- 2. BOX LOSS (Localizzazione) ---
    plt.subplot(1, 3, 2)
    if 'box_loss' in keys:
        plt.plot(epochs, history.history['box_loss'], label='Train Box Loss', color='blue')
    if 'val_box_loss' in keys:
        plt.plot(epochs, history.history['val_box_loss'], label='Val Box Loss', color='red')
    plt.title('Box Loss (Precisione Coordinate)')
    plt.xlabel('Epoche')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    # --- 3. CLASS LOSS (Classificazione) ---
    plt.subplot(1, 3, 3)
    if 'class_loss' in keys:
        plt.plot(epochs, history.history['class_loss'], label='Train Class Loss', color='blue')
    if 'val_class_loss' in keys:
        plt.plot(epochs, history.history['val_class_loss'], label='Val Class Loss', color='red')
    plt.title('Class Loss (Precisione Categoria)')
    plt.xlabel('Epoche')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

# Usa la funzione passando l'oggetto history del tuo training
plot_yolo_results(h)
# Out:
# dict_keys(['box_loss', 'class_loss', 'loss', 'val_box_loss', 'val_class_loss', 'val_loss', 'learning_rate'])

# %% [markdown]
# #### Validation
# Compute validation metrics.

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as col
import numpy as np
# %matplotlib inline

def area_intersection(boxes, box):
    xmin = np.maximum(np.min(boxes[:, 0::2], axis=1), np.min(box[0::2]))
    ymin = np.maximum(np.min(boxes[:, 1::2], axis=1), np.min(box[1::2]))
    xmax = np.minimum(np.max(boxes[:, 0::2], axis=1), np.max(box[0::2]))
    ymax = np.minimum(np.max(boxes[:, 1::2], axis=1), np.max(box[1::2]))
    w = np.maximum(xmax - xmin + 1.0, 0.0)
    h = np.maximum(ymax - ymin + 1.0, 0.0)
    return w * h

def area_union(boxes, box):
    area_anns = (np.max(box[0::2])-np.min(box[0::2])+1.0) * (np.max(box[1::2])-np.min(box[1::2])+1.0)
    area_pred = (np.max(boxes[:, 0::2], axis=1)-np.min(boxes[:, 0::2], axis=1)+1.0) * (np.max(boxes[:, 1::2], axis=1)-np.min(boxes[:, 1::2], axis=1)+1.0)
    return area_anns + area_pred - area_intersection(boxes, box)

def calc_iou(boxes, box):
    iou = area_intersection(boxes, box) / area_union(boxes, box)
    max_value = np.max(iou)
    max_index = np.argmax(iou)
    return max_value, max_index

def calc_ap(rec, prec):
    # First append sentinel values at the end
    mrec = np.concatenate(([0.0], rec, [1.0]))
    mpre = np.concatenate(([0.0], prec, [0.0]))
    # Compute the precision envelope
    for i in range(mpre.size-1, 0, -1):
        mpre[i-1] = np.maximum(mpre[i-1], mpre[i])
    # To calculate area under PR curve, look for points where X axis (recall) changes value
    i = np.where(mrec[1:] != mrec[:-1])[0]
    # and sum (\Delta recall) * prec
    ap = np.sum((mrec[i+1] - mrec[i]) * mpre[i+1])
    return ap

def draw_confusion_matrix(cm, categories):
    # Draw confusion matrix
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    cm = cm.astype('float') / np.maximum(cm.sum(axis=1)[:, np.newaxis], np.finfo(np.float64).eps)
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.get_cmap('Blues'))
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=categories, yticklabels=categories, ylabel='Annotation', xlabel='Prediction')
    # Rotate the tick labels and set their alignment
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Loop over data dimensions and create text annotations
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], '.2f'), ha="center", va="center", color="white" if cm[i, j] > thresh else "black", fontsize=int(20-pow(len(categories), 0.5)))
    fig.tight_layout()
    plt.show()

def draw_precision_recall(precisions, recalls, categories):
    # Draw precision-recall curves for each category
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    plt.axis([0, 1, 0, 1])
    c_dark = list(filter(lambda x: x.startswith('dark'), col.cnames.keys()))
    aps = []
    # Compare categories for a specific algorithm
    for idx in range(len(categories)):
        plt.plot(recalls[idx], precisions[idx], color=c_dark[idx], label=categories[idx], linewidth=4.0)
        aps.append(calc_ap(recalls[idx], precisions[idx]))
    handles, labels = ax.get_legend_handles_labels()
    labels = [str(val + ' [' + "{:.3f}".format(aps[idx]) + ']') for idx, val in enumerate(labels)]
    handles = [h for (ap, h) in sorted(zip(aps, handles), key=lambda x: x[0], reverse=True)]
    labels = [l for (ap, l) in sorted(zip(aps, labels), key=lambda x: x[0], reverse=True)]
    leg = plt.legend(handles, labels, loc='upper right')
    leg.set_zorder(100)
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.grid("on", linestyle="--", linewidth=2.0)
    fig.tight_layout()
    plt.show()

# %%
import numpy as np
from tqdm import tqdm

model.load_weights('retinanet.keras')
# Generate the list of objects from annotations
ds_valid = tf.data.Dataset.from_tensor_slices((tf.cast(filenames_valid, tf.string), tf.cast(tiles_valid, tf.int32), tf.cast(tf.ragged.constant(bboxes_valid), tf.float32).to_tensor(), tf.cast(tf.ragged.constant(categories_valid), tf.float32).to_tensor()))
ds_valid = ds_valid.map(image_generator, num_parallel_calls=tf.data.AUTOTUNE).cache()
ds_valid = ds_valid.batch(batch_size=1)
ds_valid = ds_valid.map(dict_to_tuple, num_parallel_calls=tf.data.AUTOTUNE).prefetch(tf.data.AUTOTUNE)
# Process each tile sequentially
iterator = iter(ds_valid)
annotations, predictions = {}, {}
for ann in tqdm(anns_valid):
    # Save annotations
    annotations.setdefault(ann.filename, {})
    predictions.setdefault(ann.filename, {})
    for obj in ann.objects:
        annotations[ann.filename].setdefault(obj.category, {'bbox': []})
        annotations[ann.filename][obj.category]['bbox'].append(obj.bb)
    # Save prediction
    image, _ = next(iterator)
    y_pred = model.predict(image, verbose=0)
    for i in range(np.squeeze(y_pred['num_detections'])):
        obj = GenericObject()
        bbox = np.squeeze(y_pred['boxes'])[i]
        obj.bb = (bbox[0], bbox[1], bbox[2], bbox[3])
        obj.category = categories[np.squeeze(y_pred['classes'])[i]]
        obj.score = np.squeeze(y_pred['confidence'])[i]
        predictions[ann.filename].setdefault(obj.category, {'bbox': [], 'confidence': []})
        predictions[ann.filename][obj.category]['bbox'].append(obj.bb)
        predictions[ann.filename][obj.category]['confidence'].append(obj.score)  # sort detections by confidence
# Out:
# 100%|██████████| 761/761 [02:15<00:00,  5.63it/s]

# %%
threshold = 0.5
default_cls = 'BACKGROUND'
y_true, y_pred = [], []  # confusion matrix
tps, confidences = dict(), dict()  # draw precision-recall curves for each category
for cls in categories.values():
    # Compute TP, FP and FN for each image
    tps[cls], confidences[cls] = [], []
    for f in predictions:
        # Sort 'cls' predictions by confidence for each file
        pred_boxes, pred_confidences = [], []
        if cls in predictions[f].keys():
            for idx in range(len(predictions[f][cls]['bbox'])):
                pred_boxes.append(predictions[f][cls]['bbox'][idx])
                pred_confidences.append(predictions[f][cls]['confidence'][idx])
            sorted_ind = np.argsort(-np.array(pred_confidences))
            pred_boxes = np.array(pred_boxes)[sorted_ind, :]
        pred_boxes = np.array(pred_boxes).astype(float)
        # Define 'cls' annotations for each file
        anno_boxes = []
        if cls in annotations[f].keys():
            anno_boxes = annotations[f][cls]['bbox']
        anno_boxes = np.array(anno_boxes).astype(float)
        # Define horizontal or oriented bounding boxes
        anno_indices = list(range(len(anno_boxes)))
        # Compare a single prediction 'pred_box' with all annotations 'anno_boxes'
        for pred_idx, pred_box in enumerate(pred_boxes):
            # A prediction is correct if its IoU with the ground truth is above the threshold
            iou_value, ann_index = calc_iou(anno_boxes, pred_box) if len(anno_boxes) > 0 else (-1, -1)
            if iou_value > threshold and ann_index in anno_indices:
                # TP
                anno_indices.remove(int(ann_index))
                tps[cls] += [1.0]
                y_true += [cls]
            else:
                # FP
                tps[cls] += [0.0]
                y_true += [default_cls]
            y_pred += [cls]
            confidences[cls] += [pred_confidences[pred_idx]]
        # FN
        y_true += [cls] * len(anno_indices)
        y_pred += [default_cls] * len(anno_indices)
y_true, y_pred = np.array(y_true), np.array(y_pred)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score

# Compute AP metric
precision_list, recall_list, ap_list = [], [], []
for cls in categories.values():
    sorted_ind = np.argsort(-np.array(confidences[cls]))
    tp = np.cumsum(np.array(tps[cls])[sorted_ind], dtype=float)
    recall = np.array([0.0]) if len(tp) == 0 else tp / np.maximum(np.sum(y_true == cls), np.finfo(np.float64).eps)
    precision = np.array([0.0]) if len(tp) == 0 else tp / np.maximum(list(range(1, np.sum(y_pred == cls)+1)), np.finfo(np.float64).eps)
    ap = calc_ap(recall, precision)
    print('> %s: Recall: %.3f%% Precision: %.3f%% AP: %.3f%%' % (cls, recall[-1]*100, precision[-1]*100, ap*100))
    precision_list.append(precision)
    recall_list.append(recall)
    ap_list.append(ap)
mean_ap = np.mean(ap_list)
print('mAccuracy: %.3f%%' % (accuracy_score(y_true, y_pred)*100))
print('mRecall: %.3f%%' % (recall_score(y_true, y_pred, average='macro', zero_division=1)*100))
print('mPrecision: %.3f%%' % (precision_score(y_true, y_pred, average='macro', zero_division=1)*100))
print('mAP: %.3f%%' % (mean_ap*100))
# Out:
# > Small car: Recall: 62.311% Precision: 73.638% AP: 54.357%
# > Bus: Recall: 16.562% Precision: 41.406% AP: 8.239%
# > Truck: Recall: 7.088% Precision: 37.563% AP: 3.443%
# > Building: Recall: 53.519% Precision: 62.623% AP: 45.821%
# mAccuracy: 43.189%
# mRecall: 27.896%
# mPrecision: 43.046%
# mAP: 27.965%

# %%
names = list(categories.values()).copy()
names.insert(0, default_cls)
cm = confusion_matrix(y_true, y_pred, labels=names)
print('Confusion matrix:')
print(cm)
draw_confusion_matrix(cm, names)
draw_precision_recall(precision_list, recall_list, categories)
# Out:
# Confusion matrix:
# [[    0  3904   150   123  9173]
#  [ 6596 10905     0     0     0]
#  [  534     0   106     0     0]
#  [  970     0     0    74     0]
#  [13348     0     0     0 15369]]
# /tmp/ipykernel_55/2574756117.py:44: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.get_cmap('Blues'))

# %% [markdown]
# #### Testing
# Try to improve the results provided in the competition.

# %%
import os
import numpy as np

anns = []
test_dir = '/kaggle/input/datasets/alexferroni/detection/xview_test'

for (dirpath, dirnames, filenames) in os.walk(test_dir):
    for filename in filenames:
        # Inseriamo esplicitamente solo la cartella e il nome del file
        image = GenericImage('xview_test/' + filename)
        image.tile = np.array([0, 0, 640, 640])
        anns.append(image)
        
print('Number of testing images: ' + str(len(anns)))
# Out:
# Number of testing images: 852

# %%
import numpy as np
from tqdm import tqdm

model.load_weights('retinanet.keras')
# Generate the list of objects from annotations
filenames_test, tiles_test, bboxes_test, categories_test = zip(*list(map(lambda img_ann: (img_ann.filename, list(img_ann.tile), list([list(obj_ann.bb) for obj_ann in img_ann.objects]), list([list(categories.keys())[list(categories.values()).index(obj_ann.category)] for obj_ann in img_ann.objects])), anns)))
ds_test = tf.data.Dataset.from_tensor_slices((tf.cast(filenames_test, tf.string), tf.cast(tiles_test, tf.int32), tf.cast(tf.ragged.constant(bboxes_test), tf.float32).to_tensor(), tf.cast(tf.ragged.constant(categories_test), tf.float32).to_tensor()))
ds_test = ds_test.map(image_generator, num_parallel_calls=tf.data.AUTOTUNE).cache()
ds_test = ds_test.batch(batch_size=1)
ds_test = ds_test.map(dict_to_tuple, num_parallel_calls=tf.data.AUTOTUNE).prefetch(tf.data.AUTOTUNE)
# Process each tile sequentially
iterator = iter(ds_test)
predictions = {}
for ann in tqdm(anns):
    # Generate prediction
    image, _ = next(iterator)
    y_pred = model.predict(image, verbose=0)
    predictions.setdefault(ann.filename, {})
    for i in range(np.squeeze(y_pred['num_detections'])):
        obj = GenericObject()
        bbox = np.squeeze(y_pred['boxes'])[i]
        obj.bb = (bbox[0], bbox[1], bbox[2], bbox[3])
        obj.category = categories[np.squeeze(y_pred['classes'])[i]]
        obj.score = np.squeeze(y_pred['confidence'])[i]
        predictions[ann.filename].setdefault(obj.category, {'bbox': [], 'confidence': []})
        predictions[ann.filename][obj.category]['bbox'].append(obj.bb)
        predictions[ann.filename][obj.category]['confidence'].append(obj.score)  # sort detections by confidence
# Save prediction
predictions_data = {"images": {}, "annotations": {}, "categories": {}}
predictions_data["categories"] = categories
imgs_idx, annos_idx = 0, 0
for pred in predictions:
    num_objects = 0
    for cat in predictions[pred]:
        for bb in predictions[pred][cat]['bbox']:
            num_objects += len(predictions[pred][cat]['bbox'])
    image_data = {"image_id": pred.split('/')[-1], "filename": pred, "num_objects": num_objects, "width": 640, "height": 640}
    predictions_data["images"][imgs_idx] = image_data
    imgs_idx += 1
    bboxes, confs = [], []
    for cat in predictions[pred]:
        for i in range(len(predictions[pred][cat]['bbox'])):  
            bbox = predictions[pred][cat]['bbox'][i]
            conf = predictions[pred][cat]['confidence'][i]
            annotation_data = {"image_id": pred.split('/')[-1], "category_id": cat, "bbox": (int(bbox[0]), int(bbox[1]), int(bbox[2]), int(bbox[3])), "confidence": str(conf)}
            predictions_data["annotations"][annos_idx] = annotation_data
            annos_idx += 1
# Out:
# 100%|██████████| 852/852 [02:24<00:00,  5.89it/s]

# %%
with open("prediction_retinanet.json", "w") as outfile:
    json.dump(predictions_data, outfile)

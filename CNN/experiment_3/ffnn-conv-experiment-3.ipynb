# %% [markdown]
# ## Assignment: Image recognition
# - Alumno 1: Alex Ferroni
# - Alumno 2: Vittorio Alberto Gianfrate
# - Alumno 3:
#
# The goals of the assignment are:
# * Develop proficiency in using Tensorflow/Keras for training Neural Nets (NNs).
# * Put into practice the acquired knowledge to optimize the parameters and architecture of a feedforward Neural Net (ffNN), in the context of an image recognition problem.
# * Put into practice NNs specially conceived for analysing images. Design and optimize the parameters of a Convolutional Neural Net (CNN) to deal with previous task.
# * Train popular architectures from scratch (e.g., GoogLeNet, VGG, ResNet, ...), and compare the results with the ones provided by their pre-trained versions using transfer learning.
#
# Follow the link below to download the classification data set  “xview_recognition”: [https://drive.upm.es/s/2DDPE2zHw5dbM3G](https://drive.upm.es/s/2DDPE2zHw5dbM3G)

# %%
# !pip install rasterio
# Out:
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (1.5.0)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio) (25.4.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from rasterio) (2026.1.4)
# Requirement already satisfied: click!=8.2.*,>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio) (8.3.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.0.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio) (3.3.1)

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import uuid
import numpy as np

class GenericObject:
    """
    Generic object data.
    """
    def __init__(self):
        self.id = uuid.uuid4()
        self.bb = (-1, -1, -1, -1)
        self.category= -1
        self.score = -1

class GenericImage:
    """
    Generic image data.
    """
    def __init__(self, filename):
        self.filename = filename
        self.tile = np.array([-1, -1, -1, -1])  # (pt_x, pt_y, pt_x+width, pt_y+height)
        self.objects = list([])

    def add_object(self, obj: GenericObject):
        self.objects.append(obj)

# %%
categories = {0: 'Cargo plane', 1: 'Small car', 2: 'Bus', 3: 'Truck', 4: 'Motorboat', 5: 'Fishing vessel', 6: 'Dump truck', 7: 'Excavator', 8: 'Building', 9: 'Helipad', 10: 'Storage tank', 11: 'Shipping container', 12: 'Pylon'}

# %%
import warnings
import rasterio
import numpy as np
import os
import cv2

def load_geoimage(filename):
    warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
    base_path = '/kaggle/input/datasets/alexferroni/recognition/xview_recognition/'
    
    src_raster = rasterio.open(base_path + filename, 'r')
    # --------------------

    # RasterIO to OpenCV
    input_type = src_raster.profile['dtype']
    input_channels = src_raster.count
    img = np.zeros((src_raster.height, src_raster.width, src_raster.count), dtype=input_type)
    for band in range(input_channels):
        img[:, :, band] = src_raster.read(band+1)
   
    return img

# %% [markdown]
# #### Training
# Design and train a ffNN to deal with the “xview_recognition” classification task.

# %%
import json
import os


json_file = '/kaggle/input/datasets/alexferroni/recognition/xview_recognition/xview_ann_train.json'

print(f"Caricamento annotazioni da: {json_file}")

with open(json_file) as ifs:
    json_data = json.load(ifs)
    
print("Annotazioni caricate con successo!")
# Out:
# Caricamento annotazioni da: /kaggle/input/datasets/alexferroni/recognition/xview_recognition/xview_ann_train.json
# Annotazioni caricate con successo!

# %%
import numpy as np

counts = dict.fromkeys(categories.values(), 0)
anns = []
for json_img, json_ann in zip(json_data['images'].values(), json_data['annotations'].values()):
    image = GenericImage(json_img['filename'])
    image.tile = np.array([0, 0, json_img['width'], json_img['height']])
    obj = GenericObject()
    obj.bb = (int(json_ann['bbox'][0]), int(json_ann['bbox'][1]), int(json_ann['bbox'][2]), int(json_ann['bbox'][3]))
    obj.category = json_ann['category_id']
    # Resampling strategy to reduce training time
    counts[obj.category] += 1
    image.add_object(obj)
    anns.append(image)
print(counts)
# Out:
# {'Cargo plane': 635, 'Small car': 3324, 'Bus': 1768, 'Truck': 2210, 'Motorboat': 1069, 'Fishing vessel': 706, 'Dump truck': 1236, 'Excavator': 789, 'Building': 3594, 'Helipad': 111, 'Storage tank': 1469, 'Shipping container': 1523, 'Pylon': 312}

# %%
from sklearn.model_selection import train_test_split
labels_list = [x.objects[0].category for x in anns]
anns_train, anns_valid = train_test_split(anns, test_size=0.2, random_state=1, shuffle=True,stratify=labels_list)
print('Number of training images: ' + str(len(anns_train)))
print('Number of validation images: ' + str(len(anns_valid)))
# Out:
# Number of training images: 14996
# Number of validation images: 3750

# %%
train_mean = [69.41887293,56.97948485,49.47711569]
train_std = [51.61769765,44.6239849 ,40.89414141]

# %%
import numpy as np

pixel_sum = np.zeros(3)
pixel_sq_sum = np.zeros(3)
pixel_count = 0


for ann in anns_train:
    
    img = load_geoimage(ann.filename) 
    img = img.astype(np.float64)
    pixel_sum += np.sum(img, axis=(0, 1))
    pixel_sq_sum += np.sum(img ** 2, axis=(0, 1))
    
    pixel_count += img.shape[0] * img.shape[1]

#COmpute mean and standard deviation
train_mean = pixel_sum / pixel_count
train_var = (pixel_sq_sum / pixel_count) - (train_mean ** 2)
train_var = np.maximum(train_var, 0)
train_std = np.sqrt(train_var)

print(f"Training Mean: {train_mean}")
print(f"Training Std: {train_std}")
# Out:
# Training Mean: [69.41887293 56.97948485 49.47711569]
# Training Std: [51.61769765 44.6239849  40.89414141]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (Conv2D, MaxPooling2D, GlobalAveragePooling2D, 
                                     Dense, BatchNormalization, Activation, Dropout, 
                                     RandomFlip, RandomRotation, RandomZoom, RandomTranslation,RandomContrast,SpatialDropout2D)
import tensorflow as tf

# Creiamo la "scatola" vuota
model = Sequential([
    RandomFlip("horizontal_and_vertical", input_shape=(224, 224, 3)),

    # Block 1: 64 filters
    Conv2D(64, (3,3), padding='same', use_bias=False,), BatchNormalization(), Activation('elu'),
    Conv2D(64, (3,3), padding='same', use_bias=False), BatchNormalization(), Activation('elu'),
    MaxPooling2D(2, 2),   # 112x112

    # Block 2: 128 filters
    Conv2D(128, (3,3), padding='same', use_bias=False), BatchNormalization(), Activation('elu'),
    Conv2D(128, (3,3), padding='same', use_bias=False), BatchNormalization(), Activation('elu'),
    MaxPooling2D(2, 2),  # 56x56

    # Block 3: 256 filters
    Conv2D(256, (3,3), padding='same', use_bias=False), BatchNormalization(), Activation('elu'),
    Conv2D(256, (3,3), padding='same', use_bias=False), BatchNormalization(), Activation('elu'),
    MaxPooling2D(2, 2),   # 28x28

    # Block 4: 512 filters
    Conv2D(512, (3,3), padding='same', use_bias=False), BatchNormalization(), Activation('elu'),
    Conv2D(512, (3,3), padding='same', use_bias=False), BatchNormalization(), Activation('elu'),
    MaxPooling2D(2, 2),   # 14x14

    GlobalAveragePooling2D(),
    Dense(512, use_bias=False), BatchNormalization(), Activation('elu'), Dropout(0.3),
    Dense(256, use_bias=False), BatchNormalization(), Activation('elu'), Dropout(0.1),
    Dense(13, activation='softmax')
])

# Riepilogo e Compilazione
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ random_flip_1 (RandomFlip)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 224, 224, 64)   │         1,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 224, 224, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_10 (Activation)      │ (None, 224, 224, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 224, 224, 64)   │        36,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 224, 224, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_11 (Activation)      │ (None, 224, 224, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 112, 112, 128)  │        73,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 112, 112, 128)  │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_12 (Activation)      │ (None, 112, 112, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 112, 112, 128)  │       147,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 112, 112, 128)  │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_13 (Activation)      │ (None, 112, 112, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_12 (Conv2D)              │ (None, 56, 56, 256)    │       294,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 56, 56, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_14 (Activation)      │ (None, 56, 56, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 56, 56, 256)    │       589,824 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 56, 56, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_15 (Activation)      │ (None, 56, 56, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 28, 28, 512)    │     1,179,648 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 28, 28, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_16 (Activation)      │ (None, 28, 28, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 28, 28, 512)    │     2,359,296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 28, 28, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_17 (Activation)      │ (None, 28, 28, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 512)            │       262,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_18 (Activation)      │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 256)            │       131,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_19 (Activation)      │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 13)             │         3,341 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,090,765 (19.42 MB)
#  Trainable params: 5,085,389 (19.40 MB)
#  Non-trainable params: 5,376 (21.00 KB)

# %%
from sklearn.utils import class_weight
import numpy as np

train_labels = [ann.objects[0].category for ann in anns_train]
unique_classes = np.unique(train_labels)

weights_values = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=unique_classes,
    y=train_labels
)

name_to_id = {v: k for k, v in categories.items()}

alpha_array = np.ones(len(categories), dtype=np.float32)

for class_name, weight in zip(unique_classes, weights_values):
    if class_name in name_to_id:
        class_id = name_to_id[class_name]
        alpha_array[class_id] = weight
        print(f"Classe: {class_name:<20} ID: {class_id:<3} Peso: {weight:.4f}")

alpha_list = alpha_array.tolist()

print("\nLISTA DEFINITIVA PRONTA PER FOCAL LOSS:", alpha_list)
# Out:
# Classe: Building             ID: 8   Peso: 0.4012
# Classe: Bus                  ID: 2   Peso: 0.8158
# Classe: Cargo plane          ID: 0   Peso: 2.2707
# Classe: Dump truck           ID: 6   Peso: 1.1664
# Classe: Excavator            ID: 7   Peso: 1.8281
# Classe: Fishing vessel       ID: 5   Peso: 2.0417
# Classe: Helipad              ID: 9   Peso: 12.9611
# Classe: Motorboat            ID: 4   Peso: 1.3492
# Classe: Pylon                ID: 12  Peso: 4.6142
# Classe: Shipping container   ID: 11  Peso: 0.9471
# Classe: Small car            ID: 1   Peso: 0.4338
# Classe: Storage tank         ID: 10  Peso: 0.9817
# Classe: Truck                ID: 3   Peso: 0.6525
#
# LISTA DEFINITIVA PRONTA PER FOCAL LOSS: [2.270745038986206, 0.43382418155670166, 0.8157980442047119, 0.6524538993835449, 1.349167823791504, 2.041661024093628, 1.1663684844970703, 1.8281116485595703, 0.4012307822704315, 12.961106300354004, 0.9817348718643188, 0.9470759034156799, 4.614153861999512]

# %%
from tensorflow.keras.optimizers import Adam

# Learning rate is changed to 0.001
opt = Adam(learning_rate=1e-3, beta_1=0.9, beta_2=0.999, epsilon=1e-8, amsgrad=True, clipnorm=1.0)
model.compile(optimizer=opt, loss=tf.keras.losses.CategoricalFocalCrossentropy(alpha=alpha_list), metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import TerminateOnNaN, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Callbacks
model_checkpoint = ModelCheckpoint('model.keras', monitor='val_accuracy', verbose=1, save_best_only=True)
reduce_lr = ReduceLROnPlateau('val_accuracy', factor=0.1, patience=10, verbose=1,min_lr=1e-7)
early_stop = EarlyStopping('val_accuracy', patience=22, verbose=1)
terminate = TerminateOnNaN()
callbacks = [model_checkpoint, reduce_lr, early_stop, terminate]

# %%
def generator_images(objs, batch_size, do_shuffle=False, mean=None, std=None):
    while True:
        if do_shuffle:
            np.random.shuffle(objs)
        groups = [objs[i:i+batch_size] for i in range(0, len(objs), batch_size)]
        for group in groups:
            images, labels = [], []
            for (filename, obj) in group:
                
                img = load_geoimage(filename)
                
                
                if mean is not None and std is not None:
                    # Use + 1e-7 to avoid the division for 0
                    img = (img - mean) / (std + 1e-7) 
               
                
                images.append(img)
                probabilities = np.zeros(len(categories))
                probabilities[list(categories.values()).index(obj.category)] = 1
                labels.append(probabilities)
            images = np.array(images).astype(np.float32)
            labels = np.array(labels).astype(np.float32)
            yield images, labels

# %%
# Generate the list of objects from annotations
objs_train = [(ann.filename, obj) for ann in anns_train for obj in ann.objects]
objs_valid = [(ann.filename, obj) for ann in anns_valid for obj in ann.objects]
# Generators
batch_size = 64
train_generator = generator_images(objs_train, batch_size, do_shuffle=True,mean=train_mean, std=train_std)
valid_generator = generator_images(objs_valid, batch_size, do_shuffle=False,mean=train_mean, std=train_std)

# %%
import math
import numpy as np

print('Training model')
epochs = 150
train_steps = math.ceil(len(objs_train)/batch_size)
valid_steps = math.ceil(len(objs_valid)/batch_size)
h = model.fit(train_generator, steps_per_epoch=train_steps, validation_data=valid_generator, validation_steps=valid_steps, epochs=epochs, callbacks=callbacks, verbose=1)
# Best validation model
best_idx = int(np.argmax(h.history['val_accuracy']))
best_value = np.max(h.history['val_accuracy'])
print('Best validation model: epoch ' + str(best_idx+1), ' - val_accuracy ' + str(best_value))
# Out:
# Training model
# Epoch 1/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - accuracy: 0.1749 - loss: 1.9732
# Epoch 1: val_accuracy improved from -inf to 0.15973, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 137s 526ms/step - accuracy: 0.1751 - loss: 1.9726 - val_accuracy: 0.1597 - val_loss: 3.5450 - learning_rate: 0.0010
# Epoch 2/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.2626 - loss: 1.5410
# Epoch 2: val_accuracy improved from 0.15973 to 0.17360, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 110s 470ms/step - accuracy: 0.2627 - loss: 1.5408 - val_accuracy: 0.1736 - val_loss: 2.1314 - learning_rate: 0.0010
# Epoch 3/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.2798 - loss: 1.4577
# Epoch 3: val_accuracy improved from 0.17360 to 0.30240, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 110s 467ms/step - accuracy: 0.2798 - loss: 1.4575 - val_accuracy: 0.3024 - val_loss: 1.5708 - learning_rate: 0.0010
# Epoch 4/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.3298 - loss: 1.3331
# Epoch 4: val_accuracy improved from 0.30240 to 0.36613, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 110s 466ms/step - accuracy: 0.3299 - loss: 1.3330 - val_accuracy: 0.3661 - val_loss: 1.3438 - learning_rate: 0.0010
# Epoch 5/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.3659 - loss: 1.2486
# Epoch 5: val_accuracy did not improve from 0.36613
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 462ms/step - accuracy: 0.3659 - loss: 1.2486 - val_accuracy: 0.2813 - val_loss: 1.4665 - learning_rate: 0.0010
# Epoch 6/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.3727 - loss: 1.1891
# Epoch 6: val_accuracy improved from 0.36613 to 0.39760, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 458ms/step - accuracy: 0.3727 - loss: 1.1892 - val_accuracy: 0.3976 - val_loss: 1.3264 - learning_rate: 0.0010
# Epoch 7/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.3920 - loss: 1.2092
# Epoch 7: val_accuracy did not improve from 0.39760
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 110s 469ms/step - accuracy: 0.3920 - loss: 1.2090 - val_accuracy: 0.3664 - val_loss: 1.2210 - learning_rate: 0.0010
# Epoch 8/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.4077 - loss: 1.1410
# Epoch 8: val_accuracy did not improve from 0.39760
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 458ms/step - accuracy: 0.4077 - loss: 1.1410 - val_accuracy: 0.2589 - val_loss: 1.4300 - learning_rate: 0.0010
# Epoch 9/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.4199 - loss: 1.1131
# Epoch 9: val_accuracy did not improve from 0.39760
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 456ms/step - accuracy: 0.4200 - loss: 1.1129 - val_accuracy: 0.3573 - val_loss: 1.1973 - learning_rate: 0.0010
# Epoch 10/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.4249 - loss: 1.0573
# Epoch 10: val_accuracy improved from 0.39760 to 0.39867, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 110s 467ms/step - accuracy: 0.4250 - loss: 1.0573 - val_accuracy: 0.3987 - val_loss: 1.0905 - learning_rate: 0.0010
# Epoch 11/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.4288 - loss: 1.0673
# Epoch 11: val_accuracy did not improve from 0.39867
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 458ms/step - accuracy: 0.4288 - loss: 1.0672 - val_accuracy: 0.3728 - val_loss: 1.1503 - learning_rate: 0.0010
# Epoch 12/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.4276 - loss: 1.0420
# Epoch 12: val_accuracy improved from 0.39867 to 0.44320, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 462ms/step - accuracy: 0.4276 - loss: 1.0420 - val_accuracy: 0.4432 - val_loss: 1.0391 - learning_rate: 0.0010
# Epoch 13/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.4560 - loss: 0.9714
# Epoch 13: val_accuracy did not improve from 0.44320
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 455ms/step - accuracy: 0.4560 - loss: 0.9715 - val_accuracy: 0.3461 - val_loss: 1.1227 - learning_rate: 0.0010
# Epoch 14/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.4608 - loss: 0.9847
# Epoch 14: val_accuracy improved from 0.44320 to 0.44987, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 109s 463ms/step - accuracy: 0.4608 - loss: 0.9847 - val_accuracy: 0.4499 - val_loss: 1.0995 - learning_rate: 0.0010
# Epoch 15/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.4579 - loss: 0.9686
# Epoch 15: val_accuracy improved from 0.44987 to 0.46453, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 462ms/step - accuracy: 0.4579 - loss: 0.9685 - val_accuracy: 0.4645 - val_loss: 0.9898 - learning_rate: 0.0010
# Epoch 16/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.4565 - loss: 0.9458
# Epoch 16: val_accuracy did not improve from 0.46453
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 457ms/step - accuracy: 0.4565 - loss: 0.9458 - val_accuracy: 0.3973 - val_loss: 1.0463 - learning_rate: 0.0010
# Epoch 17/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.4778 - loss: 0.9662
# Epoch 17: val_accuracy did not improve from 0.46453
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 109s 462ms/step - accuracy: 0.4778 - loss: 0.9662 - val_accuracy: 0.3331 - val_loss: 1.1747 - learning_rate: 0.0010
# Epoch 18/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.4903 - loss: 0.8937
# Epoch 18: val_accuracy did not improve from 0.46453
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 460ms/step - accuracy: 0.4903 - loss: 0.8937 - val_accuracy: 0.4565 - val_loss: 1.0201 - learning_rate: 0.0010
# Epoch 19/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.4811 - loss: 0.9124
# Epoch 19: val_accuracy did not improve from 0.46453
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 109s 466ms/step - accuracy: 0.4811 - loss: 0.9125 - val_accuracy: 0.3701 - val_loss: 1.1007 - learning_rate: 0.0010
# Epoch 20/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.4761 - loss: 0.8990
# Epoch 20: val_accuracy did not improve from 0.46453
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 109s 462ms/step - accuracy: 0.4761 - loss: 0.8990 - val_accuracy: 0.4600 - val_loss: 0.9833 - learning_rate: 0.0010
# Epoch 21/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.4963 - loss: 0.8855
# Epoch 21: val_accuracy improved from 0.46453 to 0.46533, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 461ms/step - accuracy: 0.4963 - loss: 0.8855 - val_accuracy: 0.4653 - val_loss: 0.9736 - learning_rate: 0.0010
# Epoch 22/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.5071 - loss: 0.8442
# Epoch 22: val_accuracy improved from 0.46533 to 0.49227, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 457ms/step - accuracy: 0.5070 - loss: 0.8442 - val_accuracy: 0.4923 - val_loss: 0.9741 - learning_rate: 0.0010
# Epoch 23/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.5002 - loss: 0.8539
# Epoch 23: val_accuracy improved from 0.49227 to 0.50320, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 109s 464ms/step - accuracy: 0.5002 - loss: 0.8540 - val_accuracy: 0.5032 - val_loss: 0.8428 - learning_rate: 0.0010
# Epoch 24/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.5075 - loss: 0.8307
# Epoch 24: val_accuracy did not improve from 0.50320
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 459ms/step - accuracy: 0.5075 - loss: 0.8307 - val_accuracy: 0.4800 - val_loss: 0.8896 - learning_rate: 0.0010
# Epoch 25/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.5071 - loss: 0.8322
# Epoch 25: val_accuracy improved from 0.50320 to 0.50747, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 458ms/step - accuracy: 0.5072 - loss: 0.8322 - val_accuracy: 0.5075 - val_loss: 0.9610 - learning_rate: 0.0010
# Epoch 26/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.5177 - loss: 0.8197
# Epoch 26: val_accuracy did not improve from 0.50747
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 458ms/step - accuracy: 0.5177 - loss: 0.8197 - val_accuracy: 0.4589 - val_loss: 0.9470 - learning_rate: 0.0010
# Epoch 27/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.5138 - loss: 0.7992
# Epoch 27: val_accuracy did not improve from 0.50747
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 457ms/step - accuracy: 0.5138 - loss: 0.7993 - val_accuracy: 0.4189 - val_loss: 1.0110 - learning_rate: 0.0010
# Epoch 28/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.5252 - loss: 0.7855
# Epoch 28: val_accuracy did not improve from 0.50747
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 109s 464ms/step - accuracy: 0.5252 - loss: 0.7856 - val_accuracy: 0.4992 - val_loss: 0.8217 - learning_rate: 0.0010
# Epoch 29/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.5177 - loss: 0.8156
# Epoch 29: val_accuracy did not improve from 0.50747
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 112s 475ms/step - accuracy: 0.5177 - loss: 0.8156 - val_accuracy: 0.4811 - val_loss: 0.9141 - learning_rate: 0.0010
# Epoch 30/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.5252 - loss: 0.7857
# Epoch 30: val_accuracy did not improve from 0.50747
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 462ms/step - accuracy: 0.5252 - loss: 0.7857 - val_accuracy: 0.4557 - val_loss: 0.8184 - learning_rate: 0.0010
# Epoch 31/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.5260 - loss: 0.8006
# Epoch 31: val_accuracy improved from 0.50747 to 0.52320, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 109s 464ms/step - accuracy: 0.5260 - loss: 0.8005 - val_accuracy: 0.5232 - val_loss: 0.8000 - learning_rate: 0.0010
# Epoch 32/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.5344 - loss: 0.7558
# Epoch 32: val_accuracy did not improve from 0.52320
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 452ms/step - accuracy: 0.5344 - loss: 0.7559 - val_accuracy: 0.4755 - val_loss: 0.9291 - learning_rate: 0.0010
# Epoch 33/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.5196 - loss: 0.8118
# Epoch 33: val_accuracy did not improve from 0.52320
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 460ms/step - accuracy: 0.5197 - loss: 0.8116 - val_accuracy: 0.4952 - val_loss: 0.8806 - learning_rate: 0.0010
# Epoch 34/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.5429 - loss: 0.7418
# Epoch 34: val_accuracy did not improve from 0.52320
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 458ms/step - accuracy: 0.5428 - loss: 0.7419 - val_accuracy: 0.5149 - val_loss: 0.9595 - learning_rate: 0.0010
# Epoch 35/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.5461 - loss: 0.7382
# Epoch 35: val_accuracy improved from 0.52320 to 0.55573, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 110s 467ms/step - accuracy: 0.5461 - loss: 0.7382 - val_accuracy: 0.5557 - val_loss: 0.7366 - learning_rate: 0.0010
# Epoch 36/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.5428 - loss: 0.7228
# Epoch 36: val_accuracy did not improve from 0.55573
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 109s 463ms/step - accuracy: 0.5428 - loss: 0.7228 - val_accuracy: 0.5019 - val_loss: 0.7823 - learning_rate: 0.0010
# Epoch 37/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.5628 - loss: 0.6987
# Epoch 37: val_accuracy did not improve from 0.55573
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 112s 476ms/step - accuracy: 0.5628 - loss: 0.6987 - val_accuracy: 0.5125 - val_loss: 0.7822 - learning_rate: 0.0010
# Epoch 38/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.5504 - loss: 0.7215
# Epoch 38: val_accuracy improved from 0.55573 to 0.56293, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 111s 474ms/step - accuracy: 0.5504 - loss: 0.7215 - val_accuracy: 0.5629 - val_loss: 0.7405 - learning_rate: 0.0010
# Epoch 39/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.5564 - loss: 0.6995
# Epoch 39: val_accuracy did not improve from 0.56293
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 461ms/step - accuracy: 0.5564 - loss: 0.6996 - val_accuracy: 0.5200 - val_loss: 0.7793 - learning_rate: 0.0010
# Epoch 40/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.5587 - loss: 0.6892
# Epoch 40: val_accuracy did not improve from 0.56293
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 109s 463ms/step - accuracy: 0.5587 - loss: 0.6892 - val_accuracy: 0.5331 - val_loss: 0.7698 - learning_rate: 0.0010
# Epoch 41/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.5725 - loss: 0.6766
# Epoch 41: val_accuracy did not improve from 0.56293
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 462ms/step - accuracy: 0.5725 - loss: 0.6766 - val_accuracy: 0.5243 - val_loss: 0.8663 - learning_rate: 0.0010
# Epoch 42/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.5651 - loss: 0.6740
# Epoch 42: val_accuracy did not improve from 0.56293
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 459ms/step - accuracy: 0.5651 - loss: 0.6741 - val_accuracy: 0.5429 - val_loss: 0.7555 - learning_rate: 0.0010
# Epoch 43/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.5684 - loss: 0.6724
# Epoch 43: val_accuracy did not improve from 0.56293
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 109s 463ms/step - accuracy: 0.5684 - loss: 0.6725 - val_accuracy: 0.4787 - val_loss: 0.7931 - learning_rate: 0.0010
# Epoch 44/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.5836 - loss: 0.6639
# Epoch 44: val_accuracy improved from 0.56293 to 0.57253, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 109s 465ms/step - accuracy: 0.5836 - loss: 0.6639 - val_accuracy: 0.5725 - val_loss: 0.6971 - learning_rate: 0.0010
# Epoch 45/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.5802 - loss: 0.6481
# Epoch 45: val_accuracy did not improve from 0.57253
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 109s 463ms/step - accuracy: 0.5802 - loss: 0.6481 - val_accuracy: 0.5171 - val_loss: 0.8438 - learning_rate: 0.0010
# Epoch 46/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.5779 - loss: 0.6578
# Epoch 46: val_accuracy did not improve from 0.57253
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 460ms/step - accuracy: 0.5780 - loss: 0.6578 - val_accuracy: 0.5725 - val_loss: 0.7426 - learning_rate: 0.0010
# Epoch 47/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.5846 - loss: 0.6426
# Epoch 47: val_accuracy did not improve from 0.57253
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 460ms/step - accuracy: 0.5846 - loss: 0.6426 - val_accuracy: 0.5683 - val_loss: 0.7232 - learning_rate: 0.0010
# Epoch 48/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.5899 - loss: 0.6119
# Epoch 48: val_accuracy did not improve from 0.57253
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 109s 465ms/step - accuracy: 0.5899 - loss: 0.6120 - val_accuracy: 0.5637 - val_loss: 0.8056 - learning_rate: 0.0010
# Epoch 49/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.5771 - loss: 0.6493
# Epoch 49: val_accuracy did not improve from 0.57253
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 110s 468ms/step - accuracy: 0.5771 - loss: 0.6493 - val_accuracy: 0.5637 - val_loss: 0.7892 - learning_rate: 0.0010
# Epoch 50/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.5803 - loss: 0.6199
# Epoch 50: val_accuracy did not improve from 0.57253
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 110s 468ms/step - accuracy: 0.5803 - loss: 0.6199 - val_accuracy: 0.5693 - val_loss: 0.7264 - learning_rate: 0.0010
# Epoch 51/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.5946 - loss: 0.5951
# Epoch 51: val_accuracy did not improve from 0.57253
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 109s 462ms/step - accuracy: 0.5945 - loss: 0.5952 - val_accuracy: 0.5349 - val_loss: 0.8310 - learning_rate: 0.0010
# Epoch 52/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.5971 - loss: 0.6019
# Epoch 52: val_accuracy did not improve from 0.57253
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 459ms/step - accuracy: 0.5971 - loss: 0.6019 - val_accuracy: 0.5304 - val_loss: 0.9350 - learning_rate: 0.0010
# Epoch 53/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.6049 - loss: 0.5947
# Epoch 53: val_accuracy did not improve from 0.57253
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 109s 463ms/step - accuracy: 0.6049 - loss: 0.5947 - val_accuracy: 0.5643 - val_loss: 0.7985 - learning_rate: 0.0010
# Epoch 54/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.6005 - loss: 0.5671
# Epoch 54: val_accuracy did not improve from 0.57253
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 110s 469ms/step - accuracy: 0.6005 - loss: 0.5672 - val_accuracy: 0.5205 - val_loss: 0.7984 - learning_rate: 0.0010
# Epoch 55/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.6269 - loss: 0.5473
# Epoch 55: val_accuracy improved from 0.57253 to 0.63840, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 460ms/step - accuracy: 0.6270 - loss: 0.5472 - val_accuracy: 0.6384 - val_loss: 0.5857 - learning_rate: 1.0000e-04
# Epoch 56/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.6477 - loss: 0.4793
# Epoch 56: val_accuracy improved from 0.63840 to 0.64080, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 109s 464ms/step - accuracy: 0.6477 - loss: 0.4794 - val_accuracy: 0.6408 - val_loss: 0.5842 - learning_rate: 1.0000e-04
# Epoch 57/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.6365 - loss: 0.5044
# Epoch 57: val_accuracy did not improve from 0.64080
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 456ms/step - accuracy: 0.6365 - loss: 0.5044 - val_accuracy: 0.6341 - val_loss: 0.5766 - learning_rate: 1.0000e-04
# Epoch 58/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.6437 - loss: 0.4880
# Epoch 58: val_accuracy improved from 0.64080 to 0.64160, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 459ms/step - accuracy: 0.6437 - loss: 0.4880 - val_accuracy: 0.6416 - val_loss: 0.5858 - learning_rate: 1.0000e-04
# Epoch 59/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.6431 - loss: 0.4800
# Epoch 59: val_accuracy did not improve from 0.64160
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 109s 466ms/step - accuracy: 0.6431 - loss: 0.4800 - val_accuracy: 0.6405 - val_loss: 0.5815 - learning_rate: 1.0000e-04
# Epoch 60/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.6447 - loss: 0.4846
# Epoch 60: val_accuracy did not improve from 0.64160
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 460ms/step - accuracy: 0.6447 - loss: 0.4846 - val_accuracy: 0.6373 - val_loss: 0.5823 - learning_rate: 1.0000e-04
# Epoch 61/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.6518 - loss: 0.4837
# Epoch 61: val_accuracy did not improve from 0.64160
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 460ms/step - accuracy: 0.6518 - loss: 0.4837 - val_accuracy: 0.6352 - val_loss: 0.5764 - learning_rate: 1.0000e-04
# Epoch 62/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.6491 - loss: 0.4788
# Epoch 62: val_accuracy did not improve from 0.64160
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 462ms/step - accuracy: 0.6491 - loss: 0.4788 - val_accuracy: 0.6408 - val_loss: 0.5773 - learning_rate: 1.0000e-04
# Epoch 63/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.6505 - loss: 0.4792
# Epoch 63: val_accuracy did not improve from 0.64160
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 461ms/step - accuracy: 0.6505 - loss: 0.4791 - val_accuracy: 0.6408 - val_loss: 0.5782 - learning_rate: 1.0000e-04
# Epoch 64/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.6506 - loss: 0.4741
# Epoch 64: val_accuracy improved from 0.64160 to 0.64933, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 461ms/step - accuracy: 0.6506 - loss: 0.4742 - val_accuracy: 0.6493 - val_loss: 0.5794 - learning_rate: 1.0000e-04
# Epoch 65/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.6529 - loss: 0.4698
# Epoch 65: val_accuracy did not improve from 0.64933
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 462ms/step - accuracy: 0.6529 - loss: 0.4698 - val_accuracy: 0.6464 - val_loss: 0.5819 - learning_rate: 1.0000e-04
# Epoch 66/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.6571 - loss: 0.4689
# Epoch 66: val_accuracy did not improve from 0.64933
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 461ms/step - accuracy: 0.6571 - loss: 0.4689 - val_accuracy: 0.6488 - val_loss: 0.5712 - learning_rate: 1.0000e-04
# Epoch 67/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.6479 - loss: 0.4625
# Epoch 67: val_accuracy did not improve from 0.64933
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 461ms/step - accuracy: 0.6479 - loss: 0.4626 - val_accuracy: 0.6421 - val_loss: 0.5743 - learning_rate: 1.0000e-04
# Epoch 68/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.6491 - loss: 0.4646
# Epoch 68: val_accuracy did not improve from 0.64933
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 109s 464ms/step - accuracy: 0.6491 - loss: 0.4646 - val_accuracy: 0.6488 - val_loss: 0.5761 - learning_rate: 1.0000e-04
# Epoch 69/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.6525 - loss: 0.4587
# Epoch 69: val_accuracy did not improve from 0.64933
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 109s 463ms/step - accuracy: 0.6525 - loss: 0.4587 - val_accuracy: 0.6467 - val_loss: 0.5764 - learning_rate: 1.0000e-04
# Epoch 70/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.6545 - loss: 0.4728
# Epoch 70: val_accuracy did not improve from 0.64933
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 460ms/step - accuracy: 0.6545 - loss: 0.4728 - val_accuracy: 0.6464 - val_loss: 0.5730 - learning_rate: 1.0000e-04
# Epoch 71/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.6595 - loss: 0.4642
# Epoch 71: val_accuracy did not improve from 0.64933
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 454ms/step - accuracy: 0.6595 - loss: 0.4642 - val_accuracy: 0.6477 - val_loss: 0.5817 - learning_rate: 1.0000e-04
# Epoch 72/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.6531 - loss: 0.4531
# Epoch 72: val_accuracy improved from 0.64933 to 0.65040, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 460ms/step - accuracy: 0.6531 - loss: 0.4531 - val_accuracy: 0.6504 - val_loss: 0.5801 - learning_rate: 1.0000e-04
# Epoch 73/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.6576 - loss: 0.4571
# Epoch 73: val_accuracy did not improve from 0.65040
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 457ms/step - accuracy: 0.6575 - loss: 0.4571 - val_accuracy: 0.6411 - val_loss: 0.5701 - learning_rate: 1.0000e-04
# Epoch 74/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.6567 - loss: 0.4715
# Epoch 74: val_accuracy improved from 0.65040 to 0.65547, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 461ms/step - accuracy: 0.6567 - loss: 0.4714 - val_accuracy: 0.6555 - val_loss: 0.5768 - learning_rate: 1.0000e-04
# Epoch 75/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.6612 - loss: 0.4547
# Epoch 75: val_accuracy did not improve from 0.65547
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 455ms/step - accuracy: 0.6612 - loss: 0.4547 - val_accuracy: 0.6483 - val_loss: 0.5738 - learning_rate: 1.0000e-04
# Epoch 76/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.6584 - loss: 0.4513
# Epoch 76: val_accuracy did not improve from 0.65547
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 460ms/step - accuracy: 0.6584 - loss: 0.4513 - val_accuracy: 0.6493 - val_loss: 0.5739 - learning_rate: 1.0000e-04
# Epoch 77/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.6573 - loss: 0.4586
# Epoch 77: val_accuracy did not improve from 0.65547
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 458ms/step - accuracy: 0.6573 - loss: 0.4586 - val_accuracy: 0.6413 - val_loss: 0.5672 - learning_rate: 1.0000e-04
# Epoch 78/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.6610 - loss: 0.4507
# Epoch 78: val_accuracy did not improve from 0.65547
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 452ms/step - accuracy: 0.6610 - loss: 0.4508 - val_accuracy: 0.6501 - val_loss: 0.5909 - learning_rate: 1.0000e-04
# Epoch 79/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.6524 - loss: 0.4554
# Epoch 79: val_accuracy did not improve from 0.65547
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 453ms/step - accuracy: 0.6524 - loss: 0.4554 - val_accuracy: 0.6517 - val_loss: 0.5727 - learning_rate: 1.0000e-04
# Epoch 80/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.6536 - loss: 0.4530
# Epoch 80: val_accuracy did not improve from 0.65547
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 456ms/step - accuracy: 0.6537 - loss: 0.4530 - val_accuracy: 0.6515 - val_loss: 0.5795 - learning_rate: 1.0000e-04
# Epoch 81/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.6618 - loss: 0.4478
# Epoch 81: val_accuracy did not improve from 0.65547
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 457ms/step - accuracy: 0.6618 - loss: 0.4478 - val_accuracy: 0.6477 - val_loss: 0.5773 - learning_rate: 1.0000e-04
# Epoch 82/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.6568 - loss: 0.4474
# Epoch 82: val_accuracy did not improve from 0.65547
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 457ms/step - accuracy: 0.6568 - loss: 0.4474 - val_accuracy: 0.6440 - val_loss: 0.5676 - learning_rate: 1.0000e-04
# Epoch 83/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.6630 - loss: 0.4391
# Epoch 83: val_accuracy improved from 0.65547 to 0.65733, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 459ms/step - accuracy: 0.6630 - loss: 0.4392 - val_accuracy: 0.6573 - val_loss: 0.5662 - learning_rate: 1.0000e-04
# Epoch 84/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.6685 - loss: 0.4284
# Epoch 84: val_accuracy did not improve from 0.65733
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 454ms/step - accuracy: 0.6685 - loss: 0.4285 - val_accuracy: 0.6571 - val_loss: 0.5764 - learning_rate: 1.0000e-04
# Epoch 85/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.6696 - loss: 0.4354
# Epoch 85: val_accuracy did not improve from 0.65733
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 461ms/step - accuracy: 0.6696 - loss: 0.4355 - val_accuracy: 0.6565 - val_loss: 0.5725 - learning_rate: 1.0000e-04
# Epoch 86/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.6576 - loss: 0.4425
# Epoch 86: val_accuracy did not improve from 0.65733
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 462ms/step - accuracy: 0.6576 - loss: 0.4425 - val_accuracy: 0.6568 - val_loss: 0.5731 - learning_rate: 1.0000e-04
# Epoch 87/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.6651 - loss: 0.4441
# Epoch 87: val_accuracy improved from 0.65733 to 0.66373, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 454ms/step - accuracy: 0.6651 - loss: 0.4441 - val_accuracy: 0.6637 - val_loss: 0.5648 - learning_rate: 1.0000e-04
# Epoch 88/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.6744 - loss: 0.4343
# Epoch 88: val_accuracy did not improve from 0.66373
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 109s 464ms/step - accuracy: 0.6744 - loss: 0.4343 - val_accuracy: 0.6581 - val_loss: 0.5550 - learning_rate: 1.0000e-04
# Epoch 89/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.6634 - loss: 0.4445
# Epoch 89: val_accuracy did not improve from 0.66373
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 458ms/step - accuracy: 0.6634 - loss: 0.4445 - val_accuracy: 0.6453 - val_loss: 0.5593 - learning_rate: 1.0000e-04
# Epoch 90/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.6613 - loss: 0.4334
# Epoch 90: val_accuracy did not improve from 0.66373
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 459ms/step - accuracy: 0.6613 - loss: 0.4334 - val_accuracy: 0.6517 - val_loss: 0.5566 - learning_rate: 1.0000e-04
# Epoch 91/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.6705 - loss: 0.4307
# Epoch 91: val_accuracy did not improve from 0.66373
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 455ms/step - accuracy: 0.6705 - loss: 0.4307 - val_accuracy: 0.6576 - val_loss: 0.5730 - learning_rate: 1.0000e-04
# Epoch 92/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.6703 - loss: 0.4288
# Epoch 92: val_accuracy did not improve from 0.66373
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 110s 470ms/step - accuracy: 0.6703 - loss: 0.4288 - val_accuracy: 0.6589 - val_loss: 0.5702 - learning_rate: 1.0000e-04
# Epoch 93/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.6660 - loss: 0.4468
# Epoch 93: val_accuracy did not improve from 0.66373
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 110s 469ms/step - accuracy: 0.6660 - loss: 0.4467 - val_accuracy: 0.6560 - val_loss: 0.5694 - learning_rate: 1.0000e-04
# Epoch 94/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.6698 - loss: 0.4196
# Epoch 94: val_accuracy did not improve from 0.66373
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 117s 498ms/step - accuracy: 0.6698 - loss: 0.4196 - val_accuracy: 0.6576 - val_loss: 0.5682 - learning_rate: 1.0000e-04
# Epoch 95/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.6614 - loss: 0.4477
# Epoch 95: val_accuracy did not improve from 0.66373
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 117s 500ms/step - accuracy: 0.6615 - loss: 0.4476 - val_accuracy: 0.6629 - val_loss: 0.5689 - learning_rate: 1.0000e-04
# Epoch 96/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.6662 - loss: 0.4323
# Epoch 96: val_accuracy did not improve from 0.66373
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 114s 485ms/step - accuracy: 0.6662 - loss: 0.4323 - val_accuracy: 0.6525 - val_loss: 0.5750 - learning_rate: 1.0000e-04
# Epoch 97/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.6681 - loss: 0.4315
# Epoch 97: val_accuracy did not improve from 0.66373
#
# Epoch 97: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 116s 493ms/step - accuracy: 0.6681 - loss: 0.4315 - val_accuracy: 0.6635 - val_loss: 0.5808 - learning_rate: 1.0000e-04
# Epoch 98/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.6748 - loss: 0.4133
# Epoch 98: val_accuracy did not improve from 0.66373
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 116s 493ms/step - accuracy: 0.6748 - loss: 0.4133 - val_accuracy: 0.6635 - val_loss: 0.5502 - learning_rate: 1.0000e-05
# Epoch 99/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.6787 - loss: 0.4123
# Epoch 99: val_accuracy improved from 0.66373 to 0.66640, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 116s 496ms/step - accuracy: 0.6787 - loss: 0.4123 - val_accuracy: 0.6664 - val_loss: 0.5506 - learning_rate: 1.0000e-05
# Epoch 100/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.6766 - loss: 0.4164
# Epoch 100: val_accuracy did not improve from 0.66640
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 115s 491ms/step - accuracy: 0.6766 - loss: 0.4164 - val_accuracy: 0.6643 - val_loss: 0.5517 - learning_rate: 1.0000e-05
# Epoch 101/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.6769 - loss: 0.4130
# Epoch 101: val_accuracy did not improve from 0.66640
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 113s 481ms/step - accuracy: 0.6769 - loss: 0.4130 - val_accuracy: 0.6635 - val_loss: 0.5512 - learning_rate: 1.0000e-05
# Epoch 102/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.6725 - loss: 0.4065
# Epoch 102: val_accuracy did not improve from 0.66640
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 114s 485ms/step - accuracy: 0.6726 - loss: 0.4065 - val_accuracy: 0.6637 - val_loss: 0.5509 - learning_rate: 1.0000e-05
# Epoch 103/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.6784 - loss: 0.4250
# Epoch 103: val_accuracy did not improve from 0.66640
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 113s 480ms/step - accuracy: 0.6784 - loss: 0.4249 - val_accuracy: 0.6621 - val_loss: 0.5504 - learning_rate: 1.0000e-05
# Epoch 104/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.6719 - loss: 0.4253
# Epoch 104: val_accuracy did not improve from 0.66640
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 115s 489ms/step - accuracy: 0.6719 - loss: 0.4253 - val_accuracy: 0.6640 - val_loss: 0.5509 - learning_rate: 1.0000e-05
# Epoch 105/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.6720 - loss: 0.4101
# Epoch 105: val_accuracy did not improve from 0.66640
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 114s 487ms/step - accuracy: 0.6721 - loss: 0.4101 - val_accuracy: 0.6656 - val_loss: 0.5513 - learning_rate: 1.0000e-05
# Epoch 106/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.6821 - loss: 0.4073
# Epoch 106: val_accuracy did not improve from 0.66640
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 114s 483ms/step - accuracy: 0.6821 - loss: 0.4073 - val_accuracy: 0.6651 - val_loss: 0.5539 - learning_rate: 1.0000e-05
# Epoch 107/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.6832 - loss: 0.4044
# Epoch 107: val_accuracy did not improve from 0.66640
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 113s 481ms/step - accuracy: 0.6832 - loss: 0.4044 - val_accuracy: 0.6661 - val_loss: 0.5532 - learning_rate: 1.0000e-05
# Epoch 108/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.6630 - loss: 0.4237
# Epoch 108: val_accuracy did not improve from 0.66640
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 114s 486ms/step - accuracy: 0.6631 - loss: 0.4237 - val_accuracy: 0.6637 - val_loss: 0.5521 - learning_rate: 1.0000e-05
# Epoch 109/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.6762 - loss: 0.4099
# Epoch 109: val_accuracy improved from 0.66640 to 0.66667, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 115s 491ms/step - accuracy: 0.6762 - loss: 0.4099 - val_accuracy: 0.6667 - val_loss: 0.5527 - learning_rate: 1.0000e-05
# Epoch 110/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.6805 - loss: 0.4106
# Epoch 110: val_accuracy improved from 0.66667 to 0.66747, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 117s 500ms/step - accuracy: 0.6805 - loss: 0.4106 - val_accuracy: 0.6675 - val_loss: 0.5526 - learning_rate: 1.0000e-05
# Epoch 111/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.6818 - loss: 0.4029
# Epoch 111: val_accuracy did not improve from 0.66747
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 115s 490ms/step - accuracy: 0.6818 - loss: 0.4030 - val_accuracy: 0.6669 - val_loss: 0.5522 - learning_rate: 1.0000e-05
# Epoch 112/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.6804 - loss: 0.4160
# Epoch 112: val_accuracy did not improve from 0.66747
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 113s 482ms/step - accuracy: 0.6804 - loss: 0.4160 - val_accuracy: 0.6653 - val_loss: 0.5532 - learning_rate: 1.0000e-05
# Epoch 113/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.6829 - loss: 0.4052
# Epoch 113: val_accuracy did not improve from 0.66747
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 117s 496ms/step - accuracy: 0.6829 - loss: 0.4053 - val_accuracy: 0.6637 - val_loss: 0.5519 - learning_rate: 1.0000e-05
# Epoch 114/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.6821 - loss: 0.4083
# Epoch 114: val_accuracy did not improve from 0.66747
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 112s 478ms/step - accuracy: 0.6821 - loss: 0.4083 - val_accuracy: 0.6653 - val_loss: 0.5534 - learning_rate: 1.0000e-05
# Epoch 115/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.6742 - loss: 0.4096
# Epoch 115: val_accuracy did not improve from 0.66747
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 114s 486ms/step - accuracy: 0.6742 - loss: 0.4096 - val_accuracy: 0.6664 - val_loss: 0.5533 - learning_rate: 1.0000e-05
# Epoch 116/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.6766 - loss: 0.4175
# Epoch 116: val_accuracy did not improve from 0.66747
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 115s 489ms/step - accuracy: 0.6766 - loss: 0.4175 - val_accuracy: 0.6648 - val_loss: 0.5530 - learning_rate: 1.0000e-05
# Epoch 117/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.6792 - loss: 0.4121
# Epoch 117: val_accuracy did not improve from 0.66747
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 114s 487ms/step - accuracy: 0.6792 - loss: 0.4120 - val_accuracy: 0.6659 - val_loss: 0.5541 - learning_rate: 1.0000e-05
# Epoch 118/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.6791 - loss: 0.4100
# Epoch 118: val_accuracy did not improve from 0.66747
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 114s 485ms/step - accuracy: 0.6791 - loss: 0.4100 - val_accuracy: 0.6651 - val_loss: 0.5535 - learning_rate: 1.0000e-05
# Epoch 119/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.6796 - loss: 0.4115
# Epoch 119: val_accuracy did not improve from 0.66747
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 115s 488ms/step - accuracy: 0.6795 - loss: 0.4115 - val_accuracy: 0.6664 - val_loss: 0.5519 - learning_rate: 1.0000e-05
# Epoch 120/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.6751 - loss: 0.4187
# Epoch 120: val_accuracy did not improve from 0.66747
#
# Epoch 120: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 113s 483ms/step - accuracy: 0.6751 - loss: 0.4186 - val_accuracy: 0.6635 - val_loss: 0.5494 - learning_rate: 1.0000e-05
# Epoch 121/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.6776 - loss: 0.4069
# Epoch 121: val_accuracy did not improve from 0.66747
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 114s 485ms/step - accuracy: 0.6776 - loss: 0.4069 - val_accuracy: 0.6648 - val_loss: 0.5505 - learning_rate: 1.0000e-06
# Epoch 122/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.6832 - loss: 0.4046
# Epoch 122: val_accuracy did not improve from 0.66747
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 115s 489ms/step - accuracy: 0.6832 - loss: 0.4046 - val_accuracy: 0.6661 - val_loss: 0.5511 - learning_rate: 1.0000e-06
# Epoch 123/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.6785 - loss: 0.4013
# Epoch 123: val_accuracy did not improve from 0.66747
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 113s 480ms/step - accuracy: 0.6785 - loss: 0.4013 - val_accuracy: 0.6656 - val_loss: 0.5511 - learning_rate: 1.0000e-06
# Epoch 124/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.6779 - loss: 0.4003
# Epoch 124: val_accuracy did not improve from 0.66747
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 114s 485ms/step - accuracy: 0.6779 - loss: 0.4004 - val_accuracy: 0.6661 - val_loss: 0.5511 - learning_rate: 1.0000e-06
# Epoch 125/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.6740 - loss: 0.4065
# Epoch 125: val_accuracy did not improve from 0.66747
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 114s 487ms/step - accuracy: 0.6740 - loss: 0.4065 - val_accuracy: 0.6656 - val_loss: 0.5508 - learning_rate: 1.0000e-06
# Epoch 126/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.6812 - loss: 0.4049
# Epoch 126: val_accuracy did not improve from 0.66747
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 115s 492ms/step - accuracy: 0.6812 - loss: 0.4049 - val_accuracy: 0.6643 - val_loss: 0.5499 - learning_rate: 1.0000e-06
# Epoch 127/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.6888 - loss: 0.3901
# Epoch 127: val_accuracy did not improve from 0.66747
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 115s 490ms/step - accuracy: 0.6888 - loss: 0.3902 - val_accuracy: 0.6664 - val_loss: 0.5516 - learning_rate: 1.0000e-06
# Epoch 128/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.6814 - loss: 0.3980
# Epoch 128: val_accuracy did not improve from 0.66747
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 115s 490ms/step - accuracy: 0.6814 - loss: 0.3981 - val_accuracy: 0.6653 - val_loss: 0.5515 - learning_rate: 1.0000e-06
# Epoch 129/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.6824 - loss: 0.4053
# Epoch 129: val_accuracy did not improve from 0.66747
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 116s 494ms/step - accuracy: 0.6824 - loss: 0.4052 - val_accuracy: 0.6675 - val_loss: 0.5516 - learning_rate: 1.0000e-06
# Epoch 130/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.6778 - loss: 0.4061
# Epoch 130: val_accuracy did not improve from 0.66747
#
# Epoch 130: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 114s 487ms/step - accuracy: 0.6778 - loss: 0.4061 - val_accuracy: 0.6661 - val_loss: 0.5524 - learning_rate: 1.0000e-06
# Epoch 131/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.6721 - loss: 0.4156
# Epoch 131: val_accuracy did not improve from 0.66747
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 116s 495ms/step - accuracy: 0.6722 - loss: 0.4156 - val_accuracy: 0.6651 - val_loss: 0.5506 - learning_rate: 1.0000e-07
# Epoch 132/150
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.6754 - loss: 0.4112
# Epoch 132: val_accuracy did not improve from 0.66747
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 115s 488ms/step - accuracy: 0.6755 - loss: 0.4112 - val_accuracy: 0.6664 - val_loss: 0.5514 - learning_rate: 1.0000e-07
# Epoch 132: early stopping
# Best validation model: epoch 110  - val_accuracy 0.6674666404724121

# %%
import matplotlib.pyplot as plt

def plot_results(history):
    
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    
    
    epochs_range = range(1, len(acc) + 1)

    plt.figure(figsize=(16, 6))

    # --- GRAFICO 1: ACCURACY
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy', color='blue', marker='o')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy', color='red', marker='o')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epoche')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')
    plt.grid(True)

    # --- GRAFICO 2: LOSS 
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss', color='blue', linestyle='--')
    plt.plot(epochs_range, val_loss, label='Validation Loss', color='red', linestyle='--')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoche')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')
    plt.grid(True)

    plt.show()


plot_results(h)

# %% [markdown]
# #### Validation
# Compute validation metrics.

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

def draw_confusion_matrix(cm, categories):
    # Draw confusion matrix
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    cm = cm.astype('float') / np.maximum(cm.sum(axis=1)[:, np.newaxis], np.finfo(np.float64).eps)
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.colormaps['Blues'])
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=list(categories.values()), yticklabels=list(categories.values()), ylabel='Annotation', xlabel='Prediction')
    # Rotate the tick labels and set their alignment
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Loop over data dimensions and create text annotations
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], '.2f'), ha="center", va="center", color="white" if cm[i, j] > thresh else "black", fontsize=int(20-pow(len(categories), 0.5)))
    fig.tight_layout()
    plt.show()

# %%
import numpy as np

model.load_weights('model.keras')
y_true, y_pred = [], []
for ann in anns_valid:
    # Load image
    image = load_geoimage(ann.filename)
    image = image.astype(np.float64)
    image = (image - train_mean) / (train_std + 1e-7)
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        y_true.append(obj_pred.category)
        y_pred.append(pred_category)

# %%
from sklearn.metrics import confusion_matrix

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=list(categories.values()))
draw_confusion_matrix(cm, categories)

# %%
import numpy as np

# Compute the accuracy
correct_samples_class = np.diag(cm).astype(float)
total_samples_class = np.sum(cm, axis=1).astype(float)
total_predicts_class = np.sum(cm, axis=0).astype(float)
print('Mean Accuracy: %.3f%%' % (np.sum(correct_samples_class) / np.sum(total_samples_class) * 100))
acc = correct_samples_class / np.maximum(total_samples_class, np.finfo(np.float64).eps)
print('Mean Recall: %.3f%%' % (acc.mean() * 100))
acc = correct_samples_class / np.maximum(total_predicts_class, np.finfo(np.float64).eps)
print('Mean Precision: %.3f%%' % (acc.mean() * 100))
for idx in range(len(categories)):
    # True/False Positives (TP/FP) refer to the number of predicted positives that were correct/incorrect.
    # True/False Negatives (TN/FN) refer to the number of predicted negatives that were correct/incorrect.
    tp = cm[idx, idx]
    fp = sum(cm[:, idx]) - tp
    fn = sum(cm[idx, :]) - tp
    tn = sum(np.delete(sum(cm) - cm[idx, :], idx))
    # True Positive Rate: proportion of real positive cases that were correctly predicted as positive.
    recall = tp / np.maximum(tp+fn, np.finfo(np.float64).eps)
    # Precision: proportion of predicted positive cases that were truly real positives.
    precision = tp / np.maximum(tp+fp, np.finfo(np.float64).eps)
    # True Negative Rate: proportion of real negative cases that were correctly predicted as negative.
    specificity = tn / np.maximum(tn+fp, np.finfo(np.float64).eps)
    # Dice coefficient refers to two times the intersection of two sets divided by the sum of their areas.
    # Dice = 2 |A∩B| / (|A|+|B|) = 2 TP / (2 TP + FP + FN)
    f1_score = 2 * ((precision * recall) / np.maximum(precision+recall, np.finfo(np.float64).eps))
    print('> %s: Recall: %.3f%% Precision: %.3f%% Specificity: %.3f%% Dice: %.3f%%' % (list(categories.values())[idx], recall*100, precision*100, specificity*100, f1_score*100))
# Out:
# Mean Accuracy: 66.747%
# Mean Recall: 69.499%
# Mean Precision: 63.667%
# > Cargo plane: Recall: 94.488% Precision: 86.957% Specificity: 99.503% Dice: 90.566%
# > Small car: Recall: 81.053% Precision: 81.175% Specificity: 95.948% Dice: 81.114%
# > Bus: Recall: 56.497% Precision: 53.333% Specificity: 94.847% Dice: 54.870%
# > Truck: Recall: 24.208% Precision: 38.909% Specificity: 94.921% Dice: 29.847%
# > Motorboat: Recall: 74.766% Precision: 62.500% Specificity: 97.285% Dice: 68.085%
# > Fishing vessel: Recall: 81.560% Precision: 69.277% Specificity: 98.587% Dice: 74.919%
# > Dump truck: Recall: 61.943% Precision: 47.516% Specificity: 95.176% Dice: 53.779%
# > Excavator: Recall: 76.582% Precision: 66.851% Specificity: 98.330% Dice: 71.386%
# > Building: Recall: 68.289% Precision: 87.679% Specificity: 97.724% Dice: 76.779%
# > Helipad: Recall: 54.545% Precision: 54.545% Specificity: 99.732% Dice: 54.545%
# > Storage tank: Recall: 67.347% Precision: 59.104% Specificity: 96.036% Dice: 62.957%
# > Shipping container: Recall: 76.721% Precision: 65.181% Specificity: 96.372% Dice: 70.482%
# > Pylon: Recall: 85.484% Precision: 54.639% Specificity: 98.807% Dice: 66.667%

# %% [markdown]
# #### Testing
# Try to improve the results provided in the competition.

# %%
import os
import numpy as np

anns = []
for (dirpath, dirnames, filenames) in os.walk('/kaggle/input/datasets/alexferroni/recognition/xview_recognition/xview_test'):
    for filename in filenames:
        relative_path = os.path.join('xview_test', filename)
        image = GenericImage(relative_path)
        image.tile = np.array([0, 0, 224, 224])
        obj = GenericObject()
        obj.bb = (0, 0, 224, 224)
        obj.category = dirpath[dirpath.rfind('/')+1:]
        image.add_object(obj)
        anns.append(image)
print('Number of testing images: ' + str(len(anns)))
# Out:
# Number of testing images: 2365

# %%
import numpy as np

model.load_weights('model.keras')
predictions_data = {"images": {}, "annotations": {}}
for idx, ann in enumerate(anns):
    image_data = {"image_id": ann.filename.split('/')[-1], "filename": ann.filename, "width": int(ann.tile[2]), "height": int(ann.tile[3])}
    predictions_data["images"][idx] = image_data
    # Load image
    image = load_geoimage(ann.filename)
    image = image.astype(np.float64)
    image = (image - train_mean) / (train_std + 1e-7)
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        annotation_data = {"image_id": ann.filename.split('/')[-1], "category_id": pred_category, "bbox": [int(x) for x in obj_pred.bb]}
        predictions_data["annotations"][idx] = annotation_data

# %%
with open("prediction.json", "w") as outfile:
    json.dump(predictions_data, outfile)

# %% [markdown]
# ## Assignment: Image recognition
# - Alumno 1: Alex Ferroni
# - Alumno 2: Vittorio Alberto Gianfrate
# - Alumno 3:
#
# The goals of the assignment are:
# * Develop proficiency in using Tensorflow/Keras for training Neural Nets (NNs).
# * Put into practice the acquired knowledge to optimize the parameters and architecture of a feedforward Neural Net (ffNN), in the context of an image recognition problem.
# * Put into practice NNs specially conceived for analysing images. Design and optimize the parameters of a Convolutional Neural Net (CNN) to deal with previous task.
# * Train popular architectures from scratch (e.g., GoogLeNet, VGG, ResNet, ...), and compare the results with the ones provided by their pre-trained versions using transfer learning.
#
# Follow the link below to download the classification data set  “xview_recognition”: [https://drive.upm.es/s/2DDPE2zHw5dbM3G](https://drive.upm.es/s/2DDPE2zHw5dbM3G)

# %%
# !pip install rasterio
# Out:
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (1.5.0)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio) (25.4.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from rasterio) (2026.1.4)
# Requirement already satisfied: click!=8.2.*,>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio) (8.3.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.0.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio) (3.3.1)

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# 2026-03-05 19:39:48.200861: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772739588.403273      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772739588.464262      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772739588.938113      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772739588.938162      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772739588.938167      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772739588.938171      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import uuid
import numpy as np

class GenericObject:
    """
    Generic object data.
    """
    def __init__(self):
        self.id = uuid.uuid4()
        self.bb = (-1, -1, -1, -1)
        self.category= -1
        self.score = -1

class GenericImage:
    """
    Generic image data.
    """
    def __init__(self, filename):
        self.filename = filename
        self.tile = np.array([-1, -1, -1, -1])  # (pt_x, pt_y, pt_x+width, pt_y+height)
        self.objects = list([])

    def add_object(self, obj: GenericObject):
        self.objects.append(obj)

# %%
categories = {0: 'Cargo plane', 1: 'Small car', 2: 'Bus', 3: 'Truck', 4: 'Motorboat', 5: 'Fishing vessel', 6: 'Dump truck', 7: 'Excavator', 8: 'Building', 9: 'Helipad', 10: 'Storage tank', 11: 'Shipping container', 12: 'Pylon'}

# %%
import warnings
import rasterio
import numpy as np
import os
import cv2

def load_geoimage(filename):
    warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
    base_path = '/kaggle/input/datasets/vittoriogianfrate/recognition/xview_recognition/'
    
    src_raster = rasterio.open(base_path + filename, 'r')
    # --------------------

    # RasterIO to OpenCV
    input_type = src_raster.profile['dtype']
    input_channels = src_raster.count
    img = np.zeros((src_raster.height, src_raster.width, src_raster.count), dtype=input_type)
    for band in range(input_channels):
        img[:, :, band] = src_raster.read(band+1)
   
    return img

# %% [markdown]
# #### Training
# Design and train a ffNN to deal with the “xview_recognition” classification task.

# %%
import json
import os


json_file = '/kaggle/input/datasets/vittoriogianfrate/recognition/xview_recognition/xview_ann_train.json'

print(f"Caricamento annotazioni da: {json_file}")

with open(json_file) as ifs:
    json_data = json.load(ifs)
    
print("Annotazioni caricate con successo!")
# Out:
# Caricamento annotazioni da: /kaggle/input/datasets/alexferroni/recognition/xview_recognition/xview_ann_train.json
# Annotazioni caricate con successo!

# %%
import numpy as np

counts = dict.fromkeys(categories.values(), 0)
anns = []
for json_img, json_ann in zip(json_data['images'].values(), json_data['annotations'].values()):
    image = GenericImage(json_img['filename'])
    image.tile = np.array([0, 0, json_img['width'], json_img['height']])
    obj = GenericObject()
    obj.bb = (int(json_ann['bbox'][0]), int(json_ann['bbox'][1]), int(json_ann['bbox'][2]), int(json_ann['bbox'][3]))
    obj.category = json_ann['category_id']
    # Resampling strategy to reduce training time
    counts[obj.category] += 1
    image.add_object(obj)
    anns.append(image)
print(counts)
# Out:
# {'Cargo plane': 635, 'Small car': 3324, 'Bus': 1768, 'Truck': 2210, 'Motorboat': 1069, 'Fishing vessel': 706, 'Dump truck': 1236, 'Excavator': 789, 'Building': 3594, 'Helipad': 111, 'Storage tank': 1469, 'Shipping container': 1523, 'Pylon': 312}

# %%
from sklearn.model_selection import train_test_split
labels_list = [x.objects[0].category for x in anns]
anns_train, anns_valid = train_test_split(anns, test_size=0.2, random_state=1, shuffle=True,stratify=labels_list)
print('Number of training images: ' + str(len(anns_train)))
print('Number of validation images: ' + str(len(anns_valid)))
# Out:
# Number of training images: 14996
# Number of validation images: 3750

# %%
train_mean = [69.41887293,56.97948485,49.47711569]
train_std = [51.61769765,44.6239849 ,40.89414141]

# %%
import numpy as np

pixel_sum = np.zeros(3)
pixel_sq_sum = np.zeros(3)
pixel_count = 0


for ann in anns_train:
    
    img = load_geoimage(ann.filename) 
    img = img.astype(np.float64)
    pixel_sum += np.sum(img, axis=(0, 1))
    pixel_sq_sum += np.sum(img ** 2, axis=(0, 1))
    
    pixel_count += img.shape[0] * img.shape[1]

#COmpute mean and standard deviation
train_mean = pixel_sum / pixel_count
train_var = (pixel_sq_sum / pixel_count) - (train_mean ** 2)
train_var = np.maximum(train_var, 0)
train_std = np.sqrt(train_var)

print(f"Training Mean: {train_mean}")
print(f"Training Std: {train_std}")
# Out:
# Training Mean: [69.41887293 56.97948485 49.47711569]
# Training Std: [51.61769765 44.6239849  40.89414141]

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, Input
from tensorflow.keras.applications import EfficientNetB0

data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.5),  # Rotazione libera
    layers.RandomZoom(0.2),      # Zoom casuale
    layers.RandomContrast(0.2),  # Variazione contrasto
])

# 2. Caricamento del modello pre-addestrato (Base)
base_model = EfficientNetB0(
    weights='imagenet', 
    include_top=False, 
    input_shape=(224, 224, 3)
)

base_model.trainable = False 

inputs = Input(shape=(224, 224, 3))
x = data_augmentation(inputs)

x = base_model(x, training=False) 
x = layers.GlobalAveragePooling2D()(x)
x = layers.BatchNormalization()(x) # Aiuta a stabilizzare
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(13, activation='softmax')(x)

model = models.Model(inputs, outputs)

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
from sklearn.utils import class_weight
import numpy as np

train_labels = [ann.objects[0].category for ann in anns_train]
unique_classes = np.unique(train_labels)

weights_values = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=unique_classes,
    y=train_labels
)

name_to_id = {v: k for k, v in categories.items()}

alpha_array = np.ones(len(categories), dtype=np.float32)

for class_name, weight in zip(unique_classes, weights_values):
    if class_name in name_to_id:
        class_id = name_to_id[class_name]
        alpha_array[class_id] = weight
        print(f"Classe: {class_name:<20} ID: {class_id:<3} Peso: {weight:.4f}")

alpha_list = alpha_array.tolist()

print("\nLISTA DEFINITIVA PRONTA PER FOCAL LOSS:", alpha_list)
# Out:
# Classe: Building             ID: 8   Peso: 0.4012
# Classe: Bus                  ID: 2   Peso: 0.8158
# Classe: Cargo plane          ID: 0   Peso: 2.2707
# Classe: Dump truck           ID: 6   Peso: 1.1664
# Classe: Excavator            ID: 7   Peso: 1.8281
# Classe: Fishing vessel       ID: 5   Peso: 2.0417
# Classe: Helipad              ID: 9   Peso: 12.9611
# Classe: Motorboat            ID: 4   Peso: 1.3492
# Classe: Pylon                ID: 12  Peso: 4.6142
# Classe: Shipping container   ID: 11  Peso: 0.9471
# Classe: Small car            ID: 1   Peso: 0.4338
# Classe: Storage tank         ID: 10  Peso: 0.9817
# Classe: Truck                ID: 3   Peso: 0.6525
#
# LISTA DEFINITIVA PRONTA PER FOCAL LOSS: [2.270745038986206, 0.43382418155670166, 0.8157980442047119, 0.6524538993835449, 1.349167823791504, 2.041661024093628, 1.1663684844970703, 1.8281116485595703, 0.4012307822704315, 12.961106300354004, 0.9817348718643188, 0.9470759034156799, 4.614153861999512]

# %%
from tensorflow.keras.optimizers import Adam

# Learning rate is changed to 0.001
opt = Adam(learning_rate=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-8, amsgrad=True, clipnorm=1.0)
model.compile(optimizer=opt, loss=tf.keras.losses.CategoricalFocalCrossentropy(alpha=alpha_list), metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import TerminateOnNaN, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Callbacks
model_checkpoint = ModelCheckpoint('model.keras', monitor='val_accuracy', verbose=1, save_best_only=True)
reduce_lr = ReduceLROnPlateau('val_accuracy', factor=0.1, patience=10, verbose=1,min_lr=1e-7)
early_stop = EarlyStopping('val_accuracy', patience=20, verbose=1)
terminate = TerminateOnNaN()
callbacks = [model_checkpoint, reduce_lr, early_stop, terminate]

# %%
def generator_images(objs, batch_size, do_shuffle=False, mean=None, std=None):
    while True:
        if do_shuffle:
            np.random.shuffle(objs)
        groups = [objs[i:i+batch_size] for i in range(0, len(objs), batch_size)]
        for group in groups:
            images, labels = [], []
            for (filename, obj) in group:
                img = load_geoimage(filename)
                
                images.append(img)
                probabilities = np.zeros(len(categories))
                probabilities[list(categories.values()).index(obj.category)] = 1
                labels.append(probabilities)
            images = np.array(images).astype(np.float32)
            labels = np.array(labels).astype(np.float32)
            yield images, labels

# %%
# Generate the list of objects from annotations
objs_train = [(ann.filename, obj) for ann in anns_train for obj in ann.objects]
objs_valid = [(ann.filename, obj) for ann in anns_valid for obj in ann.objects]
# Generators
batch_size = 64
train_generator = generator_images(objs_train, batch_size, do_shuffle=True, mean=None, std=None)
valid_generator = generator_images(objs_valid, batch_size, do_shuffle=False, mean=None, std=None)

# %%
import math
import numpy as np
import tensorflow as tf

# Calcolo degli step per epoca
train_steps = math.ceil(len(objs_train)/batch_size)
valid_steps = math.ceil(len(objs_valid)/batch_size)

# ==========================================
# FASE 1: Addestramento della "Testa" (Head)
# ==========================================
print('--- FASE 1: Training preliminare (solo ultimi layer) ---')

# Assicuriamoci che il modello base sia congelato
base_model.trainable = False

# Compiliamo con Learning Rate standard (1e-3 o 1e-4)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3), 
    loss=tf.keras.losses.CategoricalFocalCrossentropy(alpha=alpha_list),
    metrics=['accuracy']
)

# Addestriamo per poche epoche (es. 20) per stabilizzare i pesi iniziali
epochs_head = 20
h_head = model.fit(
    train_generator, 
    steps_per_epoch=train_steps, 
    validation_data=valid_generator, 
    validation_steps=valid_steps, 
    epochs=epochs_head, 
    callbacks=callbacks, 
    verbose=1
)

# ==========================================
# FASE 2: Fine-Tuning (Modello completo)
# ==========================================
print('\n--- FASE 2: Fine-Tuning (Sblocco modello base e affinamento) ---')

# 1. Sblocchiamo i pesi del modello pre-addestrato
base_model.trainable = True

# 2. FONDAMENTALE: Ricompiliamo con un Learning Rate molto basso (1e-5)
# Se usassimo un LR alto qui, distruggeremmo le conoscenze pre-addestrate
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5), 
    loss=tf.keras.losses.CategoricalFocalCrossentropy(alpha=alpha_list),
    metrics=['accuracy']
)

# 3. Continuiamo il training
# Aggiungiamo altre 50 epoche (o più, EarlyStopping lo fermerà se necessario)
fine_tune_epochs = 50
total_epochs = epochs_head + fine_tune_epochs

h_fine = model.fit(
    train_generator,
    steps_per_epoch=train_steps,
    validation_data=valid_generator,
    validation_steps=valid_steps,
    epochs=total_epochs,
    initial_epoch=h_head.epoch[-1], # Riparte esattamente da dove ha finito la fase 1
    callbacks=callbacks,
    verbose=1
)

# ==========================================
# Risultati e Miglior Modello
# ==========================================

# Uniamo le storie dei due addestramenti per vedere il grafico completo (opzionale)
acc = h_head.history['accuracy'] + h_fine.history['accuracy']
val_acc = h_head.history['val_accuracy'] + h_fine.history['val_accuracy']
loss = h_head.history['loss'] + h_fine.history['loss']
val_loss = h_head.history['val_loss'] + h_fine.history['val_loss']

# Troviamo il miglior risultato complessivo
best_idx = int(np.argmax(val_acc))
best_value = np.max(val_acc)

print('\nTRAINING COMPLETATO.')
print('Miglior modello salvato alla epoca complessiva: ' + str(best_idx+1))
print('Best val_accuracy raggiunta: ' + str(best_value))
# Out:
# Training model
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1772742553.237354     128 service.cc:152] XLA service 0x7a20440d8a00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1772742553.237415     128 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1772742592.731505     128 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step - accuracy: 0.1531 - loss: 2.2092
# Epoch 1: val_accuracy improved from -inf to 0.15840, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 187s 601ms/step - accuracy: 0.1532 - loss: 2.2085 - val_accuracy: 0.1584 - val_loss: 4.7542 - learning_rate: 0.0010
# Epoch 2/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.2166 - loss: 1.7776
# Epoch 2: val_accuracy improved from 0.15840 to 0.25573, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 112s 477ms/step - accuracy: 0.2166 - loss: 1.7772 - val_accuracy: 0.2557 - val_loss: 1.6615 - learning_rate: 0.0010
# Epoch 3/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.2551 - loss: 1.5729
# Epoch 3: val_accuracy improved from 0.25573 to 0.28747, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 112s 478ms/step - accuracy: 0.2551 - loss: 1.5727 - val_accuracy: 0.2875 - val_loss: 1.7310 - learning_rate: 0.0010
# Epoch 4/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.2768 - loss: 1.5538
# Epoch 4: val_accuracy did not improve from 0.28747
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 113s 481ms/step - accuracy: 0.2768 - loss: 1.5534 - val_accuracy: 0.2816 - val_loss: 1.5169 - learning_rate: 0.0010
# Epoch 5/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - accuracy: 0.3030 - loss: 1.3655
# Epoch 5: val_accuracy did not improve from 0.28747
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 111s 472ms/step - accuracy: 0.3030 - loss: 1.3655 - val_accuracy: 0.2837 - val_loss: 1.4175 - learning_rate: 0.0010
# Epoch 6/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.3175 - loss: 1.3650
# Epoch 6: val_accuracy improved from 0.28747 to 0.32053, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 111s 473ms/step - accuracy: 0.3175 - loss: 1.3649 - val_accuracy: 0.3205 - val_loss: 1.3721 - learning_rate: 0.0010
# Epoch 7/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.3224 - loss: 1.3278
# Epoch 7: val_accuracy did not improve from 0.32053
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 460ms/step - accuracy: 0.3224 - loss: 1.3277 - val_accuracy: 0.2997 - val_loss: 1.3259 - learning_rate: 0.0010
# Epoch 8/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.3573 - loss: 1.2673
# Epoch 8: val_accuracy improved from 0.32053 to 0.35493, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 459ms/step - accuracy: 0.3573 - loss: 1.2673 - val_accuracy: 0.3549 - val_loss: 1.3285 - learning_rate: 0.0010
# Epoch 9/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.3664 - loss: 1.2483
# Epoch 9: val_accuracy did not improve from 0.35493
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 460ms/step - accuracy: 0.3664 - loss: 1.2482 - val_accuracy: 0.3331 - val_loss: 1.4558 - learning_rate: 0.0010
# Epoch 10/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.3897 - loss: 1.1793
# Epoch 10: val_accuracy improved from 0.35493 to 0.41733, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 454ms/step - accuracy: 0.3897 - loss: 1.1793 - val_accuracy: 0.4173 - val_loss: 1.2957 - learning_rate: 0.0010
# Epoch 11/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.4007 - loss: 1.1181
# Epoch 11: val_accuracy did not improve from 0.41733
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 461ms/step - accuracy: 0.4007 - loss: 1.1182 - val_accuracy: 0.3819 - val_loss: 1.1219 - learning_rate: 0.0010
# Epoch 12/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.4013 - loss: 1.1388
# Epoch 12: val_accuracy did not improve from 0.41733
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 109s 466ms/step - accuracy: 0.4013 - loss: 1.1386 - val_accuracy: 0.4024 - val_loss: 1.0403 - learning_rate: 0.0010
# Epoch 13/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.4117 - loss: 1.1427
# Epoch 13: val_accuracy improved from 0.41733 to 0.43360, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 109s 465ms/step - accuracy: 0.4118 - loss: 1.1425 - val_accuracy: 0.4336 - val_loss: 1.0648 - learning_rate: 0.0010
# Epoch 14/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.4339 - loss: 1.0821
# Epoch 14: val_accuracy did not improve from 0.43360
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 461ms/step - accuracy: 0.4339 - loss: 1.0820 - val_accuracy: 0.3213 - val_loss: 1.2573 - learning_rate: 0.0010
# Epoch 15/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.4173 - loss: 1.0857
# Epoch 15: val_accuracy did not improve from 0.43360
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 456ms/step - accuracy: 0.4174 - loss: 1.0856 - val_accuracy: 0.4131 - val_loss: 1.0575 - learning_rate: 0.0010
# Epoch 16/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.4459 - loss: 1.0328
# Epoch 16: val_accuracy did not improve from 0.43360
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 456ms/step - accuracy: 0.4459 - loss: 1.0328 - val_accuracy: 0.3893 - val_loss: 1.1278 - learning_rate: 0.0010
# Epoch 17/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.4682 - loss: 0.9772
# Epoch 17: val_accuracy did not improve from 0.43360
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 455ms/step - accuracy: 0.4682 - loss: 0.9774 - val_accuracy: 0.3955 - val_loss: 1.1786 - learning_rate: 0.0010
# Epoch 18/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.4538 - loss: 1.0038
# Epoch 18: val_accuracy did not improve from 0.43360
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 459ms/step - accuracy: 0.4538 - loss: 1.0037 - val_accuracy: 0.4021 - val_loss: 1.0672 - learning_rate: 0.0010
# Epoch 19/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.4565 - loss: 0.9870
# Epoch 19: val_accuracy did not improve from 0.43360
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 460ms/step - accuracy: 0.4565 - loss: 0.9869 - val_accuracy: 0.4251 - val_loss: 1.1868 - learning_rate: 0.0010
# Epoch 20/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.4703 - loss: 0.9562
# Epoch 20: val_accuracy improved from 0.43360 to 0.49707, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 462ms/step - accuracy: 0.4703 - loss: 0.9562 - val_accuracy: 0.4971 - val_loss: 0.9543 - learning_rate: 0.0010
# Epoch 21/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.4641 - loss: 0.9582
# Epoch 21: val_accuracy improved from 0.49707 to 0.51867, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 460ms/step - accuracy: 0.4641 - loss: 0.9582 - val_accuracy: 0.5187 - val_loss: 0.9509 - learning_rate: 0.0010
# Epoch 22/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.4652 - loss: 0.9325
# Epoch 22: val_accuracy did not improve from 0.51867
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 452ms/step - accuracy: 0.4652 - loss: 0.9326 - val_accuracy: 0.4699 - val_loss: 0.9491 - learning_rate: 0.0010
# Epoch 23/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.4786 - loss: 0.9249
# Epoch 23: val_accuracy did not improve from 0.51867
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 455ms/step - accuracy: 0.4786 - loss: 0.9249 - val_accuracy: 0.4432 - val_loss: 0.9715 - learning_rate: 0.0010
# Epoch 24/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.4858 - loss: 0.9207
# Epoch 24: val_accuracy did not improve from 0.51867
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 454ms/step - accuracy: 0.4858 - loss: 0.9207 - val_accuracy: 0.4771 - val_loss: 0.8967 - learning_rate: 0.0010
# Epoch 25/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.4854 - loss: 0.8912
# Epoch 25: val_accuracy improved from 0.51867 to 0.52427, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 455ms/step - accuracy: 0.4854 - loss: 0.8912 - val_accuracy: 0.5243 - val_loss: 0.8862 - learning_rate: 0.0010
# Epoch 26/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.4958 - loss: 0.9139
# Epoch 26: val_accuracy did not improve from 0.52427
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 105s 448ms/step - accuracy: 0.4958 - loss: 0.9139 - val_accuracy: 0.4160 - val_loss: 1.1316 - learning_rate: 0.0010
# Epoch 27/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.4979 - loss: 0.8967
# Epoch 27: val_accuracy did not improve from 0.52427
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 452ms/step - accuracy: 0.4979 - loss: 0.8968 - val_accuracy: 0.5104 - val_loss: 0.9317 - learning_rate: 0.0010
# Epoch 28/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.4982 - loss: 0.8956
# Epoch 28: val_accuracy improved from 0.52427 to 0.53920, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 453ms/step - accuracy: 0.4982 - loss: 0.8955 - val_accuracy: 0.5392 - val_loss: 0.8697 - learning_rate: 0.0010
# Epoch 29/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.5082 - loss: 0.8484
# Epoch 29: val_accuracy did not improve from 0.53920
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 451ms/step - accuracy: 0.5082 - loss: 0.8485 - val_accuracy: 0.4667 - val_loss: 1.0411 - learning_rate: 0.0010
# Epoch 30/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.4962 - loss: 0.8704
# Epoch 30: val_accuracy did not improve from 0.53920
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 455ms/step - accuracy: 0.4962 - loss: 0.8703 - val_accuracy: 0.4501 - val_loss: 0.9918 - learning_rate: 0.0010
# Epoch 31/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.4983 - loss: 0.8539
# Epoch 31: val_accuracy did not improve from 0.53920
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 105s 446ms/step - accuracy: 0.4983 - loss: 0.8539 - val_accuracy: 0.4771 - val_loss: 0.9409 - learning_rate: 0.0010
# Epoch 32/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.4998 - loss: 0.8300
# Epoch 32: val_accuracy did not improve from 0.53920
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 459ms/step - accuracy: 0.4998 - loss: 0.8301 - val_accuracy: 0.4949 - val_loss: 0.8800 - learning_rate: 0.0010
# Epoch 33/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.5106 - loss: 0.8353
# Epoch 33: val_accuracy did not improve from 0.53920
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 456ms/step - accuracy: 0.5106 - loss: 0.8354 - val_accuracy: 0.5120 - val_loss: 0.8625 - learning_rate: 0.0010
# Epoch 34/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.5181 - loss: 0.8250
# Epoch 34: val_accuracy did not improve from 0.53920
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 456ms/step - accuracy: 0.5181 - loss: 0.8250 - val_accuracy: 0.4587 - val_loss: 0.9583 - learning_rate: 0.0010
# Epoch 35/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.5240 - loss: 0.8235
# Epoch 35: val_accuracy did not improve from 0.53920
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 459ms/step - accuracy: 0.5240 - loss: 0.8235 - val_accuracy: 0.5213 - val_loss: 0.8879 - learning_rate: 0.0010
# Epoch 36/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.5248 - loss: 0.8057
# Epoch 36: val_accuracy did not improve from 0.53920
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 457ms/step - accuracy: 0.5248 - loss: 0.8057 - val_accuracy: 0.5024 - val_loss: 0.8068 - learning_rate: 0.0010
# Epoch 37/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.5204 - loss: 0.8103
# Epoch 37: val_accuracy did not improve from 0.53920
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 456ms/step - accuracy: 0.5204 - loss: 0.8102 - val_accuracy: 0.4837 - val_loss: 0.9140 - learning_rate: 0.0010
# Epoch 38/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.5271 - loss: 0.7731
# Epoch 38: val_accuracy improved from 0.53920 to 0.53973, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 451ms/step - accuracy: 0.5271 - loss: 0.7733 - val_accuracy: 0.5397 - val_loss: 0.8166 - learning_rate: 0.0010
# Epoch 39/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.5344 - loss: 0.7480
# Epoch 39: val_accuracy did not improve from 0.53973
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 455ms/step - accuracy: 0.5344 - loss: 0.7482 - val_accuracy: 0.4029 - val_loss: 1.1959 - learning_rate: 0.0010
# Epoch 40/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.5427 - loss: 0.7532
# Epoch 40: val_accuracy did not improve from 0.53973
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 452ms/step - accuracy: 0.5426 - loss: 0.7533 - val_accuracy: 0.4787 - val_loss: 0.9243 - learning_rate: 0.0010
# Epoch 41/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.5258 - loss: 0.7994
# Epoch 41: val_accuracy improved from 0.53973 to 0.54400, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 455ms/step - accuracy: 0.5259 - loss: 0.7993 - val_accuracy: 0.5440 - val_loss: 0.8196 - learning_rate: 0.0010
# Epoch 42/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.5446 - loss: 0.7536
# Epoch 42: val_accuracy did not improve from 0.54400
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 105s 448ms/step - accuracy: 0.5446 - loss: 0.7536 - val_accuracy: 0.5248 - val_loss: 0.8133 - learning_rate: 0.0010
# Epoch 43/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.5424 - loss: 0.7398
# Epoch 43: val_accuracy improved from 0.54400 to 0.56187, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 454ms/step - accuracy: 0.5424 - loss: 0.7398 - val_accuracy: 0.5619 - val_loss: 0.8148 - learning_rate: 0.0010
# Epoch 44/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.5462 - loss: 0.7529
# Epoch 44: val_accuracy did not improve from 0.56187
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 450ms/step - accuracy: 0.5462 - loss: 0.7529 - val_accuracy: 0.5464 - val_loss: 0.8047 - learning_rate: 0.0010
# Epoch 45/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.5403 - loss: 0.7373
# Epoch 45: val_accuracy did not improve from 0.56187
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 451ms/step - accuracy: 0.5403 - loss: 0.7373 - val_accuracy: 0.5488 - val_loss: 0.7917 - learning_rate: 0.0010
# Epoch 46/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.5562 - loss: 0.7218
# Epoch 46: val_accuracy did not improve from 0.56187
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 457ms/step - accuracy: 0.5562 - loss: 0.7219 - val_accuracy: 0.5123 - val_loss: 0.8020 - learning_rate: 0.0010
# Epoch 47/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.5499 - loss: 0.7333
# Epoch 47: val_accuracy improved from 0.56187 to 0.57040, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 452ms/step - accuracy: 0.5499 - loss: 0.7333 - val_accuracy: 0.5704 - val_loss: 0.8023 - learning_rate: 0.0010
# Epoch 48/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.5525 - loss: 0.7140
# Epoch 48: val_accuracy did not improve from 0.57040
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 462ms/step - accuracy: 0.5525 - loss: 0.7140 - val_accuracy: 0.5427 - val_loss: 0.8359 - learning_rate: 0.0010
# Epoch 49/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.5548 - loss: 0.7184
# Epoch 49: val_accuracy did not improve from 0.57040
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 455ms/step - accuracy: 0.5548 - loss: 0.7184 - val_accuracy: 0.5253 - val_loss: 0.7957 - learning_rate: 0.0010
# Epoch 50/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.5671 - loss: 0.6940
# Epoch 50: val_accuracy did not improve from 0.57040
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 453ms/step - accuracy: 0.5671 - loss: 0.6940 - val_accuracy: 0.5320 - val_loss: 0.8113 - learning_rate: 0.0010
# Epoch 51/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.5559 - loss: 0.6985
# Epoch 51: val_accuracy did not improve from 0.57040
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 455ms/step - accuracy: 0.5560 - loss: 0.6985 - val_accuracy: 0.5341 - val_loss: 0.8173 - learning_rate: 0.0010
# Epoch 52/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.5663 - loss: 0.6987
# Epoch 52: val_accuracy did not improve from 0.57040
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 451ms/step - accuracy: 0.5663 - loss: 0.6987 - val_accuracy: 0.5141 - val_loss: 0.7776 - learning_rate: 0.0010
# Epoch 53/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.5679 - loss: 0.6623
# Epoch 53: val_accuracy did not improve from 0.57040
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 459ms/step - accuracy: 0.5679 - loss: 0.6624 - val_accuracy: 0.5632 - val_loss: 0.7396 - learning_rate: 0.0010
# Epoch 54/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.5746 - loss: 0.6614
# Epoch 54: val_accuracy did not improve from 0.57040
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 458ms/step - accuracy: 0.5746 - loss: 0.6614 - val_accuracy: 0.5424 - val_loss: 0.8641 - learning_rate: 0.0010
# Epoch 55/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.5604 - loss: 0.6788
# Epoch 55: val_accuracy did not improve from 0.57040
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 456ms/step - accuracy: 0.5604 - loss: 0.6788 - val_accuracy: 0.5125 - val_loss: 0.8988 - learning_rate: 0.0010
# Epoch 56/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.5742 - loss: 0.6627
# Epoch 56: val_accuracy improved from 0.57040 to 0.58587, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 455ms/step - accuracy: 0.5742 - loss: 0.6628 - val_accuracy: 0.5859 - val_loss: 0.7917 - learning_rate: 0.0010
# Epoch 57/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.5766 - loss: 0.6672
# Epoch 57: val_accuracy did not improve from 0.58587
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 454ms/step - accuracy: 0.5766 - loss: 0.6672 - val_accuracy: 0.5216 - val_loss: 0.8123 - learning_rate: 0.0010
# Epoch 58/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.5696 - loss: 0.6727
# Epoch 58: val_accuracy did not improve from 0.58587
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 450ms/step - accuracy: 0.5696 - loss: 0.6728 - val_accuracy: 0.5496 - val_loss: 0.7801 - learning_rate: 0.0010
# Epoch 59/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.5800 - loss: 0.6508
# Epoch 59: val_accuracy did not improve from 0.58587
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 452ms/step - accuracy: 0.5800 - loss: 0.6508 - val_accuracy: 0.5488 - val_loss: 0.7873 - learning_rate: 0.0010
# Epoch 60/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.5736 - loss: 0.6499
# Epoch 60: val_accuracy did not improve from 0.58587
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 451ms/step - accuracy: 0.5736 - loss: 0.6500 - val_accuracy: 0.5664 - val_loss: 0.8123 - learning_rate: 0.0010
# Epoch 61/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.5774 - loss: 0.6538
# Epoch 61: val_accuracy did not improve from 0.58587
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 450ms/step - accuracy: 0.5773 - loss: 0.6538 - val_accuracy: 0.4829 - val_loss: 0.9943 - learning_rate: 0.0010
# Epoch 62/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.5750 - loss: 0.6424
# Epoch 62: val_accuracy improved from 0.58587 to 0.58667, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 461ms/step - accuracy: 0.5750 - loss: 0.6424 - val_accuracy: 0.5867 - val_loss: 0.7580 - learning_rate: 0.0010
# Epoch 63/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.5897 - loss: 0.6035
# Epoch 63: val_accuracy improved from 0.58667 to 0.59600, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 453ms/step - accuracy: 0.5897 - loss: 0.6036 - val_accuracy: 0.5960 - val_loss: 0.8767 - learning_rate: 0.0010
# Epoch 64/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.5931 - loss: 0.6208
# Epoch 64: val_accuracy did not improve from 0.59600
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 452ms/step - accuracy: 0.5930 - loss: 0.6209 - val_accuracy: 0.4997 - val_loss: 0.9205 - learning_rate: 0.0010
# Epoch 65/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.5895 - loss: 0.6195
# Epoch 65: val_accuracy did not improve from 0.59600
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 455ms/step - accuracy: 0.5895 - loss: 0.6195 - val_accuracy: 0.5840 - val_loss: 0.7552 - learning_rate: 0.0010
# Epoch 66/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.5935 - loss: 0.6133
# Epoch 66: val_accuracy did not improve from 0.59600
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 456ms/step - accuracy: 0.5934 - loss: 0.6134 - val_accuracy: 0.5728 - val_loss: 0.7182 - learning_rate: 0.0010
# Epoch 67/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.5911 - loss: 0.6146
# Epoch 67: val_accuracy did not improve from 0.59600
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 462ms/step - accuracy: 0.5910 - loss: 0.6146 - val_accuracy: 0.5331 - val_loss: 0.7728 - learning_rate: 0.0010
# Epoch 68/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.5927 - loss: 0.6288
# Epoch 68: val_accuracy did not improve from 0.59600
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 109s 463ms/step - accuracy: 0.5927 - loss: 0.6289 - val_accuracy: 0.5392 - val_loss: 0.9909 - learning_rate: 0.0010
# Epoch 69/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.5987 - loss: 0.6054
# Epoch 69: val_accuracy did not improve from 0.59600
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 459ms/step - accuracy: 0.5987 - loss: 0.6054 - val_accuracy: 0.5773 - val_loss: 0.7297 - learning_rate: 0.0010
# Epoch 70/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.5911 - loss: 0.5984
# Epoch 70: val_accuracy did not improve from 0.59600
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 456ms/step - accuracy: 0.5911 - loss: 0.5984 - val_accuracy: 0.5835 - val_loss: 0.8235 - learning_rate: 0.0010
# Epoch 71/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.5903 - loss: 0.6021
# Epoch 71: val_accuracy did not improve from 0.59600
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 454ms/step - accuracy: 0.5903 - loss: 0.6022 - val_accuracy: 0.5333 - val_loss: 0.8491 - learning_rate: 0.0010
# Epoch 72/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.6060 - loss: 0.5844
# Epoch 72: val_accuracy did not improve from 0.59600
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 451ms/step - accuracy: 0.6060 - loss: 0.5844 - val_accuracy: 0.5008 - val_loss: 1.1115 - learning_rate: 0.0010
# Epoch 73/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.5997 - loss: 0.5820
# Epoch 73: val_accuracy did not improve from 0.59600
#
# Epoch 73: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 454ms/step - accuracy: 0.5997 - loss: 0.5820 - val_accuracy: 0.4523 - val_loss: 1.1840 - learning_rate: 0.0010
# Epoch 74/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.6093 - loss: 0.5589
# Epoch 74: val_accuracy improved from 0.59600 to 0.62267, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 452ms/step - accuracy: 0.6094 - loss: 0.5588 - val_accuracy: 0.6227 - val_loss: 0.6158 - learning_rate: 1.0000e-04
# Epoch 75/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.6302 - loss: 0.5117
# Epoch 75: val_accuracy improved from 0.62267 to 0.63013, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 454ms/step - accuracy: 0.6302 - loss: 0.5117 - val_accuracy: 0.6301 - val_loss: 0.6071 - learning_rate: 1.0000e-04
# Epoch 76/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.6245 - loss: 0.5210
# Epoch 76: val_accuracy did not improve from 0.63013
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 451ms/step - accuracy: 0.6245 - loss: 0.5210 - val_accuracy: 0.6216 - val_loss: 0.6162 - learning_rate: 1.0000e-04
# Epoch 77/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.6343 - loss: 0.5072
# Epoch 77: val_accuracy did not improve from 0.63013
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 455ms/step - accuracy: 0.6343 - loss: 0.5072 - val_accuracy: 0.6221 - val_loss: 0.6116 - learning_rate: 1.0000e-04
# Epoch 78/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.6288 - loss: 0.5164
# Epoch 78: val_accuracy did not improve from 0.63013
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 462ms/step - accuracy: 0.6288 - loss: 0.5164 - val_accuracy: 0.6296 - val_loss: 0.6190 - learning_rate: 1.0000e-04
# Epoch 79/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.6438 - loss: 0.5081
# Epoch 79: val_accuracy improved from 0.63013 to 0.63573, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 450ms/step - accuracy: 0.6438 - loss: 0.5081 - val_accuracy: 0.6357 - val_loss: 0.6232 - learning_rate: 1.0000e-04
# Epoch 80/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.6403 - loss: 0.5083
# Epoch 80: val_accuracy did not improve from 0.63573
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 457ms/step - accuracy: 0.6403 - loss: 0.5083 - val_accuracy: 0.6349 - val_loss: 0.6256 - learning_rate: 1.0000e-04
# Epoch 81/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.6355 - loss: 0.5012
# Epoch 81: val_accuracy did not improve from 0.63573
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 105s 449ms/step - accuracy: 0.6355 - loss: 0.5012 - val_accuracy: 0.6283 - val_loss: 0.6256 - learning_rate: 1.0000e-04
# Epoch 82/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.6308 - loss: 0.5016
# Epoch 82: val_accuracy did not improve from 0.63573
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 455ms/step - accuracy: 0.6308 - loss: 0.5016 - val_accuracy: 0.6312 - val_loss: 0.5997 - learning_rate: 1.0000e-04
# Epoch 83/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.6335 - loss: 0.5082
# Epoch 83: val_accuracy did not improve from 0.63573
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 449ms/step - accuracy: 0.6335 - loss: 0.5082 - val_accuracy: 0.6355 - val_loss: 0.6160 - learning_rate: 1.0000e-04
# Epoch 84/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.6344 - loss: 0.5092
# Epoch 84: val_accuracy did not improve from 0.63573
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 450ms/step - accuracy: 0.6344 - loss: 0.5091 - val_accuracy: 0.6336 - val_loss: 0.6234 - learning_rate: 1.0000e-04
# Epoch 85/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.6393 - loss: 0.5021
# Epoch 85: val_accuracy did not improve from 0.63573
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 456ms/step - accuracy: 0.6393 - loss: 0.5021 - val_accuracy: 0.6307 - val_loss: 0.6025 - learning_rate: 1.0000e-04
# Epoch 86/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.6361 - loss: 0.4853
# Epoch 86: val_accuracy did not improve from 0.63573
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 454ms/step - accuracy: 0.6361 - loss: 0.4854 - val_accuracy: 0.6352 - val_loss: 0.6050 - learning_rate: 1.0000e-04
# Epoch 87/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.6402 - loss: 0.4884
# Epoch 87: val_accuracy did not improve from 0.63573
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 454ms/step - accuracy: 0.6402 - loss: 0.4885 - val_accuracy: 0.6304 - val_loss: 0.5985 - learning_rate: 1.0000e-04
# Epoch 88/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.6350 - loss: 0.4924
# Epoch 88: val_accuracy did not improve from 0.63573
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 454ms/step - accuracy: 0.6351 - loss: 0.4924 - val_accuracy: 0.6355 - val_loss: 0.6156 - learning_rate: 1.0000e-04
# Epoch 89/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.6456 - loss: 0.4955
# Epoch 89: val_accuracy did not improve from 0.63573
#
# Epoch 89: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 458ms/step - accuracy: 0.6456 - loss: 0.4955 - val_accuracy: 0.6277 - val_loss: 0.6201 - learning_rate: 1.0000e-04
# Epoch 90/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.6370 - loss: 0.4976
# Epoch 90: val_accuracy did not improve from 0.63573
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 452ms/step - accuracy: 0.6370 - loss: 0.4975 - val_accuracy: 0.6355 - val_loss: 0.6005 - learning_rate: 1.0000e-05
# Epoch 91/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.6438 - loss: 0.4900
# Epoch 91: val_accuracy improved from 0.63573 to 0.64080, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 454ms/step - accuracy: 0.6438 - loss: 0.4899 - val_accuracy: 0.6408 - val_loss: 0.5984 - learning_rate: 1.0000e-05
# Epoch 92/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.6482 - loss: 0.4794
# Epoch 92: val_accuracy did not improve from 0.64080
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 456ms/step - accuracy: 0.6482 - loss: 0.4794 - val_accuracy: 0.6373 - val_loss: 0.6008 - learning_rate: 1.0000e-05
# Epoch 93/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.6424 - loss: 0.4933
# Epoch 93: val_accuracy did not improve from 0.64080
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 456ms/step - accuracy: 0.6425 - loss: 0.4933 - val_accuracy: 0.6384 - val_loss: 0.6010 - learning_rate: 1.0000e-05
# Epoch 94/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.6356 - loss: 0.4897
# Epoch 94: val_accuracy did not improve from 0.64080
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 458ms/step - accuracy: 0.6356 - loss: 0.4897 - val_accuracy: 0.6389 - val_loss: 0.6017 - learning_rate: 1.0000e-05
# Epoch 95/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.6480 - loss: 0.4760
# Epoch 95: val_accuracy did not improve from 0.64080
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 451ms/step - accuracy: 0.6480 - loss: 0.4760 - val_accuracy: 0.6400 - val_loss: 0.6009 - learning_rate: 1.0000e-05
# Epoch 96/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.6411 - loss: 0.4850
# Epoch 96: val_accuracy did not improve from 0.64080
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 455ms/step - accuracy: 0.6411 - loss: 0.4850 - val_accuracy: 0.6392 - val_loss: 0.6002 - learning_rate: 1.0000e-05
# Epoch 97/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.6448 - loss: 0.4884
# Epoch 97: val_accuracy did not improve from 0.64080
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 453ms/step - accuracy: 0.6448 - loss: 0.4884 - val_accuracy: 0.6395 - val_loss: 0.5998 - learning_rate: 1.0000e-05
# Epoch 98/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.6377 - loss: 0.4967
# Epoch 98: val_accuracy did not improve from 0.64080
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 456ms/step - accuracy: 0.6377 - loss: 0.4967 - val_accuracy: 0.6395 - val_loss: 0.6009 - learning_rate: 1.0000e-05
# Epoch 99/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.6438 - loss: 0.4914
# Epoch 99: val_accuracy did not improve from 0.64080
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 456ms/step - accuracy: 0.6438 - loss: 0.4914 - val_accuracy: 0.6389 - val_loss: 0.5995 - learning_rate: 1.0000e-05
# Epoch 100/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.6482 - loss: 0.4823
# Epoch 100: val_accuracy did not improve from 0.64080
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 450ms/step - accuracy: 0.6482 - loss: 0.4823 - val_accuracy: 0.6387 - val_loss: 0.5979 - learning_rate: 1.0000e-05
# Epoch 101/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.6427 - loss: 0.4834
# Epoch 101: val_accuracy improved from 0.64080 to 0.64267, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 456ms/step - accuracy: 0.6427 - loss: 0.4834 - val_accuracy: 0.6427 - val_loss: 0.5985 - learning_rate: 1.0000e-05
# Epoch 102/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.6359 - loss: 0.4899
# Epoch 102: val_accuracy did not improve from 0.64267
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 105s 448ms/step - accuracy: 0.6359 - loss: 0.4899 - val_accuracy: 0.6397 - val_loss: 0.6008 - learning_rate: 1.0000e-05
# Epoch 103/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.6444 - loss: 0.4763
# Epoch 103: val_accuracy did not improve from 0.64267
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 108s 460ms/step - accuracy: 0.6444 - loss: 0.4763 - val_accuracy: 0.6387 - val_loss: 0.6011 - learning_rate: 1.0000e-05
# Epoch 104/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.6525 - loss: 0.4813
# Epoch 104: val_accuracy did not improve from 0.64267
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 455ms/step - accuracy: 0.6525 - loss: 0.4812 - val_accuracy: 0.6411 - val_loss: 0.5994 - learning_rate: 1.0000e-05
# Epoch 105/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.6458 - loss: 0.4831
# Epoch 105: val_accuracy did not improve from 0.64267
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 453ms/step - accuracy: 0.6458 - loss: 0.4831 - val_accuracy: 0.6400 - val_loss: 0.5989 - learning_rate: 1.0000e-05
# Epoch 106/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.6411 - loss: 0.4896
# Epoch 106: val_accuracy did not improve from 0.64267
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 105s 448ms/step - accuracy: 0.6412 - loss: 0.4895 - val_accuracy: 0.6397 - val_loss: 0.5993 - learning_rate: 1.0000e-05
# Epoch 107/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.6397 - loss: 0.4849
# Epoch 107: val_accuracy did not improve from 0.64267
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 453ms/step - accuracy: 0.6397 - loss: 0.4849 - val_accuracy: 0.6387 - val_loss: 0.6005 - learning_rate: 1.0000e-05
# Epoch 108/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.6476 - loss: 0.4842
# Epoch 108: val_accuracy did not improve from 0.64267
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 451ms/step - accuracy: 0.6476 - loss: 0.4842 - val_accuracy: 0.6397 - val_loss: 0.6004 - learning_rate: 1.0000e-05
# Epoch 109/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.6403 - loss: 0.4787
# Epoch 109: val_accuracy did not improve from 0.64267
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 105s 449ms/step - accuracy: 0.6403 - loss: 0.4787 - val_accuracy: 0.6371 - val_loss: 0.6001 - learning_rate: 1.0000e-05
# Epoch 110/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.6430 - loss: 0.4779
# Epoch 110: val_accuracy did not improve from 0.64267
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 451ms/step - accuracy: 0.6430 - loss: 0.4779 - val_accuracy: 0.6413 - val_loss: 0.5994 - learning_rate: 1.0000e-05
# Epoch 111/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.6367 - loss: 0.4895
# Epoch 111: val_accuracy did not improve from 0.64267
#
# Epoch 111: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 105s 448ms/step - accuracy: 0.6368 - loss: 0.4895 - val_accuracy: 0.6419 - val_loss: 0.5994 - learning_rate: 1.0000e-05
# Epoch 112/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.6444 - loss: 0.4802
# Epoch 112: val_accuracy did not improve from 0.64267
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 454ms/step - accuracy: 0.6444 - loss: 0.4802 - val_accuracy: 0.6403 - val_loss: 0.5995 - learning_rate: 1.0000e-06
# Epoch 113/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.6436 - loss: 0.4787
# Epoch 113: val_accuracy did not improve from 0.64267
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 452ms/step - accuracy: 0.6436 - loss: 0.4787 - val_accuracy: 0.6411 - val_loss: 0.5984 - learning_rate: 1.0000e-06
# Epoch 114/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.6433 - loss: 0.4866
# Epoch 114: val_accuracy did not improve from 0.64267
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 453ms/step - accuracy: 0.6433 - loss: 0.4866 - val_accuracy: 0.6403 - val_loss: 0.5993 - learning_rate: 1.0000e-06
# Epoch 115/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.6500 - loss: 0.4787
# Epoch 115: val_accuracy did not improve from 0.64267
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 105s 449ms/step - accuracy: 0.6500 - loss: 0.4787 - val_accuracy: 0.6400 - val_loss: 0.6010 - learning_rate: 1.0000e-06
# Epoch 116/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.6534 - loss: 0.4709
# Epoch 116: val_accuracy did not improve from 0.64267
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 450ms/step - accuracy: 0.6533 - loss: 0.4709 - val_accuracy: 0.6387 - val_loss: 0.6012 - learning_rate: 1.0000e-06
# Epoch 117/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.6519 - loss: 0.4764
# Epoch 117: val_accuracy did not improve from 0.64267
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 454ms/step - accuracy: 0.6519 - loss: 0.4763 - val_accuracy: 0.6400 - val_loss: 0.5992 - learning_rate: 1.0000e-06
# Epoch 118/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.6432 - loss: 0.4829
# Epoch 118: val_accuracy did not improve from 0.64267
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 107s 458ms/step - accuracy: 0.6432 - loss: 0.4829 - val_accuracy: 0.6403 - val_loss: 0.5991 - learning_rate: 1.0000e-06
# Epoch 119/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.6531 - loss: 0.4853
# Epoch 119: val_accuracy did not improve from 0.64267
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 110s 466ms/step - accuracy: 0.6531 - loss: 0.4853 - val_accuracy: 0.6397 - val_loss: 0.5991 - learning_rate: 1.0000e-06
# Epoch 120/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.6520 - loss: 0.4761
# Epoch 120: val_accuracy did not improve from 0.64267
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 450ms/step - accuracy: 0.6520 - loss: 0.4762 - val_accuracy: 0.6421 - val_loss: 0.5995 - learning_rate: 1.0000e-06
# Epoch 121/200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.6407 - loss: 0.4707
# Epoch 121: val_accuracy did not improve from 0.64267
#
# Epoch 121: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 452ms/step - accuracy: 0.6407 - loss: 0.4707 - val_accuracy: 0.6419 - val_loss: 0.5981 - learning_rate: 1.0000e-06
# Epoch 121: early stopping
# Best validation model: epoch 101  - val_accuracy 0.6426666378974915

# %%
import matplotlib.pyplot as plt

def plot_results(history):
    
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    
    
    epochs_range = range(1, len(acc) + 1)

    plt.figure(figsize=(16, 6))

    # --- GRAFICO 1: ACCURACY
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy', color='blue', marker='o')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy', color='red', marker='o')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epoche')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')
    plt.grid(True)

    # --- GRAFICO 2: LOSS 
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss', color='blue', linestyle='--')
    plt.plot(epochs_range, val_loss, label='Validation Loss', color='red', linestyle='--')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoche')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')
    plt.grid(True)

    plt.show()


plot_results(h)

# %% [markdown]
# #### Validation
# Compute validation metrics.

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

def draw_confusion_matrix(cm, categories):
    # Draw confusion matrix
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    cm = cm.astype('float') / np.maximum(cm.sum(axis=1)[:, np.newaxis], np.finfo(np.float64).eps)
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.colormaps['Blues'])
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=list(categories.values()), yticklabels=list(categories.values()), ylabel='Annotation', xlabel='Prediction')
    # Rotate the tick labels and set their alignment
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Loop over data dimensions and create text annotations
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], '.2f'), ha="center", va="center", color="white" if cm[i, j] > thresh else "black", fontsize=int(20-pow(len(categories), 0.5)))
    fig.tight_layout()
    plt.show()

# %%
import numpy as np

model.load_weights('model.keras')
y_true, y_pred = [], []
for ann in anns_valid:
    # Load image
    image = load_geoimage(ann.filename)
    image = image.astype(np.float64)
    image = (image - train_mean) / (train_std + 1e-7)
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        y_true.append(obj_pred.category)
        y_pred.append(pred_category)

# %%
from sklearn.metrics import confusion_matrix

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=list(categories.values()))
draw_confusion_matrix(cm, categories)

# %%
import numpy as np

# Compute the accuracy
correct_samples_class = np.diag(cm).astype(float)
total_samples_class = np.sum(cm, axis=1).astype(float)
total_predicts_class = np.sum(cm, axis=0).astype(float)
print('Mean Accuracy: %.3f%%' % (np.sum(correct_samples_class) / np.sum(total_samples_class) * 100))
acc = correct_samples_class / np.maximum(total_samples_class, np.finfo(np.float64).eps)
print('Mean Recall: %.3f%%' % (acc.mean() * 100))
acc = correct_samples_class / np.maximum(total_predicts_class, np.finfo(np.float64).eps)
print('Mean Precision: %.3f%%' % (acc.mean() * 100))
for idx in range(len(categories)):
    # True/False Positives (TP/FP) refer to the number of predicted positives that were correct/incorrect.
    # True/False Negatives (TN/FN) refer to the number of predicted negatives that were correct/incorrect.
    tp = cm[idx, idx]
    fp = sum(cm[:, idx]) - tp
    fn = sum(cm[idx, :]) - tp
    tn = sum(np.delete(sum(cm) - cm[idx, :], idx))
    # True Positive Rate: proportion of real positive cases that were correctly predicted as positive.
    recall = tp / np.maximum(tp+fn, np.finfo(np.float64).eps)
    # Precision: proportion of predicted positive cases that were truly real positives.
    precision = tp / np.maximum(tp+fp, np.finfo(np.float64).eps)
    # True Negative Rate: proportion of real negative cases that were correctly predicted as negative.
    specificity = tn / np.maximum(tn+fp, np.finfo(np.float64).eps)
    # Dice coefficient refers to two times the intersection of two sets divided by the sum of their areas.
    # Dice = 2 |A∩B| / (|A|+|B|) = 2 TP / (2 TP + FP + FN)
    f1_score = 2 * ((precision * recall) / np.maximum(precision+recall, np.finfo(np.float64).eps))
    print('> %s: Recall: %.3f%% Precision: %.3f%% Specificity: %.3f%% Dice: %.3f%%' % (list(categories.values())[idx], recall*100, precision*100, specificity*100, f1_score*100))
# Out:
# Mean Accuracy: 64.267%
# Mean Recall: 67.882%
# Mean Precision: 61.826%
# > Cargo plane: Recall: 91.339% Precision: 89.922% Specificity: 99.641% Dice: 90.625%
# > Small car: Recall: 81.504% Precision: 79.472% Specificity: 95.462% Dice: 80.475%
# > Bus: Recall: 53.107% Precision: 52.368% Specificity: 94.965% Dice: 52.735%
# > Truck: Recall: 19.683% Precision: 33.333% Specificity: 94.740% Dice: 24.751%
# > Motorboat: Recall: 74.766% Precision: 67.227% Specificity: 97.794% Dice: 70.796%
# > Fishing vessel: Recall: 79.433% Precision: 69.136% Specificity: 98.615% Dice: 73.927%
# > Dump truck: Recall: 52.227% Precision: 43.581% Specificity: 95.233% Dice: 47.514%
# > Excavator: Recall: 74.051% Precision: 60.000% Specificity: 97.829% Dice: 66.289%
# > Building: Recall: 63.282% Precision: 88.178% Specificity: 97.987% Dice: 73.684%
# > Helipad: Recall: 59.091% Precision: 56.522% Specificity: 99.732% Dice: 57.778%
# > Storage tank: Recall: 64.286% Precision: 53.693% Specificity: 95.284% Dice: 58.514%
# > Shipping container: Recall: 80.984% Precision: 56.912% Specificity: 94.572% Dice: 66.847%
# > Pylon: Recall: 88.710% Precision: 53.398% Specificity: 98.698% Dice: 66.667%

# %% [markdown]
# #### Testing
# Try to improve the results provided in the competition.

# %%
import os
import numpy as np

anns = []
for (dirpath, dirnames, filenames) in os.walk('/kaggle/input/datasets/vittoriogianfrate/recognition/xview_recognition/xview_test'):
    for filename in filenames:
        relative_path = os.path.join('xview_test', filename)
        image = GenericImage(relative_path)
        image.tile = np.array([0, 0, 224, 224])
        obj = GenericObject()
        obj.bb = (0, 0, 224, 224)
        obj.category = dirpath[dirpath.rfind('/')+1:]
        image.add_object(obj)
        anns.append(image)
print('Number of testing images: ' + str(len(anns)))
# Out:
# Number of testing images: 2365

# %%
import numpy as np

model.load_weights('model.keras')
predictions_data = {"images": {}, "annotations": {}}
for idx, ann in enumerate(anns):
    image_data = {"image_id": ann.filename.split('/')[-1], "filename": ann.filename, "width": int(ann.tile[2]), "height": int(ann.tile[3])}
    predictions_data["images"][idx] = image_data
    # Load image
    image = load_geoimage(ann.filename)
    image = image.astype(np.float64)
    image = (image - train_mean) / (train_std + 1e-7)
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        annotation_data = {"image_id": ann.filename.split('/')[-1], "category_id": pred_category, "bbox": [int(x) for x in obj_pred.bb]}
        predictions_data["annotations"][idx] = annotation_data

# %%
with open("prediction.json", "w") as outfile:
    json.dump(predictions_data, outfile)

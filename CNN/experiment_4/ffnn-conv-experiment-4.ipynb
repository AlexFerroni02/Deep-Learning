# %% [markdown]
# ## Assignment: Image recognition
# - Alumno 1: Alex Ferroni
# - Alumno 2: Vittorio Alberto Gianfrate
# - Alumno 3:
#
# The goals of the assignment are:
# * Develop proficiency in using Tensorflow/Keras for training Neural Nets (NNs).
# * Put into practice the acquired knowledge to optimize the parameters and architecture of a feedforward Neural Net (ffNN), in the context of an image recognition problem.
# * Put into practice NNs specially conceived for analysing images. Design and optimize the parameters of a Convolutional Neural Net (CNN) to deal with previous task.
# * Train popular architectures from scratch (e.g., GoogLeNet, VGG, ResNet, ...), and compare the results with the ones provided by their pre-trained versions using transfer learning.
#
# Follow the link below to download the classification data set  “xview_recognition”: [https://drive.upm.es/s/2DDPE2zHw5dbM3G](https://drive.upm.es/s/2DDPE2zHw5dbM3G)

# %%
# !pip install rasterio
# Out:
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (1.5.0)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio) (25.4.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from rasterio) (2026.1.4)
# Requirement already satisfied: click!=8.2.*,>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio) (8.3.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.0.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio) (3.3.1)

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# 2026-03-08 11:25:24.965223: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772969125.161110      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772969125.213341      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772969125.648998      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772969125.649047      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772969125.649050      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772969125.649052      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import uuid
import numpy as np

class GenericObject:
    """
    Generic object data.
    """
    def __init__(self):
        self.id = uuid.uuid4()
        self.bb = (-1, -1, -1, -1)
        self.category= -1
        self.score = -1

class GenericImage:
    """
    Generic image data.
    """
    def __init__(self, filename):
        self.filename = filename
        self.tile = np.array([-1, -1, -1, -1])  # (pt_x, pt_y, pt_x+width, pt_y+height)
        self.objects = list([])

    def add_object(self, obj: GenericObject):
        self.objects.append(obj)

# %%
categories = {0: 'Cargo plane', 1: 'Small car', 2: 'Bus', 3: 'Truck', 4: 'Motorboat', 5: 'Fishing vessel', 6: 'Dump truck', 7: 'Excavator', 8: 'Building', 9: 'Helipad', 10: 'Storage tank', 11: 'Shipping container', 12: 'Pylon'}

# %%
import warnings
import rasterio
import numpy as np
import os
import cv2

def load_geoimage(filename):
    warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
    base_path = '/kaggle/input/datasets/alexferroni/recognition/xview_recognition/'
    
    src_raster = rasterio.open(base_path + filename, 'r')
    # --------------------

    # RasterIO to OpenCV
    input_type = src_raster.profile['dtype']
    input_channels = src_raster.count
    img = np.zeros((src_raster.height, src_raster.width, src_raster.count), dtype=input_type)
    for band in range(input_channels):
        img[:, :, band] = src_raster.read(band+1)
   
    return img

# %% [markdown]
# #### Training
# Design and train a ffNN to deal with the “xview_recognition” classification task.

# %%
import json
import os


json_file = '/kaggle/input/datasets/alexferroni/recognition/xview_recognition/xview_ann_train.json'

print(f"Caricamento annotazioni da: {json_file}")

with open(json_file) as ifs:
    json_data = json.load(ifs)
    
print("Annotazioni caricate con successo!")
# Out:
# Caricamento annotazioni da: /kaggle/input/datasets/alexferroni/recognition/xview_recognition/xview_ann_train.json
# Annotazioni caricate con successo!

# %%
import numpy as np

counts = dict.fromkeys(categories.values(), 0)
anns = []
for json_img, json_ann in zip(json_data['images'].values(), json_data['annotations'].values()):
    image = GenericImage(json_img['filename'])
    image.tile = np.array([0, 0, json_img['width'], json_img['height']])
    obj = GenericObject()
    obj.bb = (int(json_ann['bbox'][0]), int(json_ann['bbox'][1]), int(json_ann['bbox'][2]), int(json_ann['bbox'][3]))
    obj.category = json_ann['category_id']
    # Resampling strategy to reduce training time
    counts[obj.category] += 1
    image.add_object(obj)
    anns.append(image)
print(counts)
# Out:
# {'Cargo plane': 635, 'Small car': 3324, 'Bus': 1768, 'Truck': 2210, 'Motorboat': 1069, 'Fishing vessel': 706, 'Dump truck': 1236, 'Excavator': 789, 'Building': 3594, 'Helipad': 111, 'Storage tank': 1469, 'Shipping container': 1523, 'Pylon': 312}

# %%
from sklearn.model_selection import train_test_split
labels_list = [x.objects[0].category for x in anns]
anns_train, anns_valid = train_test_split(anns, test_size=0.2, random_state=1, shuffle=True,stratify=labels_list)
print('Number of training images: ' + str(len(anns_train)))
print('Number of validation images: ' + str(len(anns_valid)))
# Out:
# Number of training images: 14996
# Number of validation images: 3750

# %%
train_mean = [69.41887293,56.97948485,49.47711569]
train_std = [51.61769765,44.6239849 ,40.89414141]

# %%
import numpy as np

pixel_sum = np.zeros(3)
pixel_sq_sum = np.zeros(3)
pixel_count = 0


for ann in anns_train:
    
    img = load_geoimage(ann.filename) 
    img = img.astype(np.float64)
    pixel_sum += np.sum(img, axis=(0, 1))
    pixel_sq_sum += np.sum(img ** 2, axis=(0, 1))
    
    pixel_count += img.shape[0] * img.shape[1]

#COmpute mean and standard deviation
train_mean = pixel_sum / pixel_count
train_var = (pixel_sq_sum / pixel_count) - (train_mean ** 2)
train_var = np.maximum(train_var, 0)
train_std = np.sqrt(train_var)

print(f"Training Mean: {train_mean}")
print(f"Training Std: {train_std}")
# Out:
# Training Mean: [69.41887293 56.97948485 49.47711569]
# Training Std: [51.61769765 44.6239849  40.89414141]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (Conv2D, MaxPooling2D, GlobalAveragePooling2D, 
                                     Dense, BatchNormalization, Activation, Dropout, 
                                     RandomFlip, RandomRotation, RandomZoom, RandomTranslation,RandomContrast,SpatialDropout2D)
import tensorflow as tf

# Creiamo la "scatola" vuota
model = Sequential([
    RandomFlip("horizontal_and_vertical", input_shape=(224, 224, 3)),

    # Block 1: 64 filters
    Conv2D(64, (3,3), padding='same', use_bias=False,), BatchNormalization(), Activation('elu'),
    Conv2D(64, (3,3), padding='same', use_bias=False), BatchNormalization(), Activation('elu'),
    MaxPooling2D(2, 2),   # 112x112

    # Block 2: 128 filters
    Conv2D(128, (3,3), padding='same', use_bias=False), BatchNormalization(), Activation('elu'),
    Conv2D(128, (3,3), padding='same', use_bias=False), BatchNormalization(), Activation('elu'),
    MaxPooling2D(2, 2),  # 56x56

    # Block 3: 256 filters
    Conv2D(256, (3,3), padding='same', use_bias=False), BatchNormalization(), Activation('elu'),
    Conv2D(256, (3,3), padding='same', use_bias=False), BatchNormalization(), Activation('elu'),
    Conv2D(256, (3,3), padding='same', use_bias=False), BatchNormalization(), Activation('elu'),
    MaxPooling2D(2, 2),   # 28x28

    # Block 4: 512 filters
    Conv2D(512, (3,3), padding='same', use_bias=False), BatchNormalization(), Activation('elu'),
    Conv2D(512, (3,3), padding='same', use_bias=False), BatchNormalization(), Activation('elu'),
    Conv2D(512, (3,3), padding='same', use_bias=False), BatchNormalization(), Activation('elu'),
    MaxPooling2D(2, 2),   # 14x14

    GlobalAveragePooling2D(),
    Dense(512, use_bias=False), BatchNormalization(), Activation('elu'), Dropout(0.3),
    Dense(256, use_bias=False), BatchNormalization(), Activation('elu'), Dropout(0.1),
    Dense(13, activation='softmax')
])

# Riepilogo e Compilazione
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# I0000 00:00:1772969632.715688      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ random_flip (RandomFlip)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 224, 224, 64)   │         1,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 224, 224, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 224, 224, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 224, 224, 64)   │        36,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 224, 224, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 224, 224, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 112, 112, 128)  │        73,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 112, 112, 128)  │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 112, 112, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 112, 112, 128)  │       147,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 112, 112, 128)  │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 112, 112, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 56, 56, 256)    │       294,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 56, 56, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 56, 56, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 56, 56, 256)    │       589,824 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 56, 56, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 56, 56, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 56, 56, 256)    │       589,824 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 56, 56, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 56, 56, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 28, 28, 512)    │     1,179,648 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 28, 28, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_7 (Activation)       │ (None, 28, 28, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 28, 28, 512)    │     2,359,296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 28, 28, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_8 (Activation)       │ (None, 28, 28, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 28, 28, 512)    │     2,359,296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 28, 28, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_9 (Activation)       │ (None, 28, 28, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       262,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_10 (Activation)      │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_11 (Activation)      │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 13)             │         3,341 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,042,957 (30.68 MB)
#  Trainable params: 8,036,045 (30.66 MB)
#  Non-trainable params: 6,912 (27.00 KB)

# %%
from sklearn.utils import class_weight
import numpy as np

train_labels = [ann.objects[0].category for ann in anns_train]
unique_classes = np.unique(train_labels)

weights_values = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=unique_classes,
    y=train_labels
)

name_to_id = {v: k for k, v in categories.items()}

alpha_array = np.ones(len(categories), dtype=np.float32)

for class_name, weight in zip(unique_classes, weights_values):
    if class_name in name_to_id:
        class_id = name_to_id[class_name]
        alpha_array[class_id] = weight
        print(f"Classe: {class_name:<20} ID: {class_id:<3} Peso: {weight:.4f}")

alpha_list = alpha_array.tolist()

print("\nLISTA DEFINITIVA PRONTA PER FOCAL LOSS:", alpha_list)
# Out:
# Classe: Building             ID: 8   Peso: 0.4012
# Classe: Bus                  ID: 2   Peso: 0.8158
# Classe: Cargo plane          ID: 0   Peso: 2.2707
# Classe: Dump truck           ID: 6   Peso: 1.1664
# Classe: Excavator            ID: 7   Peso: 1.8281
# Classe: Fishing vessel       ID: 5   Peso: 2.0417
# Classe: Helipad              ID: 9   Peso: 12.9611
# Classe: Motorboat            ID: 4   Peso: 1.3492
# Classe: Pylon                ID: 12  Peso: 4.6142
# Classe: Shipping container   ID: 11  Peso: 0.9471
# Classe: Small car            ID: 1   Peso: 0.4338
# Classe: Storage tank         ID: 10  Peso: 0.9817
# Classe: Truck                ID: 3   Peso: 0.6525
#
# LISTA DEFINITIVA PRONTA PER FOCAL LOSS: [2.270745038986206, 0.43382418155670166, 0.8157980442047119, 0.6524538993835449, 1.349167823791504, 2.041661024093628, 1.1663684844970703, 1.8281116485595703, 0.4012307822704315, 12.961106300354004, 0.9817348718643188, 0.9470759034156799, 4.614153861999512]

# %%
from tensorflow.keras.optimizers import Adam

# Learning rate is changed to 0.001
opt = Adam(learning_rate=1e-3, beta_1=0.9, beta_2=0.999, epsilon=1e-8, amsgrad=True, clipnorm=1.0)
model.compile(optimizer=opt, loss=tf.keras.losses.CategoricalFocalCrossentropy(alpha=alpha_list), metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import TerminateOnNaN, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Callbacks
model_checkpoint = ModelCheckpoint('model.keras', monitor='val_accuracy', verbose=1, save_best_only=True)
reduce_lr = ReduceLROnPlateau('val_accuracy', factor=0.1, patience=10, verbose=1,min_lr=1e-7)
early_stop = EarlyStopping('val_accuracy', patience=22, verbose=1)
terminate = TerminateOnNaN()
callbacks = [model_checkpoint, reduce_lr, early_stop, terminate]

# %%
def generator_images(objs, batch_size, do_shuffle=False, mean=None, std=None):
    while True:
        if do_shuffle:
            np.random.shuffle(objs)
        groups = [objs[i:i+batch_size] for i in range(0, len(objs), batch_size)]
        for group in groups:
            images, labels = [], []
            for (filename, obj) in group:
                
                img = load_geoimage(filename)
                
                
                if mean is not None and std is not None:
                    # Use + 1e-7 to avoid the division for 0
                    img = (img - mean) / (std + 1e-7) 
               
                
                images.append(img)
                probabilities = np.zeros(len(categories))
                probabilities[list(categories.values()).index(obj.category)] = 1
                labels.append(probabilities)
            images = np.array(images).astype(np.float32)
            labels = np.array(labels).astype(np.float32)
            yield images, labels

# %%
def mixup_generator(objs, batch_size, alpha=0.3, mean=None, std=None):
    while True:
        # Prendi due batch casuali
        idx1 = np.random.choice(len(objs), batch_size)
        idx2 = np.random.choice(len(objs), batch_size)
        
        images1, labels1 = [], []
        images2, labels2 = [], []
        
        for i, j in zip(idx1, idx2):
            filename1, obj1 = objs[i]
            filename2, obj2 = objs[j]
            
            img1 = load_geoimage(filename1)
            img2 = load_geoimage(filename2)
            
            if mean is not None:
                img1 = (img1 - mean) / (std + 1e-7)
                img2 = (img2 - mean) / (std + 1e-7)
            
            lbl1 = np.zeros(len(categories))
            lbl1[list(categories.values()).index(obj1.category)] = 1
            lbl2 = np.zeros(len(categories))
            lbl2[list(categories.values()).index(obj2.category)] = 1
            
            images1.append(img1)
            labels1.append(lbl1)
            images2.append(img2)
            labels2.append(lbl2)
        
        images1 = np.array(images1, dtype=np.float32)
        images2 = np.array(images2, dtype=np.float32)
        labels1 = np.array(labels1, dtype=np.float32)
        labels2 = np.array(labels2, dtype=np.float32)
        
        # MixUp
        lam = np.random.beta(alpha, alpha)
        images = lam * images1 + (1 - lam) * images2
        labels = lam * labels1 + (1 - lam) * labels2
        
        yield images, labels

# %%
# Generate the list of objects from annotations
objs_train = [(ann.filename, obj) for ann in anns_train for obj in ann.objects]
objs_valid = [(ann.filename, obj) for ann in anns_valid for obj in ann.objects]
# Generators
batch_size = 32
# Usa questo al posto del train_generator
train_generator = mixup_generator(objs_train, batch_size,
                                   alpha=0.3,
                                   mean=train_mean, std=train_std)
# in caso da rimettere il vecchioo
valid_generator = generator_images(objs_valid, batch_size, do_shuffle=False,mean=train_mean, std=train_std)

# %%
import math
import numpy as np

print('Training model')
epochs = 100
train_steps = math.ceil(len(objs_train)/batch_size)
valid_steps = math.ceil(len(objs_valid)/batch_size)
h = model.fit(train_generator, steps_per_epoch=train_steps, validation_data=valid_generator, validation_steps=valid_steps, epochs=epochs, callbacks=callbacks, verbose=1)
# Best validation model
best_idx = int(np.argmax(h.history['val_accuracy']))
best_value = np.max(h.history['val_accuracy'])
print('Best validation model: epoch ' + str(best_idx+1), ' - val_accuracy ' + str(best_value))
# Out:
# Training model
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1772970322.227716     129 service.cc:152] XLA service 0x7d10c420c9f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1772970322.227759     129 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1772970323.931397     129 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1772970348.290483     129 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.1226 - loss: 2.2110
# Epoch 1: val_accuracy improved from -inf to 0.16373, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 330s 634ms/step - accuracy: 0.1226 - loss: 2.2107 - val_accuracy: 0.1637 - val_loss: 2.5052 - learning_rate: 0.0010
# Epoch 2/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.1769 - loss: 1.9150
# Epoch 2: val_accuracy improved from 0.16373 to 0.23227, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 184s 394ms/step - accuracy: 0.1769 - loss: 1.9149 - val_accuracy: 0.2323 - val_loss: 1.8410 - learning_rate: 0.0010
# Epoch 3/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.2153 - loss: 1.7630
# Epoch 3: val_accuracy improved from 0.23227 to 0.25040, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 172s 367ms/step - accuracy: 0.2153 - loss: 1.7630 - val_accuracy: 0.2504 - val_loss: 1.7312 - learning_rate: 0.0010
# Epoch 4/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.2714 - loss: 1.6248
# Epoch 4: val_accuracy improved from 0.25040 to 0.30107, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 176s 376ms/step - accuracy: 0.2714 - loss: 1.6248 - val_accuracy: 0.3011 - val_loss: 1.7294 - learning_rate: 0.0010
# Epoch 5/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.2861 - loss: 1.5929
# Epoch 5: val_accuracy improved from 0.30107 to 0.31920, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 174s 371ms/step - accuracy: 0.2861 - loss: 1.5929 - val_accuracy: 0.3192 - val_loss: 1.2675 - learning_rate: 0.0010
# Epoch 6/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.3230 - loss: 1.5300
# Epoch 6: val_accuracy did not improve from 0.31920
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 178s 379ms/step - accuracy: 0.3230 - loss: 1.5299 - val_accuracy: 0.2440 - val_loss: 2.1826 - learning_rate: 0.0010
# Epoch 7/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.3472 - loss: 1.4563
# Epoch 7: val_accuracy improved from 0.31920 to 0.41893, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 164s 349ms/step - accuracy: 0.3472 - loss: 1.4563 - val_accuracy: 0.4189 - val_loss: 1.2479 - learning_rate: 0.0010
# Epoch 8/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.3522 - loss: 1.4708
# Epoch 8: val_accuracy did not improve from 0.41893
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 159s 339ms/step - accuracy: 0.3522 - loss: 1.4707 - val_accuracy: 0.3691 - val_loss: 1.2553 - learning_rate: 0.0010
# Epoch 9/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.3761 - loss: 1.3921
# Epoch 9: val_accuracy did not improve from 0.41893
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 174s 372ms/step - accuracy: 0.3760 - loss: 1.3921 - val_accuracy: 0.3989 - val_loss: 1.1924 - learning_rate: 0.0010
# Epoch 10/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.3742 - loss: 1.3889
# Epoch 10: val_accuracy did not improve from 0.41893
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 166s 354ms/step - accuracy: 0.3743 - loss: 1.3889 - val_accuracy: 0.2955 - val_loss: 1.2836 - learning_rate: 0.0010
# Epoch 11/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.3989 - loss: 1.3403
# Epoch 11: val_accuracy did not improve from 0.41893
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 165s 352ms/step - accuracy: 0.3989 - loss: 1.3404 - val_accuracy: 0.3888 - val_loss: 1.1484 - learning_rate: 0.0010
# Epoch 12/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.3924 - loss: 1.3228
# Epoch 12: val_accuracy did not improve from 0.41893
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 165s 352ms/step - accuracy: 0.3925 - loss: 1.3227 - val_accuracy: 0.4120 - val_loss: 1.1063 - learning_rate: 0.0010
# Epoch 13/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.3990 - loss: 1.2911
# Epoch 13: val_accuracy did not improve from 0.41893
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 174s 372ms/step - accuracy: 0.3990 - loss: 1.2911 - val_accuracy: 0.3656 - val_loss: 1.2441 - learning_rate: 0.0010
# Epoch 14/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.4045 - loss: 1.3009
# Epoch 14: val_accuracy improved from 0.41893 to 0.44000, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 167s 356ms/step - accuracy: 0.4045 - loss: 1.3009 - val_accuracy: 0.4400 - val_loss: 1.0431 - learning_rate: 0.0010
# Epoch 15/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.4213 - loss: 1.2599
# Epoch 15: val_accuracy did not improve from 0.44000
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 157s 335ms/step - accuracy: 0.4213 - loss: 1.2599 - val_accuracy: 0.3765 - val_loss: 1.2014 - learning_rate: 0.0010
# Epoch 16/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.4189 - loss: 1.2394
# Epoch 16: val_accuracy improved from 0.44000 to 0.44800, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 164s 349ms/step - accuracy: 0.4189 - loss: 1.2394 - val_accuracy: 0.4480 - val_loss: 1.0404 - learning_rate: 0.0010
# Epoch 17/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.4252 - loss: 1.2215
# Epoch 17: val_accuracy improved from 0.44800 to 0.49813, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 162s 346ms/step - accuracy: 0.4252 - loss: 1.2216 - val_accuracy: 0.4981 - val_loss: 0.9477 - learning_rate: 0.0010
# Epoch 18/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.4414 - loss: 1.2481
# Epoch 18: val_accuracy did not improve from 0.49813
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 158s 337ms/step - accuracy: 0.4414 - loss: 1.2481 - val_accuracy: 0.4693 - val_loss: 1.0963 - learning_rate: 0.0010
# Epoch 19/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.4337 - loss: 1.2406
# Epoch 19: val_accuracy did not improve from 0.49813
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 161s 344ms/step - accuracy: 0.4337 - loss: 1.2406 - val_accuracy: 0.3909 - val_loss: 1.1042 - learning_rate: 0.0010
# Epoch 20/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.4482 - loss: 1.2055
# Epoch 20: val_accuracy did not improve from 0.49813
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 163s 347ms/step - accuracy: 0.4483 - loss: 1.2054 - val_accuracy: 0.4691 - val_loss: 1.1023 - learning_rate: 0.0010
# Epoch 21/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.4584 - loss: 1.1779
# Epoch 21: val_accuracy did not improve from 0.49813
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 158s 338ms/step - accuracy: 0.4584 - loss: 1.1780 - val_accuracy: 0.4549 - val_loss: 1.0569 - learning_rate: 0.0010
# Epoch 22/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.4680 - loss: 1.1384
# Epoch 22: val_accuracy did not improve from 0.49813
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 160s 342ms/step - accuracy: 0.4680 - loss: 1.1384 - val_accuracy: 0.4757 - val_loss: 0.9602 - learning_rate: 0.0010
# Epoch 23/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.4492 - loss: 1.2188
# Epoch 23: val_accuracy improved from 0.49813 to 0.50960, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 161s 344ms/step - accuracy: 0.4492 - loss: 1.2188 - val_accuracy: 0.5096 - val_loss: 0.9221 - learning_rate: 0.0010
# Epoch 24/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.4546 - loss: 1.1947
# Epoch 24: val_accuracy did not improve from 0.50960
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 159s 340ms/step - accuracy: 0.4546 - loss: 1.1947 - val_accuracy: 0.4440 - val_loss: 0.9669 - learning_rate: 0.0010
# Epoch 25/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.4607 - loss: 1.1645
# Epoch 25: val_accuracy did not improve from 0.50960
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 153s 327ms/step - accuracy: 0.4607 - loss: 1.1645 - val_accuracy: 0.4965 - val_loss: 0.8942 - learning_rate: 0.0010
# Epoch 26/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.4654 - loss: 1.1318
# Epoch 26: val_accuracy improved from 0.50960 to 0.51173, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 155s 332ms/step - accuracy: 0.4654 - loss: 1.1318 - val_accuracy: 0.5117 - val_loss: 0.9074 - learning_rate: 0.0010
# Epoch 27/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.4722 - loss: 1.1303
# Epoch 27: val_accuracy improved from 0.51173 to 0.52373, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 153s 327ms/step - accuracy: 0.4722 - loss: 1.1304 - val_accuracy: 0.5237 - val_loss: 0.9404 - learning_rate: 0.0010
# Epoch 28/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.4669 - loss: 1.1327
# Epoch 28: val_accuracy improved from 0.52373 to 0.53600, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 155s 331ms/step - accuracy: 0.4669 - loss: 1.1327 - val_accuracy: 0.5360 - val_loss: 0.8661 - learning_rate: 0.0010
# Epoch 29/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.4702 - loss: 1.1224
# Epoch 29: val_accuracy did not improve from 0.53600
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 155s 331ms/step - accuracy: 0.4702 - loss: 1.1223 - val_accuracy: 0.5357 - val_loss: 0.8842 - learning_rate: 0.0010
# Epoch 30/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.4940 - loss: 1.0811
# Epoch 30: val_accuracy improved from 0.53600 to 0.54000, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 154s 328ms/step - accuracy: 0.4940 - loss: 1.0812 - val_accuracy: 0.5400 - val_loss: 0.8987 - learning_rate: 0.0010
# Epoch 31/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.4999 - loss: 1.0472
# Epoch 31: val_accuracy improved from 0.54000 to 0.56613, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 153s 327ms/step - accuracy: 0.4999 - loss: 1.0472 - val_accuracy: 0.5661 - val_loss: 0.8496 - learning_rate: 0.0010
# Epoch 32/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.4964 - loss: 1.0771
# Epoch 32: val_accuracy did not improve from 0.56613
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 153s 327ms/step - accuracy: 0.4964 - loss: 1.0771 - val_accuracy: 0.5267 - val_loss: 0.8599 - learning_rate: 0.0010
# Epoch 33/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.5022 - loss: 1.0388
# Epoch 33: val_accuracy did not improve from 0.56613
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 153s 327ms/step - accuracy: 0.5022 - loss: 1.0388 - val_accuracy: 0.5024 - val_loss: 0.8777 - learning_rate: 0.0010
# Epoch 34/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.4932 - loss: 1.0728
# Epoch 34: val_accuracy did not improve from 0.56613
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 153s 327ms/step - accuracy: 0.4932 - loss: 1.0727 - val_accuracy: 0.5440 - val_loss: 0.8602 - learning_rate: 0.0010
# Epoch 35/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.4968 - loss: 1.0797
# Epoch 35: val_accuracy did not improve from 0.56613
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 151s 322ms/step - accuracy: 0.4968 - loss: 1.0797 - val_accuracy: 0.5163 - val_loss: 0.8499 - learning_rate: 0.0010
# Epoch 36/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.5068 - loss: 1.0569
# Epoch 36: val_accuracy did not improve from 0.56613
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 151s 323ms/step - accuracy: 0.5068 - loss: 1.0568 - val_accuracy: 0.4680 - val_loss: 0.9260 - learning_rate: 0.0010
# Epoch 37/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.4955 - loss: 1.0945
# Epoch 37: val_accuracy did not improve from 0.56613
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 154s 328ms/step - accuracy: 0.4955 - loss: 1.0944 - val_accuracy: 0.5437 - val_loss: 0.8173 - learning_rate: 0.0010
# Epoch 38/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.5063 - loss: 1.0368
# Epoch 38: val_accuracy improved from 0.56613 to 0.57920, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 154s 329ms/step - accuracy: 0.5063 - loss: 1.0368 - val_accuracy: 0.5792 - val_loss: 0.7936 - learning_rate: 0.0010
# Epoch 39/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.5233 - loss: 0.9899
# Epoch 39: val_accuracy did not improve from 0.57920
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 152s 324ms/step - accuracy: 0.5233 - loss: 0.9900 - val_accuracy: 0.4979 - val_loss: 0.8399 - learning_rate: 0.0010
# Epoch 40/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.5249 - loss: 0.9865
# Epoch 40: val_accuracy did not improve from 0.57920
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 154s 329ms/step - accuracy: 0.5249 - loss: 0.9865 - val_accuracy: 0.5272 - val_loss: 0.8272 - learning_rate: 0.0010
# Epoch 41/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.5248 - loss: 0.9927
# Epoch 41: val_accuracy did not improve from 0.57920
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 155s 331ms/step - accuracy: 0.5248 - loss: 0.9928 - val_accuracy: 0.5195 - val_loss: 0.9172 - learning_rate: 0.0010
# Epoch 42/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.5198 - loss: 1.0144
# Epoch 42: val_accuracy did not improve from 0.57920
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 156s 334ms/step - accuracy: 0.5198 - loss: 1.0144 - val_accuracy: 0.5451 - val_loss: 0.7710 - learning_rate: 0.0010
# Epoch 43/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.5364 - loss: 0.9576
# Epoch 43: val_accuracy did not improve from 0.57920
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 160s 341ms/step - accuracy: 0.5364 - loss: 0.9576 - val_accuracy: 0.5120 - val_loss: 0.7961 - learning_rate: 0.0010
# Epoch 44/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.5303 - loss: 0.9799
# Epoch 44: val_accuracy did not improve from 0.57920
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 160s 341ms/step - accuracy: 0.5303 - loss: 0.9799 - val_accuracy: 0.5637 - val_loss: 0.7948 - learning_rate: 0.0010
# Epoch 45/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.5331 - loss: 0.9893
# Epoch 45: val_accuracy improved from 0.57920 to 0.59493, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 158s 338ms/step - accuracy: 0.5331 - loss: 0.9894 - val_accuracy: 0.5949 - val_loss: 0.7112 - learning_rate: 0.0010
# Epoch 46/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.5230 - loss: 0.9982
# Epoch 46: val_accuracy improved from 0.59493 to 0.60213, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 156s 332ms/step - accuracy: 0.5230 - loss: 0.9982 - val_accuracy: 0.6021 - val_loss: 0.7758 - learning_rate: 0.0010
# Epoch 47/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.5381 - loss: 1.0003
# Epoch 47: val_accuracy did not improve from 0.60213
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 153s 327ms/step - accuracy: 0.5381 - loss: 1.0002 - val_accuracy: 0.5829 - val_loss: 0.7936 - learning_rate: 0.0010
# Epoch 48/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.5396 - loss: 0.9521
# Epoch 48: val_accuracy did not improve from 0.60213
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 153s 327ms/step - accuracy: 0.5396 - loss: 0.9521 - val_accuracy: 0.5560 - val_loss: 0.7920 - learning_rate: 0.0010
# Epoch 49/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.5359 - loss: 0.9831
# Epoch 49: val_accuracy did not improve from 0.60213
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 152s 325ms/step - accuracy: 0.5360 - loss: 0.9830 - val_accuracy: 0.5960 - val_loss: 0.7004 - learning_rate: 0.0010
# Epoch 50/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.5504 - loss: 0.9553
# Epoch 50: val_accuracy improved from 0.60213 to 0.61493, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 160s 342ms/step - accuracy: 0.5504 - loss: 0.9553 - val_accuracy: 0.6149 - val_loss: 0.6969 - learning_rate: 0.0010
# Epoch 51/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.5447 - loss: 0.9433
# Epoch 51: val_accuracy did not improve from 0.61493
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 156s 333ms/step - accuracy: 0.5447 - loss: 0.9433 - val_accuracy: 0.5925 - val_loss: 0.6880 - learning_rate: 0.0010
# Epoch 52/100
# 131/469 ━━━━━━━━━━━━━━━━━━━━ 1:18 232ms/step - accuracy: 0.5537 - loss: 0.8903
# Epoch 52: val_accuracy did not improve from 0.61493
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 155s 330ms/step - accuracy: 0.5513 - loss: 0.9179 - val_accuracy: 0.5760 - val_loss: 0.7440 - learning_rate: 0.0010
# Epoch 53/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.5553 - loss: 0.9394
# Epoch 53: val_accuracy did not improve from 0.61493
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 153s 326ms/step - accuracy: 0.5553 - loss: 0.9395 - val_accuracy: 0.5917 - val_loss: 0.7183 - learning_rate: 0.0010
# Epoch 54/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.5604 - loss: 0.9427
# Epoch 54: val_accuracy improved from 0.61493 to 0.63040, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 157s 335ms/step - accuracy: 0.5603 - loss: 0.9427 - val_accuracy: 0.6304 - val_loss: 0.7136 - learning_rate: 0.0010
# Epoch 55/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.5607 - loss: 0.9146
# Epoch 55: val_accuracy did not improve from 0.63040
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 172s 366ms/step - accuracy: 0.5607 - loss: 0.9147 - val_accuracy: 0.5928 - val_loss: 0.7311 - learning_rate: 0.0010
# Epoch 56/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.5466 - loss: 0.9264
# Epoch 56: val_accuracy did not improve from 0.63040
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 170s 362ms/step - accuracy: 0.5466 - loss: 0.9263 - val_accuracy: 0.5915 - val_loss: 0.7011 - learning_rate: 0.0010
# Epoch 57/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.5640 - loss: 0.9103
# Epoch 57: val_accuracy did not improve from 0.63040
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 169s 360ms/step - accuracy: 0.5640 - loss: 0.9103 - val_accuracy: 0.5707 - val_loss: 0.7641 - learning_rate: 0.0010
# Epoch 58/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.5584 - loss: 0.9195
# Epoch 58: val_accuracy did not improve from 0.63040
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 172s 367ms/step - accuracy: 0.5584 - loss: 0.9196 - val_accuracy: 0.6112 - val_loss: 0.7156 - learning_rate: 0.0010
# Epoch 59/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.5726 - loss: 0.8883
# Epoch 59: val_accuracy improved from 0.63040 to 0.63227, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 168s 358ms/step - accuracy: 0.5725 - loss: 0.8883 - val_accuracy: 0.6323 - val_loss: 0.7157 - learning_rate: 0.0010
# Epoch 60/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.5601 - loss: 0.9535
# Epoch 60: val_accuracy did not improve from 0.63227
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 153s 326ms/step - accuracy: 0.5601 - loss: 0.9535 - val_accuracy: 0.6155 - val_loss: 0.7086 - learning_rate: 0.0010
# Epoch 61/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.5730 - loss: 0.8805
# Epoch 61: val_accuracy did not improve from 0.63227
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 150s 320ms/step - accuracy: 0.5730 - loss: 0.8804 - val_accuracy: 0.6232 - val_loss: 0.6961 - learning_rate: 0.0010
# Epoch 62/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.5833 - loss: 0.8474
# Epoch 62: val_accuracy did not improve from 0.63227
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 151s 321ms/step - accuracy: 0.5833 - loss: 0.8475 - val_accuracy: 0.6123 - val_loss: 0.6822 - learning_rate: 0.0010
# Epoch 63/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.5711 - loss: 0.8777
# Epoch 63: val_accuracy did not improve from 0.63227
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 154s 329ms/step - accuracy: 0.5711 - loss: 0.8777 - val_accuracy: 0.5955 - val_loss: 0.7149 - learning_rate: 0.0010
# Epoch 64/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.5834 - loss: 0.8525
# Epoch 64: val_accuracy did not improve from 0.63227
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 151s 322ms/step - accuracy: 0.5834 - loss: 0.8526 - val_accuracy: 0.6069 - val_loss: 0.6774 - learning_rate: 0.0010
# Epoch 65/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.5676 - loss: 0.9027
# Epoch 65: val_accuracy did not improve from 0.63227
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 154s 328ms/step - accuracy: 0.5676 - loss: 0.9027 - val_accuracy: 0.5917 - val_loss: 0.7264 - learning_rate: 0.0010
# Epoch 66/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.5695 - loss: 0.8790
# Epoch 66: val_accuracy did not improve from 0.63227
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 152s 324ms/step - accuracy: 0.5695 - loss: 0.8790 - val_accuracy: 0.5960 - val_loss: 0.7226 - learning_rate: 0.0010
# Epoch 67/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.5831 - loss: 0.8791
# Epoch 67: val_accuracy did not improve from 0.63227
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 154s 329ms/step - accuracy: 0.5831 - loss: 0.8791 - val_accuracy: 0.6205 - val_loss: 0.6764 - learning_rate: 0.0010
# Epoch 68/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.5824 - loss: 0.8659
# Epoch 68: val_accuracy did not improve from 0.63227
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 153s 327ms/step - accuracy: 0.5824 - loss: 0.8659 - val_accuracy: 0.6024 - val_loss: 0.7379 - learning_rate: 0.0010
# Epoch 69/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.5838 - loss: 0.8662
# Epoch 69: val_accuracy did not improve from 0.63227
#
# Epoch 69: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 153s 326ms/step - accuracy: 0.5838 - loss: 0.8661 - val_accuracy: 0.5947 - val_loss: 0.6919 - learning_rate: 0.0010
# Epoch 70/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.5970 - loss: 0.8672
# Epoch 70: val_accuracy improved from 0.63227 to 0.66587, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 155s 330ms/step - accuracy: 0.5970 - loss: 0.8671 - val_accuracy: 0.6659 - val_loss: 0.5748 - learning_rate: 1.0000e-04
# Epoch 71/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - accuracy: 0.5997 - loss: 0.8142
# Epoch 71: val_accuracy did not improve from 0.66587
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 155s 330ms/step - accuracy: 0.5997 - loss: 0.8142 - val_accuracy: 0.6608 - val_loss: 0.5768 - learning_rate: 1.0000e-04
# Epoch 72/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.6140 - loss: 0.8245
# Epoch 72: val_accuracy did not improve from 0.66587
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 158s 337ms/step - accuracy: 0.6140 - loss: 0.8246 - val_accuracy: 0.6549 - val_loss: 0.5792 - learning_rate: 1.0000e-04
# Epoch 73/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.6165 - loss: 0.8036
# Epoch 73: val_accuracy improved from 0.66587 to 0.66800, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 155s 331ms/step - accuracy: 0.6165 - loss: 0.8036 - val_accuracy: 0.6680 - val_loss: 0.5712 - learning_rate: 1.0000e-04
# Epoch 74/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.6209 - loss: 0.7812
# Epoch 74: val_accuracy did not improve from 0.66800
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 153s 326ms/step - accuracy: 0.6209 - loss: 0.7812 - val_accuracy: 0.6672 - val_loss: 0.5670 - learning_rate: 1.0000e-04
# Epoch 75/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.6125 - loss: 0.8077
# Epoch 75: val_accuracy improved from 0.66800 to 0.66880, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 153s 327ms/step - accuracy: 0.6125 - loss: 0.8076 - val_accuracy: 0.6688 - val_loss: 0.5648 - learning_rate: 1.0000e-04
# Epoch 76/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.6125 - loss: 0.8234
# Epoch 76: val_accuracy did not improve from 0.66880
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 151s 321ms/step - accuracy: 0.6125 - loss: 0.8234 - val_accuracy: 0.6677 - val_loss: 0.5679 - learning_rate: 1.0000e-04
# Epoch 77/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.6158 - loss: 0.7832
# Epoch 77: val_accuracy improved from 0.66880 to 0.67280, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 157s 335ms/step - accuracy: 0.6158 - loss: 0.7833 - val_accuracy: 0.6728 - val_loss: 0.5775 - learning_rate: 1.0000e-04
# Epoch 78/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.6109 - loss: 0.7850
# Epoch 78: val_accuracy did not improve from 0.67280
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 158s 338ms/step - accuracy: 0.6109 - loss: 0.7851 - val_accuracy: 0.6728 - val_loss: 0.5689 - learning_rate: 1.0000e-04
# Epoch 79/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - accuracy: 0.6366 - loss: 0.7728
# Epoch 79: val_accuracy did not improve from 0.67280
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 156s 332ms/step - accuracy: 0.6366 - loss: 0.7728 - val_accuracy: 0.6707 - val_loss: 0.5621 - learning_rate: 1.0000e-04
# Epoch 80/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.6236 - loss: 0.7851
# Epoch 80: val_accuracy did not improve from 0.67280
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 154s 329ms/step - accuracy: 0.6235 - loss: 0.7851 - val_accuracy: 0.6699 - val_loss: 0.5664 - learning_rate: 1.0000e-04
# Epoch 81/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.6281 - loss: 0.7656
# Epoch 81: val_accuracy did not improve from 0.67280
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 152s 324ms/step - accuracy: 0.6281 - loss: 0.7656 - val_accuracy: 0.6709 - val_loss: 0.5753 - learning_rate: 1.0000e-04
# Epoch 82/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.6214 - loss: 0.7697
# Epoch 82: val_accuracy improved from 0.67280 to 0.67653, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 152s 325ms/step - accuracy: 0.6214 - loss: 0.7698 - val_accuracy: 0.6765 - val_loss: 0.5596 - learning_rate: 1.0000e-04
# Epoch 83/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.6209 - loss: 0.7799
# Epoch 83: val_accuracy improved from 0.67653 to 0.68000, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 150s 320ms/step - accuracy: 0.6209 - loss: 0.7799 - val_accuracy: 0.6800 - val_loss: 0.5602 - learning_rate: 1.0000e-04
# Epoch 84/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.6272 - loss: 0.7748
# Epoch 84: val_accuracy did not improve from 0.68000
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 150s 319ms/step - accuracy: 0.6272 - loss: 0.7748 - val_accuracy: 0.6747 - val_loss: 0.5598 - learning_rate: 1.0000e-04
# Epoch 85/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.6187 - loss: 0.7920
# Epoch 85: val_accuracy did not improve from 0.68000
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 165s 351ms/step - accuracy: 0.6187 - loss: 0.7920 - val_accuracy: 0.6669 - val_loss: 0.5652 - learning_rate: 1.0000e-04
# Epoch 86/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.6252 - loss: 0.7936
# Epoch 86: val_accuracy did not improve from 0.68000
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 154s 328ms/step - accuracy: 0.6252 - loss: 0.7936 - val_accuracy: 0.6771 - val_loss: 0.5505 - learning_rate: 1.0000e-04
# Epoch 87/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.6196 - loss: 0.7583
# Epoch 87: val_accuracy did not improve from 0.68000
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 152s 324ms/step - accuracy: 0.6196 - loss: 0.7583 - val_accuracy: 0.6784 - val_loss: 0.5683 - learning_rate: 1.0000e-04
# Epoch 88/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.6364 - loss: 0.7611
# Epoch 88: val_accuracy did not improve from 0.68000
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 154s 328ms/step - accuracy: 0.6364 - loss: 0.7611 - val_accuracy: 0.6773 - val_loss: 0.5532 - learning_rate: 1.0000e-04
# Epoch 89/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - accuracy: 0.6363 - loss: 0.7357
# Epoch 89: val_accuracy did not improve from 0.68000
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 155s 331ms/step - accuracy: 0.6362 - loss: 0.7357 - val_accuracy: 0.6723 - val_loss: 0.5501 - learning_rate: 1.0000e-04
# Epoch 90/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.6268 - loss: 0.7538
# Epoch 90: val_accuracy did not improve from 0.68000
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 156s 333ms/step - accuracy: 0.6268 - loss: 0.7537 - val_accuracy: 0.6760 - val_loss: 0.5505 - learning_rate: 1.0000e-04
# Epoch 91/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.6355 - loss: 0.7363
# Epoch 91: val_accuracy improved from 0.68000 to 0.68587, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 153s 325ms/step - accuracy: 0.6355 - loss: 0.7364 - val_accuracy: 0.6859 - val_loss: 0.5450 - learning_rate: 1.0000e-04
# Epoch 92/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.6222 - loss: 0.7859
# Epoch 92: val_accuracy did not improve from 0.68587
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 151s 322ms/step - accuracy: 0.6222 - loss: 0.7859 - val_accuracy: 0.6667 - val_loss: 0.5519 - learning_rate: 1.0000e-04
# Epoch 93/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - accuracy: 0.6260 - loss: 0.7665
# Epoch 93: val_accuracy did not improve from 0.68587
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 155s 330ms/step - accuracy: 0.6260 - loss: 0.7664 - val_accuracy: 0.6744 - val_loss: 0.5528 - learning_rate: 1.0000e-04
# Epoch 94/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.6189 - loss: 0.8002
# Epoch 94: val_accuracy did not improve from 0.68587
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 151s 323ms/step - accuracy: 0.6189 - loss: 0.8002 - val_accuracy: 0.6824 - val_loss: 0.5598 - learning_rate: 1.0000e-04
# Epoch 95/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.6256 - loss: 0.7895
# Epoch 95: val_accuracy did not improve from 0.68587
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 151s 323ms/step - accuracy: 0.6257 - loss: 0.7894 - val_accuracy: 0.6736 - val_loss: 0.5677 - learning_rate: 1.0000e-04
# Epoch 96/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.6215 - loss: 0.8031
# Epoch 96: val_accuracy did not improve from 0.68587
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 154s 328ms/step - accuracy: 0.6215 - loss: 0.8031 - val_accuracy: 0.6736 - val_loss: 0.5493 - learning_rate: 1.0000e-04
# Epoch 97/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.6327 - loss: 0.7467
# Epoch 97: val_accuracy did not improve from 0.68587
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 153s 327ms/step - accuracy: 0.6327 - loss: 0.7467 - val_accuracy: 0.6779 - val_loss: 0.5494 - learning_rate: 1.0000e-04
# Epoch 98/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.6274 - loss: 0.7681
# Epoch 98: val_accuracy did not improve from 0.68587
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 157s 334ms/step - accuracy: 0.6274 - loss: 0.7681 - val_accuracy: 0.6824 - val_loss: 0.5654 - learning_rate: 1.0000e-04
# Epoch 99/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.6333 - loss: 0.7583
# Epoch 99: val_accuracy did not improve from 0.68587
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 154s 329ms/step - accuracy: 0.6333 - loss: 0.7583 - val_accuracy: 0.6763 - val_loss: 0.5648 - learning_rate: 1.0000e-04
# Epoch 100/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.6350 - loss: 0.7476
# Epoch 100: val_accuracy did not improve from 0.68587
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 153s 327ms/step - accuracy: 0.6350 - loss: 0.7477 - val_accuracy: 0.6795 - val_loss: 0.5546 - learning_rate: 1.0000e-04
# Best validation model: epoch 91  - val_accuracy 0.68586665391922

# %%
import matplotlib.pyplot as plt

def plot_results(history):
    
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    
    
    epochs_range = range(1, len(acc) + 1)

    plt.figure(figsize=(16, 6))

    # --- GRAFICO 1: ACCURACY
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy', color='blue', marker='o')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy', color='red', marker='o')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epoche')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')
    plt.grid(True)

    # --- GRAFICO 2: LOSS 
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss', color='blue', linestyle='--')
    plt.plot(epochs_range, val_loss, label='Validation Loss', color='red', linestyle='--')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoche')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')
    plt.grid(True)

    plt.show()


plot_results(h)

# %% [markdown]
# #### Validation
# Compute validation metrics.

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

def draw_confusion_matrix(cm, categories):
    # Draw confusion matrix
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    cm = cm.astype('float') / np.maximum(cm.sum(axis=1)[:, np.newaxis], np.finfo(np.float64).eps)
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.colormaps['Blues'])
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=list(categories.values()), yticklabels=list(categories.values()), ylabel='Annotation', xlabel='Prediction')
    # Rotate the tick labels and set their alignment
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Loop over data dimensions and create text annotations
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], '.2f'), ha="center", va="center", color="white" if cm[i, j] > thresh else "black", fontsize=int(20-pow(len(categories), 0.5)))
    fig.tight_layout()
    plt.show()

# %%
import numpy as np

model.load_weights('model.keras')
y_true, y_pred = [], []
for ann in anns_valid:
    # Load image
    image = load_geoimage(ann.filename)
    image = image.astype(np.float64)
    image = (image - train_mean) / (train_std + 1e-7)
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        y_true.append(obj_pred.category)
        y_pred.append(pred_category)

# %%
from sklearn.metrics import confusion_matrix

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=list(categories.values()))
draw_confusion_matrix(cm, categories)

# %%
import numpy as np

# Compute the accuracy
correct_samples_class = np.diag(cm).astype(float)
total_samples_class = np.sum(cm, axis=1).astype(float)
total_predicts_class = np.sum(cm, axis=0).astype(float)
print('Mean Accuracy: %.3f%%' % (np.sum(correct_samples_class) / np.sum(total_samples_class) * 100))
acc = correct_samples_class / np.maximum(total_samples_class, np.finfo(np.float64).eps)
print('Mean Recall: %.3f%%' % (acc.mean() * 100))
acc = correct_samples_class / np.maximum(total_predicts_class, np.finfo(np.float64).eps)
print('Mean Precision: %.3f%%' % (acc.mean() * 100))
for idx in range(len(categories)):
    # True/False Positives (TP/FP) refer to the number of predicted positives that were correct/incorrect.
    # True/False Negatives (TN/FN) refer to the number of predicted negatives that were correct/incorrect.
    tp = cm[idx, idx]
    fp = sum(cm[:, idx]) - tp
    fn = sum(cm[idx, :]) - tp
    tn = sum(np.delete(sum(cm) - cm[idx, :], idx))
    # True Positive Rate: proportion of real positive cases that were correctly predicted as positive.
    recall = tp / np.maximum(tp+fn, np.finfo(np.float64).eps)
    # Precision: proportion of predicted positive cases that were truly real positives.
    precision = tp / np.maximum(tp+fp, np.finfo(np.float64).eps)
    # True Negative Rate: proportion of real negative cases that were correctly predicted as negative.
    specificity = tn / np.maximum(tn+fp, np.finfo(np.float64).eps)
    # Dice coefficient refers to two times the intersection of two sets divided by the sum of their areas.
    # Dice = 2 |A∩B| / (|A|+|B|) = 2 TP / (2 TP + FP + FN)
    f1_score = 2 * ((precision * recall) / np.maximum(precision+recall, np.finfo(np.float64).eps))
    print('> %s: Recall: %.3f%% Precision: %.3f%% Specificity: %.3f%% Dice: %.3f%%' % (list(categories.values())[idx], recall*100, precision*100, specificity*100, f1_score*100))
# Out:
# Mean Accuracy: 68.587%
# Mean Recall: 71.925%
# Mean Precision: 65.626%
# > Cargo plane: Recall: 94.488% Precision: 84.507% Specificity: 99.393% Dice: 89.219%
# > Small car: Recall: 84.060% Precision: 77.103% Specificity: 94.619% Dice: 80.432%
# > Bus: Recall: 61.864% Precision: 54.750% Specificity: 94.670% Dice: 58.090%
# > Truck: Recall: 23.982% Precision: 42.231% Specificity: 95.617% Dice: 30.592%
# > Motorboat: Recall: 77.570% Precision: 62.172% Specificity: 97.144% Dice: 69.023%
# > Fishing vessel: Recall: 78.723% Precision: 68.519% Specificity: 98.587% Dice: 73.267%
# > Dump truck: Recall: 62.753% Precision: 50.162% Specificity: 95.604% Dice: 55.755%
# > Excavator: Recall: 78.481% Precision: 68.508% Specificity: 98.413% Dice: 73.156%
# > Building: Recall: 72.045% Precision: 88.851% Specificity: 97.855% Dice: 79.570%
# > Helipad: Recall: 72.727% Precision: 50.000% Specificity: 99.571% Dice: 59.259%
# > Storage tank: Recall: 61.565% Precision: 76.371% Specificity: 98.380% Dice: 68.173%
# > Shipping container: Recall: 79.672% Precision: 64.116% Specificity: 96.052% Dice: 71.053%
# > Pylon: Recall: 87.097% Precision: 65.854% Specificity: 99.241% Dice: 75.000%

# %% [markdown]
# #### Testing
# Try to improve the results provided in the competition.

# %%
import os
import numpy as np

anns = []
for (dirpath, dirnames, filenames) in os.walk('/kaggle/input/datasets/alexferroni/recognition/xview_recognition/xview_test'):
    for filename in filenames:
        relative_path = os.path.join('xview_test', filename)
        image = GenericImage(relative_path)
        image.tile = np.array([0, 0, 224, 224])
        obj = GenericObject()
        obj.bb = (0, 0, 224, 224)
        obj.category = dirpath[dirpath.rfind('/')+1:]
        image.add_object(obj)
        anns.append(image)
print('Number of testing images: ' + str(len(anns)))
# Out:
# Number of testing images: 2365

# %%
import numpy as np

model.load_weights('model.keras')
predictions_data = {"images": {}, "annotations": {}}
for idx, ann in enumerate(anns):
    image_data = {"image_id": ann.filename.split('/')[-1], "filename": ann.filename, "width": int(ann.tile[2]), "height": int(ann.tile[3])}
    predictions_data["images"][idx] = image_data
    # Load image
    image = load_geoimage(ann.filename)
    image = image.astype(np.float64)
    image = (image - train_mean) / (train_std + 1e-7)
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        annotation_data = {"image_id": ann.filename.split('/')[-1], "category_id": pred_category, "bbox": [int(x) for x in obj_pred.bb]}
        predictions_data["annotations"][idx] = annotation_data

# %%
with open("prediction.json", "w") as outfile:
    json.dump(predictions_data, outfile)

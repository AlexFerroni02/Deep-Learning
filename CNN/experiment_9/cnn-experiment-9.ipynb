# %% [markdown]
# ## Assignment: Image recognition
# - Alumno 1: Alex Ferroni
# - Alumno 2: Vittorio Alberto Gianfrate
# - Alumno 3:
#
# The goals of the assignment are:
# * Develop proficiency in using Tensorflow/Keras for training Neural Nets (NNs).
# * Put into practice the acquired knowledge to optimize the parameters and architecture of a feedforward Neural Net (ffNN), in the context of an image recognition problem.
# * Put into practice NNs specially conceived for analysing images. Design and optimize the parameters of a Convolutional Neural Net (CNN) to deal with previous task.
# * Train popular architectures from scratch (e.g., GoogLeNet, VGG, ResNet, ...), and compare the results with the ones provided by their pre-trained versions using transfer learning.
#
# Follow the link below to download the classification data set  “xview_recognition”: [https://drive.upm.es/s/2DDPE2zHw5dbM3G](https://drive.upm.es/s/2DDPE2zHw5dbM3G)

# %%
# !pip install rasterio
# Out:
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (1.5.0)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio) (25.4.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from rasterio) (2026.1.4)
# Requirement already satisfied: click!=8.2.*,>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio) (8.3.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.0.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio) (3.3.2)

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# 2026-04-03 15:33:59.154710: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775230439.352306      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775230439.404238      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775230439.827898      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775230439.827956      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775230439.827961      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775230439.827964      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import uuid
import numpy as np

class GenericObject:
    """
    Generic object data.
    """
    def __init__(self):
        self.id = uuid.uuid4()
        self.bb = (-1, -1, -1, -1)
        self.category= -1
        self.score = -1

class GenericImage:
    """
    Generic image data.
    """
    def __init__(self, filename):
        self.filename = filename
        self.tile = np.array([-1, -1, -1, -1])  # (pt_x, pt_y, pt_x+width, pt_y+height)
        self.objects = list([])

    def add_object(self, obj: GenericObject):
        self.objects.append(obj)

# %%
categories = {0: 'Cargo plane', 1: 'Small car', 2: 'Bus', 3: 'Truck', 4: 'Motorboat', 5: 'Fishing vessel', 6: 'Dump truck', 7: 'Excavator', 8: 'Building', 9: 'Helipad', 10: 'Storage tank', 11: 'Shipping container', 12: 'Pylon'}

# %%
import warnings
import rasterio
import numpy as np
import os
import cv2

def load_geoimage(filename):
    warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
    base_path = '/kaggle/input/datasets/alexferroni/recognition/xview_recognition/'
    
    src_raster = rasterio.open(base_path + filename, 'r')
    # --------------------

    # RasterIO to OpenCV
    input_type = src_raster.profile['dtype']
    input_channels = src_raster.count
    img = np.zeros((src_raster.height, src_raster.width, src_raster.count), dtype=input_type)
    for band in range(input_channels):
        img[:, :, band] = src_raster.read(band+1)
   
    return img

# %% [markdown]
# #### Training
# Design and train a ffNN to deal with the “xview_recognition” classification task.

# %%
import json
import os


json_file = '/kaggle/input/datasets/alexferroni/recognition/xview_recognition/xview_ann_train.json'

print(f"Caricamento annotazioni da: {json_file}")

with open(json_file) as ifs:
    json_data = json.load(ifs)
    
print("Annotazioni caricate con successo!")
# Out:
# Caricamento annotazioni da: /kaggle/input/datasets/alexferroni/recognition/xview_recognition/xview_ann_train.json
# Annotazioni caricate con successo!

# %%
import numpy as np

counts = dict.fromkeys(categories.values(), 0)
anns = []
for json_img, json_ann in zip(json_data['images'].values(), json_data['annotations'].values()):
    image = GenericImage(json_img['filename'])
    image.tile = np.array([0, 0, json_img['width'], json_img['height']])
    obj = GenericObject()
    obj.bb = (int(json_ann['bbox'][0]), int(json_ann['bbox'][1]), int(json_ann['bbox'][2]), int(json_ann['bbox'][3]))
    obj.category = json_ann['category_id']
    # Resampling strategy to reduce training time
    counts[obj.category] += 1
    image.add_object(obj)
    anns.append(image)
print(counts)
# Out:
# {'Cargo plane': 635, 'Small car': 3324, 'Bus': 1768, 'Truck': 2210, 'Motorboat': 1069, 'Fishing vessel': 706, 'Dump truck': 1236, 'Excavator': 789, 'Building': 3594, 'Helipad': 111, 'Storage tank': 1469, 'Shipping container': 1523, 'Pylon': 312}

# %%
from sklearn.model_selection import train_test_split
labels_list = [x.objects[0].category for x in anns]
anns_train, anns_valid = train_test_split(anns, test_size=0.2, random_state=1, shuffle=True,stratify=labels_list)
print('Number of training images: ' + str(len(anns_train)))
print('Number of validation images: ' + str(len(anns_valid)))
# Out:
# Number of training images: 14996
# Number of validation images: 3750

# %%
train_mean = [69.41887293,56.97948485,49.47711569]
train_std = [51.61769765,44.6239849 ,40.89414141]

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.layers import Input
# Load architecture
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization, ELU,RandomFlip,Resizing,RandomRotation,RandomFlip,RandomContrast,RandomBrightness
from tensorflow.keras.regularizers import L2
from tensorflow.keras.initializers import HeNormal, Zeros
from tensorflow.keras.optimizers import Nadam
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.layers import Input, GlobalAveragePooling2D, Dense, Dropout, RandomFlip
from tensorflow.keras.models import Model

# 1. Carichiamo il modello ResNet50 inizializzato DA ZERO (weights=None)
base_model = ResNet50(weights=None, include_top=False, input_shape=(224, 224, 3))

# 2. IMPORTANTE: NON congelare i layer! La rete deve imparare tutto da zero.
base_model.trainable = True

# Definisci l'input
inputs = Input(shape=(224, 224, 3))

# Data Augmentation 
x = RandomFlip("horizontal_and_vertical")(inputs)

# 3. Passa le immagini alla DenseNet121. 
# RIMOSSO "training=False": la BatchNormalization DEVE aggiornarsi 
# quando si allena una rete completamente da zero!
x = base_model(x)

x = GlobalAveragePooling2D()(x)

# Output a 13 classi
x = Dropout(0.3)(x) 
outputs = Dense(13, activation='softmax')(x)

# Crea il modello finale
model = Model(inputs, outputs)

model.summary()
# Out:
# I0000 00:00:1775230464.298766      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_flip (RandomFlip)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 13)             │        26,637 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,614,349 (90.08 MB)
#  Trainable params: 23,561,229 (89.88 MB)
#  Non-trainable params: 53,120 (207.50 KB)

# %%
from sklearn.utils import class_weight
import numpy as np

train_labels = [ann.objects[0].category for ann in anns_train]
unique_classes = np.unique(train_labels)

weights_values = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=unique_classes,
    y=train_labels
)

name_to_id = {v: k for k, v in categories.items()}

alpha_array = np.ones(len(categories), dtype=np.float32)

for class_name, weight in zip(unique_classes, weights_values):
    if class_name in name_to_id:
        class_id = name_to_id[class_name]
        alpha_array[class_id] = weight
        print(f"Classe: {class_name:<20} ID: {class_id:<3} Peso: {weight:.4f}")

alpha_list = alpha_array.tolist()

print("\nLISTA DEFINITIVA PRONTA PER FOCAL LOSS:", alpha_list)
# Out:
# Classe: Building             ID: 8   Peso: 0.4012
# Classe: Bus                  ID: 2   Peso: 0.8158
# Classe: Cargo plane          ID: 0   Peso: 2.2707
# Classe: Dump truck           ID: 6   Peso: 1.1664
# Classe: Excavator            ID: 7   Peso: 1.8281
# Classe: Fishing vessel       ID: 5   Peso: 2.0417
# Classe: Helipad              ID: 9   Peso: 12.9611
# Classe: Motorboat            ID: 4   Peso: 1.3492
# Classe: Pylon                ID: 12  Peso: 4.6142
# Classe: Shipping container   ID: 11  Peso: 0.9471
# Classe: Small car            ID: 1   Peso: 0.4338
# Classe: Storage tank         ID: 10  Peso: 0.9817
# Classe: Truck                ID: 3   Peso: 0.6525
#
# LISTA DEFINITIVA PRONTA PER FOCAL LOSS: [2.270745038986206, 0.43382418155670166, 0.8157980442047119, 0.6524538993835449, 1.349167823791504, 2.041661024093628, 1.1663684844970703, 1.8281116485595703, 0.4012307822704315, 12.961106300354004, 0.9817348718643188, 0.9470759034156799, 4.614153861999512]

# %%
from tensorflow.keras.optimizers import Adam

# Learning rate is changed to 0.001
opt = Adam(learning_rate=1e-3, beta_1=0.9, beta_2=0.999, epsilon=1e-8, amsgrad=True, clipnorm=1.0)
model.compile(optimizer=opt, loss=tf.keras.losses.CategoricalFocalCrossentropy(alpha=alpha_list), metrics=['accuracy'])

# %%
from tensorflow.keras.applications.resnet50 import preprocess_input
#from tensorflow.keras.applications.densenet import preprocess_input
def generator_images(objs, batch_size, do_shuffle=False, mean=None, std=None):
    while True:
        if do_shuffle:
            np.random.shuffle(objs)
        groups = [objs[i:i+batch_size] for i in range(0, len(objs), batch_size)]
        for group in groups:
            images, labels = [], []
            for (filename, obj) in group:
                
                img = load_geoimage(filename)
                
                
                # ---> IL SEGRETO È QUI: via la vecchia normalizzazione <---
                img = preprocess_input(img.astype(np.float32))
               
                
                images.append(img)
                probabilities = np.zeros(len(categories))
                probabilities[list(categories.values()).index(obj.category)] = 1
                labels.append(probabilities)
            images = np.array(images).astype(np.float32)
            labels = np.array(labels).astype(np.float32)
            yield images, labels

# %%
def mixup_generator(objs, batch_size, alpha=0.3, mean=None, std=None):
    while True:
        # Prendi due batch casuali
        idx1 = np.random.choice(len(objs), batch_size)
        idx2 = np.random.choice(len(objs), batch_size)
        
        images1, labels1 = [], []
        images2, labels2 = [], []
        
        for i, j in zip(idx1, idx2):
            filename1, obj1 = objs[i]
            filename2, obj2 = objs[j]
            
            img1 = load_geoimage(filename1)
            img2 = load_geoimage(filename2)
            
            img1 = preprocess_input(img1.astype(np.float32))
            img2 = preprocess_input(img2.astype(np.float32))
            
            lbl1 = np.zeros(len(categories))
            lbl1[list(categories.values()).index(obj1.category)] = 1
            lbl2 = np.zeros(len(categories))
            lbl2[list(categories.values()).index(obj2.category)] = 1
            
            images1.append(img1)
            labels1.append(lbl1)
            images2.append(img2)
            labels2.append(lbl2)
        
        images1 = np.array(images1, dtype=np.float32)
        images2 = np.array(images2, dtype=np.float32)
        labels1 = np.array(labels1, dtype=np.float32)
        labels2 = np.array(labels2, dtype=np.float32)
        
        # MixUp
        lam = np.random.beta(alpha, alpha)
        images = lam * images1 + (1 - lam) * images2
        labels = lam * labels1 + (1 - lam) * labels2
        
        yield images, labels

# %%
from tensorflow.keras.callbacks import TerminateOnNaN, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Callbacks
model_checkpoint = ModelCheckpoint('model.keras', monitor='val_accuracy', verbose=1, save_best_only=True)
reduce_lr = ReduceLROnPlateau('val_accuracy', factor=0.1, patience=9, verbose=1,min_lr=1e-7)
early_stop = EarlyStopping('val_accuracy', patience=20, verbose=1)
terminate = TerminateOnNaN()
callbacks= [model_checkpoint, reduce_lr, early_stop, terminate]

# %%
# Generate the list of objects from annotations
objs_train = [(ann.filename, obj) for ann in anns_train for obj in ann.objects]
objs_valid = [(ann.filename, obj) for ann in anns_valid for obj in ann.objects]
# Generators
batch_size = 32
# Usa questo al posto del train_generator
train_generator = generator_images(objs_train, batch_size, do_shuffle=True)
# in caso da rimettere il vecchioo
valid_generator = generator_images(objs_valid, batch_size, do_shuffle=False)

# %%
import math
import numpy as np

print('Training model PHASE 1')
epochs = 70
train_steps = math.ceil(len(objs_train)/batch_size)
valid_steps = math.ceil(len(objs_valid)/batch_size)
h = model.fit(train_generator, steps_per_epoch=train_steps, validation_data=valid_generator, validation_steps=valid_steps, epochs=epochs, callbacks=callbacks, verbose=1)
# Best validation model
best_idx = int(np.argmax(h.history['val_accuracy']))
best_value = np.max(h.history['val_accuracy'])
print('Best validation model: epoch ' + str(best_idx+1), ' - val_accuracy ' + str(best_value))
# Out:
# Training model PHASE 1
# Epoch 1/70
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775230509.866012     124 service.cc:152] XLA service 0x7e0314001fa0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1775230509.866056     124 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1775230519.420641     124 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1775230549.029307     124 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1409 - loss: 2.7624
# Epoch 1: val_accuracy improved from -inf to 0.12720, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 858s 2s/step - accuracy: 0.1409 - loss: 2.7617 - val_accuracy: 0.1272 - val_loss: 1.9981 - learning_rate: 0.0010
# Epoch 2/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.1756 - loss: 2.0966
# Epoch 2: val_accuracy improved from 0.12720 to 0.21547, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 99s 212ms/step - accuracy: 0.1756 - loss: 2.0964 - val_accuracy: 0.2155 - val_loss: 1.8809 - learning_rate: 0.0010
# Epoch 3/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.2186 - loss: 1.7479
# Epoch 3: val_accuracy improved from 0.21547 to 0.23360, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 97s 207ms/step - accuracy: 0.2186 - loss: 1.7478 - val_accuracy: 0.2336 - val_loss: 1.6935 - learning_rate: 0.0010
# Epoch 4/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.2823 - loss: 1.5377
# Epoch 4: val_accuracy improved from 0.23360 to 0.25413, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 97s 208ms/step - accuracy: 0.2823 - loss: 1.5377 - val_accuracy: 0.2541 - val_loss: 1.5967 - learning_rate: 0.0010
# Epoch 5/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.3161 - loss: 1.4154
# Epoch 5: val_accuracy improved from 0.25413 to 0.26000, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 97s 207ms/step - accuracy: 0.3161 - loss: 1.4154 - val_accuracy: 0.2600 - val_loss: 1.9089 - learning_rate: 0.0010
# Epoch 6/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.3458 - loss: 1.3783
# Epoch 6: val_accuracy did not improve from 0.26000
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 93s 199ms/step - accuracy: 0.3459 - loss: 1.3783 - val_accuracy: 0.2237 - val_loss: 1.6581 - learning_rate: 0.0010
# Epoch 7/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.3879 - loss: 1.2480
# Epoch 7: val_accuracy improved from 0.26000 to 0.38880, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 96s 204ms/step - accuracy: 0.3879 - loss: 1.2480 - val_accuracy: 0.3888 - val_loss: 1.3406 - learning_rate: 0.0010
# Epoch 8/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.4096 - loss: 1.2732
# Epoch 8: val_accuracy did not improve from 0.38880
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 94s 200ms/step - accuracy: 0.4096 - loss: 1.2731 - val_accuracy: 0.3544 - val_loss: 1.3181 - learning_rate: 0.0010
# Epoch 9/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.4255 - loss: 1.1820
# Epoch 9: val_accuracy did not improve from 0.38880
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 94s 201ms/step - accuracy: 0.4255 - loss: 1.1820 - val_accuracy: 0.3035 - val_loss: 1.5489 - learning_rate: 0.0010
# Epoch 10/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.4308 - loss: 1.1281
# Epoch 10: val_accuracy did not improve from 0.38880
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 94s 200ms/step - accuracy: 0.4308 - loss: 1.1282 - val_accuracy: 0.3576 - val_loss: 1.2630 - learning_rate: 0.0010
# Epoch 11/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.4432 - loss: 1.0642
# Epoch 11: val_accuracy did not improve from 0.38880
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 93s 199ms/step - accuracy: 0.4432 - loss: 1.0642 - val_accuracy: 0.2325 - val_loss: 1.5742 - learning_rate: 0.0010
# Epoch 12/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.4530 - loss: 1.1067
# Epoch 12: val_accuracy improved from 0.38880 to 0.39600, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 94s 201ms/step - accuracy: 0.4530 - loss: 1.1066 - val_accuracy: 0.3960 - val_loss: 1.4321 - learning_rate: 0.0010
# Epoch 13/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.4563 - loss: 1.0316
# Epoch 13: val_accuracy did not improve from 0.39600
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 93s 197ms/step - accuracy: 0.4564 - loss: 1.0316 - val_accuracy: 0.2123 - val_loss: 1.7972 - learning_rate: 0.0010
# Epoch 14/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.4615 - loss: 1.0086
# Epoch 14: val_accuracy did not improve from 0.39600
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 93s 197ms/step - accuracy: 0.4615 - loss: 1.0086 - val_accuracy: 0.2632 - val_loss: 1.5195 - learning_rate: 0.0010
# Epoch 15/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.4749 - loss: 0.9732
# Epoch 15: val_accuracy improved from 0.39600 to 0.47307, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 96s 205ms/step - accuracy: 0.4749 - loss: 0.9732 - val_accuracy: 0.4731 - val_loss: 1.0541 - learning_rate: 0.0010
# Epoch 16/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.4916 - loss: 0.9391
# Epoch 16: val_accuracy improved from 0.47307 to 0.48133, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 95s 202ms/step - accuracy: 0.4916 - loss: 0.9391 - val_accuracy: 0.4813 - val_loss: 0.9994 - learning_rate: 0.0010
# Epoch 17/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.5001 - loss: 0.8585
# Epoch 17: val_accuracy did not improve from 0.48133
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 92s 197ms/step - accuracy: 0.5001 - loss: 0.8586 - val_accuracy: 0.3187 - val_loss: 1.3433 - learning_rate: 0.0010
# Epoch 18/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.5000 - loss: 0.8960
# Epoch 18: val_accuracy improved from 0.48133 to 0.50267, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 95s 202ms/step - accuracy: 0.5000 - loss: 0.8959 - val_accuracy: 0.5027 - val_loss: 0.9111 - learning_rate: 0.0010
# Epoch 19/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.5105 - loss: 0.8421
# Epoch 19: val_accuracy did not improve from 0.50267
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 94s 201ms/step - accuracy: 0.5105 - loss: 0.8421 - val_accuracy: 0.3701 - val_loss: 1.4214 - learning_rate: 0.0010
# Epoch 20/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.5235 - loss: 0.7989
# Epoch 20: val_accuracy did not improve from 0.50267
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 93s 198ms/step - accuracy: 0.5235 - loss: 0.7989 - val_accuracy: 0.4112 - val_loss: 1.2013 - learning_rate: 0.0010
# Epoch 21/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.5280 - loss: 0.8000
# Epoch 21: val_accuracy did not improve from 0.50267
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 93s 198ms/step - accuracy: 0.5281 - loss: 0.7999 - val_accuracy: 0.4667 - val_loss: 0.8927 - learning_rate: 0.0010
# Epoch 22/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.5330 - loss: 0.7613
# Epoch 22: val_accuracy did not improve from 0.50267
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 92s 197ms/step - accuracy: 0.5330 - loss: 0.7613 - val_accuracy: 0.4240 - val_loss: 1.1350 - learning_rate: 0.0010
# Epoch 23/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.5577 - loss: 0.7153
# Epoch 23: val_accuracy did not improve from 0.50267
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 104s 223ms/step - accuracy: 0.5577 - loss: 0.7153 - val_accuracy: 0.4784 - val_loss: 0.9096 - learning_rate: 0.0010
# Epoch 24/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.5680 - loss: 0.6787
# Epoch 24: val_accuracy improved from 0.50267 to 0.57173, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 101s 215ms/step - accuracy: 0.5680 - loss: 0.6787 - val_accuracy: 0.5717 - val_loss: 0.7899 - learning_rate: 0.0010
# Epoch 25/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.5669 - loss: 0.6780
# Epoch 25: val_accuracy did not improve from 0.57173
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 95s 202ms/step - accuracy: 0.5669 - loss: 0.6780 - val_accuracy: 0.4544 - val_loss: 1.2349 - learning_rate: 0.0010
# Epoch 26/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.5792 - loss: 0.6812
# Epoch 26: val_accuracy did not improve from 0.57173
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 102s 218ms/step - accuracy: 0.5792 - loss: 0.6813 - val_accuracy: 0.4149 - val_loss: 1.1625 - learning_rate: 0.0010
# Epoch 27/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.5706 - loss: 0.6552
# Epoch 27: val_accuracy did not improve from 0.57173
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 98s 210ms/step - accuracy: 0.5706 - loss: 0.6552 - val_accuracy: 0.5064 - val_loss: 0.9484 - learning_rate: 0.0010
# Epoch 28/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.5796 - loss: 0.6384
# Epoch 28: val_accuracy did not improve from 0.57173
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 92s 197ms/step - accuracy: 0.5796 - loss: 0.6384 - val_accuracy: 0.5357 - val_loss: 0.8662 - learning_rate: 0.0010
# Epoch 29/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.6085 - loss: 0.5700
# Epoch 29: val_accuracy did not improve from 0.57173
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 93s 199ms/step - accuracy: 0.6085 - loss: 0.5700 - val_accuracy: 0.4888 - val_loss: 1.6621 - learning_rate: 0.0010
# Epoch 30/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.6005 - loss: 0.5911
# Epoch 30: val_accuracy did not improve from 0.57173
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 95s 202ms/step - accuracy: 0.6004 - loss: 0.5912 - val_accuracy: 0.5139 - val_loss: 0.8211 - learning_rate: 0.0010
# Epoch 31/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.5941 - loss: 0.5969
# Epoch 31: val_accuracy improved from 0.57173 to 0.61600, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 95s 203ms/step - accuracy: 0.5941 - loss: 0.5968 - val_accuracy: 0.6160 - val_loss: 0.7065 - learning_rate: 0.0010
# Epoch 32/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.6133 - loss: 0.5666
# Epoch 32: val_accuracy did not improve from 0.61600
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 95s 202ms/step - accuracy: 0.6133 - loss: 0.5666 - val_accuracy: 0.5365 - val_loss: 0.8191 - learning_rate: 0.0010
# Epoch 33/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.6421 - loss: 0.4987
# Epoch 33: val_accuracy did not improve from 0.61600
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 94s 201ms/step - accuracy: 0.6420 - loss: 0.4988 - val_accuracy: 0.6011 - val_loss: 0.7112 - learning_rate: 0.0010
# Epoch 34/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.6337 - loss: 0.5076
# Epoch 34: val_accuracy did not improve from 0.61600
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 93s 198ms/step - accuracy: 0.6337 - loss: 0.5077 - val_accuracy: 0.5000 - val_loss: 0.9306 - learning_rate: 0.0010
# Epoch 35/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.6239 - loss: 0.5336
# Epoch 35: val_accuracy did not improve from 0.61600
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 94s 201ms/step - accuracy: 0.6239 - loss: 0.5336 - val_accuracy: 0.6112 - val_loss: 0.6743 - learning_rate: 0.0010
# Epoch 36/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.6529 - loss: 0.4704
# Epoch 36: val_accuracy improved from 0.61600 to 0.61760, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 95s 203ms/step - accuracy: 0.6529 - loss: 0.4704 - val_accuracy: 0.6176 - val_loss: 0.7083 - learning_rate: 0.0010
# Epoch 37/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.6613 - loss: 0.4375
# Epoch 37: val_accuracy improved from 0.61760 to 0.63867, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 95s 202ms/step - accuracy: 0.6613 - loss: 0.4375 - val_accuracy: 0.6387 - val_loss: 0.7098 - learning_rate: 0.0010
# Epoch 38/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.6796 - loss: 0.4074
# Epoch 38: val_accuracy did not improve from 0.63867
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 93s 197ms/step - accuracy: 0.6796 - loss: 0.4074 - val_accuracy: 0.4851 - val_loss: 1.0769 - learning_rate: 0.0010
# Epoch 39/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.6703 - loss: 0.4114
# Epoch 39: val_accuracy did not improve from 0.63867
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 92s 197ms/step - accuracy: 0.6703 - loss: 0.4114 - val_accuracy: 0.5811 - val_loss: 0.8897 - learning_rate: 0.0010
# Epoch 40/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.6897 - loss: 0.3904
# Epoch 40: val_accuracy did not improve from 0.63867
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 93s 199ms/step - accuracy: 0.6897 - loss: 0.3904 - val_accuracy: 0.5160 - val_loss: 1.3434 - learning_rate: 0.0010
# Epoch 41/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.6849 - loss: 0.4158
# Epoch 41: val_accuracy did not improve from 0.63867
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 92s 197ms/step - accuracy: 0.6849 - loss: 0.4157 - val_accuracy: 0.5901 - val_loss: 0.6868 - learning_rate: 0.0010
# Epoch 42/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.7039 - loss: 0.3649
# Epoch 42: val_accuracy did not improve from 0.63867
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 93s 199ms/step - accuracy: 0.7039 - loss: 0.3650 - val_accuracy: 0.6197 - val_loss: 0.8431 - learning_rate: 0.0010
# Epoch 43/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.6880 - loss: 0.3876
# Epoch 43: val_accuracy did not improve from 0.63867
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 92s 196ms/step - accuracy: 0.6880 - loss: 0.3876 - val_accuracy: 0.5904 - val_loss: 1.1079 - learning_rate: 0.0010
# Epoch 44/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.6830 - loss: 0.4275
# Epoch 44: val_accuracy did not improve from 0.63867
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 93s 199ms/step - accuracy: 0.6830 - loss: 0.4274 - val_accuracy: 0.5293 - val_loss: 0.8734 - learning_rate: 0.0010
# Epoch 45/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.7067 - loss: 0.3548
# Epoch 45: val_accuracy improved from 0.63867 to 0.65200, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 94s 201ms/step - accuracy: 0.7067 - loss: 0.3549 - val_accuracy: 0.6520 - val_loss: 0.6515 - learning_rate: 0.0010
# Epoch 46/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.7211 - loss: 0.3349
# Epoch 46: val_accuracy did not improve from 0.65200
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 93s 199ms/step - accuracy: 0.7211 - loss: 0.3350 - val_accuracy: 0.6333 - val_loss: 0.6687 - learning_rate: 0.0010
# Epoch 47/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.7394 - loss: 0.2859
# Epoch 47: val_accuracy did not improve from 0.65200
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 93s 198ms/step - accuracy: 0.7393 - loss: 0.2860 - val_accuracy: 0.6435 - val_loss: 0.6862 - learning_rate: 0.0010
# Epoch 48/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.7211 - loss: 0.3560
# Epoch 48: val_accuracy did not improve from 0.65200
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 93s 198ms/step - accuracy: 0.7211 - loss: 0.3560 - val_accuracy: 0.6376 - val_loss: 0.7052 - learning_rate: 0.0010
# Epoch 49/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.7470 - loss: 0.2784
# Epoch 49: val_accuracy did not improve from 0.65200
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 93s 197ms/step - accuracy: 0.7470 - loss: 0.2784 - val_accuracy: 0.6240 - val_loss: 0.7425 - learning_rate: 0.0010
# Epoch 50/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.7434 - loss: 0.3007
# Epoch 50: val_accuracy did not improve from 0.65200
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 93s 198ms/step - accuracy: 0.7433 - loss: 0.3008 - val_accuracy: 0.6064 - val_loss: 0.6493 - learning_rate: 0.0010
# Epoch 51/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.7549 - loss: 0.2684
# Epoch 51: val_accuracy did not improve from 0.65200
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 93s 198ms/step - accuracy: 0.7549 - loss: 0.2684 - val_accuracy: 0.4845 - val_loss: 2.1774 - learning_rate: 0.0010
# Epoch 52/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.7614 - loss: 0.2494
# Epoch 52: val_accuracy did not improve from 0.65200
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 94s 199ms/step - accuracy: 0.7614 - loss: 0.2494 - val_accuracy: 0.5331 - val_loss: 1.4203 - learning_rate: 0.0010
# Epoch 53/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.7792 - loss: 0.2237
# Epoch 53: val_accuracy did not improve from 0.65200
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 94s 200ms/step - accuracy: 0.7792 - loss: 0.2237 - val_accuracy: 0.6064 - val_loss: 0.9744 - learning_rate: 0.0010
# Epoch 54/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.7955 - loss: 0.1999
# Epoch 54: val_accuracy did not improve from 0.65200
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 92s 196ms/step - accuracy: 0.7955 - loss: 0.1999 - val_accuracy: 0.6320 - val_loss: 0.7688 - learning_rate: 0.0010
# Epoch 55/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.8317 - loss: 0.1585
# Epoch 55: val_accuracy improved from 0.65200 to 0.69147, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 96s 206ms/step - accuracy: 0.8317 - loss: 0.1585 - val_accuracy: 0.6915 - val_loss: 0.6983 - learning_rate: 1.0000e-04
# Epoch 56/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.8410 - loss: 0.1381
# Epoch 56: val_accuracy did not improve from 0.69147
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 94s 201ms/step - accuracy: 0.8410 - loss: 0.1381 - val_accuracy: 0.6912 - val_loss: 0.7192 - learning_rate: 1.0000e-04
# Epoch 57/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.8549 - loss: 0.1218
# Epoch 57: val_accuracy improved from 0.69147 to 0.69253, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 96s 204ms/step - accuracy: 0.8549 - loss: 0.1218 - val_accuracy: 0.6925 - val_loss: 0.7404 - learning_rate: 1.0000e-04
# Epoch 58/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.8613 - loss: 0.1132
# Epoch 58: val_accuracy improved from 0.69253 to 0.69280, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 95s 203ms/step - accuracy: 0.8613 - loss: 0.1132 - val_accuracy: 0.6928 - val_loss: 0.7546 - learning_rate: 1.0000e-04
# Epoch 59/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.8648 - loss: 0.1077
# Epoch 59: val_accuracy did not improve from 0.69280
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 93s 198ms/step - accuracy: 0.8648 - loss: 0.1077 - val_accuracy: 0.6888 - val_loss: 0.7994 - learning_rate: 1.0000e-04
# Epoch 60/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.8712 - loss: 0.1082
# Epoch 60: val_accuracy improved from 0.69280 to 0.69733, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 94s 200ms/step - accuracy: 0.8712 - loss: 0.1082 - val_accuracy: 0.6973 - val_loss: 0.8127 - learning_rate: 1.0000e-04
# Epoch 61/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.8718 - loss: 0.1040
# Epoch 61: val_accuracy did not improve from 0.69733
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 93s 199ms/step - accuracy: 0.8718 - loss: 0.1040 - val_accuracy: 0.6928 - val_loss: 0.7994 - learning_rate: 1.0000e-04
# Epoch 62/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.8747 - loss: 0.0994
# Epoch 62: val_accuracy improved from 0.69733 to 0.69973, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 96s 205ms/step - accuracy: 0.8747 - loss: 0.0994 - val_accuracy: 0.6997 - val_loss: 0.7902 - learning_rate: 1.0000e-04
# Epoch 63/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.8782 - loss: 0.0968
# Epoch 63: val_accuracy improved from 0.69973 to 0.70000, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 96s 205ms/step - accuracy: 0.8782 - loss: 0.0968 - val_accuracy: 0.7000 - val_loss: 0.8138 - learning_rate: 1.0000e-04
# Epoch 64/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.8875 - loss: 0.0912
# Epoch 64: val_accuracy did not improve from 0.70000
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 93s 199ms/step - accuracy: 0.8875 - loss: 0.0912 - val_accuracy: 0.6915 - val_loss: 0.8229 - learning_rate: 1.0000e-04
# Epoch 65/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.8777 - loss: 0.0910
# Epoch 65: val_accuracy did not improve from 0.70000
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 93s 199ms/step - accuracy: 0.8777 - loss: 0.0910 - val_accuracy: 0.6909 - val_loss: 0.8263 - learning_rate: 1.0000e-04
# Epoch 66/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.8810 - loss: 0.0890
# Epoch 66: val_accuracy did not improve from 0.70000
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 93s 198ms/step - accuracy: 0.8810 - loss: 0.0890 - val_accuracy: 0.6917 - val_loss: 0.8538 - learning_rate: 1.0000e-04
# Epoch 67/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.8885 - loss: 0.0817
# Epoch 67: val_accuracy did not improve from 0.70000
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 93s 198ms/step - accuracy: 0.8884 - loss: 0.0817 - val_accuracy: 0.6984 - val_loss: 0.8469 - learning_rate: 1.0000e-04
# Epoch 68/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.8950 - loss: 0.0769
# Epoch 68: val_accuracy did not improve from 0.70000
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 93s 199ms/step - accuracy: 0.8950 - loss: 0.0769 - val_accuracy: 0.6947 - val_loss: 0.9163 - learning_rate: 1.0000e-04
# Epoch 69/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.8920 - loss: 0.0812
# Epoch 69: val_accuracy did not improve from 0.70000
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 94s 201ms/step - accuracy: 0.8920 - loss: 0.0812 - val_accuracy: 0.6952 - val_loss: 0.9220 - learning_rate: 1.0000e-04
# Epoch 70/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.8945 - loss: 0.0786
# Epoch 70: val_accuracy did not improve from 0.70000
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 92s 196ms/step - accuracy: 0.8945 - loss: 0.0786 - val_accuracy: 0.6915 - val_loss: 0.9226 - learning_rate: 1.0000e-04
# Best validation model: epoch 63  - val_accuracy 0.699999988079071

# %%
import matplotlib.pyplot as plt

def plot_results(history):
    
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    
    
    epochs_range = range(1, len(acc) + 1)

    plt.figure(figsize=(16, 6))

    # --- GRAFICO 1: ACCURACY
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy', color='blue', marker='o')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy', color='red', marker='o')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epoche')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')
    plt.grid(True)

    # --- GRAFICO 2: LOSS 
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss', color='blue', linestyle='--')
    plt.plot(epochs_range, val_loss, label='Validation Loss', color='red', linestyle='--')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoche')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')
    plt.grid(True)

    plt.show()


plot_results(h)

# %% [markdown]
# #### Validation
# Compute validation metrics.

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

def draw_confusion_matrix(cm, categories):
    # Draw confusion matrix
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    cm = cm.astype('float') / np.maximum(cm.sum(axis=1)[:, np.newaxis], np.finfo(np.float64).eps)
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.colormaps['Blues'])
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=list(categories.values()), yticklabels=list(categories.values()), ylabel='Annotation', xlabel='Prediction')
    # Rotate the tick labels and set their alignment
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Loop over data dimensions and create text annotations
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], '.2f'), ha="center", va="center", color="white" if cm[i, j] > thresh else "black", fontsize=int(20-pow(len(categories), 0.5)))
    fig.tight_layout()
    plt.show()

# %%
import numpy as np

model.load_weights('model.keras')
y_true, y_pred = [], []
for ann in anns_valid:
    # Load image
    image = load_geoimage(ann.filename)
    image = preprocess_input(image.astype(np.float32))  
            
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        y_true.append(obj_pred.category)
        y_pred.append(pred_category)

# %%
from sklearn.metrics import confusion_matrix

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=list(categories.values()))
draw_confusion_matrix(cm, categories)

# %%
import numpy as np

# Compute the accuracy
correct_samples_class = np.diag(cm).astype(float)
total_samples_class = np.sum(cm, axis=1).astype(float)
total_predicts_class = np.sum(cm, axis=0).astype(float)
print('Mean Accuracy: %.3f%%' % (np.sum(correct_samples_class) / np.sum(total_samples_class) * 100))
acc = correct_samples_class / np.maximum(total_samples_class, np.finfo(np.float64).eps)
print('Mean Recall: %.3f%%' % (acc.mean() * 100))
acc = correct_samples_class / np.maximum(total_predicts_class, np.finfo(np.float64).eps)
print('Mean Precision: %.3f%%' % (acc.mean() * 100))
for idx in range(len(categories)):
    # True/False Positives (TP/FP) refer to the number of predicted positives that were correct/incorrect.
    # True/False Negatives (TN/FN) refer to the number of predicted negatives that were correct/incorrect.
    tp = cm[idx, idx]
    fp = sum(cm[:, idx]) - tp
    fn = sum(cm[idx, :]) - tp
    tn = sum(np.delete(sum(cm) - cm[idx, :], idx))
    # True Positive Rate: proportion of real positive cases that were correctly predicted as positive.
    recall = tp / np.maximum(tp+fn, np.finfo(np.float64).eps)
    # Precision: proportion of predicted positive cases that were truly real positives.
    precision = tp / np.maximum(tp+fp, np.finfo(np.float64).eps)
    # True Negative Rate: proportion of real negative cases that were correctly predicted as negative.
    specificity = tn / np.maximum(tn+fp, np.finfo(np.float64).eps)
    # Dice coefficient refers to two times the intersection of two sets divided by the sum of their areas.
    # Dice = 2 |A∩B| / (|A|+|B|) = 2 TP / (2 TP + FP + FN)
    f1_score = 2 * ((precision * recall) / np.maximum(precision+recall, np.finfo(np.float64).eps))
    print('> %s: Recall: %.3f%% Precision: %.3f%% Specificity: %.3f%% Dice: %.3f%%' % (list(categories.values())[idx], recall*100, precision*100, specificity*100, f1_score*100))
# Out:
# Mean Accuracy: 70.000%
# Mean Recall: 71.238%
# Mean Precision: 71.865%
# > Cargo plane: Recall: 92.913% Precision: 97.521% Specificity: 99.917% Dice: 95.161%
# > Small car: Recall: 78.195% Precision: 81.377% Specificity: 96.143% Dice: 79.755%
# > Bus: Recall: 57.062% Precision: 50.627% Specificity: 94.199% Dice: 53.652%
# > Truck: Recall: 38.914% Precision: 42.680% Specificity: 93.017% Dice: 40.710%
# > Motorboat: Recall: 72.430% Precision: 67.982% Specificity: 97.936% Dice: 70.136%
# > Fishing vessel: Recall: 74.468% Precision: 70.000% Specificity: 98.753% Dice: 72.165%
# > Dump truck: Recall: 66.802% Precision: 63.218% Specificity: 97.259% Dice: 64.961%
# > Excavator: Recall: 79.747% Precision: 81.818% Specificity: 99.220% Dice: 80.769%
# > Building: Recall: 79.833% Precision: 80.731% Specificity: 95.480% Dice: 80.280%
# > Helipad: Recall: 63.636% Precision: 73.684% Specificity: 99.866% Dice: 68.293%
# > Storage tank: Recall: 67.347% Precision: 75.000% Specificity: 98.090% Dice: 70.968%
# > Shipping container: Recall: 74.098% Precision: 66.276% Specificity: 96.662% Dice: 69.969%
# > Pylon: Recall: 80.645% Precision: 83.333% Specificity: 99.729% Dice: 81.967%

# %% [markdown]
# #### Testing
# Try to improve the results provided in the competition.

# %%
import os
import numpy as np

anns = []
for (dirpath, dirnames, filenames) in os.walk('/kaggle/input/datasets/alexferroni/recognition/xview_recognition/xview_test'):
    for filename in filenames:
        relative_path = os.path.join('xview_test', filename)
        image = GenericImage(relative_path)
        image.tile = np.array([0, 0, 224, 224])
        obj = GenericObject()
        obj.bb = (0, 0, 224, 224)
        obj.category = dirpath[dirpath.rfind('/')+1:]
        image.add_object(obj)
        anns.append(image)
print('Number of testing images: ' + str(len(anns)))
# Out:
# Number of testing images: 2365

# %%
import numpy as np

model.load_weights('model.keras')
predictions_data = {"images": {}, "annotations": {}}
for idx, ann in enumerate(anns):
    image_data = {"image_id": ann.filename.split('/')[-1], "filename": ann.filename, "width": int(ann.tile[2]), "height": int(ann.tile[3])}
    predictions_data["images"][idx] = image_data
    # Load image
    image = load_geoimage(ann.filename)
    image = preprocess_input(image.astype(np.float32)) 
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        annotation_data = {"image_id": ann.filename.split('/')[-1], "category_id": pred_category, "bbox": [int(x) for x in obj_pred.bb]}
        predictions_data["annotations"][idx] = annotation_data

# %%
with open("prediction.json", "w") as outfile:
    json.dump(predictions_data, outfile)

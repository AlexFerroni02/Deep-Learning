# %% [markdown]
# ## Assignment: Image recognition
# - Alumno 1: Alex Ferroni
# - Alumno 2: Vittorio Alberto Gianfrate
# - Alumno 3:
#
# The goals of the assignment are:
# * Develop proficiency in using Tensorflow/Keras for training Neural Nets (NNs).
# * Put into practice the acquired knowledge to optimize the parameters and architecture of a feedforward Neural Net (ffNN), in the context of an image recognition problem.
# * Put into practice NNs specially conceived for analysing images. Design and optimize the parameters of a Convolutional Neural Net (CNN) to deal with previous task.
# * Train popular architectures from scratch (e.g., GoogLeNet, VGG, ResNet, ...), and compare the results with the ones provided by their pre-trained versions using transfer learning.
#
# Follow the link below to download the classification data set  “xview_recognition”: [https://drive.upm.es/s/2DDPE2zHw5dbM3G](https://drive.upm.es/s/2DDPE2zHw5dbM3G)

# %%
# !pip install rasterio
# Out:
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (1.5.0)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio) (25.4.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from rasterio) (2026.1.4)
# Requirement already satisfied: click!=8.2.*,>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio) (8.3.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.0.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio) (3.3.2)

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import uuid
import numpy as np

class GenericObject:
    """
    Generic object data.
    """
    def __init__(self):
        self.id = uuid.uuid4()
        self.bb = (-1, -1, -1, -1)
        self.category= -1
        self.score = -1

class GenericImage:
    """
    Generic image data.
    """
    def __init__(self, filename):
        self.filename = filename
        self.tile = np.array([-1, -1, -1, -1])  # (pt_x, pt_y, pt_x+width, pt_y+height)
        self.objects = list([])

    def add_object(self, obj: GenericObject):
        self.objects.append(obj)

# %%
categories = {0: 'Cargo plane', 1: 'Small car', 2: 'Bus', 3: 'Truck', 4: 'Motorboat', 5: 'Fishing vessel', 6: 'Dump truck', 7: 'Excavator', 8: 'Building', 9: 'Helipad', 10: 'Storage tank', 11: 'Shipping container', 12: 'Pylon'}

# %%
import warnings
import rasterio
import numpy as np
import os
import cv2

def load_geoimage(filename):
    warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
    base_path = '/kaggle/input/datasets/alexferroni/recognition/xview_recognition/'
    
    src_raster = rasterio.open(base_path + filename, 'r')
    # --------------------

    # RasterIO to OpenCV
    input_type = src_raster.profile['dtype']
    input_channels = src_raster.count
    img = np.zeros((src_raster.height, src_raster.width, src_raster.count), dtype=input_type)
    for band in range(input_channels):
        img[:, :, band] = src_raster.read(band+1)
   
    return img

# %% [markdown]
# #### Training
# Design and train a ffNN to deal with the “xview_recognition” classification task.

# %%
import json
import os


json_file = '/kaggle/input/datasets/alexferroni/recognition/xview_recognition/xview_ann_train.json'

print(f"Caricamento annotazioni da: {json_file}")

with open(json_file) as ifs:
    json_data = json.load(ifs)
    
print("Annotazioni caricate con successo!")
# Out:
# Caricamento annotazioni da: /kaggle/input/datasets/alexferroni/recognition/xview_recognition/xview_ann_train.json
# Annotazioni caricate con successo!

# %%
import numpy as np

counts = dict.fromkeys(categories.values(), 0)
anns = []
for json_img, json_ann in zip(json_data['images'].values(), json_data['annotations'].values()):
    image = GenericImage(json_img['filename'])
    image.tile = np.array([0, 0, json_img['width'], json_img['height']])
    obj = GenericObject()
    obj.bb = (int(json_ann['bbox'][0]), int(json_ann['bbox'][1]), int(json_ann['bbox'][2]), int(json_ann['bbox'][3]))
    obj.category = json_ann['category_id']
    # Resampling strategy to reduce training time
    counts[obj.category] += 1
    image.add_object(obj)
    anns.append(image)
print(counts)
# Out:
# {'Cargo plane': 635, 'Small car': 3324, 'Bus': 1768, 'Truck': 2210, 'Motorboat': 1069, 'Fishing vessel': 706, 'Dump truck': 1236, 'Excavator': 789, 'Building': 3594, 'Helipad': 111, 'Storage tank': 1469, 'Shipping container': 1523, 'Pylon': 312}

# %%
from sklearn.model_selection import train_test_split
labels_list = [x.objects[0].category for x in anns]
anns_train, anns_valid = train_test_split(anns, test_size=0.2, random_state=1, shuffle=True,stratify=labels_list)
print('Number of training images: ' + str(len(anns_train)))
print('Number of validation images: ' + str(len(anns_valid)))
# Out:
# Number of training images: 14996
# Number of validation images: 3750

# %%
train_mean = [69.41887293,56.97948485,49.47711569]
train_std = [51.61769765,44.6239849 ,40.89414141]

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.layers import Input
# Load architecture
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization, ELU,RandomFlip,Resizing,RandomRotation,RandomFlip,RandomContrast,RandomBrightness
from tensorflow.keras.regularizers import L2
from tensorflow.keras.initializers import HeNormal, Zeros
from tensorflow.keras.optimizers import Nadam
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.layers import Input, GlobalAveragePooling2D, Dense, Dropout, RandomFlip
from tensorflow.keras.models import Model
from tensorflow.keras.applications import EfficientNetB0
# 1. Carichiamo il modello ResNet50 inizializzato DA ZERO (weights=None)
base_model = EfficientNetB0(weights=None, include_top=False, input_shape=(224, 224, 3))

# 2. IMPORTANTE: NON congelare i layer! La rete deve imparare tutto da zero.
base_model.trainable = True

# Definisci l'input
inputs = Input(shape=(224, 224, 3))

# Data Augmentation 
x = RandomFlip("horizontal_and_vertical")(inputs)

# 3. Passa le immagini alla DenseNet121. 
# RIMOSSO "training=False": la BatchNormalization DEVE aggiornarsi 
# quando si allena una rete completamente da zero!
x = base_model(x)

x = GlobalAveragePooling2D()(x)

# Output a 13 classi
x = Dropout(0.3)(x) 
outputs = Dense(13, activation='softmax')(x)

# Crea il modello finale
model = Model(inputs, outputs)

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_flip_1 (RandomFlip)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 13)             │        16,653 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,066,224 (15.51 MB)
#  Trainable params: 4,024,201 (15.35 MB)
#  Non-trainable params: 42,023 (164.16 KB)

# %%
from sklearn.utils import class_weight
import numpy as np

train_labels = [ann.objects[0].category for ann in anns_train]
unique_classes = np.unique(train_labels)

weights_values = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=unique_classes,
    y=train_labels
)

name_to_id = {v: k for k, v in categories.items()}

alpha_array = np.ones(len(categories), dtype=np.float32)

for class_name, weight in zip(unique_classes, weights_values):
    if class_name in name_to_id:
        class_id = name_to_id[class_name]
        alpha_array[class_id] = weight
        print(f"Classe: {class_name:<20} ID: {class_id:<3} Peso: {weight:.4f}")

alpha_list = alpha_array.tolist()

print("\nLISTA DEFINITIVA PRONTA PER FOCAL LOSS:", alpha_list)
# Out:
# Classe: Building             ID: 8   Peso: 0.4012
# Classe: Bus                  ID: 2   Peso: 0.8158
# Classe: Cargo plane          ID: 0   Peso: 2.2707
# Classe: Dump truck           ID: 6   Peso: 1.1664
# Classe: Excavator            ID: 7   Peso: 1.8281
# Classe: Fishing vessel       ID: 5   Peso: 2.0417
# Classe: Helipad              ID: 9   Peso: 12.9611
# Classe: Motorboat            ID: 4   Peso: 1.3492
# Classe: Pylon                ID: 12  Peso: 4.6142
# Classe: Shipping container   ID: 11  Peso: 0.9471
# Classe: Small car            ID: 1   Peso: 0.4338
# Classe: Storage tank         ID: 10  Peso: 0.9817
# Classe: Truck                ID: 3   Peso: 0.6525
#
# LISTA DEFINITIVA PRONTA PER FOCAL LOSS: [2.270745038986206, 0.43382418155670166, 0.8157980442047119, 0.6524538993835449, 1.349167823791504, 2.041661024093628, 1.1663684844970703, 1.8281116485595703, 0.4012307822704315, 12.961106300354004, 0.9817348718643188, 0.9470759034156799, 4.614153861999512]

# %%
from tensorflow.keras.optimizers import Adam

# Learning rate is changed to 0.001
opt = Adam(learning_rate=1e-3, beta_1=0.9, beta_2=0.999, epsilon=1e-8, amsgrad=True, clipnorm=1.0)
model.compile(optimizer=opt, loss=tf.keras.losses.CategoricalFocalCrossentropy(alpha=alpha_list), metrics=['accuracy'])

# %%
#from tensorflow.keras.applications.resnet50 import preprocess_input
#from tensorflow.keras.applications.densenet import preprocess_input
from tensorflow.keras.applications.efficientnet import preprocess_input
def generator_images(objs, batch_size, do_shuffle=False, mean=None, std=None):
    while True:
        if do_shuffle:
            np.random.shuffle(objs)
        groups = [objs[i:i+batch_size] for i in range(0, len(objs), batch_size)]
        for group in groups:
            images, labels = [], []
            for (filename, obj) in group:
                
                img = load_geoimage(filename)
                
                
                # ---> IL SEGRETO È QUI: via la vecchia normalizzazione <---
                img = preprocess_input(img.astype(np.float32))
               
                
                images.append(img)
                probabilities = np.zeros(len(categories))
                probabilities[list(categories.values()).index(obj.category)] = 1
                labels.append(probabilities)
            images = np.array(images).astype(np.float32)
            labels = np.array(labels).astype(np.float32)
            yield images, labels

# %%
def mixup_generator(objs, batch_size, alpha=0.3, mean=None, std=None):
    while True:
        # Prendi due batch casuali
        idx1 = np.random.choice(len(objs), batch_size)
        idx2 = np.random.choice(len(objs), batch_size)
        
        images1, labels1 = [], []
        images2, labels2 = [], []
        
        for i, j in zip(idx1, idx2):
            filename1, obj1 = objs[i]
            filename2, obj2 = objs[j]
            
            img1 = load_geoimage(filename1)
            img2 = load_geoimage(filename2)
            
            img1 = preprocess_input(img1.astype(np.float32))
            img2 = preprocess_input(img2.astype(np.float32))
            
            lbl1 = np.zeros(len(categories))
            lbl1[list(categories.values()).index(obj1.category)] = 1
            lbl2 = np.zeros(len(categories))
            lbl2[list(categories.values()).index(obj2.category)] = 1
            
            images1.append(img1)
            labels1.append(lbl1)
            images2.append(img2)
            labels2.append(lbl2)
        
        images1 = np.array(images1, dtype=np.float32)
        images2 = np.array(images2, dtype=np.float32)
        labels1 = np.array(labels1, dtype=np.float32)
        labels2 = np.array(labels2, dtype=np.float32)
        
        # MixUp
        lam = np.random.beta(alpha, alpha)
        images = lam * images1 + (1 - lam) * images2
        labels = lam * labels1 + (1 - lam) * labels2
        
        yield images, labels

# %%
from tensorflow.keras.callbacks import TerminateOnNaN, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Callbacks
model_checkpoint = ModelCheckpoint('model.keras', monitor='val_accuracy', verbose=1, save_best_only=True)
reduce_lr = ReduceLROnPlateau('val_accuracy', factor=0.1, patience=9, verbose=1,min_lr=1e-7)
early_stop = EarlyStopping('val_accuracy', patience=20, verbose=1)
terminate = TerminateOnNaN()
callbacks= [model_checkpoint, reduce_lr, early_stop, terminate]

# %%
# Generate the list of objects from annotations
objs_train = [(ann.filename, obj) for ann in anns_train for obj in ann.objects]
objs_valid = [(ann.filename, obj) for ann in anns_valid for obj in ann.objects]
# Generators
batch_size = 32
# Usa questo al posto del train_generator
train_generator = generator_images(objs_train, batch_size, do_shuffle=True)
# in caso da rimettere il vecchioo
valid_generator = generator_images(objs_valid, batch_size, do_shuffle=False)

# %%
import math
import numpy as np

print('Training model PHASE 1')
epochs = 70
train_steps = math.ceil(len(objs_train)/batch_size)
valid_steps = math.ceil(len(objs_valid)/batch_size)
h = model.fit(train_generator, steps_per_epoch=train_steps, validation_data=valid_generator, validation_steps=valid_steps, epochs=epochs, callbacks=callbacks, verbose=1)
# Best validation model
best_idx = int(np.argmax(h.history['val_accuracy']))
best_value = np.max(h.history['val_accuracy'])
print('Best validation model: epoch ' + str(best_idx+1), ' - val_accuracy ' + str(best_value))
# Out:
# Training model PHASE 1
# Epoch 1/70
# 2026-04-03 18:11:53.939905: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-03 18:11:54.128559: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-03 18:11:54.614610: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-03 18:11:54.821428: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-03 18:11:55.192509: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-03 18:11:55.399403: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 468/469 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.1427 - loss: 2.1327
# 2026-04-03 18:14:06.924573: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-03 18:14:07.110029: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-03 18:14:07.563674: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-03 18:14:07.772882: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-03 18:14:08.133398: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-03 18:14:08.342384: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.1428 - loss: 2.1322
# Epoch 1: val_accuracy improved from -inf to 0.16373, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 267s 360ms/step - accuracy: 0.1429 - loss: 2.1317 - val_accuracy: 0.1637 - val_loss: 2.8617 - learning_rate: 0.0010
# Epoch 2/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.2956 - loss: 1.4502
# Epoch 2: val_accuracy improved from 0.16373 to 0.39787, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 78s 166ms/step - accuracy: 0.2957 - loss: 1.4501 - val_accuracy: 0.3979 - val_loss: 1.5062 - learning_rate: 0.0010
# Epoch 3/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.3884 - loss: 1.1852
# Epoch 3: val_accuracy did not improve from 0.39787
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 84s 179ms/step - accuracy: 0.3885 - loss: 1.1852 - val_accuracy: 0.3883 - val_loss: 1.2119 - learning_rate: 0.0010
# Epoch 4/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.4639 - loss: 0.9912
# Epoch 4: val_accuracy improved from 0.39787 to 0.48187, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 93s 199ms/step - accuracy: 0.4639 - loss: 0.9912 - val_accuracy: 0.4819 - val_loss: 0.9809 - learning_rate: 0.0010
# Epoch 5/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.4971 - loss: 0.8814
# Epoch 5: val_accuracy improved from 0.48187 to 0.52747, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 76s 163ms/step - accuracy: 0.4971 - loss: 0.8814 - val_accuracy: 0.5275 - val_loss: 0.9674 - learning_rate: 0.0010
# Epoch 6/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.5279 - loss: 0.8301
# Epoch 6: val_accuracy did not improve from 0.52747
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 74s 157ms/step - accuracy: 0.5279 - loss: 0.8300 - val_accuracy: 0.4992 - val_loss: 0.8777 - learning_rate: 0.0010
# Epoch 7/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.5509 - loss: 0.7108
# Epoch 7: val_accuracy improved from 0.52747 to 0.57093, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 74s 157ms/step - accuracy: 0.5509 - loss: 0.7108 - val_accuracy: 0.5709 - val_loss: 0.8928 - learning_rate: 0.0010
# Epoch 8/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.5853 - loss: 0.6281
# Epoch 8: val_accuracy improved from 0.57093 to 0.57787, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 72s 153ms/step - accuracy: 0.5853 - loss: 0.6281 - val_accuracy: 0.5779 - val_loss: 0.6927 - learning_rate: 0.0010
# Epoch 9/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.6008 - loss: 0.5803
# Epoch 9: val_accuracy improved from 0.57787 to 0.59307, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 73s 155ms/step - accuracy: 0.6008 - loss: 0.5803 - val_accuracy: 0.5931 - val_loss: 0.7362 - learning_rate: 0.0010
# Epoch 10/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.6246 - loss: 0.5523
# Epoch 10: val_accuracy improved from 0.59307 to 0.61147, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 73s 157ms/step - accuracy: 0.6246 - loss: 0.5523 - val_accuracy: 0.6115 - val_loss: 0.9322 - learning_rate: 0.0010
# Epoch 11/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.6458 - loss: 0.4798
# Epoch 11: val_accuracy improved from 0.61147 to 0.62933, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 72s 154ms/step - accuracy: 0.6458 - loss: 0.4798 - val_accuracy: 0.6293 - val_loss: 0.7273 - learning_rate: 0.0010
# Epoch 12/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.6726 - loss: 0.4269
# Epoch 12: val_accuracy improved from 0.62933 to 0.64480, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 73s 156ms/step - accuracy: 0.6725 - loss: 0.4269 - val_accuracy: 0.6448 - val_loss: 0.6219 - learning_rate: 0.0010
# Epoch 13/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.6806 - loss: 0.4090
# Epoch 13: val_accuracy did not improve from 0.64480
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 71s 150ms/step - accuracy: 0.6806 - loss: 0.4090 - val_accuracy: 0.6253 - val_loss: 0.6913 - learning_rate: 0.0010
# Epoch 14/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.6913 - loss: 0.3786
# Epoch 14: val_accuracy did not improve from 0.64480
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 71s 151ms/step - accuracy: 0.6913 - loss: 0.3786 - val_accuracy: 0.5997 - val_loss: 0.6783 - learning_rate: 0.0010
# Epoch 15/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.6962 - loss: 0.3803
# Epoch 15: val_accuracy improved from 0.64480 to 0.66213, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 73s 155ms/step - accuracy: 0.6962 - loss: 0.3803 - val_accuracy: 0.6621 - val_loss: 0.5786 - learning_rate: 0.0010
# Epoch 16/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.7247 - loss: 0.3366
# Epoch 16: val_accuracy did not improve from 0.66213
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 70s 149ms/step - accuracy: 0.7247 - loss: 0.3366 - val_accuracy: 0.6416 - val_loss: 0.7148 - learning_rate: 0.0010
# Epoch 17/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.7435 - loss: 0.2988
# Epoch 17: val_accuracy improved from 0.66213 to 0.66853, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 72s 154ms/step - accuracy: 0.7435 - loss: 0.2988 - val_accuracy: 0.6685 - val_loss: 0.6151 - learning_rate: 0.0010
# Epoch 18/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.7530 - loss: 0.2767
# Epoch 18: val_accuracy did not improve from 0.66853
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 70s 149ms/step - accuracy: 0.7530 - loss: 0.2767 - val_accuracy: 0.6496 - val_loss: 0.7466 - learning_rate: 0.0010
# Epoch 19/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.7629 - loss: 0.2496
# Epoch 19: val_accuracy did not improve from 0.66853
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 70s 150ms/step - accuracy: 0.7629 - loss: 0.2496 - val_accuracy: 0.6667 - val_loss: 0.6607 - learning_rate: 0.0010
# Epoch 20/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.7727 - loss: 0.2336
# Epoch 20: val_accuracy improved from 0.66853 to 0.68000, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 72s 153ms/step - accuracy: 0.7727 - loss: 0.2337 - val_accuracy: 0.6800 - val_loss: 0.7173 - learning_rate: 0.0010
# Epoch 21/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.7796 - loss: 0.2364
# Epoch 21: val_accuracy did not improve from 0.68000
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 70s 150ms/step - accuracy: 0.7796 - loss: 0.2364 - val_accuracy: 0.6608 - val_loss: 0.6854 - learning_rate: 0.0010
# Epoch 22/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.7848 - loss: 0.2257
# Epoch 22: val_accuracy did not improve from 0.68000
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 71s 151ms/step - accuracy: 0.7848 - loss: 0.2258 - val_accuracy: 0.6651 - val_loss: 0.6238 - learning_rate: 0.0010
# Epoch 23/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8030 - loss: 0.2050
# Epoch 23: val_accuracy did not improve from 0.68000
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 72s 153ms/step - accuracy: 0.8030 - loss: 0.2050 - val_accuracy: 0.6688 - val_loss: 0.6245 - learning_rate: 0.0010
# Epoch 24/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.8191 - loss: 0.1646
# Epoch 24: val_accuracy did not improve from 0.68000
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 69s 147ms/step - accuracy: 0.8191 - loss: 0.1646 - val_accuracy: 0.6720 - val_loss: 0.7054 - learning_rate: 0.0010
# Epoch 25/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8303 - loss: 0.1610
# Epoch 25: val_accuracy did not improve from 0.68000
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 71s 151ms/step - accuracy: 0.8303 - loss: 0.1610 - val_accuracy: 0.6691 - val_loss: 0.6377 - learning_rate: 0.0010
# Epoch 26/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8277 - loss: 0.1624
# Epoch 26: val_accuracy improved from 0.68000 to 0.68480, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 72s 154ms/step - accuracy: 0.8277 - loss: 0.1624 - val_accuracy: 0.6848 - val_loss: 0.6831 - learning_rate: 0.0010
# Epoch 27/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8456 - loss: 0.1463
# Epoch 27: val_accuracy improved from 0.68480 to 0.69147, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 72s 153ms/step - accuracy: 0.8456 - loss: 0.1463 - val_accuracy: 0.6915 - val_loss: 0.6259 - learning_rate: 0.0010
# Epoch 28/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8547 - loss: 0.1307
# Epoch 28: val_accuracy did not improve from 0.69147
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 71s 152ms/step - accuracy: 0.8547 - loss: 0.1307 - val_accuracy: 0.6717 - val_loss: 0.7033 - learning_rate: 0.0010
# Epoch 29/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8581 - loss: 0.1245
# Epoch 29: val_accuracy did not improve from 0.69147
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 70s 150ms/step - accuracy: 0.8581 - loss: 0.1246 - val_accuracy: 0.6843 - val_loss: 0.6846 - learning_rate: 0.0010
# Epoch 30/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.8632 - loss: 0.1152
# Epoch 30: val_accuracy did not improve from 0.69147
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 71s 151ms/step - accuracy: 0.8632 - loss: 0.1153 - val_accuracy: 0.6483 - val_loss: 0.7190 - learning_rate: 0.0010
# Epoch 31/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8577 - loss: 0.1293
# Epoch 31: val_accuracy improved from 0.69147 to 0.69600, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 72s 153ms/step - accuracy: 0.8577 - loss: 0.1293 - val_accuracy: 0.6960 - val_loss: 0.6830 - learning_rate: 0.0010
# Epoch 32/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8750 - loss: 0.1116
# Epoch 32: val_accuracy did not improve from 0.69600
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 71s 150ms/step - accuracy: 0.8750 - loss: 0.1116 - val_accuracy: 0.6760 - val_loss: 0.6679 - learning_rate: 0.0010
# Epoch 33/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8749 - loss: 0.1013
# Epoch 33: val_accuracy improved from 0.69600 to 0.69947, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 71s 152ms/step - accuracy: 0.8749 - loss: 0.1013 - val_accuracy: 0.6995 - val_loss: 0.6935 - learning_rate: 0.0010
# Epoch 34/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8882 - loss: 0.0946
# Epoch 34: val_accuracy did not improve from 0.69947
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 70s 149ms/step - accuracy: 0.8882 - loss: 0.0946 - val_accuracy: 0.6875 - val_loss: 0.7499 - learning_rate: 0.0010
# Epoch 35/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8947 - loss: 0.0974
# Epoch 35: val_accuracy improved from 0.69947 to 0.70053, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 72s 153ms/step - accuracy: 0.8947 - loss: 0.0974 - val_accuracy: 0.7005 - val_loss: 0.7362 - learning_rate: 0.0010
# Epoch 36/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8974 - loss: 0.0871
# Epoch 36: val_accuracy did not improve from 0.70053
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 72s 153ms/step - accuracy: 0.8974 - loss: 0.0871 - val_accuracy: 0.6944 - val_loss: 0.6906 - learning_rate: 0.0010
# Epoch 37/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8996 - loss: 0.0951
# Epoch 37: val_accuracy did not improve from 0.70053
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 70s 150ms/step - accuracy: 0.8996 - loss: 0.0951 - val_accuracy: 0.6923 - val_loss: 0.6856 - learning_rate: 0.0010
# Epoch 38/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9197 - loss: 0.0647
# Epoch 38: val_accuracy improved from 0.70053 to 0.70613, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 71s 152ms/step - accuracy: 0.9197 - loss: 0.0647 - val_accuracy: 0.7061 - val_loss: 0.7324 - learning_rate: 0.0010
# Epoch 39/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9146 - loss: 0.0701
# Epoch 39: val_accuracy did not improve from 0.70613
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 72s 154ms/step - accuracy: 0.9146 - loss: 0.0701 - val_accuracy: 0.7061 - val_loss: 0.7896 - learning_rate: 0.0010
# Epoch 40/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9145 - loss: 0.0732
# Epoch 40: val_accuracy did not improve from 0.70613
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 71s 151ms/step - accuracy: 0.9145 - loss: 0.0732 - val_accuracy: 0.6947 - val_loss: 0.6841 - learning_rate: 0.0010
# Epoch 41/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9297 - loss: 0.0517
# Epoch 41: val_accuracy did not improve from 0.70613
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 72s 153ms/step - accuracy: 0.9297 - loss: 0.0517 - val_accuracy: 0.6971 - val_loss: 0.7866 - learning_rate: 0.0010
# Epoch 42/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9318 - loss: 0.0512
# Epoch 42: val_accuracy did not improve from 0.70613
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 70s 150ms/step - accuracy: 0.9318 - loss: 0.0512 - val_accuracy: 0.6973 - val_loss: 0.8409 - learning_rate: 0.0010
# Epoch 43/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9350 - loss: 0.0504
# Epoch 43: val_accuracy improved from 0.70613 to 0.70933, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 73s 155ms/step - accuracy: 0.9350 - loss: 0.0504 - val_accuracy: 0.7093 - val_loss: 0.7647 - learning_rate: 0.0010
# Epoch 44/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9534 - loss: 0.0357
# Epoch 44: val_accuracy did not improve from 0.70933
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 71s 152ms/step - accuracy: 0.9534 - loss: 0.0357 - val_accuracy: 0.7093 - val_loss: 0.8130 - learning_rate: 0.0010
# Epoch 45/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9370 - loss: 0.0489
# Epoch 45: val_accuracy did not improve from 0.70933
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 70s 149ms/step - accuracy: 0.9370 - loss: 0.0489 - val_accuracy: 0.6947 - val_loss: 0.8102 - learning_rate: 0.0010
# Epoch 46/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9446 - loss: 0.0450
# Epoch 46: val_accuracy improved from 0.70933 to 0.71013, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 73s 155ms/step - accuracy: 0.9445 - loss: 0.0450 - val_accuracy: 0.7101 - val_loss: 0.7547 - learning_rate: 0.0010
# Epoch 47/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9371 - loss: 0.0530
# Epoch 47: val_accuracy did not improve from 0.71013
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 71s 152ms/step - accuracy: 0.9371 - loss: 0.0530 - val_accuracy: 0.6832 - val_loss: 0.8625 - learning_rate: 0.0010
# Epoch 48/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9441 - loss: 0.0489
# Epoch 48: val_accuracy did not improve from 0.71013
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 70s 149ms/step - accuracy: 0.9441 - loss: 0.0489 - val_accuracy: 0.6979 - val_loss: 0.8110 - learning_rate: 0.0010
# Epoch 49/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9531 - loss: 0.0384
# Epoch 49: val_accuracy did not improve from 0.71013
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 69s 147ms/step - accuracy: 0.9531 - loss: 0.0384 - val_accuracy: 0.6965 - val_loss: 0.7457 - learning_rate: 0.0010
# Epoch 50/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9465 - loss: 0.0409
# Epoch 50: val_accuracy did not improve from 0.71013
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 70s 149ms/step - accuracy: 0.9465 - loss: 0.0409 - val_accuracy: 0.7003 - val_loss: 0.8020 - learning_rate: 0.0010
# Epoch 51/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9462 - loss: 0.0440
# Epoch 51: val_accuracy did not improve from 0.71013
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 69s 147ms/step - accuracy: 0.9462 - loss: 0.0441 - val_accuracy: 0.6667 - val_loss: 0.8168 - learning_rate: 0.0010
# Epoch 52/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9267 - loss: 0.0666
# Epoch 52: val_accuracy did not improve from 0.71013
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 70s 150ms/step - accuracy: 0.9267 - loss: 0.0666 - val_accuracy: 0.7000 - val_loss: 0.7745 - learning_rate: 0.0010
# Epoch 53/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9338 - loss: 0.0555
# Epoch 53: val_accuracy did not improve from 0.71013
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 68s 146ms/step - accuracy: 0.9338 - loss: 0.0555 - val_accuracy: 0.7093 - val_loss: 0.8137 - learning_rate: 0.0010
# Epoch 54/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9493 - loss: 0.0420
# Epoch 54: val_accuracy did not improve from 0.71013
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 69s 147ms/step - accuracy: 0.9493 - loss: 0.0420 - val_accuracy: 0.6981 - val_loss: 0.8399 - learning_rate: 0.0010
# Epoch 55/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9541 - loss: 0.0371
# Epoch 55: val_accuracy did not improve from 0.71013
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 69s 147ms/step - accuracy: 0.9541 - loss: 0.0371 - val_accuracy: 0.7096 - val_loss: 0.8436 - learning_rate: 0.0010
# Epoch 56/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9642 - loss: 0.0243
# Epoch 56: val_accuracy improved from 0.71013 to 0.72133, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 70s 149ms/step - accuracy: 0.9642 - loss: 0.0243 - val_accuracy: 0.7213 - val_loss: 0.8046 - learning_rate: 1.0000e-04
# Epoch 57/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9753 - loss: 0.0184
# Epoch 57: val_accuracy improved from 0.72133 to 0.72453, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 71s 152ms/step - accuracy: 0.9753 - loss: 0.0184 - val_accuracy: 0.7245 - val_loss: 0.7702 - learning_rate: 1.0000e-04
# Epoch 58/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9812 - loss: 0.0128
# Epoch 58: val_accuracy improved from 0.72453 to 0.72560, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 71s 151ms/step - accuracy: 0.9812 - loss: 0.0128 - val_accuracy: 0.7256 - val_loss: 0.7841 - learning_rate: 1.0000e-04
# Epoch 59/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9805 - loss: 0.0116
# Epoch 59: val_accuracy did not improve from 0.72560
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 70s 150ms/step - accuracy: 0.9806 - loss: 0.0116 - val_accuracy: 0.7256 - val_loss: 0.7905 - learning_rate: 1.0000e-04
# Epoch 60/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9831 - loss: 0.0120
# Epoch 60: val_accuracy improved from 0.72560 to 0.72880, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 72s 154ms/step - accuracy: 0.9831 - loss: 0.0120 - val_accuracy: 0.7288 - val_loss: 0.7960 - learning_rate: 1.0000e-04
# Epoch 61/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9849 - loss: 0.0112
# Epoch 61: val_accuracy did not improve from 0.72880
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 69s 148ms/step - accuracy: 0.9849 - loss: 0.0112 - val_accuracy: 0.7259 - val_loss: 0.7968 - learning_rate: 1.0000e-04
# Epoch 62/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9857 - loss: 0.0095
# Epoch 62: val_accuracy did not improve from 0.72880
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 69s 148ms/step - accuracy: 0.9857 - loss: 0.0095 - val_accuracy: 0.7280 - val_loss: 0.8083 - learning_rate: 1.0000e-04
# Epoch 63/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9871 - loss: 0.0088
# Epoch 63: val_accuracy improved from 0.72880 to 0.72907, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 77s 165ms/step - accuracy: 0.9871 - loss: 0.0088 - val_accuracy: 0.7291 - val_loss: 0.8088 - learning_rate: 1.0000e-04
# Epoch 64/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.9868 - loss: 0.0086
# Epoch 64: val_accuracy did not improve from 0.72907
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 79s 169ms/step - accuracy: 0.9868 - loss: 0.0086 - val_accuracy: 0.7269 - val_loss: 0.8239 - learning_rate: 1.0000e-04
# Epoch 65/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9908 - loss: 0.0070
# Epoch 65: val_accuracy improved from 0.72907 to 0.73253, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 71s 151ms/step - accuracy: 0.9908 - loss: 0.0070 - val_accuracy: 0.7325 - val_loss: 0.8269 - learning_rate: 1.0000e-04
# Epoch 66/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9874 - loss: 0.0137
# Epoch 66: val_accuracy did not improve from 0.73253
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 69s 146ms/step - accuracy: 0.9874 - loss: 0.0137 - val_accuracy: 0.7293 - val_loss: 0.8205 - learning_rate: 1.0000e-04
# Epoch 67/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9887 - loss: 0.0108
# Epoch 67: val_accuracy did not improve from 0.73253
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 70s 148ms/step - accuracy: 0.9887 - loss: 0.0108 - val_accuracy: 0.7293 - val_loss: 0.8238 - learning_rate: 1.0000e-04
# Epoch 68/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9889 - loss: 0.0075
# Epoch 68: val_accuracy did not improve from 0.73253
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 72s 153ms/step - accuracy: 0.9889 - loss: 0.0075 - val_accuracy: 0.7272 - val_loss: 0.8271 - learning_rate: 1.0000e-04
# Epoch 69/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9896 - loss: 0.0068
# Epoch 69: val_accuracy did not improve from 0.73253
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 75s 160ms/step - accuracy: 0.9896 - loss: 0.0068 - val_accuracy: 0.7291 - val_loss: 0.8391 - learning_rate: 1.0000e-04
# Epoch 70/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9901 - loss: 0.0092
# Epoch 70: val_accuracy did not improve from 0.73253
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 70s 150ms/step - accuracy: 0.9901 - loss: 0.0092 - val_accuracy: 0.7293 - val_loss: 0.8365 - learning_rate: 1.0000e-04
# Best validation model: epoch 65  - val_accuracy 0.73253333568573

# %%
import matplotlib.pyplot as plt

def plot_results(history):
    
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    
    
    epochs_range = range(1, len(acc) + 1)

    plt.figure(figsize=(16, 6))

    # --- GRAFICO 1: ACCURACY
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy', color='blue', marker='o')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy', color='red', marker='o')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epoche')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')
    plt.grid(True)

    # --- GRAFICO 2: LOSS 
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss', color='blue', linestyle='--')
    plt.plot(epochs_range, val_loss, label='Validation Loss', color='red', linestyle='--')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoche')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')
    plt.grid(True)

    plt.show()


plot_results(h)

# %% [markdown]
# #### Validation
# Compute validation metrics.

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

def draw_confusion_matrix(cm, categories):
    # Draw confusion matrix
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    cm = cm.astype('float') / np.maximum(cm.sum(axis=1)[:, np.newaxis], np.finfo(np.float64).eps)
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.colormaps['Blues'])
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=list(categories.values()), yticklabels=list(categories.values()), ylabel='Annotation', xlabel='Prediction')
    # Rotate the tick labels and set their alignment
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Loop over data dimensions and create text annotations
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], '.2f'), ha="center", va="center", color="white" if cm[i, j] > thresh else "black", fontsize=int(20-pow(len(categories), 0.5)))
    fig.tight_layout()
    plt.show()

# %%
import numpy as np

model.load_weights('model.keras')
y_true, y_pred = [], []
for ann in anns_valid:
    # Load image
    image = load_geoimage(ann.filename)
    image = preprocess_input(image.astype(np.float32))  
            
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        y_true.append(obj_pred.category)
        y_pred.append(pred_category)

# %%
from sklearn.metrics import confusion_matrix

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=list(categories.values()))
draw_confusion_matrix(cm, categories)

# %%
import numpy as np

# Compute the accuracy
correct_samples_class = np.diag(cm).astype(float)
total_samples_class = np.sum(cm, axis=1).astype(float)
total_predicts_class = np.sum(cm, axis=0).astype(float)
print('Mean Accuracy: %.3f%%' % (np.sum(correct_samples_class) / np.sum(total_samples_class) * 100))
acc = correct_samples_class / np.maximum(total_samples_class, np.finfo(np.float64).eps)
print('Mean Recall: %.3f%%' % (acc.mean() * 100))
acc = correct_samples_class / np.maximum(total_predicts_class, np.finfo(np.float64).eps)
print('Mean Precision: %.3f%%' % (acc.mean() * 100))
for idx in range(len(categories)):
    # True/False Positives (TP/FP) refer to the number of predicted positives that were correct/incorrect.
    # True/False Negatives (TN/FN) refer to the number of predicted negatives that were correct/incorrect.
    tp = cm[idx, idx]
    fp = sum(cm[:, idx]) - tp
    fn = sum(cm[idx, :]) - tp
    tn = sum(np.delete(sum(cm) - cm[idx, :], idx))
    # True Positive Rate: proportion of real positive cases that were correctly predicted as positive.
    recall = tp / np.maximum(tp+fn, np.finfo(np.float64).eps)
    # Precision: proportion of predicted positive cases that were truly real positives.
    precision = tp / np.maximum(tp+fp, np.finfo(np.float64).eps)
    # True Negative Rate: proportion of real negative cases that were correctly predicted as negative.
    specificity = tn / np.maximum(tn+fp, np.finfo(np.float64).eps)
    # Dice coefficient refers to two times the intersection of two sets divided by the sum of their areas.
    # Dice = 2 |A∩B| / (|A|+|B|) = 2 TP / (2 TP + FP + FN)
    f1_score = 2 * ((precision * recall) / np.maximum(precision+recall, np.finfo(np.float64).eps))
    print('> %s: Recall: %.3f%% Precision: %.3f%% Specificity: %.3f%% Dice: %.3f%%' % (list(categories.values())[idx], recall*100, precision*100, specificity*100, f1_score*100))
# Out:
# Mean Accuracy: 73.253%
# Mean Recall: 74.236%
# Mean Precision: 75.855%
# > Cargo plane: Recall: 88.976% Precision: 97.414% Specificity: 99.917% Dice: 93.004%
# > Small car: Recall: 83.158% Precision: 79.913% Specificity: 95.494% Dice: 81.503%
# > Bus: Recall: 57.062% Precision: 55.801% Specificity: 95.289% Dice: 56.425%
# > Truck: Recall: 40.045% Precision: 42.961% Specificity: 92.896% Dice: 41.452%
# > Motorboat: Recall: 73.832% Precision: 74.882% Specificity: 98.501% Dice: 74.353%
# > Fishing vessel: Recall: 80.851% Precision: 72.611% Specificity: 98.809% Dice: 76.510%
# > Dump truck: Recall: 67.206% Precision: 64.844% Specificity: 97.431% Dice: 66.004%
# > Excavator: Recall: 84.810% Precision: 83.230% Specificity: 99.248% Dice: 84.013%
# > Building: Recall: 85.118% Precision: 85.955% Specificity: 96.701% Dice: 85.535%
# > Helipad: Recall: 68.182% Precision: 88.235% Specificity: 99.946% Dice: 76.923%
# > Storage tank: Recall: 77.551% Precision: 85.075% Specificity: 98.843% Dice: 81.139%
# > Shipping container: Recall: 72.787% Precision: 68.308% Specificity: 97.010% Dice: 70.476%
# > Pylon: Recall: 85.484% Precision: 86.885% Specificity: 99.783% Dice: 86.179%

# %% [markdown]
# #### Testing
# Try to improve the results provided in the competition.

# %%
import os
import numpy as np

anns = []
for (dirpath, dirnames, filenames) in os.walk('/kaggle/input/datasets/alexferroni/recognition/xview_recognition/xview_test'):
    for filename in filenames:
        relative_path = os.path.join('xview_test', filename)
        image = GenericImage(relative_path)
        image.tile = np.array([0, 0, 224, 224])
        obj = GenericObject()
        obj.bb = (0, 0, 224, 224)
        obj.category = dirpath[dirpath.rfind('/')+1:]
        image.add_object(obj)
        anns.append(image)
print('Number of testing images: ' + str(len(anns)))
# Out:
# Number of testing images: 2365

# %%
import numpy as np

model.load_weights('model.keras')
predictions_data = {"images": {}, "annotations": {}}
for idx, ann in enumerate(anns):
    image_data = {"image_id": ann.filename.split('/')[-1], "filename": ann.filename, "width": int(ann.tile[2]), "height": int(ann.tile[3])}
    predictions_data["images"][idx] = image_data
    # Load image
    image = load_geoimage(ann.filename)
    image = preprocess_input(image.astype(np.float32)) 
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        annotation_data = {"image_id": ann.filename.split('/')[-1], "category_id": pred_category, "bbox": [int(x) for x in obj_pred.bb]}
        predictions_data["annotations"][idx] = annotation_data

# %%
with open("prediction.json", "w") as outfile:
    json.dump(predictions_data, outfile)

# %% [markdown]
# ## Assignment: Image recognition
# - Alumno 1: Alex Ferroni
# - Alumno 2: Vittorio Alberto Gianfrate
# - Alumno 3:
#
# The goals of the assignment are:
# * Develop proficiency in using Tensorflow/Keras for training Neural Nets (NNs).
# * Put into practice the acquired knowledge to optimize the parameters and architecture of a feedforward Neural Net (ffNN), in the context of an image recognition problem.
# * Put into practice NNs specially conceived for analysing images. Design and optimize the parameters of a Convolutional Neural Net (CNN) to deal with previous task.
# * Train popular architectures from scratch (e.g., GoogLeNet, VGG, ResNet, ...), and compare the results with the ones provided by their pre-trained versions using transfer learning.
#
# Follow the link below to download the classification data set  “xview_recognition”: [https://drive.upm.es/s/2DDPE2zHw5dbM3G](https://drive.upm.es/s/2DDPE2zHw5dbM3G)

# %%
# !pip install rasterio
# Out:
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (1.5.0)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio) (25.4.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from rasterio) (2026.1.4)
# Requirement already satisfied: click!=8.2.*,>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio) (8.3.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.0.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio) (3.3.2)

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# 2026-04-02 18:50:54.857836: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775155855.072197      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775155855.130623      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775155855.628265      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775155855.628326      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775155855.628329      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775155855.628332      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import uuid
import numpy as np

class GenericObject:
    """
    Generic object data.
    """
    def __init__(self):
        self.id = uuid.uuid4()
        self.bb = (-1, -1, -1, -1)
        self.category= -1
        self.score = -1

class GenericImage:
    """
    Generic image data.
    """
    def __init__(self, filename):
        self.filename = filename
        self.tile = np.array([-1, -1, -1, -1])  # (pt_x, pt_y, pt_x+width, pt_y+height)
        self.objects = list([])

    def add_object(self, obj: GenericObject):
        self.objects.append(obj)

# %%
categories = {0: 'Cargo plane', 1: 'Small car', 2: 'Bus', 3: 'Truck', 4: 'Motorboat', 5: 'Fishing vessel', 6: 'Dump truck', 7: 'Excavator', 8: 'Building', 9: 'Helipad', 10: 'Storage tank', 11: 'Shipping container', 12: 'Pylon'}

# %%
import warnings
import rasterio
import numpy as np
import os
import cv2

def load_geoimage(filename):
    warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
    base_path = '/kaggle/input/datasets/alexferroni/recognition/xview_recognition/'
    
    src_raster = rasterio.open(base_path + filename, 'r')
    # --------------------

    # RasterIO to OpenCV
    input_type = src_raster.profile['dtype']
    input_channels = src_raster.count
    img = np.zeros((src_raster.height, src_raster.width, src_raster.count), dtype=input_type)
    for band in range(input_channels):
        img[:, :, band] = src_raster.read(band+1)
   
    return img

# %% [markdown]
# #### Training
# Design and train a ffNN to deal with the “xview_recognition” classification task.

# %%
import json
import os


json_file = '/kaggle/input/datasets/alexferroni/recognition/xview_recognition/xview_ann_train.json'

print(f"Caricamento annotazioni da: {json_file}")

with open(json_file) as ifs:
    json_data = json.load(ifs)
    
print("Annotazioni caricate con successo!")
# Out:
# Caricamento annotazioni da: /kaggle/input/datasets/alexferroni/recognition/xview_recognition/xview_ann_train.json
# Annotazioni caricate con successo!

# %%
import numpy as np

counts = dict.fromkeys(categories.values(), 0)
anns = []
for json_img, json_ann in zip(json_data['images'].values(), json_data['annotations'].values()):
    image = GenericImage(json_img['filename'])
    image.tile = np.array([0, 0, json_img['width'], json_img['height']])
    obj = GenericObject()
    obj.bb = (int(json_ann['bbox'][0]), int(json_ann['bbox'][1]), int(json_ann['bbox'][2]), int(json_ann['bbox'][3]))
    obj.category = json_ann['category_id']
    # Resampling strategy to reduce training time
    counts[obj.category] += 1
    image.add_object(obj)
    anns.append(image)
print(counts)
# Out:
# {'Cargo plane': 635, 'Small car': 3324, 'Bus': 1768, 'Truck': 2210, 'Motorboat': 1069, 'Fishing vessel': 706, 'Dump truck': 1236, 'Excavator': 789, 'Building': 3594, 'Helipad': 111, 'Storage tank': 1469, 'Shipping container': 1523, 'Pylon': 312}

# %%
from sklearn.model_selection import train_test_split
labels_list = [x.objects[0].category for x in anns]
anns_train, anns_valid = train_test_split(anns, test_size=0.2, random_state=1, shuffle=True,stratify=labels_list)
print('Number of training images: ' + str(len(anns_train)))
print('Number of validation images: ' + str(len(anns_valid)))
# Out:
# Number of training images: 14996
# Number of validation images: 3750

# %%
train_mean = [69.41887293,56.97948485,49.47711569]
train_std = [51.61769765,44.6239849 ,40.89414141]

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.layers import Input
# Load architecture
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization, ELU,RandomFlip,Resizing,RandomRotation,RandomFlip,RandomContrast,RandomBrightness
from tensorflow.keras.regularizers import L2
from tensorflow.keras.initializers import HeNormal, Zeros
from tensorflow.keras.optimizers import Nadam
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.layers import Input, GlobalAveragePooling2D, Dense, Dropout, RandomFlip
from tensorflow.keras.models import Model

# 1. Carichiamo il modello DenseNet121 inizializzato DA ZERO (weights=None)
base_model = DenseNet121(weights=None, include_top=False, input_shape=(224, 224, 3))

# 2. IMPORTANTE: NON congelare i layer! La rete deve imparare tutto da zero.
base_model.trainable = True

# Definisci l'input
inputs = Input(shape=(224, 224, 3))

# Data Augmentation 
x = RandomFlip("horizontal_and_vertical")(inputs)

# 3. Passa le immagini alla DenseNet121. 
# RIMOSSO "training=False": la BatchNormalization DEVE aggiornarsi 
# quando si allena una rete completamente da zero!
x = base_model(x)

x = GlobalAveragePooling2D()(x)

# Output a 13 classi
x = Dropout(0.3)(x) 
outputs = Dense(13, activation='softmax')(x)

# Crea il modello finale
model = Model(inputs, outputs)

model.summary()
# Out:
# I0000 00:00:1775155886.130484      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_flip (RandomFlip)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ densenet121 (Functional)        │ (None, 7, 7, 1024)     │     7,037,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1024)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 13)             │        13,325 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,050,829 (26.90 MB)
#  Trainable params: 6,967,181 (26.58 MB)
#  Non-trainable params: 83,648 (326.75 KB)

# %%
from sklearn.utils import class_weight
import numpy as np

train_labels = [ann.objects[0].category for ann in anns_train]
unique_classes = np.unique(train_labels)

weights_values = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=unique_classes,
    y=train_labels
)

name_to_id = {v: k for k, v in categories.items()}

alpha_array = np.ones(len(categories), dtype=np.float32)

for class_name, weight in zip(unique_classes, weights_values):
    if class_name in name_to_id:
        class_id = name_to_id[class_name]
        alpha_array[class_id] = weight
        print(f"Classe: {class_name:<20} ID: {class_id:<3} Peso: {weight:.4f}")

alpha_list = alpha_array.tolist()

print("\nLISTA DEFINITIVA PRONTA PER FOCAL LOSS:", alpha_list)
# Out:
# Classe: Building             ID: 8   Peso: 0.4012
# Classe: Bus                  ID: 2   Peso: 0.8158
# Classe: Cargo plane          ID: 0   Peso: 2.2707
# Classe: Dump truck           ID: 6   Peso: 1.1664
# Classe: Excavator            ID: 7   Peso: 1.8281
# Classe: Fishing vessel       ID: 5   Peso: 2.0417
# Classe: Helipad              ID: 9   Peso: 12.9611
# Classe: Motorboat            ID: 4   Peso: 1.3492
# Classe: Pylon                ID: 12  Peso: 4.6142
# Classe: Shipping container   ID: 11  Peso: 0.9471
# Classe: Small car            ID: 1   Peso: 0.4338
# Classe: Storage tank         ID: 10  Peso: 0.9817
# Classe: Truck                ID: 3   Peso: 0.6525
#
# LISTA DEFINITIVA PRONTA PER FOCAL LOSS: [2.270745038986206, 0.43382418155670166, 0.8157980442047119, 0.6524538993835449, 1.349167823791504, 2.041661024093628, 1.1663684844970703, 1.8281116485595703, 0.4012307822704315, 12.961106300354004, 0.9817348718643188, 0.9470759034156799, 4.614153861999512]

# %%
from tensorflow.keras.optimizers import Adam

# Learning rate is changed to 0.001
opt = Adam(learning_rate=1e-3, beta_1=0.9, beta_2=0.999, epsilon=1e-8, amsgrad=True, clipnorm=1.0)
model.compile(optimizer=opt, loss=tf.keras.losses.CategoricalFocalCrossentropy(alpha=alpha_list), metrics=['accuracy'])

# %%
#from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.applications.densenet import preprocess_input
def generator_images(objs, batch_size, do_shuffle=False, mean=None, std=None):
    while True:
        if do_shuffle:
            np.random.shuffle(objs)
        groups = [objs[i:i+batch_size] for i in range(0, len(objs), batch_size)]
        for group in groups:
            images, labels = [], []
            for (filename, obj) in group:
                
                img = load_geoimage(filename)
                
                
                # ---> IL SEGRETO È QUI: via la vecchia normalizzazione <---
                img = preprocess_input(img.astype(np.float32))
               
                
                images.append(img)
                probabilities = np.zeros(len(categories))
                probabilities[list(categories.values()).index(obj.category)] = 1
                labels.append(probabilities)
            images = np.array(images).astype(np.float32)
            labels = np.array(labels).astype(np.float32)
            yield images, labels

# %%
def mixup_generator(objs, batch_size, alpha=0.3, mean=None, std=None):
    while True:
        # Prendi due batch casuali
        idx1 = np.random.choice(len(objs), batch_size)
        idx2 = np.random.choice(len(objs), batch_size)
        
        images1, labels1 = [], []
        images2, labels2 = [], []
        
        for i, j in zip(idx1, idx2):
            filename1, obj1 = objs[i]
            filename2, obj2 = objs[j]
            
            img1 = load_geoimage(filename1)
            img2 = load_geoimage(filename2)
            
            img1 = preprocess_input(img1.astype(np.float32))
            img2 = preprocess_input(img2.astype(np.float32))
            
            lbl1 = np.zeros(len(categories))
            lbl1[list(categories.values()).index(obj1.category)] = 1
            lbl2 = np.zeros(len(categories))
            lbl2[list(categories.values()).index(obj2.category)] = 1
            
            images1.append(img1)
            labels1.append(lbl1)
            images2.append(img2)
            labels2.append(lbl2)
        
        images1 = np.array(images1, dtype=np.float32)
        images2 = np.array(images2, dtype=np.float32)
        labels1 = np.array(labels1, dtype=np.float32)
        labels2 = np.array(labels2, dtype=np.float32)
        
        # MixUp
        lam = np.random.beta(alpha, alpha)
        images = lam * images1 + (1 - lam) * images2
        labels = lam * labels1 + (1 - lam) * labels2
        
        yield images, labels

# %%
from tensorflow.keras.callbacks import TerminateOnNaN, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Callbacks
model_checkpoint = ModelCheckpoint('model.keras', monitor='val_accuracy', verbose=1, save_best_only=True)
reduce_lr = ReduceLROnPlateau('val_accuracy', factor=0.1, patience=9, verbose=1,min_lr=1e-7)
early_stop = EarlyStopping('val_accuracy', patience=20, verbose=1)
terminate = TerminateOnNaN()
callbacks= [model_checkpoint, reduce_lr, early_stop, terminate]

# %%
# Generate the list of objects from annotations
objs_train = [(ann.filename, obj) for ann in anns_train for obj in ann.objects]
objs_valid = [(ann.filename, obj) for ann in anns_valid for obj in ann.objects]
# Generators
batch_size = 32
# Usa questo al posto del train_generator
train_generator = generator_images(objs_train, batch_size, do_shuffle=True)
# in caso da rimettere il vecchioo
valid_generator = generator_images(objs_valid, batch_size, do_shuffle=False)

# %%
import math
import numpy as np

print('Training model PHASE 1')
epochs = 70
train_steps = math.ceil(len(objs_train)/batch_size)
valid_steps = math.ceil(len(objs_valid)/batch_size)
h = model.fit(train_generator, steps_per_epoch=train_steps, validation_data=valid_generator, validation_steps=valid_steps, epochs=epochs, callbacks=callbacks, verbose=1)
# Best validation model
best_idx = int(np.argmax(h.history['val_accuracy']))
best_value = np.max(h.history['val_accuracy'])
print('Best validation model: epoch ' + str(best_idx+1), ' - val_accuracy ' + str(best_value))
# Out:
# Training model PHASE 1
# Epoch 1/70
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775155984.132851     131 service.cc:152] XLA service 0x7b4900006490 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1775155984.132928     131 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1775156006.932111     131 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1775156159.903975     131 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1862 - loss: 1.9491
# Epoch 1: val_accuracy improved from -inf to 0.23973, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1404s 2s/step - accuracy: 0.1862 - loss: 1.9489 - val_accuracy: 0.2397 - val_loss: 1.7070 - learning_rate: 0.0010
# Epoch 2/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.2641 - loss: 1.6296
# Epoch 2: val_accuracy improved from 0.23973 to 0.28907, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 135s 289ms/step - accuracy: 0.2642 - loss: 1.6295 - val_accuracy: 0.2891 - val_loss: 1.8405 - learning_rate: 0.0010
# Epoch 3/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.3108 - loss: 1.5764
# Epoch 3: val_accuracy improved from 0.28907 to 0.31440, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 115s 245ms/step - accuracy: 0.3108 - loss: 1.5763 - val_accuracy: 0.3144 - val_loss: 2.9289 - learning_rate: 0.0010
# Epoch 4/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.3565 - loss: 1.3914
# Epoch 4: val_accuracy improved from 0.31440 to 0.31520, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 107s 229ms/step - accuracy: 0.3565 - loss: 1.3912 - val_accuracy: 0.3152 - val_loss: 1.5551 - learning_rate: 0.0010
# Epoch 5/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.3987 - loss: 1.2371
# Epoch 5: val_accuracy did not improve from 0.31520
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 120s 255ms/step - accuracy: 0.3987 - loss: 1.2372 - val_accuracy: 0.2101 - val_loss: 5.2855 - learning_rate: 0.0010
# Epoch 6/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.4081 - loss: 1.2239
# Epoch 6: val_accuracy improved from 0.31520 to 0.41040, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 107s 227ms/step - accuracy: 0.4081 - loss: 1.2239 - val_accuracy: 0.4104 - val_loss: 1.3358 - learning_rate: 0.0010
# Epoch 7/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.4289 - loss: 1.1685
# Epoch 7: val_accuracy did not improve from 0.41040
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 106s 226ms/step - accuracy: 0.4289 - loss: 1.1685 - val_accuracy: 0.3789 - val_loss: 1.9356 - learning_rate: 0.0010
# Epoch 8/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.4475 - loss: 1.1043
# Epoch 8: val_accuracy improved from 0.41040 to 0.41973, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 109s 232ms/step - accuracy: 0.4475 - loss: 1.1043 - val_accuracy: 0.4197 - val_loss: 1.1532 - learning_rate: 0.0010
# Epoch 9/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.4432 - loss: 1.1151
# Epoch 9: val_accuracy did not improve from 0.41973
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 106s 226ms/step - accuracy: 0.4432 - loss: 1.1151 - val_accuracy: 0.3893 - val_loss: 1.6107 - learning_rate: 0.0010
# Epoch 10/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.4601 - loss: 1.0602
# Epoch 10: val_accuracy did not improve from 0.41973
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 104s 221ms/step - accuracy: 0.4601 - loss: 1.0602 - val_accuracy: 0.2947 - val_loss: 1.4899 - learning_rate: 0.0010
# Epoch 11/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.4735 - loss: 0.9912
# Epoch 11: val_accuracy improved from 0.41973 to 0.47840, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 106s 226ms/step - accuracy: 0.4735 - loss: 0.9912 - val_accuracy: 0.4784 - val_loss: 1.2113 - learning_rate: 0.0010
# Epoch 12/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.4966 - loss: 0.9219
# Epoch 12: val_accuracy did not improve from 0.47840
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 104s 221ms/step - accuracy: 0.4966 - loss: 0.9220 - val_accuracy: 0.2416 - val_loss: 2.1325 - learning_rate: 0.0010
# Epoch 13/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.5093 - loss: 0.9075
# Epoch 13: val_accuracy improved from 0.47840 to 0.49067, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 106s 227ms/step - accuracy: 0.5093 - loss: 0.9075 - val_accuracy: 0.4907 - val_loss: 0.9928 - learning_rate: 0.0010
# Epoch 14/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.5197 - loss: 0.8607
# Epoch 14: val_accuracy did not improve from 0.49067
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 104s 221ms/step - accuracy: 0.5197 - loss: 0.8607 - val_accuracy: 0.2576 - val_loss: 3.8592 - learning_rate: 0.0010
# Epoch 15/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.5232 - loss: 0.8645
# Epoch 15: val_accuracy improved from 0.49067 to 0.50373, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 106s 225ms/step - accuracy: 0.5232 - loss: 0.8645 - val_accuracy: 0.5037 - val_loss: 1.1888 - learning_rate: 0.0010
# Epoch 16/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.5297 - loss: 0.8253
# Epoch 16: val_accuracy improved from 0.50373 to 0.51893, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 106s 227ms/step - accuracy: 0.5297 - loss: 0.8253 - val_accuracy: 0.5189 - val_loss: 0.9514 - learning_rate: 0.0010
# Epoch 17/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.5330 - loss: 0.8241
# Epoch 17: val_accuracy improved from 0.51893 to 0.54187, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 106s 225ms/step - accuracy: 0.5330 - loss: 0.8241 - val_accuracy: 0.5419 - val_loss: 0.8252 - learning_rate: 0.0010
# Epoch 18/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.5473 - loss: 0.7606
# Epoch 18: val_accuracy did not improve from 0.54187
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 104s 222ms/step - accuracy: 0.5473 - loss: 0.7606 - val_accuracy: 0.3760 - val_loss: 1.7795 - learning_rate: 0.0010
# Epoch 19/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.5557 - loss: 0.7360
# Epoch 19: val_accuracy did not improve from 0.54187
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 105s 224ms/step - accuracy: 0.5557 - loss: 0.7360 - val_accuracy: 0.4979 - val_loss: 1.1274 - learning_rate: 0.0010
# Epoch 20/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.5569 - loss: 0.7041
# Epoch 20: val_accuracy did not improve from 0.54187
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 103s 221ms/step - accuracy: 0.5569 - loss: 0.7041 - val_accuracy: 0.5181 - val_loss: 1.1022 - learning_rate: 0.0010
# Epoch 21/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.5708 - loss: 0.7021
# Epoch 21: val_accuracy did not improve from 0.54187
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 105s 223ms/step - accuracy: 0.5708 - loss: 0.7021 - val_accuracy: 0.3261 - val_loss: 2.0685 - learning_rate: 0.0010
# Epoch 22/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.5592 - loss: 0.7286
# Epoch 22: val_accuracy did not improve from 0.54187
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 105s 224ms/step - accuracy: 0.5593 - loss: 0.7285 - val_accuracy: 0.3760 - val_loss: 1.2265 - learning_rate: 0.0010
# Epoch 23/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.5800 - loss: 0.6622
# Epoch 23: val_accuracy did not improve from 0.54187
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 106s 225ms/step - accuracy: 0.5800 - loss: 0.6622 - val_accuracy: 0.3832 - val_loss: 1.1670 - learning_rate: 0.0010
# Epoch 24/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.5869 - loss: 0.6408
# Epoch 24: val_accuracy improved from 0.54187 to 0.59360, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 108s 230ms/step - accuracy: 0.5869 - loss: 0.6408 - val_accuracy: 0.5936 - val_loss: 0.7227 - learning_rate: 0.0010
# Epoch 25/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.5913 - loss: 0.6492
# Epoch 25: val_accuracy did not improve from 0.59360
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 109s 233ms/step - accuracy: 0.5913 - loss: 0.6491 - val_accuracy: 0.4163 - val_loss: 1.4381 - learning_rate: 0.0010
# Epoch 26/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.5976 - loss: 0.6080
# Epoch 26: val_accuracy did not improve from 0.59360
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 105s 224ms/step - accuracy: 0.5976 - loss: 0.6080 - val_accuracy: 0.5469 - val_loss: 0.8501 - learning_rate: 0.0010
# Epoch 27/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.6050 - loss: 0.5690
# Epoch 27: val_accuracy did not improve from 0.59360
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 104s 221ms/step - accuracy: 0.6050 - loss: 0.5690 - val_accuracy: 0.5365 - val_loss: 0.8894 - learning_rate: 0.0010
# Epoch 28/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.6131 - loss: 0.5660
# Epoch 28: val_accuracy did not improve from 0.59360
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 105s 224ms/step - accuracy: 0.6131 - loss: 0.5660 - val_accuracy: 0.3749 - val_loss: 2.0450 - learning_rate: 0.0010
# Epoch 29/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.6001 - loss: 0.6205
# Epoch 29: val_accuracy did not improve from 0.59360
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 103s 220ms/step - accuracy: 0.6001 - loss: 0.6204 - val_accuracy: 0.5792 - val_loss: 0.9237 - learning_rate: 0.0010
# Epoch 30/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.6333 - loss: 0.5134
# Epoch 30: val_accuracy did not improve from 0.59360
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 115s 246ms/step - accuracy: 0.6333 - loss: 0.5134 - val_accuracy: 0.5896 - val_loss: 0.7327 - learning_rate: 0.0010
# Epoch 31/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.6356 - loss: 0.5107
# Epoch 31: val_accuracy did not improve from 0.59360
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 105s 224ms/step - accuracy: 0.6356 - loss: 0.5107 - val_accuracy: 0.5501 - val_loss: 0.8595 - learning_rate: 0.0010
# Epoch 32/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.6422 - loss: 0.5024
# Epoch 32: val_accuracy did not improve from 0.59360
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 105s 223ms/step - accuracy: 0.6422 - loss: 0.5024 - val_accuracy: 0.4989 - val_loss: 1.1087 - learning_rate: 0.0010
# Epoch 33/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.6500 - loss: 0.4995
# Epoch 33: val_accuracy did not improve from 0.59360
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 112s 238ms/step - accuracy: 0.6500 - loss: 0.4996 - val_accuracy: 0.5195 - val_loss: 1.1057 - learning_rate: 0.0010
# Epoch 34/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.6560 - loss: 0.4685
# Epoch 34: val_accuracy improved from 0.59360 to 0.66427, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 107s 229ms/step - accuracy: 0.6560 - loss: 0.4684 - val_accuracy: 0.6643 - val_loss: 0.5421 - learning_rate: 1.0000e-04
# Epoch 35/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.6761 - loss: 0.4066
# Epoch 35: val_accuracy improved from 0.66427 to 0.67520, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 109s 232ms/step - accuracy: 0.6761 - loss: 0.4066 - val_accuracy: 0.6752 - val_loss: 0.5277 - learning_rate: 1.0000e-04
# Epoch 36/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.6971 - loss: 0.3766
# Epoch 36: val_accuracy improved from 0.67520 to 0.67600, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 105s 225ms/step - accuracy: 0.6971 - loss: 0.3766 - val_accuracy: 0.6760 - val_loss: 0.5226 - learning_rate: 1.0000e-04
# Epoch 37/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.7007 - loss: 0.3700
# Epoch 37: val_accuracy improved from 0.67600 to 0.67760, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 105s 224ms/step - accuracy: 0.7007 - loss: 0.3700 - val_accuracy: 0.6776 - val_loss: 0.5269 - learning_rate: 1.0000e-04
# Epoch 38/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.7172 - loss: 0.3493
# Epoch 38: val_accuracy did not improve from 0.67760
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 103s 221ms/step - accuracy: 0.7172 - loss: 0.3494 - val_accuracy: 0.6709 - val_loss: 0.5271 - learning_rate: 1.0000e-04
# Epoch 39/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.7030 - loss: 0.3584
# Epoch 39: val_accuracy improved from 0.67760 to 0.68347, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 105s 224ms/step - accuracy: 0.7030 - loss: 0.3584 - val_accuracy: 0.6835 - val_loss: 0.5043 - learning_rate: 1.0000e-04
# Epoch 40/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.7132 - loss: 0.3452
# Epoch 40: val_accuracy did not improve from 0.68347
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 100s 213ms/step - accuracy: 0.7132 - loss: 0.3452 - val_accuracy: 0.6821 - val_loss: 0.5245 - learning_rate: 1.0000e-04
# Epoch 41/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7196 - loss: 0.3319
# Epoch 41: val_accuracy did not improve from 0.68347
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 99s 211ms/step - accuracy: 0.7196 - loss: 0.3319 - val_accuracy: 0.6776 - val_loss: 0.5180 - learning_rate: 1.0000e-04
# Epoch 42/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.7100 - loss: 0.3307
# Epoch 42: val_accuracy improved from 0.68347 to 0.68960, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 103s 220ms/step - accuracy: 0.7100 - loss: 0.3307 - val_accuracy: 0.6896 - val_loss: 0.5090 - learning_rate: 1.0000e-04
# Epoch 43/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.7170 - loss: 0.3208
# Epoch 43: val_accuracy improved from 0.68960 to 0.69013, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 102s 217ms/step - accuracy: 0.7170 - loss: 0.3208 - val_accuracy: 0.6901 - val_loss: 0.5116 - learning_rate: 1.0000e-04
# Epoch 44/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7165 - loss: 0.3232
# Epoch 44: val_accuracy did not improve from 0.69013
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 98s 210ms/step - accuracy: 0.7165 - loss: 0.3232 - val_accuracy: 0.6883 - val_loss: 0.5352 - learning_rate: 1.0000e-04
# Epoch 45/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7202 - loss: 0.3285
# Epoch 45: val_accuracy did not improve from 0.69013
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 100s 213ms/step - accuracy: 0.7202 - loss: 0.3285 - val_accuracy: 0.6835 - val_loss: 0.5208 - learning_rate: 1.0000e-04
# Epoch 46/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.7248 - loss: 0.3239
# Epoch 46: val_accuracy improved from 0.69013 to 0.69360, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 103s 220ms/step - accuracy: 0.7248 - loss: 0.3239 - val_accuracy: 0.6936 - val_loss: 0.5149 - learning_rate: 1.0000e-04
# Epoch 47/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.7262 - loss: 0.3085
# Epoch 47: val_accuracy did not improve from 0.69360
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 100s 213ms/step - accuracy: 0.7262 - loss: 0.3085 - val_accuracy: 0.6832 - val_loss: 0.5324 - learning_rate: 1.0000e-04
# Epoch 48/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7232 - loss: 0.3184
# Epoch 48: val_accuracy improved from 0.69360 to 0.69467, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 102s 217ms/step - accuracy: 0.7232 - loss: 0.3184 - val_accuracy: 0.6947 - val_loss: 0.5054 - learning_rate: 1.0000e-04
# Epoch 49/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.7261 - loss: 0.2964
# Epoch 49: val_accuracy did not improve from 0.69467
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 101s 215ms/step - accuracy: 0.7261 - loss: 0.2964 - val_accuracy: 0.6771 - val_loss: 0.5102 - learning_rate: 1.0000e-04
# Epoch 50/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.7238 - loss: 0.3054
# Epoch 50: val_accuracy improved from 0.69467 to 0.69493, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 103s 220ms/step - accuracy: 0.7238 - loss: 0.3054 - val_accuracy: 0.6949 - val_loss: 0.5076 - learning_rate: 1.0000e-04
# Epoch 51/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.7314 - loss: 0.2896
# Epoch 51: val_accuracy did not improve from 0.69493
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 98s 210ms/step - accuracy: 0.7314 - loss: 0.2896 - val_accuracy: 0.6944 - val_loss: 0.5016 - learning_rate: 1.0000e-04
# Epoch 52/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.7377 - loss: 0.2878
# Epoch 52: val_accuracy did not improve from 0.69493
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 99s 212ms/step - accuracy: 0.7377 - loss: 0.2878 - val_accuracy: 0.6928 - val_loss: 0.5141 - learning_rate: 1.0000e-04
# Epoch 53/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7399 - loss: 0.2796
# Epoch 53: val_accuracy did not improve from 0.69493
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 99s 212ms/step - accuracy: 0.7399 - loss: 0.2796 - val_accuracy: 0.6837 - val_loss: 0.5239 - learning_rate: 1.0000e-04
# Epoch 54/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.7483 - loss: 0.2675
# Epoch 54: val_accuracy did not improve from 0.69493
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 101s 214ms/step - accuracy: 0.7483 - loss: 0.2675 - val_accuracy: 0.6941 - val_loss: 0.5282 - learning_rate: 1.0000e-04
# Epoch 55/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7536 - loss: 0.2715
# Epoch 55: val_accuracy improved from 0.69493 to 0.70133, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 103s 221ms/step - accuracy: 0.7536 - loss: 0.2715 - val_accuracy: 0.7013 - val_loss: 0.5109 - learning_rate: 1.0000e-04
# Epoch 56/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7461 - loss: 0.2698
# Epoch 56: val_accuracy did not improve from 0.70133
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 101s 216ms/step - accuracy: 0.7461 - loss: 0.2698 - val_accuracy: 0.6856 - val_loss: 0.5267 - learning_rate: 1.0000e-04
# Epoch 57/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7550 - loss: 0.2664
# Epoch 57: val_accuracy did not improve from 0.70133
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 100s 212ms/step - accuracy: 0.7550 - loss: 0.2664 - val_accuracy: 0.6960 - val_loss: 0.5365 - learning_rate: 1.0000e-04
# Epoch 58/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.7515 - loss: 0.2647
# Epoch 58: val_accuracy did not improve from 0.70133
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 99s 212ms/step - accuracy: 0.7515 - loss: 0.2647 - val_accuracy: 0.6981 - val_loss: 0.5180 - learning_rate: 1.0000e-04
# Epoch 59/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.7540 - loss: 0.2521
# Epoch 59: val_accuracy did not improve from 0.70133
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 104s 221ms/step - accuracy: 0.7540 - loss: 0.2521 - val_accuracy: 0.6976 - val_loss: 0.5319 - learning_rate: 1.0000e-04
# Epoch 60/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.7615 - loss: 0.2503
# Epoch 60: val_accuracy did not improve from 0.70133
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 105s 224ms/step - accuracy: 0.7615 - loss: 0.2504 - val_accuracy: 0.7008 - val_loss: 0.5368 - learning_rate: 1.0000e-04
# Epoch 61/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7636 - loss: 0.2428
# Epoch 61: val_accuracy did not improve from 0.70133
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 101s 215ms/step - accuracy: 0.7636 - loss: 0.2428 - val_accuracy: 0.6995 - val_loss: 0.5431 - learning_rate: 1.0000e-04
# Epoch 62/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7629 - loss: 0.2411
# Epoch 62: val_accuracy did not improve from 0.70133
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 101s 215ms/step - accuracy: 0.7629 - loss: 0.2411 - val_accuracy: 0.6997 - val_loss: 0.5407 - learning_rate: 1.0000e-04
# Epoch 63/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7683 - loss: 0.2308
# Epoch 63: val_accuracy did not improve from 0.70133
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 100s 213ms/step - accuracy: 0.7683 - loss: 0.2308 - val_accuracy: 0.6955 - val_loss: 0.5438 - learning_rate: 1.0000e-04
# Epoch 64/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.7672 - loss: 0.2235
# Epoch 64: val_accuracy did not improve from 0.70133
#
# Epoch 64: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 99s 211ms/step - accuracy: 0.7672 - loss: 0.2235 - val_accuracy: 0.7005 - val_loss: 0.5662 - learning_rate: 1.0000e-04
# Epoch 65/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.7716 - loss: 0.2229
# Epoch 65: val_accuracy improved from 0.70133 to 0.70560, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 102s 217ms/step - accuracy: 0.7716 - loss: 0.2229 - val_accuracy: 0.7056 - val_loss: 0.5346 - learning_rate: 1.0000e-05
# Epoch 66/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7752 - loss: 0.2191
# Epoch 66: val_accuracy did not improve from 0.70560
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 99s 212ms/step - accuracy: 0.7752 - loss: 0.2191 - val_accuracy: 0.7037 - val_loss: 0.5334 - learning_rate: 1.0000e-05
# Epoch 67/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7762 - loss: 0.2207
# Epoch 67: val_accuracy improved from 0.70560 to 0.70720, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 105s 223ms/step - accuracy: 0.7762 - loss: 0.2207 - val_accuracy: 0.7072 - val_loss: 0.5330 - learning_rate: 1.0000e-05
# Epoch 68/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7847 - loss: 0.2148
# Epoch 68: val_accuracy did not improve from 0.70720
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 100s 213ms/step - accuracy: 0.7847 - loss: 0.2148 - val_accuracy: 0.7037 - val_loss: 0.5340 - learning_rate: 1.0000e-05
# Epoch 69/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.7832 - loss: 0.2130
# Epoch 69: val_accuracy did not improve from 0.70720
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 99s 211ms/step - accuracy: 0.7832 - loss: 0.2130 - val_accuracy: 0.7048 - val_loss: 0.5355 - learning_rate: 1.0000e-05
# Epoch 70/70
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.7743 - loss: 0.2199
# Epoch 70: val_accuracy did not improve from 0.70720
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 99s 211ms/step - accuracy: 0.7743 - loss: 0.2199 - val_accuracy: 0.7024 - val_loss: 0.5360 - learning_rate: 1.0000e-05
# Best validation model: epoch 67  - val_accuracy 0.7071999907493591

# %%
import matplotlib.pyplot as plt

def plot_results(history):
    
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    
    
    epochs_range = range(1, len(acc) + 1)

    plt.figure(figsize=(16, 6))

    # --- GRAFICO 1: ACCURACY
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy', color='blue', marker='o')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy', color='red', marker='o')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epoche')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')
    plt.grid(True)

    # --- GRAFICO 2: LOSS 
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss', color='blue', linestyle='--')
    plt.plot(epochs_range, val_loss, label='Validation Loss', color='red', linestyle='--')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoche')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')
    plt.grid(True)

    plt.show()


plot_results(h)

# %% [markdown]
# #### Validation
# Compute validation metrics.

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

def draw_confusion_matrix(cm, categories):
    # Draw confusion matrix
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    cm = cm.astype('float') / np.maximum(cm.sum(axis=1)[:, np.newaxis], np.finfo(np.float64).eps)
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.colormaps['Blues'])
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=list(categories.values()), yticklabels=list(categories.values()), ylabel='Annotation', xlabel='Prediction')
    # Rotate the tick labels and set their alignment
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Loop over data dimensions and create text annotations
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], '.2f'), ha="center", va="center", color="white" if cm[i, j] > thresh else "black", fontsize=int(20-pow(len(categories), 0.5)))
    fig.tight_layout()
    plt.show()

# %%
import numpy as np

model.load_weights('model.keras')
y_true, y_pred = [], []
for ann in anns_valid:
    # Load image
    image = load_geoimage(ann.filename)
    image = preprocess_input(image.astype(np.float32))  
            
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        y_true.append(obj_pred.category)
        y_pred.append(pred_category)

# %%
from sklearn.metrics import confusion_matrix

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=list(categories.values()))
draw_confusion_matrix(cm, categories)

# %%
import numpy as np

# Compute the accuracy
correct_samples_class = np.diag(cm).astype(float)
total_samples_class = np.sum(cm, axis=1).astype(float)
total_predicts_class = np.sum(cm, axis=0).astype(float)
print('Mean Accuracy: %.3f%%' % (np.sum(correct_samples_class) / np.sum(total_samples_class) * 100))
acc = correct_samples_class / np.maximum(total_samples_class, np.finfo(np.float64).eps)
print('Mean Recall: %.3f%%' % (acc.mean() * 100))
acc = correct_samples_class / np.maximum(total_predicts_class, np.finfo(np.float64).eps)
print('Mean Precision: %.3f%%' % (acc.mean() * 100))
for idx in range(len(categories)):
    # True/False Positives (TP/FP) refer to the number of predicted positives that were correct/incorrect.
    # True/False Negatives (TN/FN) refer to the number of predicted negatives that were correct/incorrect.
    tp = cm[idx, idx]
    fp = sum(cm[:, idx]) - tp
    fn = sum(cm[idx, :]) - tp
    tn = sum(np.delete(sum(cm) - cm[idx, :], idx))
    # True Positive Rate: proportion of real positive cases that were correctly predicted as positive.
    recall = tp / np.maximum(tp+fn, np.finfo(np.float64).eps)
    # Precision: proportion of predicted positive cases that were truly real positives.
    precision = tp / np.maximum(tp+fp, np.finfo(np.float64).eps)
    # True Negative Rate: proportion of real negative cases that were correctly predicted as negative.
    specificity = tn / np.maximum(tn+fp, np.finfo(np.float64).eps)
    # Dice coefficient refers to two times the intersection of two sets divided by the sum of their areas.
    # Dice = 2 |A∩B| / (|A|+|B|) = 2 TP / (2 TP + FP + FN)
    f1_score = 2 * ((precision * recall) / np.maximum(precision+recall, np.finfo(np.float64).eps))
    print('> %s: Recall: %.3f%% Precision: %.3f%% Specificity: %.3f%% Dice: %.3f%%' % (list(categories.values())[idx], recall*100, precision*100, specificity*100, f1_score*100))
# Out:
# Mean Accuracy: 70.720%
# Mean Recall: 74.100%
# Mean Precision: 70.310%
# > Cargo plane: Recall: 94.488% Precision: 96.000% Specificity: 99.862% Dice: 95.238%
# > Small car: Recall: 80.902% Precision: 81.269% Specificity: 95.981% Dice: 81.085%
# > Bus: Recall: 58.757% Precision: 51.232% Specificity: 94.170% Dice: 54.737%
# > Truck: Recall: 27.376% Precision: 41.156% Specificity: 94.770% Dice: 32.880%
# > Motorboat: Recall: 75.701% Precision: 70.435% Specificity: 98.077% Dice: 72.973%
# > Fishing vessel: Recall: 82.270% Precision: 73.885% Specificity: 98.864% Dice: 77.852%
# > Dump truck: Recall: 72.470% Precision: 58.497% Specificity: 96.375% Dice: 64.738%
# > Excavator: Recall: 80.380% Precision: 76.970% Specificity: 98.942% Dice: 78.638%
# > Building: Recall: 78.025% Precision: 85.911% Specificity: 96.965% Dice: 81.778%
# > Helipad: Recall: 77.273% Precision: 70.833% Specificity: 99.812% Dice: 73.913%
# > Storage tank: Recall: 73.129% Precision: 65.350% Specificity: 96.701% Dice: 69.021%
# > Shipping container: Recall: 77.049% Precision: 72.755% Specificity: 97.446% Dice: 74.841%
# > Pylon: Recall: 85.484% Precision: 69.737% Specificity: 99.376% Dice: 76.812%

# %% [markdown]
# #### Testing
# Try to improve the results provided in the competition.

# %%
import os
import numpy as np

anns = []
for (dirpath, dirnames, filenames) in os.walk('/kaggle/input/datasets/alexferroni/recognition/xview_recognition/xview_test'):
    for filename in filenames:
        relative_path = os.path.join('xview_test', filename)
        image = GenericImage(relative_path)
        image.tile = np.array([0, 0, 224, 224])
        obj = GenericObject()
        obj.bb = (0, 0, 224, 224)
        obj.category = dirpath[dirpath.rfind('/')+1:]
        image.add_object(obj)
        anns.append(image)
print('Number of testing images: ' + str(len(anns)))
# Out:
# Number of testing images: 2365

# %%
import numpy as np

model.load_weights('model.keras')
predictions_data = {"images": {}, "annotations": {}}
for idx, ann in enumerate(anns):
    image_data = {"image_id": ann.filename.split('/')[-1], "filename": ann.filename, "width": int(ann.tile[2]), "height": int(ann.tile[3])}
    predictions_data["images"][idx] = image_data
    # Load image
    image = load_geoimage(ann.filename)
    image = preprocess_input(image.astype(np.float32)) 
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        annotation_data = {"image_id": ann.filename.split('/')[-1], "category_id": pred_category, "bbox": [int(x) for x in obj_pred.bb]}
        predictions_data["annotations"][idx] = annotation_data

# %%
with open("prediction.json", "w") as outfile:
    json.dump(predictions_data, outfile)

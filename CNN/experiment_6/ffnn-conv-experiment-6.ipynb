# %% [markdown]
# ## Assignment: Image recognition
# - Alumno 1: Alex Ferroni
# - Alumno 2: Vittorio Alberto Gianfrate
# - Alumno 3:
#
# The goals of the assignment are:
# * Develop proficiency in using Tensorflow/Keras for training Neural Nets (NNs).
# * Put into practice the acquired knowledge to optimize the parameters and architecture of a feedforward Neural Net (ffNN), in the context of an image recognition problem.
# * Put into practice NNs specially conceived for analysing images. Design and optimize the parameters of a Convolutional Neural Net (CNN) to deal with previous task.
# * Train popular architectures from scratch (e.g., GoogLeNet, VGG, ResNet, ...), and compare the results with the ones provided by their pre-trained versions using transfer learning.
#
# Follow the link below to download the classification data set  “xview_recognition”: [https://drive.upm.es/s/2DDPE2zHw5dbM3G](https://drive.upm.es/s/2DDPE2zHw5dbM3G)

# %%
# !pip install rasterio
# Out:
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (1.5.0)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio) (25.4.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from rasterio) (2026.1.4)
# Requirement already satisfied: click!=8.2.*,>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio) (8.3.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.0.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio) (3.3.1)

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# 2026-03-10 10:03:13.183291: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773136993.383556      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773136993.442009      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773136993.878782      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773136993.878829      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773136993.878831      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773136993.878834      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import uuid
import numpy as np

class GenericObject:
    """
    Generic object data.
    """
    def __init__(self):
        self.id = uuid.uuid4()
        self.bb = (-1, -1, -1, -1)
        self.category= -1
        self.score = -1

class GenericImage:
    """
    Generic image data.
    """
    def __init__(self, filename):
        self.filename = filename
        self.tile = np.array([-1, -1, -1, -1])  # (pt_x, pt_y, pt_x+width, pt_y+height)
        self.objects = list([])

    def add_object(self, obj: GenericObject):
        self.objects.append(obj)

# %%
categories = {0: 'Cargo plane', 1: 'Small car', 2: 'Bus', 3: 'Truck', 4: 'Motorboat', 5: 'Fishing vessel', 6: 'Dump truck', 7: 'Excavator', 8: 'Building', 9: 'Helipad', 10: 'Storage tank', 11: 'Shipping container', 12: 'Pylon'}

# %%
import warnings
import rasterio
import numpy as np
import os
import cv2

def load_geoimage(filename):
    warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
    base_path = '/kaggle/input/datasets/alexferroni/recognition/xview_recognition/'
    
    src_raster = rasterio.open(base_path + filename, 'r')
    # --------------------

    # RasterIO to OpenCV
    input_type = src_raster.profile['dtype']
    input_channels = src_raster.count
    img = np.zeros((src_raster.height, src_raster.width, src_raster.count), dtype=input_type)
    for band in range(input_channels):
        img[:, :, band] = src_raster.read(band+1)
   
    return img

# %% [markdown]
# #### Training
# Design and train a ffNN to deal with the “xview_recognition” classification task.

# %%
import json
import os


json_file = '/kaggle/input/datasets/alexferroni/recognition/xview_recognition/xview_ann_train.json'

print(f"Caricamento annotazioni da: {json_file}")

with open(json_file) as ifs:
    json_data = json.load(ifs)
    
print("Annotazioni caricate con successo!")
# Out:
# Caricamento annotazioni da: /kaggle/input/datasets/alexferroni/recognition/xview_recognition/xview_ann_train.json
# Annotazioni caricate con successo!

# %%
import numpy as np

counts = dict.fromkeys(categories.values(), 0)
anns = []
for json_img, json_ann in zip(json_data['images'].values(), json_data['annotations'].values()):
    image = GenericImage(json_img['filename'])
    image.tile = np.array([0, 0, json_img['width'], json_img['height']])
    obj = GenericObject()
    obj.bb = (int(json_ann['bbox'][0]), int(json_ann['bbox'][1]), int(json_ann['bbox'][2]), int(json_ann['bbox'][3]))
    obj.category = json_ann['category_id']
    # Resampling strategy to reduce training time
    counts[obj.category] += 1
    image.add_object(obj)
    anns.append(image)
print(counts)
# Out:
# {'Cargo plane': 635, 'Small car': 3324, 'Bus': 1768, 'Truck': 2210, 'Motorboat': 1069, 'Fishing vessel': 706, 'Dump truck': 1236, 'Excavator': 789, 'Building': 3594, 'Helipad': 111, 'Storage tank': 1469, 'Shipping container': 1523, 'Pylon': 312}

# %%
from sklearn.model_selection import train_test_split
labels_list = [x.objects[0].category for x in anns]
anns_train, anns_valid = train_test_split(anns, test_size=0.2, random_state=1, shuffle=True,stratify=labels_list)
print('Number of training images: ' + str(len(anns_train)))
print('Number of validation images: ' + str(len(anns_valid)))
# Out:
# Number of training images: 14996
# Number of validation images: 3750

# %%
train_mean = [69.41887293,56.97948485,49.47711569]
train_std = [51.61769765,44.6239849 ,40.89414141]

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Input
# Load architecture
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization, ELU,RandomFlip,Resizing,RandomRotation,RandomFlip,RandomContrast,RandomBrightness
from tensorflow.keras.regularizers import L2
from tensorflow.keras.initializers import HeNormal, Zeros
from tensorflow.keras.optimizers import Nadam
# Carichiamo il modello ResNet50 senza i suoi layer densi finali (include_top=False)
# e con i pesi già addestrati su ImageNet
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
# Congela tutti i layer convoluzionali
base_model.trainable = False

from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout

# Definisci l'input
inputs = Input(shape=(224, 224, 3))

# 1. Data Augmentation (che avevi già)
x = RandomFlip("horizontal_and_vertical")(inputs)


# 2. Passa le immagini alla ResNet50 (mettendo training=False per i layer di BatchNormalization interni)
x = base_model(x, training=False)

x = GlobalAveragePooling2D()(x)

# 4. Output a 13 classi
x = Dropout(0.3)(x) 
outputs = Dense(13, activation='softmax')(x)

# Crea il modello finale
model = Model(inputs, outputs)

model.summary()
# Out:
# I0000 00:00:1773137018.315052      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_flip (RandomFlip)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 13)             │        26,637 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,614,349 (90.08 MB)
#  Trainable params: 26,637 (104.05 KB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %%
from sklearn.utils import class_weight
import numpy as np

train_labels = [ann.objects[0].category for ann in anns_train]
unique_classes = np.unique(train_labels)

weights_values = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=unique_classes,
    y=train_labels
)

name_to_id = {v: k for k, v in categories.items()}

alpha_array = np.ones(len(categories), dtype=np.float32)

for class_name, weight in zip(unique_classes, weights_values):
    if class_name in name_to_id:
        class_id = name_to_id[class_name]
        alpha_array[class_id] = weight
        print(f"Classe: {class_name:<20} ID: {class_id:<3} Peso: {weight:.4f}")

alpha_list = alpha_array.tolist()

print("\nLISTA DEFINITIVA PRONTA PER FOCAL LOSS:", alpha_list)
# Out:
# Classe: Building             ID: 8   Peso: 0.4012
# Classe: Bus                  ID: 2   Peso: 0.8158
# Classe: Cargo plane          ID: 0   Peso: 2.2707
# Classe: Dump truck           ID: 6   Peso: 1.1664
# Classe: Excavator            ID: 7   Peso: 1.8281
# Classe: Fishing vessel       ID: 5   Peso: 2.0417
# Classe: Helipad              ID: 9   Peso: 12.9611
# Classe: Motorboat            ID: 4   Peso: 1.3492
# Classe: Pylon                ID: 12  Peso: 4.6142
# Classe: Shipping container   ID: 11  Peso: 0.9471
# Classe: Small car            ID: 1   Peso: 0.4338
# Classe: Storage tank         ID: 10  Peso: 0.9817
# Classe: Truck                ID: 3   Peso: 0.6525
#
# LISTA DEFINITIVA PRONTA PER FOCAL LOSS: [2.270745038986206, 0.43382418155670166, 0.8157980442047119, 0.6524538993835449, 1.349167823791504, 2.041661024093628, 1.1663684844970703, 1.8281116485595703, 0.4012307822704315, 12.961106300354004, 0.9817348718643188, 0.9470759034156799, 4.614153861999512]

# %%
from tensorflow.keras.optimizers import Adam

# Learning rate is changed to 0.001
opt = Adam(learning_rate=1e-3, beta_1=0.9, beta_2=0.999, epsilon=1e-8, amsgrad=True, clipnorm=1.0)
model.compile(optimizer=opt, loss=tf.keras.losses.CategoricalFocalCrossentropy(alpha=alpha_list), metrics=['accuracy'])

# %%
from tensorflow.keras.applications.resnet50 import preprocess_input

def generator_images(objs, batch_size, do_shuffle=False, mean=None, std=None):
    while True:
        if do_shuffle:
            np.random.shuffle(objs)
        groups = [objs[i:i+batch_size] for i in range(0, len(objs), batch_size)]
        for group in groups:
            images, labels = [], []
            for (filename, obj) in group:
                
                img = load_geoimage(filename)
                
                
                # ---> IL SEGRETO È QUI: via la vecchia normalizzazione <---
                img = preprocess_input(img.astype(np.float32))
               
                
                images.append(img)
                probabilities = np.zeros(len(categories))
                probabilities[list(categories.values()).index(obj.category)] = 1
                labels.append(probabilities)
            images = np.array(images).astype(np.float32)
            labels = np.array(labels).astype(np.float32)
            yield images, labels

# %%
def mixup_generator(objs, batch_size, alpha=0.3, mean=None, std=None):
    while True:
        # Prendi due batch casuali
        idx1 = np.random.choice(len(objs), batch_size)
        idx2 = np.random.choice(len(objs), batch_size)
        
        images1, labels1 = [], []
        images2, labels2 = [], []
        
        for i, j in zip(idx1, idx2):
            filename1, obj1 = objs[i]
            filename2, obj2 = objs[j]
            
            img1 = load_geoimage(filename1)
            img2 = load_geoimage(filename2)
            
            img1 = preprocess_input(img1.astype(np.float32))
            img2 = preprocess_input(img2.astype(np.float32))
            
            lbl1 = np.zeros(len(categories))
            lbl1[list(categories.values()).index(obj1.category)] = 1
            lbl2 = np.zeros(len(categories))
            lbl2[list(categories.values()).index(obj2.category)] = 1
            
            images1.append(img1)
            labels1.append(lbl1)
            images2.append(img2)
            labels2.append(lbl2)
        
        images1 = np.array(images1, dtype=np.float32)
        images2 = np.array(images2, dtype=np.float32)
        labels1 = np.array(labels1, dtype=np.float32)
        labels2 = np.array(labels2, dtype=np.float32)
        
        # MixUp
        lam = np.random.beta(alpha, alpha)
        images = lam * images1 + (1 - lam) * images2
        labels = lam * labels1 + (1 - lam) * labels2
        
        yield images, labels

# %%
from tensorflow.keras.callbacks import TerminateOnNaN, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Callbacks
model_checkpoint = ModelCheckpoint('resnet_phase1.keras', monitor='val_accuracy', verbose=1, save_best_only=True)
reduce_lr = ReduceLROnPlateau('val_accuracy', factor=0.1, patience=10, verbose=1,min_lr=1e-7)
early_stop = EarlyStopping('val_accuracy', patience=22, verbose=1)
terminate = TerminateOnNaN()
callbacks_phase1 = [model_checkpoint, reduce_lr, early_stop, terminate]

# %%
# Generate the list of objects from annotations
objs_train = [(ann.filename, obj) for ann in anns_train for obj in ann.objects]
objs_valid = [(ann.filename, obj) for ann in anns_valid for obj in ann.objects]
# Generators
batch_size = 32
# Usa questo al posto del train_generator
train_generator = mixup_generator(objs_train, batch_size,
                                   alpha=0.3)
# in caso da rimettere il vecchioo
valid_generator = generator_images(objs_valid, batch_size, do_shuffle=False)

# %%
import math
import numpy as np

print('Training model PHASE 1')
epochs = 20
train_steps = math.ceil(len(objs_train)/batch_size)
valid_steps = math.ceil(len(objs_valid)/batch_size)
h_phase1 = model.fit(train_generator, steps_per_epoch=train_steps, validation_data=valid_generator, validation_steps=valid_steps, epochs=epochs, callbacks=callbacks_phase1, verbose=1)
# Best validation model
best_idx = int(np.argmax(h_phase1.history['val_accuracy']))
best_value = np.max(h_phase1.history['val_accuracy'])
print('Best validation model: epoch ' + str(best_idx+1), ' - val_accuracy ' + str(best_value))
# Out:
# Training model PHASE 1
# Epoch 1/20
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1773137039.498055     128 service.cc:152] XLA service 0x7b8670013970 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1773137039.498094     128 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1773137041.406232     128 cuda_dnn.cc:529] Loaded cuDNN version 91002
#   1/469 ━━━━━━━━━━━━━━━━━━━━ 1:44:35 13s/step - accuracy: 0.1250 - loss: 2.5873
# I0000 00:00:1773137046.276666     128 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4280 - loss: 1.4586
# Epoch 1: val_accuracy improved from -inf to 0.66000, saving model to resnet_phase1.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 704s 1s/step - accuracy: 0.4282 - loss: 1.4581 - val_accuracy: 0.6600 - val_loss: 0.6299 - learning_rate: 0.0010
# Epoch 2/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.5577 - loss: 1.0465
# Epoch 2: val_accuracy improved from 0.66000 to 0.67040, saving model to resnet_phase1.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 198s 422ms/step - accuracy: 0.5577 - loss: 1.0464 - val_accuracy: 0.6704 - val_loss: 0.5973 - learning_rate: 0.0010
# Epoch 3/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.5849 - loss: 0.9317
# Epoch 3: val_accuracy did not improve from 0.67040
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 143s 305ms/step - accuracy: 0.5849 - loss: 0.9317 - val_accuracy: 0.6507 - val_loss: 0.5717 - learning_rate: 0.0010
# Epoch 4/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.5973 - loss: 0.8916
# Epoch 4: val_accuracy improved from 0.67040 to 0.68747, saving model to resnet_phase1.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 151s 322ms/step - accuracy: 0.5973 - loss: 0.8916 - val_accuracy: 0.6875 - val_loss: 0.5734 - learning_rate: 0.0010
# Epoch 5/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.5936 - loss: 0.9492
# Epoch 5: val_accuracy did not improve from 0.68747
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 135s 287ms/step - accuracy: 0.5936 - loss: 0.9492 - val_accuracy: 0.6835 - val_loss: 0.5213 - learning_rate: 0.0010
# Epoch 6/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.6005 - loss: 0.9198
# Epoch 6: val_accuracy improved from 0.68747 to 0.70080, saving model to resnet_phase1.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 133s 285ms/step - accuracy: 0.6005 - loss: 0.9198 - val_accuracy: 0.7008 - val_loss: 0.5566 - learning_rate: 0.0010
# Epoch 7/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.6263 - loss: 0.8495
# Epoch 7: val_accuracy did not improve from 0.70080
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 123s 263ms/step - accuracy: 0.6263 - loss: 0.8496 - val_accuracy: 0.6864 - val_loss: 0.5637 - learning_rate: 0.0010
# Epoch 8/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.5885 - loss: 0.9272
# Epoch 8: val_accuracy did not improve from 0.70080
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 122s 262ms/step - accuracy: 0.5885 - loss: 0.9272 - val_accuracy: 0.6899 - val_loss: 0.5830 - learning_rate: 0.0010
# Epoch 9/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.6136 - loss: 0.8950
# Epoch 9: val_accuracy did not improve from 0.70080
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 128s 272ms/step - accuracy: 0.6136 - loss: 0.8949 - val_accuracy: 0.6933 - val_loss: 0.5421 - learning_rate: 0.0010
# Epoch 10/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.5873 - loss: 0.9634
# Epoch 10: val_accuracy did not improve from 0.70080
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 129s 276ms/step - accuracy: 0.5873 - loss: 0.9634 - val_accuracy: 0.6963 - val_loss: 0.5497 - learning_rate: 0.0010
# Epoch 11/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.6147 - loss: 0.8728
# Epoch 11: val_accuracy did not improve from 0.70080
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 132s 282ms/step - accuracy: 0.6147 - loss: 0.8728 - val_accuracy: 0.6907 - val_loss: 0.5543 - learning_rate: 0.0010
# Epoch 12/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.5994 - loss: 0.9385
# Epoch 12: val_accuracy improved from 0.70080 to 0.70613, saving model to resnet_phase1.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 126s 269ms/step - accuracy: 0.5994 - loss: 0.9385 - val_accuracy: 0.7061 - val_loss: 0.5660 - learning_rate: 0.0010
# Epoch 13/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.6279 - loss: 0.8386
# Epoch 13: val_accuracy did not improve from 0.70613
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 126s 270ms/step - accuracy: 0.6279 - loss: 0.8388 - val_accuracy: 0.6813 - val_loss: 0.5621 - learning_rate: 0.0010
# Epoch 14/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.6137 - loss: 0.9102
# Epoch 14: val_accuracy did not improve from 0.70613
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 123s 262ms/step - accuracy: 0.6137 - loss: 0.9102 - val_accuracy: 0.6853 - val_loss: 0.5752 - learning_rate: 0.0010
# Epoch 15/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.5980 - loss: 0.9230
# Epoch 15: val_accuracy did not improve from 0.70613
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 121s 259ms/step - accuracy: 0.5980 - loss: 0.9230 - val_accuracy: 0.7035 - val_loss: 0.5528 - learning_rate: 0.0010
# Epoch 16/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.6159 - loss: 0.9040
# Epoch 16: val_accuracy did not improve from 0.70613
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 131s 279ms/step - accuracy: 0.6159 - loss: 0.9040 - val_accuracy: 0.6957 - val_loss: 0.5579 - learning_rate: 0.0010
# Epoch 17/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.6048 - loss: 0.9313
# Epoch 17: val_accuracy did not improve from 0.70613
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 123s 262ms/step - accuracy: 0.6048 - loss: 0.9313 - val_accuracy: 0.6995 - val_loss: 0.5503 - learning_rate: 0.0010
# Epoch 18/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.6014 - loss: 0.9072
# Epoch 18: val_accuracy did not improve from 0.70613
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 123s 262ms/step - accuracy: 0.6014 - loss: 0.9072 - val_accuracy: 0.6832 - val_loss: 0.5539 - learning_rate: 0.0010
# Epoch 19/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.6115 - loss: 0.8962
# Epoch 19: val_accuracy did not improve from 0.70613
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 124s 265ms/step - accuracy: 0.6115 - loss: 0.8963 - val_accuracy: 0.6896 - val_loss: 0.5477 - learning_rate: 0.0010
# Epoch 20/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.6040 - loss: 0.8753
# Epoch 20: val_accuracy did not improve from 0.70613
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 124s 264ms/step - accuracy: 0.6040 - loss: 0.8753 - val_accuracy: 0.6891 - val_loss: 0.5649 - learning_rate: 0.0010
# Best validation model: epoch 12  - val_accuracy 0.7061333060264587

# %%
import matplotlib.pyplot as plt

def plot_results(history):
    
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    
    
    epochs_range = range(1, len(acc) + 1)

    plt.figure(figsize=(16, 6))

    # --- GRAFICO 1: ACCURACY
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy', color='blue', marker='o')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy', color='red', marker='o')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epoche')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')
    plt.grid(True)

    # --- GRAFICO 2: LOSS 
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss', color='blue', linestyle='--')
    plt.plot(epochs_range, val_loss, label='Validation Loss', color='red', linestyle='--')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoche')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')
    plt.grid(True)

    plt.show()


plot_results(h_phase1)

# %%
# PHASE 2
model.load_weights('resnet_phase1.keras')
#SBLOCCA LA RESNET
base_model.trainable = True

for layer in base_model.layers:
    if layer.name.startswith('conv5'):
        layer.trainable = True
    else:
        layer.trainable = False
        
for layer in base_model.layers:
    if isinstance(layer, tf.keras.layers.BatchNormalization):
        layer.trainable = False
opt = Adam(learning_rate=1e-5, beta_1=0.9, beta_2=0.999, epsilon=1e-8, amsgrad=True, clipnorm=1.0)
model.compile(optimizer=opt, loss=tf.keras.losses.CategoricalFocalCrossentropy(alpha=alpha_list), metrics=['accuracy'])
model_checkpoint = ModelCheckpoint('model.keras', monitor='val_accuracy', verbose=1, save_best_only=True)
reduce_lr = ReduceLROnPlateau('val_accuracy', factor=0.1, patience=10, verbose=1,min_lr=1e-7)
early_stop = EarlyStopping('val_accuracy', patience=22, verbose=1)
terminate = TerminateOnNaN()
callbacks_phase2 = [model_checkpoint, reduce_lr, early_stop, terminate]
epochs =50

h_phase2 = model.fit(train_generator, steps_per_epoch=train_steps, validation_data=valid_generator, validation_steps=valid_steps, epochs=epochs, callbacks=callbacks_phase2, verbose=1)
# Best validation model
best_idx = int(np.argmax(h_phase2.history['val_accuracy']))
best_value = np.max(h_phase2.history['val_accuracy'])
print('Best validation model: epoch ' + str(best_idx+1), ' - val_accuracy ' + str(best_value))
# Out:
# Epoch 1/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.6292 - loss: 0.8371
# Epoch 1: val_accuracy improved from -inf to 0.72000, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 162s 311ms/step - accuracy: 0.6292 - loss: 0.8370 - val_accuracy: 0.7200 - val_loss: 0.5098 - learning_rate: 1.0000e-05
# Epoch 2/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.6570 - loss: 0.7799
# Epoch 2: val_accuracy improved from 0.72000 to 0.73093, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 162s 347ms/step - accuracy: 0.6570 - loss: 0.7798 - val_accuracy: 0.7309 - val_loss: 0.4755 - learning_rate: 1.0000e-05
# Epoch 3/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.6850 - loss: 0.7385
# Epoch 3: val_accuracy improved from 0.73093 to 0.73120, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 144s 307ms/step - accuracy: 0.6850 - loss: 0.7385 - val_accuracy: 0.7312 - val_loss: 0.4717 - learning_rate: 1.0000e-05
# Epoch 4/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.6737 - loss: 0.7334
# Epoch 4: val_accuracy improved from 0.73120 to 0.73680, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 141s 301ms/step - accuracy: 0.6737 - loss: 0.7333 - val_accuracy: 0.7368 - val_loss: 0.4667 - learning_rate: 1.0000e-05
# Epoch 5/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.6930 - loss: 0.7281
# Epoch 5: val_accuracy improved from 0.73680 to 0.74187, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 141s 301ms/step - accuracy: 0.6930 - loss: 0.7281 - val_accuracy: 0.7419 - val_loss: 0.4543 - learning_rate: 1.0000e-05
# Epoch 6/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.7020 - loss: 0.7201
# Epoch 6: val_accuracy did not improve from 0.74187
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 135s 289ms/step - accuracy: 0.7020 - loss: 0.7201 - val_accuracy: 0.7413 - val_loss: 0.4396 - learning_rate: 1.0000e-05
# Epoch 7/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.7023 - loss: 0.6794
# Epoch 7: val_accuracy improved from 0.74187 to 0.74533, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 132s 282ms/step - accuracy: 0.7023 - loss: 0.6794 - val_accuracy: 0.7453 - val_loss: 0.4322 - learning_rate: 1.0000e-05
# Epoch 8/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.7430 - loss: 0.6064
# Epoch 8: val_accuracy improved from 0.74533 to 0.74560, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 132s 283ms/step - accuracy: 0.7430 - loss: 0.6065 - val_accuracy: 0.7456 - val_loss: 0.4272 - learning_rate: 1.0000e-05
# Epoch 9/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.7080 - loss: 0.7123
# Epoch 9: val_accuracy improved from 0.74560 to 0.74800, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 142s 303ms/step - accuracy: 0.7080 - loss: 0.7123 - val_accuracy: 0.7480 - val_loss: 0.4221 - learning_rate: 1.0000e-05
# Epoch 10/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.7490 - loss: 0.5719
# Epoch 10: val_accuracy improved from 0.74800 to 0.75813, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 130s 277ms/step - accuracy: 0.7489 - loss: 0.5720 - val_accuracy: 0.7581 - val_loss: 0.4348 - learning_rate: 1.0000e-05
# Epoch 11/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.7604 - loss: 0.6020
# Epoch 11: val_accuracy did not improve from 0.75813
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 129s 275ms/step - accuracy: 0.7604 - loss: 0.6020 - val_accuracy: 0.7451 - val_loss: 0.4327 - learning_rate: 1.0000e-05
# Epoch 12/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.7425 - loss: 0.6293
# Epoch 12: val_accuracy did not improve from 0.75813
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 128s 273ms/step - accuracy: 0.7425 - loss: 0.6293 - val_accuracy: 0.7523 - val_loss: 0.4157 - learning_rate: 1.0000e-05
# Epoch 13/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.7596 - loss: 0.5920
# Epoch 13: val_accuracy did not improve from 0.75813
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 130s 277ms/step - accuracy: 0.7596 - loss: 0.5920 - val_accuracy: 0.7557 - val_loss: 0.4091 - learning_rate: 1.0000e-05
# Epoch 14/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.7600 - loss: 0.5849
# Epoch 14: val_accuracy did not improve from 0.75813
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 129s 274ms/step - accuracy: 0.7600 - loss: 0.5850 - val_accuracy: 0.7539 - val_loss: 0.4470 - learning_rate: 1.0000e-05
# Epoch 15/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.7637 - loss: 0.5947
# Epoch 15: val_accuracy did not improve from 0.75813
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 129s 275ms/step - accuracy: 0.7637 - loss: 0.5947 - val_accuracy: 0.7579 - val_loss: 0.4054 - learning_rate: 1.0000e-05
# Epoch 16/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.7754 - loss: 0.5508
# Epoch 16: val_accuracy improved from 0.75813 to 0.76240, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 131s 279ms/step - accuracy: 0.7754 - loss: 0.5509 - val_accuracy: 0.7624 - val_loss: 0.4169 - learning_rate: 1.0000e-05
# Epoch 17/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.7652 - loss: 0.5933
# Epoch 17: val_accuracy did not improve from 0.76240
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 127s 271ms/step - accuracy: 0.7652 - loss: 0.5932 - val_accuracy: 0.7571 - val_loss: 0.4117 - learning_rate: 1.0000e-05
# Epoch 18/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.7739 - loss: 0.5911
# Epoch 18: val_accuracy did not improve from 0.76240
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 132s 281ms/step - accuracy: 0.7739 - loss: 0.5911 - val_accuracy: 0.7592 - val_loss: 0.4090 - learning_rate: 1.0000e-05
# Epoch 19/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.7897 - loss: 0.5279
# Epoch 19: val_accuracy did not improve from 0.76240
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 129s 276ms/step - accuracy: 0.7897 - loss: 0.5280 - val_accuracy: 0.7581 - val_loss: 0.4334 - learning_rate: 1.0000e-05
# Epoch 20/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.7951 - loss: 0.5444
# Epoch 20: val_accuracy improved from 0.76240 to 0.76400, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 131s 279ms/step - accuracy: 0.7951 - loss: 0.5444 - val_accuracy: 0.7640 - val_loss: 0.4080 - learning_rate: 1.0000e-05
# Epoch 21/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.8083 - loss: 0.5110
# Epoch 21: val_accuracy improved from 0.76400 to 0.76480, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 126s 270ms/step - accuracy: 0.8083 - loss: 0.5110 - val_accuracy: 0.7648 - val_loss: 0.4276 - learning_rate: 1.0000e-05
# Epoch 22/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.8111 - loss: 0.5470
# Epoch 22: val_accuracy did not improve from 0.76480
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 122s 261ms/step - accuracy: 0.8110 - loss: 0.5470 - val_accuracy: 0.7469 - val_loss: 0.4393 - learning_rate: 1.0000e-05
# Epoch 23/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.7982 - loss: 0.5566
# Epoch 23: val_accuracy improved from 0.76480 to 0.76587, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 127s 271ms/step - accuracy: 0.7982 - loss: 0.5566 - val_accuracy: 0.7659 - val_loss: 0.4435 - learning_rate: 1.0000e-05
# Epoch 24/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.7987 - loss: 0.5429
# Epoch 24: val_accuracy did not improve from 0.76587
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 121s 259ms/step - accuracy: 0.7987 - loss: 0.5429 - val_accuracy: 0.7576 - val_loss: 0.4401 - learning_rate: 1.0000e-05
# Epoch 25/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.8143 - loss: 0.5337
# Epoch 25: val_accuracy improved from 0.76587 to 0.76693, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 125s 267ms/step - accuracy: 0.8143 - loss: 0.5337 - val_accuracy: 0.7669 - val_loss: 0.4226 - learning_rate: 1.0000e-05
# Epoch 26/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.8103 - loss: 0.5573
# Epoch 26: val_accuracy did not improve from 0.76693
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 122s 260ms/step - accuracy: 0.8103 - loss: 0.5573 - val_accuracy: 0.7573 - val_loss: 0.4412 - learning_rate: 1.0000e-05
# Epoch 27/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.8334 - loss: 0.4679
# Epoch 27: val_accuracy did not improve from 0.76693
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 121s 259ms/step - accuracy: 0.8334 - loss: 0.4679 - val_accuracy: 0.7667 - val_loss: 0.4370 - learning_rate: 1.0000e-05
# Epoch 28/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.8042 - loss: 0.5499
# Epoch 28: val_accuracy improved from 0.76693 to 0.77653, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 127s 272ms/step - accuracy: 0.8042 - loss: 0.5498 - val_accuracy: 0.7765 - val_loss: 0.4222 - learning_rate: 1.0000e-05
# Epoch 29/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.8226 - loss: 0.4975
# Epoch 29: val_accuracy did not improve from 0.77653
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 124s 266ms/step - accuracy: 0.8226 - loss: 0.4976 - val_accuracy: 0.7640 - val_loss: 0.4239 - learning_rate: 1.0000e-05
# Epoch 30/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.8374 - loss: 0.4685
# Epoch 30: val_accuracy did not improve from 0.77653
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 141s 300ms/step - accuracy: 0.8374 - loss: 0.4686 - val_accuracy: 0.7675 - val_loss: 0.4245 - learning_rate: 1.0000e-05
# Epoch 31/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.8537 - loss: 0.4590
# Epoch 31: val_accuracy did not improve from 0.77653
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 124s 266ms/step - accuracy: 0.8536 - loss: 0.4591 - val_accuracy: 0.7672 - val_loss: 0.4368 - learning_rate: 1.0000e-05
# Epoch 32/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.8314 - loss: 0.5130
# Epoch 32: val_accuracy did not improve from 0.77653
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 126s 268ms/step - accuracy: 0.8314 - loss: 0.5130 - val_accuracy: 0.7760 - val_loss: 0.4339 - learning_rate: 1.0000e-05
# Epoch 33/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.8370 - loss: 0.4913
# Epoch 33: val_accuracy did not improve from 0.77653
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 127s 272ms/step - accuracy: 0.8370 - loss: 0.4913 - val_accuracy: 0.7699 - val_loss: 0.4413 - learning_rate: 1.0000e-05
# Epoch 34/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.8164 - loss: 0.5510
# Epoch 34: val_accuracy did not improve from 0.77653
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 125s 267ms/step - accuracy: 0.8164 - loss: 0.5509 - val_accuracy: 0.7688 - val_loss: 0.4157 - learning_rate: 1.0000e-05
# Epoch 35/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.8384 - loss: 0.5074
# Epoch 35: val_accuracy did not improve from 0.77653
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 134s 286ms/step - accuracy: 0.8384 - loss: 0.5074 - val_accuracy: 0.7685 - val_loss: 0.4217 - learning_rate: 1.0000e-05
# Epoch 36/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.8475 - loss: 0.4601
# Epoch 36: val_accuracy did not improve from 0.77653
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 128s 274ms/step - accuracy: 0.8475 - loss: 0.4601 - val_accuracy: 0.7683 - val_loss: 0.4244 - learning_rate: 1.0000e-05
# Epoch 37/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.8405 - loss: 0.4939
# Epoch 37: val_accuracy did not improve from 0.77653
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 128s 272ms/step - accuracy: 0.8405 - loss: 0.4939 - val_accuracy: 0.7688 - val_loss: 0.4079 - learning_rate: 1.0000e-05
# Epoch 38/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.8379 - loss: 0.5275
# Epoch 38: val_accuracy did not improve from 0.77653
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 120s 256ms/step - accuracy: 0.8379 - loss: 0.5274 - val_accuracy: 0.7731 - val_loss: 0.4182 - learning_rate: 1.0000e-05
# Epoch 39/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.8612 - loss: 0.4363
# Epoch 39: val_accuracy improved from 0.77653 to 0.77680, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 125s 267ms/step - accuracy: 0.8612 - loss: 0.4364 - val_accuracy: 0.7768 - val_loss: 0.4056 - learning_rate: 1.0000e-06
# Epoch 40/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.8315 - loss: 0.5325
# Epoch 40: val_accuracy improved from 0.77680 to 0.77867, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 128s 273ms/step - accuracy: 0.8315 - loss: 0.5325 - val_accuracy: 0.7787 - val_loss: 0.4088 - learning_rate: 1.0000e-06
# Epoch 41/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.8479 - loss: 0.5053
# Epoch 41: val_accuracy did not improve from 0.77867
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 122s 261ms/step - accuracy: 0.8479 - loss: 0.5054 - val_accuracy: 0.7781 - val_loss: 0.4122 - learning_rate: 1.0000e-06
# Epoch 42/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.8537 - loss: 0.5075
# Epoch 42: val_accuracy did not improve from 0.77867
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 127s 270ms/step - accuracy: 0.8537 - loss: 0.5075 - val_accuracy: 0.7768 - val_loss: 0.4146 - learning_rate: 1.0000e-06
# Epoch 43/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.8270 - loss: 0.5270
# Epoch 43: val_accuracy did not improve from 0.77867
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 124s 264ms/step - accuracy: 0.8270 - loss: 0.5270 - val_accuracy: 0.7763 - val_loss: 0.4164 - learning_rate: 1.0000e-06
# Epoch 44/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.8451 - loss: 0.4953
# Epoch 44: val_accuracy did not improve from 0.77867
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 125s 266ms/step - accuracy: 0.8450 - loss: 0.4953 - val_accuracy: 0.7757 - val_loss: 0.4221 - learning_rate: 1.0000e-06
# Epoch 45/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.8442 - loss: 0.4989
# Epoch 45: val_accuracy did not improve from 0.77867
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 120s 257ms/step - accuracy: 0.8442 - loss: 0.4988 - val_accuracy: 0.7787 - val_loss: 0.4178 - learning_rate: 1.0000e-06
# Epoch 46/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.8615 - loss: 0.4416
# Epoch 46: val_accuracy did not improve from 0.77867
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 124s 264ms/step - accuracy: 0.8615 - loss: 0.4416 - val_accuracy: 0.7779 - val_loss: 0.4194 - learning_rate: 1.0000e-06
# Epoch 47/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.8560 - loss: 0.4518
# Epoch 47: val_accuracy did not improve from 0.77867
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 124s 265ms/step - accuracy: 0.8560 - loss: 0.4518 - val_accuracy: 0.7784 - val_loss: 0.4217 - learning_rate: 1.0000e-06
# Epoch 48/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.8608 - loss: 0.4637
# Epoch 48: val_accuracy improved from 0.77867 to 0.77893, saving model to model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 124s 265ms/step - accuracy: 0.8608 - loss: 0.4637 - val_accuracy: 0.7789 - val_loss: 0.4279 - learning_rate: 1.0000e-06
# Epoch 49/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.8369 - loss: 0.5059
# Epoch 49: val_accuracy did not improve from 0.77893
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 125s 266ms/step - accuracy: 0.8369 - loss: 0.5058 - val_accuracy: 0.7757 - val_loss: 0.4235 - learning_rate: 1.0000e-06
# Epoch 50/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.8757 - loss: 0.4335
# Epoch 50: val_accuracy did not improve from 0.77893
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 121s 259ms/step - accuracy: 0.8756 - loss: 0.4336 - val_accuracy: 0.7784 - val_loss: 0.4169 - learning_rate: 1.0000e-06
# Best validation model: epoch 48  - val_accuracy 0.7789333462715149

# %%
plot_results(h_phase2)

# %% [markdown]
# #### Validation
# Compute validation metrics.

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

def draw_confusion_matrix(cm, categories):
    # Draw confusion matrix
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    cm = cm.astype('float') / np.maximum(cm.sum(axis=1)[:, np.newaxis], np.finfo(np.float64).eps)
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.colormaps['Blues'])
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=list(categories.values()), yticklabels=list(categories.values()), ylabel='Annotation', xlabel='Prediction')
    # Rotate the tick labels and set their alignment
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Loop over data dimensions and create text annotations
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], '.2f'), ha="center", va="center", color="white" if cm[i, j] > thresh else "black", fontsize=int(20-pow(len(categories), 0.5)))
    fig.tight_layout()
    plt.show()

# %%
import numpy as np

model.load_weights('model.keras')
y_true, y_pred = [], []
for ann in anns_valid:
    # Load image
    image = load_geoimage(ann.filename)
    image = preprocess_input(image.astype(np.float32))  
            
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        y_true.append(obj_pred.category)
        y_pred.append(pred_category)

# %%
from sklearn.metrics import confusion_matrix

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=list(categories.values()))
draw_confusion_matrix(cm, categories)

# %%
import numpy as np

# Compute the accuracy
correct_samples_class = np.diag(cm).astype(float)
total_samples_class = np.sum(cm, axis=1).astype(float)
total_predicts_class = np.sum(cm, axis=0).astype(float)
print('Mean Accuracy: %.3f%%' % (np.sum(correct_samples_class) / np.sum(total_samples_class) * 100))
acc = correct_samples_class / np.maximum(total_samples_class, np.finfo(np.float64).eps)
print('Mean Recall: %.3f%%' % (acc.mean() * 100))
acc = correct_samples_class / np.maximum(total_predicts_class, np.finfo(np.float64).eps)
print('Mean Precision: %.3f%%' % (acc.mean() * 100))
for idx in range(len(categories)):
    # True/False Positives (TP/FP) refer to the number of predicted positives that were correct/incorrect.
    # True/False Negatives (TN/FN) refer to the number of predicted negatives that were correct/incorrect.
    tp = cm[idx, idx]
    fp = sum(cm[:, idx]) - tp
    fn = sum(cm[idx, :]) - tp
    tn = sum(np.delete(sum(cm) - cm[idx, :], idx))
    # True Positive Rate: proportion of real positive cases that were correctly predicted as positive.
    recall = tp / np.maximum(tp+fn, np.finfo(np.float64).eps)
    # Precision: proportion of predicted positive cases that were truly real positives.
    precision = tp / np.maximum(tp+fp, np.finfo(np.float64).eps)
    # True Negative Rate: proportion of real negative cases that were correctly predicted as negative.
    specificity = tn / np.maximum(tn+fp, np.finfo(np.float64).eps)
    # Dice coefficient refers to two times the intersection of two sets divided by the sum of their areas.
    # Dice = 2 |A∩B| / (|A|+|B|) = 2 TP / (2 TP + FP + FN)
    f1_score = 2 * ((precision * recall) / np.maximum(precision+recall, np.finfo(np.float64).eps))
    print('> %s: Recall: %.3f%% Precision: %.3f%% Specificity: %.3f%% Dice: %.3f%%' % (list(categories.values())[idx], recall*100, precision*100, specificity*100, f1_score*100))
# Out:
# Mean Accuracy: 77.893%
# Mean Recall: 78.817%
# Mean Precision: 80.480%
# > Cargo plane: Recall: 95.276% Precision: 98.374% Specificity: 99.945% Dice: 96.800%
# > Small car: Recall: 87.669% Precision: 77.733% Specificity: 94.587% Dice: 82.403%
# > Bus: Recall: 65.254% Precision: 59.536% Specificity: 95.377% Dice: 62.264%
# > Truck: Recall: 41.403% Precision: 53.043% Specificity: 95.103% Dice: 46.506%
# > Motorboat: Recall: 83.645% Precision: 78.855% Specificity: 98.643% Dice: 81.179%
# > Fishing vessel: Recall: 79.433% Precision: 78.873% Specificity: 99.169% Dice: 79.152%
# > Dump truck: Recall: 65.992% Precision: 68.487% Specificity: 97.859% Dice: 67.216%
# > Excavator: Recall: 86.076% Precision: 87.742% Specificity: 99.471% Dice: 86.901%
# > Building: Recall: 88.734% Precision: 91.404% Specificity: 98.020% Dice: 90.049%
# > Helipad: Recall: 72.727% Precision: 100.000% Specificity: 100.000% Dice: 84.211%
# > Storage tank: Recall: 88.095% Precision: 92.832% Specificity: 99.421% Dice: 90.401%
# > Shipping container: Recall: 80.000% Precision: 75.776% Specificity: 97.736% Dice: 77.831%
# > Pylon: Recall: 90.323% Precision: 83.582% Specificity: 99.702% Dice: 86.822%

# %% [markdown]
# #### Testing
# Try to improve the results provided in the competition.

# %%
import os
import numpy as np

anns = []
for (dirpath, dirnames, filenames) in os.walk('/kaggle/input/datasets/alexferroni/recognition/xview_recognition/xview_test'):
    for filename in filenames:
        relative_path = os.path.join('xview_test', filename)
        image = GenericImage(relative_path)
        image.tile = np.array([0, 0, 224, 224])
        obj = GenericObject()
        obj.bb = (0, 0, 224, 224)
        obj.category = dirpath[dirpath.rfind('/')+1:]
        image.add_object(obj)
        anns.append(image)
print('Number of testing images: ' + str(len(anns)))
# Out:
# Number of testing images: 2365

# %%
import numpy as np

model.load_weights('model.keras')
predictions_data = {"images": {}, "annotations": {}}
for idx, ann in enumerate(anns):
    image_data = {"image_id": ann.filename.split('/')[-1], "filename": ann.filename, "width": int(ann.tile[2]), "height": int(ann.tile[3])}
    predictions_data["images"][idx] = image_data
    # Load image
    image = load_geoimage(ann.filename)
    image = preprocess_input(image.astype(np.float32)) 
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        annotation_data = {"image_id": ann.filename.split('/')[-1], "category_id": pred_category, "bbox": [int(x) for x in obj_pred.bb]}
        predictions_data["annotations"][idx] = annotation_data

# %%
with open("prediction.json", "w") as outfile:
    json.dump(predictions_data, outfile)

# %% [markdown]
# ## Assignment: Image recognition
# - Alumno 1: Alex Ferroni
# - Alumno 2: Vittorio Alberto Gianfrate
# - Alumno 3:
#
# The goals of the assignment are:
# * Develop proficiency in using Tensorflow/Keras for training Neural Nets (NNs).
# * Put into practice the acquired knowledge to optimize the parameters and architecture of a feedforward Neural Net (ffNN), in the context of an image recognition problem.
# * Put into practice NNs specially conceived for analysing images. Design and optimize the parameters of a Convolutional Neural Net (CNN) to deal with previous task.
# * Train popular architectures from scratch (e.g., GoogLeNet, VGG, ResNet, ...), and compare the results with the ones provided by their pre-trained versions using transfer learning.
#
# Follow the link below to download the classification data set  “xview_recognition”: [https://drive.upm.es/s/2DDPE2zHw5dbM3G](https://drive.upm.es/s/2DDPE2zHw5dbM3G)

# %%
# !pip install rasterio
# Out:
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (1.5.0)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio) (25.4.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from rasterio) (2026.1.4)
# Requirement already satisfied: click!=8.2.*,>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio) (8.3.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.0.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio) (3.2.5)

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import uuid
import numpy as np

class GenericObject:
    """
    Generic object data.
    """
    def __init__(self):
        self.id = uuid.uuid4()
        self.bb = (-1, -1, -1, -1)
        self.category= -1
        self.score = -1

class GenericImage:
    """
    Generic image data.
    """
    def __init__(self, filename):
        self.filename = filename
        self.tile = np.array([-1, -1, -1, -1])  # (pt_x, pt_y, pt_x+width, pt_y+height)
        self.objects = list([])

    def add_object(self, obj: GenericObject):
        self.objects.append(obj)

# %%
categories = {0: 'Cargo plane', 1: 'Small car', 2: 'Bus', 3: 'Truck', 4: 'Motorboat', 5: 'Fishing vessel', 6: 'Dump truck', 7: 'Excavator', 8: 'Building', 9: 'Helipad', 10: 'Storage tank', 11: 'Shipping container', 12: 'Pylon'}

# %%
import warnings
import rasterio
import numpy as np
import os

def load_geoimage(filename):
    warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
    base_path = '/kaggle/input/datasets/vittoriogianfrate/recognition/xview_recognition/'
    
    src_raster = rasterio.open(base_path + filename, 'r')
    # --------------------

    # RasterIO to OpenCV
    input_type = src_raster.profile['dtype']
    input_channels = src_raster.count
    img = np.zeros((src_raster.height, src_raster.width, src_raster.count), dtype=input_type)
    for band in range(input_channels):
        img[:, :, band] = src_raster.read(band+1)
    return img /255.0

# %% [markdown]
# #### Training
# Design and train a ffNN to deal with the “xview_recognition” classification task.

# %%
import json
import os

json_file = '/kaggle/input/datasets/vittoriogianfrate/recognition/xview_recognition/xview_ann_train.json'
if not os.path.exists(json_file):
    json_file = '/kaggle/input/datasets/vittoriogianfrate/recognition/xview_recognition/xview_ann_train.json'
print(f"Caricamento annotazioni da: {json_file}")

with open(json_file) as ifs:
    json_data = json.load(ifs)
    
print("Annotazioni caricate con successo!")
# Out:
# Caricamento annotazioni da: /kaggle/input/datasets/vittoriogianfrate/recognition/xview_recognition/xview_ann_train.json
# Annotazioni caricate con successo!

# %%
import numpy as np

counts = dict.fromkeys(categories.values(), 0)
anns = []
for json_img, json_ann in zip(json_data['images'].values(), json_data['annotations'].values()):
    image = GenericImage(json_img['filename'])
    image.tile = np.array([0, 0, json_img['width'], json_img['height']])
    obj = GenericObject()
    obj.bb = (int(json_ann['bbox'][0]), int(json_ann['bbox'][1]), int(json_ann['bbox'][2]), int(json_ann['bbox'][3]))
    obj.category = json_ann['category_id']
    # Resampling strategy to reduce training time
    counts[obj.category] += 1
    image.add_object(obj)
    anns.append(image)
print(counts)
# Out:
# {'Cargo plane': 635, 'Small car': 3324, 'Bus': 1768, 'Truck': 2210, 'Motorboat': 1069, 'Fishing vessel': 706, 'Dump truck': 1236, 'Excavator': 789, 'Building': 3594, 'Helipad': 111, 'Storage tank': 1469, 'Shipping container': 1523, 'Pylon': 312}

# %%
from sklearn.model_selection import train_test_split
labels_list = [x.objects[0].category for x in anns]
anns_train, anns_valid = train_test_split(anns, test_size=0.2, random_state=1, shuffle=True,stratify=labels_list)
print('Number of training images: ' + str(len(anns_train)))
print('Number of validation images: ' + str(len(anns_valid)))
# Out:
# Number of training images: 14996
# Number of validation images: 3750

# %%
# Load architecture
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten

print('Load model')
model = Sequential()
model.add(Flatten(input_shape=(224, 224, 3)))
model.add(Activation('relu'))
model.add(Dense(1024))
model.add(Activation('relu'))
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dense(256))      
model.add(Activation('relu'))
model.add(Dense(128))      
model.add(Activation('relu'))
model.add(Dense(len(categories)))
model.add(Activation('softmax'))
model.summary()
# Out:
# Load model
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)             │ (None, 150528)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 150528)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1024)           │   154,141,696 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_7 (Activation)       │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_8 (Activation)       │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_9 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_10 (Activation)      │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 13)             │         1,677 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_11 (Activation)      │ (None, 13)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 154,832,397 (590.64 MB)
#  Trainable params: 154,832,397 (590.64 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from sklearn.utils import class_weight
import numpy as np

train_labels = [ann.objects[0].category for ann in anns_train]
unique_classes = np.unique(train_labels)

weights_values = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=unique_classes,
    y=train_labels
)

name_to_id = {v: k for k, v in categories.items()}

alpha_array = np.ones(len(categories), dtype=np.float32)

for class_name, weight in zip(unique_classes, weights_values):
    if class_name in name_to_id:
        class_id = name_to_id[class_name]
        alpha_array[class_id] = weight
        print(f"Classe: {class_name:<20} ID: {class_id:<3} Peso: {weight:.4f}")

alpha_list = alpha_array.tolist()

print("\nLISTA DEFINITIVA PRONTA PER FOCAL LOSS:", alpha_list)
# Out:
# Classe: Building             ID: 8   Peso: 0.4012
# Classe: Bus                  ID: 2   Peso: 0.8158
# Classe: Cargo plane          ID: 0   Peso: 2.2707
# Classe: Dump truck           ID: 6   Peso: 1.1664
# Classe: Excavator            ID: 7   Peso: 1.8281
# Classe: Fishing vessel       ID: 5   Peso: 2.0417
# Classe: Helipad              ID: 9   Peso: 12.9611
# Classe: Motorboat            ID: 4   Peso: 1.3492
# Classe: Pylon                ID: 12  Peso: 4.6142
# Classe: Shipping container   ID: 11  Peso: 0.9471
# Classe: Small car            ID: 1   Peso: 0.4338
# Classe: Storage tank         ID: 10  Peso: 0.9817
# Classe: Truck                ID: 3   Peso: 0.6525
#
# LISTA DEFINITIVA PRONTA PER FOCAL LOSS: [2.270745038986206, 0.43382418155670166, 0.8157980442047119, 0.6524538993835449, 1.349167823791504, 2.041661024093628, 1.1663684844970703, 1.8281116485595703, 0.4012307822704315, 12.961106300354004, 0.9817348718643188, 0.9470759034156799, 4.614153861999512]

# %%
from tensorflow.keras.optimizers import Adam

# Learning rate is changed to 0.001
opt = Adam(learning_rate=5e-5, beta_1=0.9, beta_2=0.999, epsilon=1e-8, amsgrad=True, clipnorm=1.0)
model.compile(optimizer=opt, loss=tf.keras.losses.CategoricalFocalCrossentropy(gamma=3.0, alpha=alpha_list), metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import TerminateOnNaN, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Callbacks
model_checkpoint = ModelCheckpoint('model.keras', monitor='val_accuracy', verbose=1, save_best_only=True)
reduce_lr = ReduceLROnPlateau('val_accuracy', factor=0.1, patience=7, verbose=1)
early_stop = EarlyStopping('val_accuracy', patience=20, verbose=1)
terminate = TerminateOnNaN()
callbacks = [model_checkpoint, reduce_lr, early_stop, terminate]

# %%
def generator_images(objs, batch_size, do_shuffle=False,class_weights=None):
    while True:
        if do_shuffle:
            np.random.shuffle(objs)
        groups = [objs[i:i+batch_size] for i in range(0, len(objs), batch_size)]
        for group in groups:
            images, labels,weights = [], [], []
            for (filename, obj) in group:
                # Load image
                images.append(load_geoimage(filename))
                probabilities = np.zeros(len(categories))
                probabilities[list(categories.values()).index(obj.category)] = 1
                labels.append(probabilities)
                if class_weights is not None:
                    weights.append(class_weights[obj.category])
            images = np.array(images).astype(np.float32)
            labels = np.array(labels).astype(np.float32)
            if class_weights is not None:
                weights = np.array(weights).astype(np.float32)
                yield images, labels, weights # <--- Restituisce 3 cose!
            else:
                yield images, labels

# %%
from sklearn.utils import class_weight
import numpy as np

# compute the weights based on train data
train_labels = [ann.objects[0].category for ann in anns_train]
unique_classes = np.unique(train_labels)

weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=unique_classes,
    y=train_labels
)

# Dictionare for Keras
class_weights_dict = dict(zip(unique_classes, weights))

# %%
import random
SEED = 42

def set_seeds(seed=SEED):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)

set_seeds()

# %%
# Generate the list of objects from annotations
objs_train = [(ann.filename, obj) for ann in anns_train for obj in ann.objects]
objs_valid = [(ann.filename, obj) for ann in anns_valid for obj in ann.objects]
# Generators
batch_size = 64
train_generator = generator_images(objs_train, batch_size, do_shuffle=True)
valid_generator = generator_images(objs_valid, batch_size, do_shuffle=False)

# %%
import math
import numpy as np

print('Training model')
epochs = 75
train_steps = math.ceil(len(objs_train)/batch_size)
valid_steps = math.ceil(len(objs_valid)/batch_size)
h = model.fit(train_generator, steps_per_epoch=train_steps, validation_data=valid_generator, validation_steps=valid_steps, epochs=epochs, callbacks=callbacks, verbose=1)
# Best validation model
best_idx = int(np.argmax(h.history['val_accuracy']))
best_value = np.max(h.history['val_accuracy'])
print('Best validation model: epoch ' + str(best_idx+1), ' - val_accuracy ' + str(best_value))
# Out:
# Training model
# Epoch 1/75
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1771155135.358635     124 service.cc:152] XLA service 0x7c2bfc00e610 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1771155135.358709     124 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1771155135.888232     124 cuda_dnn.cc:529] Loaded cuDNN version 91002
#   2/235 ━━━━━━━━━━━━━━━━━━━━ 13s 58ms/step - accuracy: 0.0898 - loss: 2.9456
# I0000 00:00:1771155137.792400     124 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1714 - loss: 1.9344
# Epoch 1: val_accuracy improved from -inf to 0.30773, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 648s 3s/step - accuracy: 0.1716 - loss: 1.9334 - val_accuracy: 0.3077 - val_loss: 1.4188 - learning_rate: 5.0000e-05
# Epoch 2/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - accuracy: 0.3083 - loss: 1.3692
# Epoch 2: val_accuracy improved from 0.30773 to 0.35653, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 92s 394ms/step - accuracy: 0.3083 - loss: 1.3691 - val_accuracy: 0.3565 - val_loss: 1.3994 - learning_rate: 5.0000e-05
# Epoch 3/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.3346 - loss: 1.3027
# Epoch 3: val_accuracy did not improve from 0.35653
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 80s 341ms/step - accuracy: 0.3346 - loss: 1.3025 - val_accuracy: 0.3093 - val_loss: 1.3941 - learning_rate: 5.0000e-05
# Epoch 4/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.3603 - loss: 1.2390
# Epoch 4: val_accuracy improved from 0.35653 to 0.37200, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 91s 389ms/step - accuracy: 0.3603 - loss: 1.2388 - val_accuracy: 0.3720 - val_loss: 1.2458 - learning_rate: 5.0000e-05
# Epoch 5/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.3831 - loss: 1.1720
# Epoch 5: val_accuracy did not improve from 0.37200
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 82s 351ms/step - accuracy: 0.3832 - loss: 1.1718 - val_accuracy: 0.3347 - val_loss: 1.3022 - learning_rate: 5.0000e-05
# Epoch 6/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.4006 - loss: 1.1010
# Epoch 6: val_accuracy improved from 0.37200 to 0.39467, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 91s 388ms/step - accuracy: 0.4006 - loss: 1.1009 - val_accuracy: 0.3947 - val_loss: 1.1202 - learning_rate: 5.0000e-05
# Epoch 7/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.4182 - loss: 1.0231
# Epoch 7: val_accuracy did not improve from 0.39467
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 71s 301ms/step - accuracy: 0.4182 - loss: 1.0232 - val_accuracy: 0.3792 - val_loss: 1.1559 - learning_rate: 5.0000e-05
# Epoch 8/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.4370 - loss: 0.9885
# Epoch 8: val_accuracy did not improve from 0.39467
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 74s 315ms/step - accuracy: 0.4370 - loss: 0.9885 - val_accuracy: 0.3915 - val_loss: 1.0704 - learning_rate: 5.0000e-05
# Epoch 9/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.4499 - loss: 0.9483
# Epoch 9: val_accuracy did not improve from 0.39467
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 76s 325ms/step - accuracy: 0.4499 - loss: 0.9483 - val_accuracy: 0.3869 - val_loss: 1.1095 - learning_rate: 5.0000e-05
# Epoch 10/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.4581 - loss: 0.9494
# Epoch 10: val_accuracy improved from 0.39467 to 0.43173, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 85s 362ms/step - accuracy: 0.4581 - loss: 0.9494 - val_accuracy: 0.4317 - val_loss: 1.0170 - learning_rate: 5.0000e-05
# Epoch 11/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.4769 - loss: 0.8672
# Epoch 11: val_accuracy did not improve from 0.43173
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 68s 292ms/step - accuracy: 0.4769 - loss: 0.8673 - val_accuracy: 0.4107 - val_loss: 1.1031 - learning_rate: 5.0000e-05
# Epoch 12/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.4830 - loss: 0.8372
# Epoch 12: val_accuracy did not improve from 0.43173
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 73s 310ms/step - accuracy: 0.4830 - loss: 0.8373 - val_accuracy: 0.3883 - val_loss: 1.0887 - learning_rate: 5.0000e-05
# Epoch 13/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.5008 - loss: 0.8192
# Epoch 13: val_accuracy improved from 0.43173 to 0.43307, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 84s 358ms/step - accuracy: 0.5008 - loss: 0.8191 - val_accuracy: 0.4331 - val_loss: 1.0840 - learning_rate: 5.0000e-05
# Epoch 14/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.5087 - loss: 0.7893
# Epoch 14: val_accuracy improved from 0.43307 to 0.46827, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 74s 318ms/step - accuracy: 0.5087 - loss: 0.7894 - val_accuracy: 0.4683 - val_loss: 0.9948 - learning_rate: 5.0000e-05
# Epoch 15/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.5262 - loss: 0.7387
# Epoch 15: val_accuracy did not improve from 0.46827
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 62s 264ms/step - accuracy: 0.5262 - loss: 0.7388 - val_accuracy: 0.4560 - val_loss: 0.9891 - learning_rate: 5.0000e-05
# Epoch 16/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.5221 - loss: 0.7512
# Epoch 16: val_accuracy did not improve from 0.46827
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 70s 299ms/step - accuracy: 0.5221 - loss: 0.7511 - val_accuracy: 0.4605 - val_loss: 1.0576 - learning_rate: 5.0000e-05
# Epoch 17/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.5419 - loss: 0.6976
# Epoch 17: val_accuracy improved from 0.46827 to 0.49573, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 88s 376ms/step - accuracy: 0.5419 - loss: 0.6976 - val_accuracy: 0.4957 - val_loss: 1.0968 - learning_rate: 5.0000e-05
# Epoch 18/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 0.5493 - loss: 0.6983
# Epoch 18: val_accuracy did not improve from 0.49573
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 131s 558ms/step - accuracy: 0.5493 - loss: 0.6983 - val_accuracy: 0.4744 - val_loss: 1.0245 - learning_rate: 5.0000e-05
# Epoch 19/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.5634 - loss: 0.6570
# Epoch 19: val_accuracy did not improve from 0.49573
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 97s 415ms/step - accuracy: 0.5634 - loss: 0.6570 - val_accuracy: 0.4453 - val_loss: 0.9760 - learning_rate: 5.0000e-05
# Epoch 20/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.5687 - loss: 0.6329
# Epoch 20: val_accuracy did not improve from 0.49573
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 71s 304ms/step - accuracy: 0.5687 - loss: 0.6329 - val_accuracy: 0.4736 - val_loss: 0.9837 - learning_rate: 5.0000e-05
# Epoch 21/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.5797 - loss: 0.5980
# Epoch 21: val_accuracy did not improve from 0.49573
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 70s 301ms/step - accuracy: 0.5797 - loss: 0.5981 - val_accuracy: 0.4893 - val_loss: 1.0340 - learning_rate: 5.0000e-05
# Epoch 22/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.5837 - loss: 0.5822
# Epoch 22: val_accuracy did not improve from 0.49573
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 69s 294ms/step - accuracy: 0.5837 - loss: 0.5822 - val_accuracy: 0.4635 - val_loss: 1.0752 - learning_rate: 5.0000e-05
# Epoch 23/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.5929 - loss: 0.5643
# Epoch 23: val_accuracy did not improve from 0.49573
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 69s 295ms/step - accuracy: 0.5929 - loss: 0.5643 - val_accuracy: 0.4680 - val_loss: 0.9773 - learning_rate: 5.0000e-05
# Epoch 24/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.5943 - loss: 0.5557
# Epoch 24: val_accuracy improved from 0.49573 to 0.50560, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 83s 352ms/step - accuracy: 0.5943 - loss: 0.5557 - val_accuracy: 0.5056 - val_loss: 1.0110 - learning_rate: 5.0000e-05
# Epoch 25/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.6151 - loss: 0.5236
# Epoch 25: val_accuracy did not improve from 0.50560
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 99s 425ms/step - accuracy: 0.6150 - loss: 0.5237 - val_accuracy: 0.4600 - val_loss: 1.0148 - learning_rate: 5.0000e-05
# Epoch 26/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.6094 - loss: 0.5071
# Epoch 26: val_accuracy did not improve from 0.50560
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 85s 363ms/step - accuracy: 0.6095 - loss: 0.5072 - val_accuracy: 0.5040 - val_loss: 1.0952 - learning_rate: 5.0000e-05
# Epoch 27/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.6248 - loss: 0.4856
# Epoch 27: val_accuracy did not improve from 0.50560
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 70s 300ms/step - accuracy: 0.6248 - loss: 0.4856 - val_accuracy: 0.5048 - val_loss: 1.0823 - learning_rate: 5.0000e-05
# Epoch 28/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.6178 - loss: 0.5138
# Epoch 28: val_accuracy did not improve from 0.50560
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 70s 300ms/step - accuracy: 0.6179 - loss: 0.5137 - val_accuracy: 0.5008 - val_loss: 1.0092 - learning_rate: 5.0000e-05
# Epoch 29/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.6312 - loss: 0.4906
# Epoch 29: val_accuracy did not improve from 0.50560
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 71s 302ms/step - accuracy: 0.6312 - loss: 0.4906 - val_accuracy: 0.4899 - val_loss: 0.9791 - learning_rate: 5.0000e-05
# Epoch 30/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.6539 - loss: 0.4357
# Epoch 30: val_accuracy improved from 0.50560 to 0.51760, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 83s 353ms/step - accuracy: 0.6539 - loss: 0.4357 - val_accuracy: 0.5176 - val_loss: 1.0254 - learning_rate: 5.0000e-05
# Epoch 31/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.6487 - loss: 0.4408
# Epoch 31: val_accuracy did not improve from 0.51760
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 106s 454ms/step - accuracy: 0.6487 - loss: 0.4408 - val_accuracy: 0.5117 - val_loss: 1.0471 - learning_rate: 5.0000e-05
# Epoch 32/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.6660 - loss: 0.4086
# Epoch 32: val_accuracy did not improve from 0.51760
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 92s 392ms/step - accuracy: 0.6659 - loss: 0.4087 - val_accuracy: 0.5091 - val_loss: 1.1031 - learning_rate: 5.0000e-05
# Epoch 33/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.6606 - loss: 0.4063
# Epoch 33: val_accuracy did not improve from 0.51760
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 77s 331ms/step - accuracy: 0.6606 - loss: 0.4063 - val_accuracy: 0.5165 - val_loss: 1.0168 - learning_rate: 5.0000e-05
# Epoch 34/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.6704 - loss: 0.3902
# Epoch 34: val_accuracy did not improve from 0.51760
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 81s 345ms/step - accuracy: 0.6703 - loss: 0.3902 - val_accuracy: 0.4997 - val_loss: 1.0117 - learning_rate: 5.0000e-05
# Epoch 35/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.6755 - loss: 0.3889
# Epoch 35: val_accuracy improved from 0.51760 to 0.52640, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 95s 405ms/step - accuracy: 0.6755 - loss: 0.3889 - val_accuracy: 0.5264 - val_loss: 1.0725 - learning_rate: 5.0000e-05
# Epoch 36/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 561ms/step - accuracy: 0.6862 - loss: 0.3712
# Epoch 36: val_accuracy improved from 0.52640 to 0.54080, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 184s 787ms/step - accuracy: 0.6862 - loss: 0.3712 - val_accuracy: 0.5408 - val_loss: 1.0770 - learning_rate: 5.0000e-05
# Epoch 37/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.6928 - loss: 0.3568
# Epoch 37: val_accuracy did not improve from 0.54080
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 209s 893ms/step - accuracy: 0.6928 - loss: 0.3568 - val_accuracy: 0.5184 - val_loss: 1.2473 - learning_rate: 5.0000e-05
# Epoch 38/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.6934 - loss: 0.3636
# Epoch 38: val_accuracy did not improve from 0.54080
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 102s 438ms/step - accuracy: 0.6934 - loss: 0.3635 - val_accuracy: 0.5285 - val_loss: 1.1132 - learning_rate: 5.0000e-05
# Epoch 39/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.7009 - loss: 0.3386
# Epoch 39: val_accuracy did not improve from 0.54080
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 80s 340ms/step - accuracy: 0.7009 - loss: 0.3386 - val_accuracy: 0.5088 - val_loss: 1.1114 - learning_rate: 5.0000e-05
# Epoch 40/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.7079 - loss: 0.3347
# Epoch 40: val_accuracy did not improve from 0.54080
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 84s 361ms/step - accuracy: 0.7079 - loss: 0.3347 - val_accuracy: 0.5352 - val_loss: 1.1715 - learning_rate: 5.0000e-05
# Epoch 41/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.7223 - loss: 0.3111
# Epoch 41: val_accuracy did not improve from 0.54080
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 86s 369ms/step - accuracy: 0.7223 - loss: 0.3112 - val_accuracy: 0.5099 - val_loss: 1.1152 - learning_rate: 5.0000e-05
# Epoch 42/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.7237 - loss: 0.3178
# Epoch 42: val_accuracy did not improve from 0.54080
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 76s 325ms/step - accuracy: 0.7237 - loss: 0.3177 - val_accuracy: 0.4813 - val_loss: 1.0942 - learning_rate: 5.0000e-05
# Epoch 43/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.7286 - loss: 0.2984
# Epoch 43: val_accuracy did not improve from 0.54080
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 76s 327ms/step - accuracy: 0.7286 - loss: 0.2984 - val_accuracy: 0.5299 - val_loss: 1.1192 - learning_rate: 5.0000e-05
# Epoch 44/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.7709 - loss: 0.2366
# Epoch 44: val_accuracy improved from 0.54080 to 0.55333, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 84s 359ms/step - accuracy: 0.7710 - loss: 0.2365 - val_accuracy: 0.5533 - val_loss: 1.1228 - learning_rate: 5.0000e-06
# Epoch 45/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.8063 - loss: 0.2086
# Epoch 45: val_accuracy improved from 0.55333 to 0.55653, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 126s 538ms/step - accuracy: 0.8063 - loss: 0.2086 - val_accuracy: 0.5565 - val_loss: 1.1131 - learning_rate: 5.0000e-06
# Epoch 46/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.8064 - loss: 0.2125
# Epoch 46: val_accuracy improved from 0.55653 to 0.55813, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 139s 592ms/step - accuracy: 0.8064 - loss: 0.2125 - val_accuracy: 0.5581 - val_loss: 1.1412 - learning_rate: 5.0000e-06
# Epoch 47/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.8114 - loss: 0.2110
# Epoch 47: val_accuracy did not improve from 0.55813
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 111s 473ms/step - accuracy: 0.8114 - loss: 0.2110 - val_accuracy: 0.5515 - val_loss: 1.1425 - learning_rate: 5.0000e-06
# Epoch 48/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.8092 - loss: 0.2012
# Epoch 48: val_accuracy did not improve from 0.55813
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 72s 308ms/step - accuracy: 0.8092 - loss: 0.2012 - val_accuracy: 0.5547 - val_loss: 1.1253 - learning_rate: 5.0000e-06
# Epoch 49/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.8078 - loss: 0.2071
# Epoch 49: val_accuracy improved from 0.55813 to 0.55973, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 87s 371ms/step - accuracy: 0.8079 - loss: 0.2070 - val_accuracy: 0.5597 - val_loss: 1.1754 - learning_rate: 5.0000e-06
# Epoch 50/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.8160 - loss: 0.1972
# Epoch 50: val_accuracy did not improve from 0.55973
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 121s 515ms/step - accuracy: 0.8160 - loss: 0.1972 - val_accuracy: 0.5552 - val_loss: 1.1585 - learning_rate: 5.0000e-06
# Epoch 51/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.8140 - loss: 0.2004
# Epoch 51: val_accuracy did not improve from 0.55973
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 83s 354ms/step - accuracy: 0.8140 - loss: 0.2004 - val_accuracy: 0.5597 - val_loss: 1.1575 - learning_rate: 5.0000e-06
# Epoch 52/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.8114 - loss: 0.1930
# Epoch 52: val_accuracy did not improve from 0.55973
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 78s 331ms/step - accuracy: 0.8115 - loss: 0.1930 - val_accuracy: 0.5571 - val_loss: 1.1887 - learning_rate: 5.0000e-06
# Epoch 53/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.8182 - loss: 0.1924
# Epoch 53: val_accuracy did not improve from 0.55973
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 75s 321ms/step - accuracy: 0.8182 - loss: 0.1924 - val_accuracy: 0.5528 - val_loss: 1.1576 - learning_rate: 5.0000e-06
# Epoch 54/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.8201 - loss: 0.1910
# Epoch 54: val_accuracy did not improve from 0.55973
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 76s 326ms/step - accuracy: 0.8201 - loss: 0.1910 - val_accuracy: 0.5579 - val_loss: 1.1830 - learning_rate: 5.0000e-06
# Epoch 55/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.8170 - loss: 0.1954
# Epoch 55: val_accuracy did not improve from 0.55973
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 77s 327ms/step - accuracy: 0.8170 - loss: 0.1954 - val_accuracy: 0.5571 - val_loss: 1.1695 - learning_rate: 5.0000e-06
# Epoch 56/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.8200 - loss: 0.1895
# Epoch 56: val_accuracy did not improve from 0.55973
#
# Epoch 56: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-07.
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 75s 322ms/step - accuracy: 0.8200 - loss: 0.1895 - val_accuracy: 0.5587 - val_loss: 1.1846 - learning_rate: 5.0000e-06
# Epoch 57/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.8311 - loss: 0.1844
# Epoch 57: val_accuracy improved from 0.55973 to 0.56053, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 90s 387ms/step - accuracy: 0.8310 - loss: 0.1844 - val_accuracy: 0.5605 - val_loss: 1.1733 - learning_rate: 5.0000e-07
# Epoch 58/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.8351 - loss: 0.1770
# Epoch 58: val_accuracy improved from 0.56053 to 0.56293, saving model to model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 91s 387ms/step - accuracy: 0.8351 - loss: 0.1770 - val_accuracy: 0.5629 - val_loss: 1.1750 - learning_rate: 5.0000e-07
# Epoch 59/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - accuracy: 0.8266 - loss: 0.1867
# Epoch 59: val_accuracy did not improve from 0.56293
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 124s 529ms/step - accuracy: 0.8266 - loss: 0.1867 - val_accuracy: 0.5587 - val_loss: 1.1744 - learning_rate: 5.0000e-07
# Epoch 60/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.8314 - loss: 0.1841
# Epoch 60: val_accuracy did not improve from 0.56293
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 93s 398ms/step - accuracy: 0.8314 - loss: 0.1841 - val_accuracy: 0.5605 - val_loss: 1.1798 - learning_rate: 5.0000e-07
# Epoch 61/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.8344 - loss: 0.1787
# Epoch 61: val_accuracy did not improve from 0.56293
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 78s 335ms/step - accuracy: 0.8344 - loss: 0.1787 - val_accuracy: 0.5584 - val_loss: 1.1780 - learning_rate: 5.0000e-07
# Epoch 62/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.8321 - loss: 0.1789
# Epoch 62: val_accuracy did not improve from 0.56293
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 76s 326ms/step - accuracy: 0.8321 - loss: 0.1789 - val_accuracy: 0.5603 - val_loss: 1.1789 - learning_rate: 5.0000e-07
# Epoch 63/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.8354 - loss: 0.1758
# Epoch 63: val_accuracy did not improve from 0.56293
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 73s 310ms/step - accuracy: 0.8354 - loss: 0.1758 - val_accuracy: 0.5595 - val_loss: 1.1747 - learning_rate: 5.0000e-07
# Epoch 64/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.8270 - loss: 0.1848
# Epoch 64: val_accuracy did not improve from 0.56293
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 78s 335ms/step - accuracy: 0.8270 - loss: 0.1848 - val_accuracy: 0.5576 - val_loss: 1.1776 - learning_rate: 5.0000e-07
# Epoch 65/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.8315 - loss: 0.1774
# Epoch 65: val_accuracy did not improve from 0.56293
#
# Epoch 65: ReduceLROnPlateau reducing learning rate to 4.999999987376214e-08.
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 77s 327ms/step - accuracy: 0.8315 - loss: 0.1774 - val_accuracy: 0.5587 - val_loss: 1.1747 - learning_rate: 5.0000e-07
# Epoch 66/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.8322 - loss: 0.1828
# Epoch 66: val_accuracy did not improve from 0.56293
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 77s 327ms/step - accuracy: 0.8322 - loss: 0.1828 - val_accuracy: 0.5592 - val_loss: 1.1745 - learning_rate: 5.0000e-08
# Epoch 67/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.8329 - loss: 0.1794
# Epoch 67: val_accuracy did not improve from 0.56293
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 77s 330ms/step - accuracy: 0.8329 - loss: 0.1794 - val_accuracy: 0.5595 - val_loss: 1.1742 - learning_rate: 5.0000e-08
# Epoch 68/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.8319 - loss: 0.1766
# Epoch 68: val_accuracy did not improve from 0.56293
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 73s 312ms/step - accuracy: 0.8319 - loss: 0.1766 - val_accuracy: 0.5595 - val_loss: 1.1747 - learning_rate: 5.0000e-08
# Epoch 69/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.8340 - loss: 0.1827
# Epoch 69: val_accuracy did not improve from 0.56293
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 75s 319ms/step - accuracy: 0.8340 - loss: 0.1827 - val_accuracy: 0.5597 - val_loss: 1.1748 - learning_rate: 5.0000e-08
# Epoch 70/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.8354 - loss: 0.1794
# Epoch 70: val_accuracy did not improve from 0.56293
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 74s 316ms/step - accuracy: 0.8354 - loss: 0.1794 - val_accuracy: 0.5595 - val_loss: 1.1749 - learning_rate: 5.0000e-08
# Epoch 71/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.8305 - loss: 0.1822
# Epoch 71: val_accuracy did not improve from 0.56293
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 79s 337ms/step - accuracy: 0.8305 - loss: 0.1822 - val_accuracy: 0.5597 - val_loss: 1.1752 - learning_rate: 5.0000e-08
# Epoch 72/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.8310 - loss: 0.1851
# Epoch 72: val_accuracy did not improve from 0.56293
#
# Epoch 72: ReduceLROnPlateau reducing learning rate to 5.000000058430488e-09.
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 77s 329ms/step - accuracy: 0.8310 - loss: 0.1850 - val_accuracy: 0.5597 - val_loss: 1.1756 - learning_rate: 5.0000e-08
# Epoch 73/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.8350 - loss: 0.1844
# Epoch 73: val_accuracy did not improve from 0.56293
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 75s 321ms/step - accuracy: 0.8350 - loss: 0.1843 - val_accuracy: 0.5597 - val_loss: 1.1756 - learning_rate: 5.0000e-09
# Epoch 74/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.8326 - loss: 0.1789
# Epoch 74: val_accuracy did not improve from 0.56293
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 76s 324ms/step - accuracy: 0.8326 - loss: 0.1789 - val_accuracy: 0.5597 - val_loss: 1.1756 - learning_rate: 5.0000e-09
# Epoch 75/75
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.8282 - loss: 0.1864
# Epoch 75: val_accuracy did not improve from 0.56293
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 75s 320ms/step - accuracy: 0.8282 - loss: 0.1864 - val_accuracy: 0.5597 - val_loss: 1.1756 - learning_rate: 5.0000e-09
# Best validation model: epoch 58  - val_accuracy 0.5629333257675171

# %%
import matplotlib.pyplot as plt

def plot_results(history):
    
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    
    
    epochs_range = range(1, len(acc) + 1)

    plt.figure(figsize=(16, 6))

    # --- GRAFICO 1: ACCURACY
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy', color='blue', marker='o')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy', color='red', marker='o')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epoche')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')
    plt.grid(True)

    # --- GRAFICO 2: LOSS 
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss', color='blue', linestyle='--')
    plt.plot(epochs_range, val_loss, label='Validation Loss', color='red', linestyle='--')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoche')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')
    plt.grid(True)

    plt.show()


plot_results(h)

# %% [markdown]
# #### Validation
# Compute validation metrics.

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

def draw_confusion_matrix(cm, categories):
    # Draw confusion matrix
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    cm = cm.astype('float') / np.maximum(cm.sum(axis=1)[:, np.newaxis], np.finfo(np.float64).eps)
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.colormaps['Blues'])
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=list(categories.values()), yticklabels=list(categories.values()), ylabel='Annotation', xlabel='Prediction')
    # Rotate the tick labels and set their alignment
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Loop over data dimensions and create text annotations
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], '.2f'), ha="center", va="center", color="white" if cm[i, j] > thresh else "black", fontsize=int(20-pow(len(categories), 0.5)))
    fig.tight_layout()
    plt.show()

# %%
import numpy as np

model.load_weights('model.keras')
y_true, y_pred = [], []
for ann in anns_valid:
    # Load image
    image = load_geoimage(ann.filename)
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        y_true.append(obj_pred.category)
        y_pred.append(pred_category)

# %%
from sklearn.metrics import confusion_matrix

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=list(categories.values()))
draw_confusion_matrix(cm, categories)

# %%
import numpy as np

# Compute the accuracy
correct_samples_class = np.diag(cm).astype(float)
total_samples_class = np.sum(cm, axis=1).astype(float)
total_predicts_class = np.sum(cm, axis=0).astype(float)
print('Mean Accuracy: %.3f%%' % (np.sum(correct_samples_class) / np.sum(total_samples_class) * 100))
acc = correct_samples_class / np.maximum(total_samples_class, np.finfo(np.float64).eps)
print('Mean Recall: %.3f%%' % (acc.mean() * 100))
acc = correct_samples_class / np.maximum(total_predicts_class, np.finfo(np.float64).eps)
print('Mean Precision: %.3f%%' % (acc.mean() * 100))
for idx in range(len(categories)):
    # True/False Positives (TP/FP) refer to the number of predicted positives that were correct/incorrect.
    # True/False Negatives (TN/FN) refer to the number of predicted negatives that were correct/incorrect.
    tp = cm[idx, idx]
    fp = sum(cm[:, idx]) - tp
    fn = sum(cm[idx, :]) - tp
    tn = sum(np.delete(sum(cm) - cm[idx, :], idx))
    # True Positive Rate: proportion of real positive cases that were correctly predicted as positive.
    recall = tp / np.maximum(tp+fn, np.finfo(np.float64).eps)
    # Precision: proportion of predicted positive cases that were truly real positives.
    precision = tp / np.maximum(tp+fp, np.finfo(np.float64).eps)
    # True Negative Rate: proportion of real negative cases that were correctly predicted as negative.
    specificity = tn / np.maximum(tn+fp, np.finfo(np.float64).eps)
    # Dice coefficient refers to two times the intersection of two sets divided by the sum of their areas.
    # Dice = 2 |A∩B| / (|A|+|B|) = 2 TP / (2 TP + FP + FN)
    f1_score = 2 * ((precision * recall) / np.maximum(precision+recall, np.finfo(np.float64).eps))
    print('> %s: Recall: %.3f%% Precision: %.3f%% Specificity: %.3f%% Dice: %.3f%%' % (list(categories.values())[idx], recall*100, precision*100, specificity*100, f1_score*100))
# Out:
# Mean Accuracy: 56.293%
# Mean Recall: 54.749%
# Mean Precision: 54.511%
# > Cargo plane: Recall: 70.079% Precision: 86.408% Specificity: 99.614% Dice: 77.391%
# > Small car: Recall: 71.128% Precision: 73.333% Specificity: 94.425% Dice: 72.214%
# > Bus: Recall: 43.785% Precision: 45.190% Specificity: 94.464% Dice: 44.476%
# > Truck: Recall: 23.529% Precision: 25.428% Specificity: 90.780% Dice: 24.442%
# > Motorboat: Recall: 50.935% Precision: 46.983% Specificity: 96.521% Dice: 48.879%
# > Fishing vessel: Recall: 58.156% Precision: 50.000% Specificity: 97.728% Dice: 53.770%
# > Dump truck: Recall: 55.466% Precision: 50.554% Specificity: 96.175% Dice: 52.896%
# > Excavator: Recall: 60.127% Precision: 53.073% Specificity: 97.661% Dice: 56.380%
# > Building: Recall: 65.925% Precision: 71.278% Specificity: 93.698% Dice: 68.497%
# > Helipad: Recall: 27.273% Precision: 37.500% Specificity: 99.732% Dice: 31.579%
# > Storage tank: Recall: 53.061% Precision: 53.608% Specificity: 96.094% Dice: 53.333%
# > Shipping container: Recall: 61.311% Precision: 51.515% Specificity: 94.891% Dice: 55.988%
# > Pylon: Recall: 70.968% Precision: 63.768% Specificity: 99.322% Dice: 67.176%

# %% [markdown]
# #### opt = Adam(learning_rate=1e-5, beta_1=0.9, beta_2=0.999, epsilon=1e-8, amsgrad=True, clipnorm=1.0)
# model.compile(optimizer=opt, loss=tf.keras.losses.CategoricalFocalCrossentropy(gamma=3.0, alpha=alpha_list), metrics=['accuracy'])Testing
# Try to improve the results provided in the competition.

# %%
import os
import numpy as np

anns = []
for (dirpath, dirnames, filenames) in os.walk('/kaggle/input/datasets/vittoriogianfrate/recognition/xview_recognition/xview_test'):
    for filename in filenames:
        relative_path = os.path.join('xview_test', filename)
        image = GenericImage(relative_path)
        image.tile = np.array([0, 0, 224, 224])
        obj = GenericObject()
        obj.bb = (0, 0, 224, 224)
        obj.category = dirpath[dirpath.rfind('/')+1:]
        image.add_object(obj)
        anns.append(image)
print('Number of testing images: ' + str(len(anns)))
# Out:
# Number of testing images: 2365

# %%
import numpy as np

model.load_weights('model.keras')
predictions_data = {"images": {}, "annotations": {}}
for idx, ann in enumerate(anns):
    image_data = {"image_id": ann.filename.split('/')[-1], "filename": ann.filename, "width": int(ann.tile[2]), "height": int(ann.tile[3])}
    predictions_data["images"][idx] = image_data
    # Load image
    image = load_geoimage(ann.filename)
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        annotation_data = {"image_id": ann.filename.split('/')[-1], "category_id": pred_category, "bbox": [int(x) for x in obj_pred.bb]}
        predictions_data["annotations"][idx] = annotation_data

# %%
with open("prediction.json", "w") as outfile:
    json.dump(predictions_data, outfile)
